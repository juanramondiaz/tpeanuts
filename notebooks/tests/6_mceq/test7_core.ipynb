# %% [markdown]
# # Master's Thesis Notebook
#
# This notebook is part of the **Master's Thesis (MSc Dissertation)**: **Fast Simulation of Neutrino Oscillations in Matter**.
#
# **Author**
# Juan Ramon Diaz Santos <diazjuan@alumni.uv.es>
#
# **Supervisors**
# Roberto Ruiz de Austri Bazan <rruiz@ific.uv.es>
# Michele Lucente <michele.lucente@unibo.it>
#
# **Date**
# June 2026

# %% [markdown]
# # test7 core
#
# Notebook equivalent of `tests/6_mceq/test7_core.py`. The original Python test module remains the source of truth; this notebook imports it and runs each numerical test and diagnostic plot in its own cell for interactive inspection.
#
# The notebook uses the shared TPeanuts output-root convention defined in section `2. Paths`. Generated `mceq` test artifacts and figures are redirected to the notebook-specific `OUTPUT_DIR` under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`.

# %% [markdown]
# ## 1. Libraries and test module
#
# This section locates the repository, imports the original `mceq` test module, and reloads it so source changes are reflected when the notebook is rerun. The expected result is that the module imports without errors. Possible problems include running the notebook from outside the repository tree, missing optional dependencies, or unavailable external model data.

# %%
from __future__ import annotations

import importlib
import importlib.util
import os
import sys
import traceback
from pathlib import Path

import matplotlib.pyplot as plt


from tpeanuts.util.notebooks import find_repo_root
HERE = Path.cwd().resolve()
PACKAGE_DIR = find_repo_root(HERE, folder="analysis")
print(f"PACKAGE_DIR = {PACKAGE_DIR}")

NOTEBOOK_STEM = "test7_core"
TEST_MODULE_PATH = PACKAGE_DIR / "notebooks" / "tests" / "6_mceq" / f"{NOTEBOOK_STEM}.py"
TEST_MODULE_NAME = f"notebook_tests_{TEST_MODULE_PATH.parent.name.replace('.', '_')}_{NOTEBOOK_STEM}"
if not TEST_MODULE_PATH.exists():
    raise FileNotFoundError(f"Could not find local test module: {TEST_MODULE_PATH}")
spec = importlib.util.spec_from_file_location(TEST_MODULE_NAME, TEST_MODULE_PATH)
if spec is None or spec.loader is None:
    raise ImportError(f"Could not load test module spec from {TEST_MODULE_PATH}")
TEST_MODULE = importlib.util.module_from_spec(spec)
sys.modules[TEST_MODULE_NAME] = TEST_MODULE
spec.loader.exec_module(TEST_MODULE)
print("Loaded local test module:", TEST_MODULE_PATH)

from tpeanuts.util.notebooks import build_notebook_test_runner

# %% [markdown]
# ## 2. Paths
#
# All outputs are rooted at `DEFAULT_OUTPUT_ROOT` unless `TPEANUTS_OUTPUT_ROOT` is defined in the environment. This notebook writes `mceq` test figures and generated artifacts under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`, while data, analysis, benchmark, and external roots follow the same shared structure used by the analysis notebooks.

# %%
DEFAULT_OUTPUT_ROOT = Path(r"V:\output")
OUTPUT_ROOT = Path(os.environ.get("TPEANUTS_OUTPUT_ROOT", DEFAULT_OUTPUT_ROOT))

OUTPUT_DATA_ROOT = Path(OUTPUT_ROOT / "data")
OUTPUT_ANALYSIS_ROOT = Path(OUTPUT_ROOT / "analysis")
OUTPUT_BENCHMARK_ROOT = Path(OUTPUT_ROOT / "benchmark")
OUTPUT_TEST_ROOT = Path(OUTPUT_ROOT / "test")

OUTPUT_DATA_ATMOSPHERE = Path(OUTPUT_DATA_ROOT / "atmosphere")
OUTPUT_DATA_SOLAR = Path(OUTPUT_DATA_ROOT / "solar")
OUTPUT_DATA_EXTERNAL = Path(OUTPUT_DATA_ROOT / "external")

OUTPUT_ANALYSIS_ATMOSPHERE = Path(OUTPUT_ANALYSIS_ROOT / "atmosphere")
OUTPUT_ANALYSIS_SOLAR = Path(OUTPUT_ANALYSIS_ROOT / "solar")
OUTPUT_ANALYSIS_EXTERNAL = Path(OUTPUT_ANALYSIS_ROOT / "external")

OUTPUT_DATA_MCEQ = Path(OUTPUT_DATA_ROOT / "mceq")
OUTPUT_DATA_HONDA = Path(OUTPUT_DATA_ROOT / "honda")

OUTPUT_DIR = OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SHOW_PLOTS = True
print("Output root     :", OUTPUT_ROOT)
print("Output directory:", OUTPUT_DIR)

# %%
NOTEBOOK_RUNNER_ATTRS = {}
if "RUN_REAL_DATA_ANALYSIS" in globals():
    NOTEBOOK_RUNNER_ATTRS["RUN_REAL_mceq_run1_analysis"] = RUN_REAL_DATA_ANALYSIS

runner = build_notebook_test_runner(
    TEST_MODULE,
    OUTPUT_DIR,
    show_plots=SHOW_PLOTS,
    auto_save_figures=True,
    extra_module_attrs=NOTEBOOK_RUNNER_ATTRS,
)
run_notebook_test = runner.run_test
run_notebook_call = runner.run_call

# %% [markdown]
# ## Test: `test_resolve_primary_model_default`
#
# **What is checked:** Resolve primary model default behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_primary_model_default)

# %% [markdown]
# ## Test: `test_resolve_primary_model_from_string`
#
# **What is checked:** Resolve primary model from string behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_primary_model_from_string)

# %% [markdown]
# ## Test: `test_resolve_primary_model_accepts_tuple`
#
# **What is checked:** Resolve primary model accepts tuple behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_primary_model_accepts_tuple)

# %% [markdown]
# ## Test: `test_resolve_primary_model_invalid_raises`
#
# **What is checked:** Resolve primary model invalid raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_primary_model_invalid_raises)

# %% [markdown]
# ## Test: `test_resolve_density_model_default`
#
# **What is checked:** Resolve density model default behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_density_model_default)

# %% [markdown]
# ## Test: `test_resolve_density_model_from_string`
#
# **What is checked:** Resolve density model from string behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_density_model_from_string)

# %% [markdown]
# ## Test: `test_resolve_density_model_invalid_raises`
#
# **What is checked:** Resolve density model invalid raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_resolve_density_model_invalid_raises)

# %% [markdown]
# ## Test: `test_theta_to_float_from_float`
#
# **What is checked:** Theta to float from float behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 45.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_from_float)

# %% [markdown]
# ## Test: `test_theta_to_float_from_int`
#
# **What is checked:** Theta to float from int behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 30.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_from_int)

# %% [markdown]
# ## Test: `test_theta_to_float_from_tensor_scalar`
#
# **What is checked:** Theta to float from tensor scalar behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 60.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_from_tensor_scalar)

# %% [markdown]
# ## Test: `test_theta_to_float_from_tensor_vector_uses_first_value`
#
# **What is checked:** Theta to float from tensor vector uses first value behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 15.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_from_tensor_vector_uses_first_value)

# %% [markdown]
# ## Test: `test_theta_to_float_rejects_negative`
#
# **What is checked:** Theta to float rejects negative behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_rejects_negative)

# %% [markdown]
# ## Test: `test_theta_to_float_rejects_90_deg`
#
# **What is checked:** Theta to float rejects 90 deg behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_rejects_90_deg)

# %% [markdown]
# ## Test: `test_theta_to_float_rejects_above_90_deg`
#
# **What is checked:** Theta to float rejects above 90 deg behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_to_float_rejects_above_90_deg)

# %% [markdown]
# ## Test: `test_set_mceq_logging_runs`
#
# **What is checked:** Set mceq logging runs behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_set_mceq_logging_runs)

# %% [markdown]
# ## Test: `test_init_mceq_returns_object`
#
# **What is checked:** Init mceq returns object behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_returns_object)

# %% [markdown]
# ## Test: `test_init_mceq_has_energy_grid`
#
# **What is checked:** Init mceq has energy grid behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_has_energy_grid)

# %% [markdown]
# ## Test: `test_init_mceq_has_density_model`
#
# **What is checked:** Init mceq has density model behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_has_density_model)

# %% [markdown]
# ## Test: `test_init_mceq_theta_45`
#
# **What is checked:** Init mceq theta 45 behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_theta_45)

# %% [markdown]
# ## Test: `test_init_mceq_accepts_overrides`
#
# **What is checked:** Init mceq accepts overrides behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_accepts_overrides)

# %% [markdown]
# ## Test: `test_init_mceq_rejects_invalid_theta`
#
# **What is checked:** Init mceq rejects invalid theta behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_rejects_invalid_theta)

# %% [markdown]
# ## Test: `test_init_mceq_rejects_invalid_interaction_model`
#
# **What is checked:** Init mceq rejects invalid interaction model behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_rejects_invalid_interaction_model)

# %% [markdown]
# ## Test: `test_init_mceq_rejects_invalid_primary_model`
#
# **What is checked:** Init mceq rejects invalid primary model behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_rejects_invalid_primary_model)

# %% [markdown]
# ## Test: `test_init_mceq_rejects_invalid_density_model`
#
# **What is checked:** Init mceq rejects invalid density model behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; solver tests may fail when optional external MCEq data or packages are not installed.

# %%
run_notebook_test(TEST_MODULE.test_init_mceq_rejects_invalid_density_model)
