# %% [markdown]
# # Master's Thesis Notebook
#
# This notebook is part of the **Master's Thesis (MSc Dissertation)**: **Fast Simulation of Neutrino Oscillations in Matter**.
#
# **Author**
# Juan Ramon Diaz Santos <diazjuan@alumni.uv.es>
#
# **Supervisors**
# Roberto Ruiz de Austri Bazan <rruiz@ific.uv.es>
# Michele Lucente <michele.lucente@unibo.it>
#
# **Date**
# June 2026

# %% [markdown]
# # test12 generator
#
# Notebook equivalent of `tests/6_mceq/test12_generator.py`. The original Python test module remains the source of truth; this notebook imports it and runs each numerical test and diagnostic plot in its own cell for interactive inspection.
#
# The notebook uses the shared TPeanuts output-root convention defined in section `2. Paths`. Generated `mceq` test artifacts and figures are redirected to the notebook-specific `OUTPUT_DIR` under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`.

# %% [markdown]
# ## 1. Libraries and test module
#
# This section locates the repository, imports the original `mceq` test module, and reloads it so source changes are reflected when the notebook is rerun. The expected result is that the module imports without errors. Possible problems include running the notebook from outside the repository tree, missing optional dependencies, or unavailable external model data.

# %%
from __future__ import annotations

import importlib
import importlib.util
import os
import sys
import traceback
from pathlib import Path

import matplotlib.pyplot as plt


from tpeanuts.util.notebooks import find_repo_root
HERE = Path.cwd().resolve()
PACKAGE_DIR = find_repo_root(HERE, folder="analysis")
print(f"PACKAGE_DIR = {PACKAGE_DIR}")

NOTEBOOK_STEM = "test12_generator"
TEST_MODULE_PATH = PACKAGE_DIR / "notebooks" / "tests" / "6_mceq" / f"{NOTEBOOK_STEM}.py"
TEST_MODULE_NAME = f"notebook_tests_{TEST_MODULE_PATH.parent.name.replace('.', '_')}_{NOTEBOOK_STEM}"
if not TEST_MODULE_PATH.exists():
    raise FileNotFoundError(f"Could not find local test module: {TEST_MODULE_PATH}")
spec = importlib.util.spec_from_file_location(TEST_MODULE_NAME, TEST_MODULE_PATH)
if spec is None or spec.loader is None:
    raise ImportError(f"Could not load test module spec from {TEST_MODULE_PATH}")
TEST_MODULE = importlib.util.module_from_spec(spec)
sys.modules[TEST_MODULE_NAME] = TEST_MODULE
spec.loader.exec_module(TEST_MODULE)
print("Loaded local test module:", TEST_MODULE_PATH)

from tpeanuts.util.notebooks import build_notebook_test_runner
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Loaded local test module: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\notebooks\tests\6_mceq\test12_generator.py

# %% [markdown]
# ## 2. Paths
#
# All outputs are rooted at `DEFAULT_OUTPUT_ROOT` unless `TPEANUTS_OUTPUT_ROOT` is defined in the environment. This notebook writes `mceq` test figures and generated artifacts under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`, while data, analysis, benchmark, and external roots follow the same shared structure used by the analysis notebooks.

# %%
DEFAULT_OUTPUT_ROOT = Path(r"V:\output")
OUTPUT_ROOT = Path(os.environ.get("TPEANUTS_OUTPUT_ROOT", DEFAULT_OUTPUT_ROOT))

OUTPUT_DATA_ROOT = Path(OUTPUT_ROOT / "data")
OUTPUT_ANALYSIS_ROOT = Path(OUTPUT_ROOT / "analysis")
OUTPUT_BENCHMARK_ROOT = Path(OUTPUT_ROOT / "benchmark")
OUTPUT_TEST_ROOT = Path(OUTPUT_ROOT / "test")

OUTPUT_DATA_ATMOSPHERE = Path(OUTPUT_DATA_ROOT / "atmosphere")
OUTPUT_DATA_SOLAR = Path(OUTPUT_DATA_ROOT / "solar")
OUTPUT_DATA_EXTERNAL = Path(OUTPUT_DATA_ROOT / "external")

OUTPUT_ANALYSIS_ATMOSPHERE = Path(OUTPUT_ANALYSIS_ROOT / "atmosphere")
OUTPUT_ANALYSIS_SOLAR = Path(OUTPUT_ANALYSIS_ROOT / "solar")
OUTPUT_ANALYSIS_EXTERNAL = Path(OUTPUT_ANALYSIS_ROOT / "external")

OUTPUT_DATA_MCEQ = Path(OUTPUT_DATA_ROOT / "mceq")
OUTPUT_DATA_HONDA = Path(OUTPUT_DATA_ROOT / "honda")

OUTPUT_DIR = OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SHOW_PLOTS = True
print("Output root     :", OUTPUT_ROOT)
print("Output directory:", OUTPUT_DIR)
# Out:
# Output root     : V:\output
# Output directory: V:\output\test\mceq\test12_generator

# %%
NOTEBOOK_RUNNER_ATTRS = {}
if "RUN_REAL_DATA_ANALYSIS" in globals():
    NOTEBOOK_RUNNER_ATTRS["RUN_REAL_mceq_run1_analysis"] = RUN_REAL_DATA_ANALYSIS

runner = build_notebook_test_runner(
    TEST_MODULE,
    OUTPUT_DIR,
    show_plots=SHOW_PLOTS,
    auto_save_figures=True,
    extra_module_attrs=NOTEBOOK_RUNNER_ATTRS,
)
run_notebook_test = runner.run_test
run_notebook_call = runner.run_call

# %% [markdown]
# ## Test: `test_detector_alpha_to_surface_theta_surface_identity`
#
# **What is checked:** Detector alpha to surface theta surface identity behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 30.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_detector_alpha_to_surface_theta_surface_identity)
# Out:
# Running test_detector_alpha_to_surface_theta_surface_identity ...
# theta: tensor(30.0000, dtype=torch.float64)
# ------------------------------------------------------------------------------------------
# PASSED: test_detector_alpha_to_surface_theta_surface_identity

# %% [markdown]
# ## Test: `test_detector_alpha_accepts_default_device_function`
#
# **What is checked:** Detector alpha accepts default device function behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: 30.0.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_detector_alpha_accepts_default_device_function)
# Out:
# Running test_detector_alpha_accepts_default_device_function ...
# theta with callable device: tensor(30.0000, device='cuda:0', dtype=torch.float64)
# ------------------------------------------------------------------------------------------
# PASSED: test_detector_alpha_accepts_default_device_function

# %% [markdown]
# ## Test: `test_generate_one_particle_angle_saves_file`
#
# **What is checked:** Generate one particle angle saves file behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_generate_one_particle_angle_saves_file)
# Out:
# Running test_generate_one_particle_angle_saves_file ...
# Generating numu | alpha=None deg | theta=20.000 deg
# Saved numu: V:\output\test\mceq\test12_generator\flux_numu_theta_20p000deg.pt. Time Execution: 0.04494699998758733 s.
# output path: V:\output\test\mceq\test12_generator\flux_numu_theta_20p000deg.pt
# ------------------------------------------------------------------------------------------
# PASSED: test_generate_one_particle_angle_saves_file

# %% [markdown]
# ## Test: `test_generate_particles_angle_grid_and_load_directory`
#
# **What is checked:** Generate particles angle grid and load directory behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_generate_particles_angle_grid_and_load_directory)
# Out:
# Running test_generate_particles_angle_grid_and_load_directory ...
# Generating 4 mceq flux jobs (2 particles x 2 angles). parallel=False
# mceq flux generation: 100%|█████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 181.81it/s]
# Generating numu | alpha=None deg | theta=0.000 deg
# Saved numu: V:\output\test\mceq\test12_generator\flux_numu_theta_0p000deg.pt. Time Execution: 0.0013408999657258391 s.
# Generating numu | alpha=None deg | theta=20.000 deg
# Saved numu: V:\output\test\mceq\test12_generator\flux_numu_theta_20p000deg.pt. Time Execution: 0.000757100060582161 s.
# Generating nue | alpha=None deg | theta=0.000 deg
# Saved nue: V:\output\test\mceq\test12_generator\flux_nue_theta_0p000deg.pt. Time Execution: 0.0006813999498263001 s.
# Generating nue | alpha=None deg | theta=20.000 deg
# Saved nue: V:\output\test\mceq\test12_generator\flux_nue_theta_20p000deg.pt. Time Execution: 0.00076299998909235 s.
# result groups: dict_keys(['numu', 'nue'])
# loaded groups: dict_keys(['nue', 'numu'])
# ------------------------------------------------------------------------------------------
# PASSED: test_generate_particles_angle_grid_and_load_directory
