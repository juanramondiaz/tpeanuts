# %% [markdown]
# # Master's Thesis Notebook
#
# This notebook is part of the **Master's Thesis (MSc Dissertation)**: **Fast Simulation of Neutrino Oscillations in Matter**.
#
# **Author**
# Juan Ramon Diaz Santos <diazjuan@alumni.uv.es>
#
# **Supervisors**
# Roberto Ruiz de Austri Bazan <rruiz@ific.uv.es>
# Michele Lucente <michele.lucente@unibo.it>
#
# **Date**
# June 2026

# %% [markdown]
# # test4 profile syntetic
#
# Notebook equivalent of `tests/6_mceq/test4_profile_syntetic.py`. The original Python test module remains the source of truth; this notebook imports it and runs each numerical test and diagnostic plot in its own cell for interactive inspection.
#
# The notebook uses the shared TPeanuts output-root convention defined in section `2. Paths`. Generated `mceq` test artifacts and figures are redirected to the notebook-specific `OUTPUT_DIR` under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`.

# %% [markdown]
# ## 1. Libraries and test module
#
# This section locates the repository, imports the original `mceq` test module, and reloads it so source changes are reflected when the notebook is rerun. The expected result is that the module imports without errors. Possible problems include running the notebook from outside the repository tree, missing optional dependencies, or unavailable external model data.

# %%
from __future__ import annotations

import importlib
import importlib.util
import os
import sys
import traceback
from pathlib import Path

import matplotlib.pyplot as plt


from tpeanuts.util.notebooks import find_repo_root
HERE = Path.cwd().resolve()
PACKAGE_DIR = find_repo_root(HERE, folder="analysis")
print(f"PACKAGE_DIR = {PACKAGE_DIR}")

NOTEBOOK_STEM = "test4_profile_syntetic"
TEST_MODULE_PATH = PACKAGE_DIR / "notebooks" / "tests" / "6_mceq" / f"{NOTEBOOK_STEM}.py"
TEST_MODULE_NAME = f"notebook_tests_{TEST_MODULE_PATH.parent.name.replace('.', '_')}_{NOTEBOOK_STEM}"
if not TEST_MODULE_PATH.exists():
    raise FileNotFoundError(f"Could not find local test module: {TEST_MODULE_PATH}")
spec = importlib.util.spec_from_file_location(TEST_MODULE_NAME, TEST_MODULE_PATH)
if spec is None or spec.loader is None:
    raise ImportError(f"Could not load test module spec from {TEST_MODULE_PATH}")
TEST_MODULE = importlib.util.module_from_spec(spec)
sys.modules[TEST_MODULE_NAME] = TEST_MODULE
spec.loader.exec_module(TEST_MODULE)
print("Loaded local test module:", TEST_MODULE_PATH)

from tpeanuts.util.notebooks import build_notebook_test_runner
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Loaded local test module: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\notebooks\tests\6_mceq\test4_profile_syntetic.py

# %% [markdown]
# ## 2. Paths
#
# All outputs are rooted at `DEFAULT_OUTPUT_ROOT` unless `TPEANUTS_OUTPUT_ROOT` is defined in the environment. This notebook writes `mceq` test figures and generated artifacts under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`, while data, analysis, benchmark, and external roots follow the same shared structure used by the analysis notebooks.

# %%
DEFAULT_OUTPUT_ROOT = Path(r"V:\output")
OUTPUT_ROOT = Path(os.environ.get("TPEANUTS_OUTPUT_ROOT", DEFAULT_OUTPUT_ROOT))

OUTPUT_DATA_ROOT = Path(OUTPUT_ROOT / "data")
OUTPUT_ANALYSIS_ROOT = Path(OUTPUT_ROOT / "analysis")
OUTPUT_BENCHMARK_ROOT = Path(OUTPUT_ROOT / "benchmark")
OUTPUT_TEST_ROOT = Path(OUTPUT_ROOT / "test")

OUTPUT_DATA_ATMOSPHERE = Path(OUTPUT_DATA_ROOT / "atmosphere")
OUTPUT_DATA_SOLAR = Path(OUTPUT_DATA_ROOT / "solar")
OUTPUT_DATA_EXTERNAL = Path(OUTPUT_DATA_ROOT / "external")

OUTPUT_ANALYSIS_ATMOSPHERE = Path(OUTPUT_ANALYSIS_ROOT / "atmosphere")
OUTPUT_ANALYSIS_SOLAR = Path(OUTPUT_ANALYSIS_ROOT / "solar")
OUTPUT_ANALYSIS_EXTERNAL = Path(OUTPUT_ANALYSIS_ROOT / "external")

OUTPUT_DATA_MCEQ = Path(OUTPUT_DATA_ROOT / "mceq")
OUTPUT_DATA_HONDA = Path(OUTPUT_DATA_ROOT / "honda")

OUTPUT_DIR = OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SHOW_PLOTS = True
print("Output root     :", OUTPUT_ROOT)
print("Output directory:", OUTPUT_DIR)
# Out:
# Output root     : V:\output
# Output directory: V:\output\test\mceq\test4_profile_syntetic

# %%
NOTEBOOK_RUNNER_ATTRS = {}
if "RUN_REAL_DATA_ANALYSIS" in globals():
    NOTEBOOK_RUNNER_ATTRS["RUN_REAL_mceq_run1_analysis"] = RUN_REAL_DATA_ANALYSIS

runner = build_notebook_test_runner(
    TEST_MODULE,
    OUTPUT_DIR,
    show_plots=SHOW_PLOTS,
    auto_save_figures=True,
    extra_module_attrs=NOTEBOOK_RUNNER_ATTRS,
)
run_notebook_test = runner.run_test
run_notebook_call = runner.run_call

# %% [markdown]
# ## Test: `test_interpolate_source_X_to_h_shape`
#
# **What is checked:** Interpolate source x to h shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_interpolate_source_X_to_h_shape)
# Out:
# Running test_interpolate_source_X_to_h_shape ...
# source_XE shape: torch.Size([500, 5])
# source_Eh shape: torch.Size([5, 400])
# ------------------------------------------------------------------------------------------
# PASSED: test_interpolate_source_X_to_h_shape

# %% [markdown]
# ## Test: `test_interpolate_source_X_to_h_positive`
#
# **What is checked:** Interpolate source x to h positive behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_interpolate_source_X_to_h_positive)
# Out:
# Running test_interpolate_source_X_to_h_positive ...
# source_Eh min: 0.0
# source_Eh max: 3.983711012760175
# ------------------------------------------------------------------------------------------
# PASSED: test_interpolate_source_X_to_h_positive

# %% [markdown]
# ## Test: `test_convert_depth_source_to_height_source_shape`
#
# **What is checked:** Convert depth source to height source shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_convert_depth_source_to_height_source_shape)
# Out:
# Running test_convert_depth_source_to_height_source_shape ...
# height source shape: torch.Size([5, 400])
# ------------------------------------------------------------------------------------------
# PASSED: test_convert_depth_source_to_height_source_shape

# %% [markdown]
# ## Test: `test_convert_depth_source_to_height_source_positive`
#
# **What is checked:** Convert depth source to height source positive behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_convert_depth_source_to_height_source_positive)
# Out:
# Running test_convert_depth_source_to_height_source_positive ...
# height source min: 0.0
# height source max: 45.98170898502435
# ------------------------------------------------------------------------------------------
# PASSED: test_convert_depth_source_to_height_source_positive

# %% [markdown]
# ## Test: `test_normalize_height_profiles_shape`
#
# **What is checked:** Normalize height profiles shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; normalization failures often point to probability conservation or broadcasting issues.

# %%
run_notebook_test(TEST_MODULE.test_normalize_height_profiles_shape)
# Out:
# Running test_normalize_height_profiles_shape ...
# f_Eh shape: torch.Size([5, 400])
# ------------------------------------------------------------------------------------------
# PASSED: test_normalize_height_profiles_shape

# %% [markdown]
# ## Test: `test_normalize_height_profiles_integral_is_one`
#
# **What is checked:** Normalize height profiles integral is one behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; normalization failures often point to probability conservation or broadcasting issues.

# %%
run_notebook_test(TEST_MODULE.test_normalize_height_profiles_integral_is_one)
# Out:
# Running test_normalize_height_profiles_integral_is_one ...
# normalizations: tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000], dtype=torch.float64)
# max |norm - 1|: 2.220446049250313e-16
# ------------------------------------------------------------------------------------------
# PASSED: test_normalize_height_profiles_integral_is_one

# %% [markdown]
# ## Test: `test_build_phi_Eh_from_profile_shape`
#
# **What is checked:** Build phi eh from profile shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_build_phi_Eh_from_profile_shape)
# Out:
# Running test_build_phi_Eh_from_profile_shape ...
# phi_E_obs shape: torch.Size([5])
# phi_Eh shape: torch.Size([5, 400])
# ------------------------------------------------------------------------------------------
# PASSED: test_build_phi_Eh_from_profile_shape

# %% [markdown]
# ## Test: `test_build_phi_Eh_reconstructs_phi_E_obs`
#
# **What is checked:** Build phi eh reconstructs phi e obs behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_build_phi_Eh_reconstructs_phi_E_obs)
# Out:
# Running test_build_phi_Eh_reconstructs_phi_E_obs ...
# phi_E_obs: tensor([6.4980e+00, 1.0000e+00, 1.2965e-02, 1.9953e-03, 2.5869e-05],
#        dtype=torch.float64)
# phi_rec  : tensor([6.4980e+00, 1.0000e+00, 1.2965e-02, 1.9953e-03, 2.5869e-05],
#        dtype=torch.float64)
# max relative error: 2.220446049250313e-16
# ------------------------------------------------------------------------------------------
# PASSED: test_build_phi_Eh_reconstructs_phi_E_obs

# %% [markdown]
# ## Test: `test_interpolate_rejects_bad_source_shape`
#
# **What is checked:** Interpolate rejects bad source shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_interpolate_rejects_bad_source_shape)
# Out:
# Running test_interpolate_rejects_bad_source_shape ...
# ------------------------------------------------------------------------------------------
# PASSED: test_interpolate_rejects_bad_source_shape

# %% [markdown]
# ## Test: `test_interpolate_rejects_non_monotonic_X_grid`
#
# **What is checked:** Interpolate rejects non monotonic x grid behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_interpolate_rejects_non_monotonic_X_grid)
# Out:
# Running test_interpolate_rejects_non_monotonic_X_grid ...
# ------------------------------------------------------------------------------------------
# PASSED: test_interpolate_rejects_non_monotonic_X_grid

# %% [markdown]
# ## Test: `test_normalize_rejects_bad_shape`
#
# **What is checked:** Normalize rejects bad shape behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; normalization failures often point to probability conservation or broadcasting issues.

# %%
run_notebook_test(TEST_MODULE.test_normalize_rejects_bad_shape)
# Out:
# Running test_normalize_rejects_bad_shape ...
# ------------------------------------------------------------------------------------------
# PASSED: test_normalize_rejects_bad_shape

# %% [markdown]
# ## Test: `test_build_phi_Eh_rejects_energy_mismatch`
#
# **What is checked:** Build phi eh rejects energy mismatch behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_build_phi_Eh_rejects_energy_mismatch)
# Out:
# Running test_build_phi_Eh_rejects_energy_mismatch ...
# ------------------------------------------------------------------------------------------
# PASSED: test_build_phi_Eh_rejects_energy_mismatch

# %% [markdown]
# ## Plot: `plot_depth_to_height_mapping()`
#
# **What is checked:** Depth to height mapping behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic plot call completes and writes its figure output to `OUTPUT_DIR`.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem.

# %% [markdown]
# ### Output files for `plot_depth_to_height_mapping()`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `plot_depth_to_height_mapping_figure_001.png`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_call('plot_depth_to_height_mapping()', lambda: TEST_MODULE.plot_depth_to_height_mapping())
# Out:
# Running plot_depth_to_height_mapping() ...
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_depth_to_height_mapping_figure_001.png
# PASSED: plot_depth_to_height_mapping()

# %% [markdown]
# ## Plot: `plot_source_X_and_h()`
#
# **What is checked:** Source x and h behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic plot call completes and writes its figure output to `OUTPUT_DIR`.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem.

# %% [markdown]
# ### Output files for `plot_source_X_and_h()`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `plot_source_X_and_h_figure_001.png`
# - `plot_source_X_and_h_figure_002.png`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_call('plot_source_X_and_h()', lambda: TEST_MODULE.plot_source_X_and_h())
# Out:
# Running plot_source_X_and_h() ...
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_source_X_and_h_figure_001.png
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_source_X_and_h_figure_002.png
# PASSED: plot_source_X_and_h()

# %% [markdown]
# ## Plot: `plot_normalized_profiles()`
#
# **What is checked:** Normalized profiles behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic plot call completes and writes its figure output to `OUTPUT_DIR`.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem; normalization failures often point to probability conservation or broadcasting issues.

# %% [markdown]
# ### Output files for `plot_normalized_profiles()`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `plot_normalized_profiles_figure_001.png`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_call('plot_normalized_profiles()', lambda: TEST_MODULE.plot_normalized_profiles())
# Out:
# Running plot_normalized_profiles() ...
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_normalized_profiles_figure_001.png
# PASSED: plot_normalized_profiles()

# %% [markdown]
# ## Plot: `plot_phi_Eh_profiles()`
#
# **What is checked:** Phi eh profiles behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic plot call completes and writes its figure output to `OUTPUT_DIR`.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem.

# %% [markdown]
# ### Output files for `plot_phi_Eh_profiles()`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `plot_phi_Eh_profiles_figure_001.png`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_call('plot_phi_Eh_profiles()', lambda: TEST_MODULE.plot_phi_Eh_profiles())
# Out:
# Running plot_phi_Eh_profiles() ...
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_phi_Eh_profiles_figure_001.png
# PASSED: plot_phi_Eh_profiles()

# %% [markdown]
# ## Plot: `plot_reconstruction_check()`
#
# **What is checked:** Reconstruction check behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic plot call completes and writes its figure output to `OUTPUT_DIR`.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem.

# %% [markdown]
# ### Output files for `plot_reconstruction_check()`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `plot_reconstruction_check_figure_001.png`
# - `plot_reconstruction_check_figure_002.png`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_call('plot_reconstruction_check()', lambda: TEST_MODULE.plot_reconstruction_check())
# Out:
# Running plot_reconstruction_check() ...
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_reconstruction_check_figure_001.png
# Saved plot: V:\output\test\mceq\test4_profile_syntetic\plot_reconstruction_check_figure_002.png
# PASSED: plot_reconstruction_check()
