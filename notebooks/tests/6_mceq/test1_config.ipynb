# %% [markdown]
# # Master's Thesis Notebook
#
# This notebook is part of the **Master's Thesis (MSc Dissertation)**: **Fast Simulation of Neutrino Oscillations in Matter**.
#
# **Author**
# Juan Ramon Diaz Santos <diazjuan@alumni.uv.es>
#
# **Supervisors**
# Roberto Ruiz de Austri Bazan <rruiz@ific.uv.es>
# Michele Lucente <michele.lucente@unibo.it>
#
# **Date**
# June 2026

# %% [markdown]
# # test1 config
#
# Notebook equivalent of `tests/6_mceq/test1_config.py`. The original Python test module remains the source of truth; this notebook imports it and runs each numerical test and diagnostic plot in its own cell for interactive inspection.
#
# The notebook uses the shared TPeanuts output-root convention defined in section `2. Paths`. Generated `mceq` test artifacts and figures are redirected to the notebook-specific `OUTPUT_DIR` under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`.

# %% [markdown]
# ## 1. Libraries and test module
#
# This section locates the repository, imports the original `mceq` test module, and reloads it so source changes are reflected when the notebook is rerun. The expected result is that the module imports without errors. Possible problems include running the notebook from outside the repository tree, missing optional dependencies, or unavailable external model data.

# %%
from __future__ import annotations

import importlib
import importlib.util
import os
import sys
import traceback
from pathlib import Path

import matplotlib.pyplot as plt


from tpeanuts.util.notebooks import find_repo_root
HERE = Path.cwd().resolve()
PACKAGE_DIR = find_repo_root(HERE, folder="analysis")
print(f"PACKAGE_DIR = {PACKAGE_DIR}")

NOTEBOOK_STEM = "test1_config"
TEST_MODULE_PATH = PACKAGE_DIR / "notebooks" / "tests" / "6_mceq" / f"{NOTEBOOK_STEM}.py"
TEST_MODULE_NAME = f"notebook_tests_{TEST_MODULE_PATH.parent.name.replace('.', '_')}_{NOTEBOOK_STEM}"
if not TEST_MODULE_PATH.exists():
    raise FileNotFoundError(f"Could not find local test module: {TEST_MODULE_PATH}")
spec = importlib.util.spec_from_file_location(TEST_MODULE_NAME, TEST_MODULE_PATH)
if spec is None or spec.loader is None:
    raise ImportError(f"Could not load test module spec from {TEST_MODULE_PATH}")
TEST_MODULE = importlib.util.module_from_spec(spec)
sys.modules[TEST_MODULE_NAME] = TEST_MODULE
spec.loader.exec_module(TEST_MODULE)
print("Loaded local test module:", TEST_MODULE_PATH)

from tpeanuts.util.notebooks import build_notebook_test_runner
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Loaded local test module: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\notebooks\tests\6_mceq\test1_config.py

# %% [markdown]
# ## 2. Paths
#
# All outputs are rooted at `DEFAULT_OUTPUT_ROOT` unless `TPEANUTS_OUTPUT_ROOT` is defined in the environment. This notebook writes `mceq` test figures and generated artifacts under `OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM`, while data, analysis, benchmark, and external roots follow the same shared structure used by the analysis notebooks.

# %%
DEFAULT_OUTPUT_ROOT = Path(r"V:\output")
OUTPUT_ROOT = Path(os.environ.get("TPEANUTS_OUTPUT_ROOT", DEFAULT_OUTPUT_ROOT))

OUTPUT_DATA_ROOT = Path(OUTPUT_ROOT / "data")
OUTPUT_ANALYSIS_ROOT = Path(OUTPUT_ROOT / "analysis")
OUTPUT_BENCHMARK_ROOT = Path(OUTPUT_ROOT / "benchmark")
OUTPUT_TEST_ROOT = Path(OUTPUT_ROOT / "test")

OUTPUT_DATA_ATMOSPHERE = Path(OUTPUT_DATA_ROOT / "atmosphere")
OUTPUT_DATA_SOLAR = Path(OUTPUT_DATA_ROOT / "solar")
OUTPUT_DATA_EXTERNAL = Path(OUTPUT_DATA_ROOT / "external")

OUTPUT_ANALYSIS_ATMOSPHERE = Path(OUTPUT_ANALYSIS_ROOT / "atmosphere")
OUTPUT_ANALYSIS_SOLAR = Path(OUTPUT_ANALYSIS_ROOT / "solar")
OUTPUT_ANALYSIS_EXTERNAL = Path(OUTPUT_ANALYSIS_ROOT / "external")

OUTPUT_DATA_MCEQ = Path(OUTPUT_DATA_ROOT / "mceq")
OUTPUT_DATA_HONDA = Path(OUTPUT_DATA_ROOT / "honda")

OUTPUT_DIR = OUTPUT_TEST_ROOT / "mceq" / NOTEBOOK_STEM
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SHOW_PLOTS = True
print("Output root     :", OUTPUT_ROOT)
print("Output directory:", OUTPUT_DIR)
# Out:
# Output root     : V:\output
# Output directory: V:\output\test\mceq\test1_config

# %%
NOTEBOOK_RUNNER_ATTRS = {}
if "RUN_REAL_DATA_ANALYSIS" in globals():
    NOTEBOOK_RUNNER_ATTRS["RUN_REAL_mceq_run1_analysis"] = RUN_REAL_DATA_ANALYSIS

runner = build_notebook_test_runner(
    TEST_MODULE,
    OUTPUT_DIR,
    show_plots=SHOW_PLOTS,
    auto_save_figures=True,
    extra_module_attrs=NOTEBOOK_RUNNER_ATTRS,
)
run_notebook_test = runner.run_test
run_notebook_call = runner.run_call

# %% [markdown]
# ## Test: `test_default_config_is_valid`
#
# **What is checked:** Default config is valid behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_default_config_is_valid)
# Out:
# Running test_default_config_is_valid ...
# Default RunConfig:
# RunConfig(model=MCEqModelConfig(interaction_model='SIBYLL23D', primary_model='HillasGaisser H3a', density_model='CORSIKA', info=False), grid=GridConfig(theta_grid_deg=tensor([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60., 65.,
#         70., 75., 80., 85.], dtype=torch.float64), X_grid_gcm2=tensor([1.0000e+00, 5.6986e+00, 1.0397e+01, 1.5096e+01, 1.9795e+01, 2.4493e+01,
#         2.9192e+01, 3.3890e+01, 3.8589e+01, 4.3288e+01, 4.7986e+01, 5.2685e+01,
#         5.7384e+01, 6.2082e+01, 6.6781e+01, 7.1479e+01, 7.6178e+01, 8.0877e+01,
#         8.5575e+01, 9.0274e+01, 9.4973e+01, 9.9671e+01, 1.0437e+02, 1.0907e+02,
#         1.1377e+02, 1.1847e+02, 1.2316e+02, 1.2786e+02, 1.3256e+02, 1.3726e+02,
#         1.4196e+02, 1.4666e+02, 1.5136e+02, 1.5605e+02, 1.6075e+02, 1.6545e+02,
#         1.7015e+02, 1.7485e+02, 1.7955e+02, 1.8425e+02, 1.8895e+02, 1.9364e+02,
#         1.9834e+02, 2.0304e+02, 2.0774e+02, 2.1244e+02, 2.1714e+02, 2.2184e+02,
#         2.2653e+02, 2.3123e+02, 2.3593e+02, 2.4063e+02, 2.4533e+02, 2.5003e+02,
#         2.5473e+02, 2.5942e+02, 2.6412e+02, 2.6882e+02, 2.7352e+02, 2.7822e+02,
#         2.8292e+02, 2.8762e+02, 2.9232e+02, 2.9701e+02, 3.0171e+02, 3.0641e+02,
#         3.1111e+02, 3.1581e+02, 3.2051e+02, 3.2521e+02, 3.2990e+02, 3.3460e+02,
#         3.3930e+02, 3.4400e+02, 3.4870e+02, 3.5340e+02, 3.5810e+02, 3.6279e+02,
#         3.6749e+02, 3.7219e+02, 3.7689e+02, 3.8159e+02, 3.8629e+02, 3.9099e+02,
#         3.9568e+02, 4.0038e+02, 4.0508e+02, 4.0978e+02, 4.1448e+02, 4.1918e+02,
#         4.2388e+02, 4.2858e+02, 4.3327e+02, 4.3797e+02, 4.4267e+02, 4.4737e+02,
#         4.5207e+02, 4.5677e+02, 4.6147e+02, 4.6616e+02, 4.7086e+02, 4.7556e+02,
#         4.8026e+02, 4.8496e+02, 4.8966e+02, 4.9436e+02, 4.9905e+02, 5.0375e+02,
#         5.0845e+02, 5.1315e+02, 5.1785e+02, 5.2255e+02, 5.2725e+02, 5.3195e+02,
#         5.3664e+02, 5.4134e+02, 5.4604e+02, 5.5074e+02, 5.5544e+02, 5.6014e+02,
#         25.6856, 25.9532, 26.2207, 26.4883, 26.7559, 27.0234, 27.2910, 27.5585,
#         27.8261, 28.0936, 28.3612, 28.6288, 28.8963, 29.1639, 29.4314, 29.6990,
#         29.9666, 30.2341, 30.5017, 30.7692, 31.0368, 31.3043, 31.5719, 31.8395,
#         32.1070, 32.3746, 32.6421, 32.9097, 33.1773, 33.4448, 33.7124, 33.9799,
#         34.2475, 34.5150, 34.7826, 35.0502, 35.3177, 35.5853, 35.8528, 36.1204,
#         36.3880, 36.6555, 36.9231, 37.1906, 37.4582, 37.7257, 37.9933, 38.2609,
#         38.5284, 38.7960, 39.0635, 39.3311, 39.5987, 39.8662, 40.1338, 40.4013,
#         40.6689, 40.9365, 41.2040, 41.4716, 41.7391, 42.0067, 42.2743, 42.5418,
#         42.8094, 43.0769, 43.3445, 43.6120, 43.8796, 44.1472, 44.4147, 44.6823,
#         44.9498, 45.2174, 45.4850, 45.7525, 46.0201, 46.2876, 46.5552, 46.8227,
#         47.0903, 47.3579, 47.6254, 47.8930, 48.1605, 48.4281, 48.6957, 48.9632,
#         49.2308, 49.4983, 49.7659, 50.0334, 50.3010, 50.5686, 50.8361, 51.1037,
#         51.3712, 51.6388, 51.9064, 52.1739, 52.4415, 52.7090, 52.9766, 53.2441,
#         53.5117, 53.7793, 54.0468, 54.3144, 54.5819, 54.8495, 55.1171, 55.3846,
#         55.6522, 55.9197, 56.1873, 56.4548, 56.7224, 56.9900, 57.2575, 57.5251,
#         57.7926, 58.0602, 58.3278, 58.5953, 58.8629, 59.1304, 59.3980, 59.6656,
#         59.9331, 60.2007, 60.4682, 60.7358, 61.0033, 61.2709, 61.5385, 61.8060,
#         62.0736, 62.3411, 62.6087, 62.8763, 63.1438, 63.4114, 63.6789, 63.9465,
#         64.2141, 64.4816, 64.7492, 65.0167, 65.2843, 65.5518, 65.8194, 66.0870,
#         66.3545, 66.6221, 66.8896, 67.1572, 67.4248, 67.6923, 67.9599, 68.2274,
#         68.4950, 68.7625, 69.0301, 69.2977, 69.5652, 69.8328, 70.1003, 70.3679,
#         70.6355, 70.9030, 71.1706, 71.4381, 71.7057, 71.9732, 72.2408, 72.5084,
#         72.7759, 73.0435, 73.3110, 73.5786, 73.8462, 74.1137, 74.3813, 74.6488,
#         74.9164, 75.1839, 75.4515, 75.7191, 75.9866, 76.2542, 76.5217, 76.7893,
#         77.0569, 77.3244, 77.5920, 77.8595, 78.1271, 78.3946, 78.6622, 78.9298,
#         79.1973, 79.4649, 79.7324, 80.0000], dtype=torch.float64), X_obs_gcm2=1030.0), smoothing=SmoothingConfig(method='spline', smoothing=0.0001, gaussian_sigma=2.0, positive_only=True), output=OutputConfig(output_dir='atmosphere_height_flux_outputs', filename='phi_E_theta_h.pt', dtype=torch.float32, compressed=True, overwrite=False, save_intermediate=False), parallel=ParallelConfig(parallel=False, n_jobs=4, backend='loky'), flavours={'numu': 'numu', 'antinumu': 'antinumu', 'nue': 'nue', 'antinue': 'antinue'})
# ------------------------------------------------------------------------------------------
# PASSED: test_default_config_is_valid

# %% [markdown]
# ## Test: `test_make_config_is_valid`
#
# **What is checked:** Make config is valid behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_make_config_is_valid)
# Out:
# Running test_make_config_is_valid ...
# theta_grid_deg: tensor([ 0., 15., 30., 60.], dtype=torch.float64)
# X_grid shape: torch.Size([20])
# h_grid shape: torch.Size([50])
# ------------------------------------------------------------------------------------------
# PASSED: test_make_config_is_valid

# %% [markdown]
# ## Test: `test_invalid_interaction_model_raises`
#
# **What is checked:** Invalid interaction model raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_invalid_interaction_model_raises)
# Out:
# Running test_invalid_interaction_model_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_invalid_interaction_model_raises

# %% [markdown]
# ## Test: `test_invalid_density_model_raises`
#
# **What is checked:** Invalid density model raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_invalid_density_model_raises)
# Out:
# Running test_invalid_density_model_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_invalid_density_model_raises

# %% [markdown]
# ## Test: `test_invalid_primary_model_raises`
#
# **What is checked:** Invalid primary model raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_invalid_primary_model_raises)
# Out:
# Running test_invalid_primary_model_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_invalid_primary_model_raises

# %% [markdown]
# ## Test: `test_theta_grid_must_be_1d`
#
# **What is checked:** Theta grid must be 1d behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_grid_must_be_1d)
# Out:
# Running test_theta_grid_must_be_1d ...
# ------------------------------------------------------------------------------------------
# PASSED: test_theta_grid_must_be_1d

# %% [markdown]
# ## Test: `test_theta_grid_must_be_below_90_deg`
#
# **What is checked:** Theta grid must be below 90 deg behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_grid_must_be_below_90_deg)
# Out:
# Running test_theta_grid_must_be_below_90_deg ...
# ------------------------------------------------------------------------------------------
# PASSED: test_theta_grid_must_be_below_90_deg

# %% [markdown]
# ## Test: `test_theta_grid_cannot_be_negative`
#
# **What is checked:** Theta grid cannot be negative behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_theta_grid_cannot_be_negative)
# Out:
# Running test_theta_grid_cannot_be_negative ...
# ------------------------------------------------------------------------------------------
# PASSED: test_theta_grid_cannot_be_negative

# %% [markdown]
# ## Test: `test_X_grid_must_be_strictly_increasing`
#
# **What is checked:** X grid must be strictly increasing behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_X_grid_must_be_strictly_increasing)
# Out:
# Running test_X_grid_must_be_strictly_increasing ...
# ------------------------------------------------------------------------------------------
# PASSED: test_X_grid_must_be_strictly_increasing

# %% [markdown]
# ## Test: `test_h_grid_must_be_strictly_increasing`
#
# **What is checked:** H grid must be strictly increasing behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_h_grid_must_be_strictly_increasing)
# Out:
# Running test_h_grid_must_be_strictly_increasing ...
# ------------------------------------------------------------------------------------------
# PASSED: test_h_grid_must_be_strictly_increasing

# %% [markdown]
# ## Test: `test_X_obs_must_be_inside_X_grid`
#
# **What is checked:** X obs must be inside x grid behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_X_obs_must_be_inside_X_grid)
# Out:
# Running test_X_obs_must_be_inside_X_grid ...
# ------------------------------------------------------------------------------------------
# PASSED: test_X_obs_must_be_inside_X_grid

# %% [markdown]
# ## Test: `test_smoothing_config_valid`
#
# **What is checked:** Smoothing config valid behavior and numerical consistency.
#
# **Expected result:** The expected result is that the cell completes without raising an exception.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_smoothing_config_valid)
# Out:
# Running test_smoothing_config_valid ...
# SmoothingConfig:
# SmoothingConfig(method='spline', smoothing=0.0001, gaussian_sigma=2.0, positive_only=True)
# ------------------------------------------------------------------------------------------
# PASSED: test_smoothing_config_valid

# %% [markdown]
# ## Test: `test_invalid_smoothing_method_raises`
#
# **What is checked:** Invalid smoothing method raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_invalid_smoothing_method_raises)
# Out:
# Running test_invalid_smoothing_method_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_invalid_smoothing_method_raises

# %% [markdown]
# ## Test: `test_negative_smoothing_raises`
#
# **What is checked:** Negative smoothing raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_negative_smoothing_raises)
# Out:
# Running test_negative_smoothing_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_negative_smoothing_raises

# %% [markdown]
# ## Test: `test_negative_gaussian_sigma_raises`
#
# **What is checked:** Negative gaussian sigma raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_negative_gaussian_sigma_raises)
# Out:
# Running test_negative_gaussian_sigma_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_negative_gaussian_sigma_raises

# %% [markdown]
# ## Test: `test_output_config_valid`
#
# **What is checked:** Output config valid behavior and numerical consistency.
#
# **Expected result:** The expected result is that the diagnostic function completes and generates the listed output files.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check; missing or blank plots may indicate a path, backend, or non-finite numerical-data problem.

# %% [markdown]
# ### Output files for `test_output_config_valid`
#
# This block generates or validates files in `OUTPUT_DIR`:
#
# - `test_output.npz`
#
# The expected result is that each relevant image or data artifact is written to disk and, for figures, also displayed inline when `SHOW_PLOTS = True`. Possible problems include a non-writable output directory, an inactive Matplotlib backend, missing optional external data, or upstream numerical values that make the plotted curves empty or non-finite.

# %%
run_notebook_test(TEST_MODULE.test_output_config_valid)
# Out:
# Running test_output_config_valid ...
# OutputConfig:
# OutputConfig(output_dir='outputs', filename='test_output.npz', dtype=torch.float32, compressed=True, overwrite=False, save_intermediate=False)
# ------------------------------------------------------------------------------------------
# PASSED: test_output_config_valid

# %% [markdown]
# ## Test: `test_output_invalid_dtype_raises`
#
# **What is checked:** Output invalid dtype raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_output_invalid_dtype_raises)
# Out:
# Running test_output_invalid_dtype_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_output_invalid_dtype_raises

# %% [markdown]
# ## Test: `test_parallel_config_valid`
#
# **What is checked:** Parallel config valid behavior and numerical consistency.
#
# **Expected result:** The expected result is that the cell completes without raising an exception.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_parallel_config_valid)
# Out:
# Running test_parallel_config_valid ...
# ParallelConfig:
# ParallelConfig(parallel=True, n_jobs=2, backend='loky')
# ------------------------------------------------------------------------------------------
# PASSED: test_parallel_config_valid

# %% [markdown]
# ## Test: `test_parallel_n_jobs_zero_raises`
#
# **What is checked:** Parallel n jobs zero raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_parallel_n_jobs_zero_raises)
# Out:
# Running test_parallel_n_jobs_zero_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_parallel_n_jobs_zero_raises

# %% [markdown]
# ## Test: `test_parallel_invalid_backend_raises`
#
# **What is checked:** Parallel invalid backend raises behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_parallel_invalid_backend_raises)
# Out:
# Running test_parallel_invalid_backend_raises ...
# ------------------------------------------------------------------------------------------
# PASSED: test_parallel_invalid_backend_raises

# %% [markdown]
# ## Test: `test_run_config_requires_non_empty_flavours`
#
# **What is checked:** Run config requires non empty flavours behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_run_config_requires_non_empty_flavours)
# Out:
# Running test_run_config_requires_non_empty_flavours ...
# ------------------------------------------------------------------------------------------
# PASSED: test_run_config_requires_non_empty_flavours

# %% [markdown]
# ## Test: `test_run_config_requires_string_flavour_names`
#
# **What is checked:** Run config requires string flavour names behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_run_config_requires_string_flavour_names)
# Out:
# Running test_run_config_requires_string_flavour_names ...
# ------------------------------------------------------------------------------------------
# PASSED: test_run_config_requires_string_flavour_names

# %% [markdown]
# ## Test: `test_run_config_requires_string_particle_names`
#
# **What is checked:** Run config requires string particle names behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_raises.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; optional MCEq/crflux dependencies or atmospheric-model availability can affect this check.

# %%
run_notebook_test(TEST_MODULE.test_run_config_requires_string_particle_names)
# Out:
# Running test_run_config_requires_string_particle_names ...
# ------------------------------------------------------------------------------------------
# PASSED: test_run_config_requires_string_particle_names
