# %% [markdown]
# # Master's Thesis Notebook
#
# This notebook is part of the **Master's Thesis (MSc Dissertation)**: **Fast Simulation of Neutrino Oscillations in Matter**.
#
# **Author**
# Juan Ramon Diaz Santos <diazjuan@alumni.uv.es>
#
# **Supervisors**
# Roberto Ruiz de Austri Bazan <rruiz@ific.uv.es>
# Michele Lucente <michele.lucente@unibo.it>
#
# **Date**
# June 2026

# %% [markdown]
# # test9 core pipeline
#
# Notebook equivalent of `tests/1_core/test9_core_pipeline.py`. The original Python test module remains the source of truth; this notebook imports it and runs each `test_*` function in its own cell for interactive inspection.
#
# The notebook uses the shared TPeanuts output-root convention defined in section `2. Paths`. Generated test artifacts and figures are redirected to the notebook-specific `OUTPUT_DIR` under `OUTPUT_TEST_ROOT / "core" / NOTEBOOK_STEM`.

# %% [markdown]
# ## 1. Libraries and test module
#
# This section locates the repository, imports the original Python test module, and reloads it so changes in the source file are reflected when the notebook is rerun. The expected result is that the module imports without errors. Possible problems include running the notebook from outside the repository tree or missing editable installation paths.

# %%
from __future__ import annotations

import importlib
import importlib.util
import os
import sys
import traceback
from pathlib import Path

import matplotlib.pyplot as plt


from tpeanuts.util.notebooks import find_repo_root
HERE = Path.cwd().resolve()
PACKAGE_DIR = find_repo_root(HERE, folder="analysis")
print(f"PACKAGE_DIR = {PACKAGE_DIR}")

NOTEBOOK_STEM = "test9_core_pipeline"
TEST_MODULE_PATH = PACKAGE_DIR / "notebooks" / "tests" / "1_core" / f"{NOTEBOOK_STEM}.py"
TEST_MODULE_NAME = f"notebook_tests_{TEST_MODULE_PATH.parent.name.replace('.', '_')}_{NOTEBOOK_STEM}"
if not TEST_MODULE_PATH.exists():
    raise FileNotFoundError(f"Could not find local test module: {TEST_MODULE_PATH}")
spec = importlib.util.spec_from_file_location(TEST_MODULE_NAME, TEST_MODULE_PATH)
if spec is None or spec.loader is None:
    raise ImportError(f"Could not load test module spec from {TEST_MODULE_PATH}")
TEST_MODULE = importlib.util.module_from_spec(spec)
sys.modules[TEST_MODULE_NAME] = TEST_MODULE
spec.loader.exec_module(TEST_MODULE)
print("Loaded local test module:", TEST_MODULE_PATH)

from tpeanuts.util.notebooks import build_notebook_test_runner
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Loaded local test module: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\notebooks\tests\1_core\test9_core_pipeline.py

# %% [markdown]
# ## 2. Paths
#
# All outputs are rooted at `DEFAULT_OUTPUT_ROOT` unless `TPEANUTS_OUTPUT_ROOT` is defined in the environment. This notebook writes test figures and any generated artifacts under `OUTPUT_TEST_ROOT / "core" / NOTEBOOK_STEM`, while data, analysis, benchmark, and external roots are defined with the same shared structure used by the analysis notebooks.

# %%
DEFAULT_OUTPUT_ROOT = Path(r"V:\output")
OUTPUT_ROOT = Path(os.environ.get("TPEANUTS_OUTPUT_ROOT", DEFAULT_OUTPUT_ROOT))

OUTPUT_DATA_ROOT = Path(OUTPUT_ROOT / "data")
OUTPUT_ANALYSIS_ROOT = Path(OUTPUT_ROOT / "analysis")
OUTPUT_BENCHMARK_ROOT = Path(OUTPUT_ROOT / "benchmark")
OUTPUT_TEST_ROOT = Path(OUTPUT_ROOT / "test")

OUTPUT_DATA_ATMOSPHERE = Path(OUTPUT_DATA_ROOT / "atmosphere")
OUTPUT_DATA_SOLAR = Path(OUTPUT_DATA_ROOT / "solar")
OUTPUT_DATA_EXTERNAL = Path(OUTPUT_DATA_ROOT / "external")

OUTPUT_ANALYSIS_ATMOSPHERE = Path(OUTPUT_ANALYSIS_ROOT / "atmosphere")
OUTPUT_ANALYSIS_SOLAR = Path(OUTPUT_ANALYSIS_ROOT / "solar")
OUTPUT_ANALYSIS_EXTERNAL = Path(OUTPUT_ANALYSIS_ROOT / "external")

OUTPUT_DATA_MCEQ = Path(OUTPUT_DATA_ROOT / "mceq")
OUTPUT_DATA_HONDA = Path(OUTPUT_DATA_ROOT / "honda")

OUTPUT_DIR = OUTPUT_TEST_ROOT / "core" / NOTEBOOK_STEM
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

SHOW_PLOTS = True
print("Output root     :", OUTPUT_ROOT)
print("Output directory:", OUTPUT_DIR)
# Out:
# Output root     : V:\output
# Output directory: V:\output\test\core\test9_core_pipeline

# %%
NOTEBOOK_RUNNER_ATTRS = {}
if "RUN_REAL_DATA_ANALYSIS" in globals():
    NOTEBOOK_RUNNER_ATTRS["RUN_REAL_mceq_run1_analysis"] = RUN_REAL_DATA_ANALYSIS

runner = build_notebook_test_runner(
    TEST_MODULE,
    OUTPUT_DIR,
    show_plots=SHOW_PLOTS,
    auto_save_figures=True,
    extra_module_attrs=NOTEBOOK_RUNNER_ATTRS,
)
run_notebook_test = runner.run_test
run_notebook_call = runner.run_call

# %% [markdown]
# ## Test: `test_core_pipeline_scalar`
#
# **What is checked:** Core pipeline scalar behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: Full PMNS unitarity; Reduced PMNS unitarity; Average density consistency; Segment length consistency; and additional consistency checks.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change.

# %%
run_notebook_test(TEST_MODULE.test_core_pipeline_scalar)
# Out:
# Running test_core_pipeline_scalar ...
#
# ==========================================================================================
# peanuts-TORCH core PIPELINE TEST: SCALAR SEGMENT
# ==========================================================================================
#
# ####################################################################################################
# STEP 1: pmns.py: build full and reduced mixing matrices
# ####################################################################################################
# Full PMNS matrix U_PMNS:
# tensor([[8.2161011097e-01+0.0000000000e+00j, 5.5011368835e-01+0.0000000000e+00j, 5.4150066116e-02-1.3928218040e-01j],
#         [-4.2716898719e-01-8.1394205031e-02j, 5.6953928872e-01-5.4497949504e-02j, 6.9538234941e-01-7.7110546805e-18j],
#         [3.5928935214e-01-8.2277741525e-02j, -6.0580116052e-01-5.5089526351e-02j, 7.0293074530e-01-3.1977221788e-18j]], device='cuda:0',
#        dtype=torch.complex128)
# Reduced matrix U_red = R13 @ R12:
# tensor([[8.2161011097e-01+0.j, 5.5011368835e-01+0.j, 1.4943813247e-01+0.j],
#         [-5.5636102291e-01+0.j, 8.3094067910e-01+0.j, 0.0000000000e+00+0.j],
#         [-1.2417422328e-01+0.j, -8.3141552245e-02+0.j, 9.8877107794e-01+0.j]], device='cuda:0', dtype=torch.complex128)
#
# ####################################################################################################
# STEP 2: hamiltonian.py: build kinetic terms, matter potential and Hamiltonian
# ####################################################################################################
# ki:
# tensor([0.0000000000e+00, 1.1978296101e+00, 4.0632575858e+01], dtype=torch.float64)
# L          = 5.000000000000e-01
# naverage   = 1.148021666667e+00
# V          = 2.829073007627e+00
# zero_mask  = False
# Hkin:
# tensor([[1.2698900166e+00+0.j, 5.4754209922e-01+0.j, 5.9490881081e+00+0.j],
#         [5.4754209922e-01+0.j, 8.2705632199e-01+0.j, -8.2752894562e-02+0.j],
#         [5.9490881081e+00+0.j, -8.2752894562e-02+0.j, 3.9733459130e+01+0.j]], dtype=torch.complex128)
# Hmat:
# tensor([[2.8290730076e+00+0.j, 0.0000000000e+00+0.j, 0.0000000000e+00+0.j],
#         [0.0000000000e+00+0.j, 0.0000000000e+00+0.j, 0.0000000000e+00+0.j],
#         [0.0000000000e+00+0.j, 0.0000000000e+00+0.j, 0.0000000000e+00+0.j]], dtype=torch.complex128)
# H = Hkin + Hmat:
# tensor([[4.0989630242e+00+0.j, 5.4754209922e-01+0.j, 5.9490881081e+00+0.j],
#         [5.4754209922e-01+0.j, 8.2705632199e-01+0.j, -8.2752894562e-02+0.j],
#         [5.9490881081e+00+0.j, -8.2752894562e-02+0.j, 3.9733459130e+01+0.j]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 3: spectral.py: trace split, eigenvalues and projectors
# ####################################################################################################
# Tr(H) = (44.65947847609312+0j)
# Tr(T) = (-3.552713678800501e-15+0j)
# lambda:
# tensor([-1.4185559215e+01+0.j, -1.1628354874e+01+0.j, 2.5813914090e+01+0.j], dtype=torch.complex128)
# Projectors M:
# tensor([[[ 4.8061320226e-02+0.j, -2.1375436025e-01+0.j, -7.7783801228e-03+0.j],
#          [-2.1375436025e-01+0.j,  9.5067980472e-01+0.j,  3.4594610783e-02+0.j],
#          [-7.7783801228e-03+0.j,  3.4594610783e-02+0.j,  1.2588750590e-03+0.j]],
#
#         [[ 9.2619964963e-01-0.j,  2.1372956151e-01-0.j, -1.5057733295e-01-0.j],
#          [ 2.1372956151e-01-0.j,  4.9320171392e-02-0.j, -3.4747181514e-02-0.j],
#          [-1.5057733295e-01-0.j, -3.4747181514e-02-0.j,  2.4480178983e-02-0.j]],
#
#         [[ 2.5739030149e-02+0.j,  2.4798742979e-05+0.j,  1.5835571307e-01+0.j],
#          [ 2.4798742979e-05+0.j,  2.3892805868e-08+0.j,  1.5257073032e-04+0.j],
#          [ 1.5835571307e-01+0.j,  1.5257073032e-04+0.j,  9.7426094596e-01+0.j]]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 4: evolution.py: constant-density evolutor
# ####################################################################################################
# U0 spectral:
# tensor([[-6.9976903484e-03-9.6680446748e-01j, -2.1320657853e-01-1.4000189545e-01j, 1.2563376269e-02-4.9739027482e-03j],
#         [-2.1320657853e-01-1.4000189545e-01j, 8.9001800894e-01-3.7563934246e-01j, 3.4526050842e-02+2.2658422417e-02j],
#         [1.2563376269e-02-4.9739027482e-03j, 3.4526050842e-02+2.2658422417e-02j, 6.8043823541e-02-9.9673567592e-01j]], dtype=torch.complex128)
# U0 matrix_exp:
# tensor([[-6.9976903484e-03-9.6680446748e-01j, -2.1320657853e-01-1.4000189545e-01j, 1.2563376269e-02-4.9739027482e-03j],
#         [-2.1320657853e-01-1.4000189545e-01j, 8.9001800894e-01-3.7563934246e-01j, 3.4526050842e-02+2.2658422417e-02j],
#         [1.2563376269e-02-4.9739027482e-03j, 3.4526050842e-02+2.2658422417e-02j, 6.8043823541e-02-9.9673567592e-01j]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 5: integrals.py: compute analytical I_ab integrals
# ####################################################################################################
# atilde = -4.802166666667e-02
# Iab:
# tensor([[0.0000000000e+00+0.0000000000e+00j, -4.3872118804e-03-2.7070933185e-03j, 1.8475330489e-03+8.5238204666e-04j],
#         [4.2278001530e-03+2.9498624009e-03j, 0.0000000000e+00+0.0000000000e+00j, 2.7319653796e-03-1.3712610885e-04j],
#         [-1.3302522766e-03-1.5395981296e-03j, -2.7301442290e-03-1.6956088482e-04j, 0.0000000000e+00+0.0000000000e+00j]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 6: perturbation.py: compute first-order correction and segment evolutor
# ####################################################################################################
# u1:
# tensor([[ 6.5189043514e-06+1.5803069911e-05j, -1.4891371575e-03+2.1925340934e-03j, -3.5289182780e-05-1.0519984018e-03j],
#         [ 1.3819805510e-03-2.2592856423e-03j, -2.7326752605e-05-1.7940351433e-05j, -3.0934072020e-04+2.9152895281e-04j],
#         [-9.3819112229e-05+1.0362379384e-03j,  3.5934980832e-04-2.3654069682e-04j,  2.0807848253e-05+2.1372815213e-06j]], dtype=torch.complex128)
# U_core = U0 + u1:
# tensor([[-6.9911714440e-03-9.6678866441e-01j, -2.1469571569e-01-1.3780936135e-01j, 1.2528087086e-02-6.0259011500e-03j],
#         [-2.1182459798e-01-1.4226118109e-01j, 8.8999068219e-01-3.7565728281e-01j, 3.4216710122e-02+2.2949951370e-02j],
#         [1.2469557157e-02-3.9376648098e-03j, 3.4885400650e-02+2.2421881720e-02j, 6.8064631390e-02-9.9673353864e-01j]], dtype=torch.complex128)
# max|u1| = 2.650422e-03
#
# ####################################################################################################
# STEP 7: segment_evolution.py: high-level segment evolutor
# ####################################################################################################
# [DEBUG] H Hermitian error: max|H-H†| = 1.1102e-16
# [DEBUG] H Hermitian error: max|H-H†| = 1.1102e-16
# U_segment high-level:
# tensor([[-6.9911714440e-03-9.6678866441e-01j, -2.1469571569e-01-1.3780936135e-01j, 1.2528087086e-02-6.0259011500e-03j],
#         [-2.1182459798e-01-1.4226118109e-01j, 8.8999068219e-01-3.7565728281e-01j, 3.4216710122e-02+2.2949951370e-02j],
#         [1.2469557157e-02-3.9376648098e-03j, 3.4885400650e-02+2.2421881720e-02j, 6.8064631390e-02-9.9673353864e-01j]], dtype=torch.complex128)
# U_segment_const high-level:
# tensor([[-6.9976903484e-03-9.6680446748e-01j, -2.1320657853e-01-1.4000189545e-01j, 1.2563376269e-02-4.9739027482e-03j],
#         [-2.1320657853e-01-1.4000189545e-01j, 8.9001800894e-01-3.7563934246e-01j, 3.4526050842e-02+2.2658422417e-02j],
#         [1.2563376269e-02-4.9739027482e-03j, 3.4526050842e-02+2.2658422417e-02j, 6.8043823541e-02-9.9673567592e-01j]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 8: probabilities.py: probability matrix and final flux
# ####################################################################################################
# Probability matrix P[beta, alpha] = |U[beta, alpha]|^2:
# tensor([[9.3472919811e-01, 6.5085670412e-02, 1.9326445071e-04],
#         [6.5107903955e-02, 9.3320180852e-01, 1.6974835194e-03],
#         [1.7099505984e-04, 1.7197319584e-03, 9.9811054109e-01]], dtype=torch.float64)
# Column sums sum_beta P[beta, alpha]:
# tensor([1.0000080971e+00, 1.0000072109e+00, 1.0000012891e+00], dtype=torch.float64)
# Initial flux [phi_e, phi_mu, phi_tau]:
# tensor([1.0000000000e+00, 2.0000000000e+00, 1.0000000000e-01], dtype=torch.float64)
# Final flux:
# tensor([1.0649198654e+00, 1.9316812693e+00, 1.0342151309e-01], dtype=torch.float64)
# P(e -> e)   = 9.347291981104e-01
# P(e -> mu)  = 6.510790395495e-02
# P(e -> tau) = 1.709950598418e-04
# Sum e-column = 1.000008097125e+00
#
# ==========================================================================================
# SCALAR core PIPELINE TEST PASSED
# ==========================================================================================
# ------------------------------------------------------------------------------------------
# PASSED: test_core_pipeline_scalar

# %% [markdown]
# ## Test: `test_core_pipeline_batched`
#
# **What is checked:** Core pipeline batched behavior and numerical consistency.
#
# **Expected result:** The expected result is a clean pass for these checks: assert_true.
#
# **Possible problems:** a failed assertion usually indicates a numerical regression or an unexpected API change; shape, dtype, or broadcasting changes may break downstream vectorized calls.

# %%
run_notebook_test(TEST_MODULE.test_core_pipeline_batched)
# Out:
# Running test_core_pipeline_batched ...
#
# ==========================================================================================
# peanuts-TORCH core PIPELINE TEST: BATCHED SEGMENTS
# ==========================================================================================
#
# ####################################################################################################
# STEP 1: segment_evolution.py: build batched perturbative segment evolutors
# ####################################################################################################
# U_batch shape: torch.Size([3, 3, 3])
# U_batch:
# tensor([[[5.4858163554e-01-7.4001867197e-01j, -2.1162637939e-01-2.3935606681e-01j, 3.0091580415e-02+2.2010926924e-01j],
#          [-2.1118465105e-01-2.3975045979e-01j, 8.3599297756e-01-4.4333974619e-01j, 3.2920474253e-02+3.7452680061e-02j],
#          [2.9988516666e-02+2.2011836299e-01j, 3.3001847730e-02+3.7410261400e-02j, 7.3643737314e-01+6.3703998761e-01j]],
#
#         [[2.8041937568e-01-8.8899270566e-01j, -1.4898329393e-01-1.4720421807e-01j, -1.8227356296e-01+2.3231338937e-01j],
#          [-1.4739732740e-01-1.4882297153e-01j, 9.2652137760e-01-3.1070663677e-01j, 2.3624635505e-02+2.4258370191e-02j],
#          [-1.8204331799e-01+2.3247416999e-01j, 2.3969941220e-02+2.4107732062e-02j, -8.1129257422e-01+5.0345275581e-01j]],
#
#         [[-3.1632196099e-01-8.2163565062e-01j, -4.8286808437e-02-2.7528321189e-02j, 1.5343571702e-01+4.4552307905e-01j],
#          [-4.6600233947e-02-3.0513308289e-02j, 9.9355377159e-01-9.7791540543e-02j, 1.0681492121e-02+8.5998384536e-03j],
#          [1.2238820804e-01+4.5501776456e-01j, 1.1005664824e-02+8.9553023446e-03j, 1.9835460588e-01+8.5947579551e-01j]]], dtype=torch.complex128)
#
# ####################################################################################################
# STEP 2: probabilities.py: convert batched evolutors into probabilities
# ####################################################################################################
# P_batch shape: torch.Size([3, 3, 3])
# P_batch:
# tensor([[[8.4856944571e-01, 1.0207705118e-01, 4.9353593616e-02],
#          [1.0207923981e-01, 8.9543438907e-01, 2.4864608688e-03],
#          [4.9351404856e-02, 2.4886496116e-03, 9.4815995037e-01]],
#
#         [[8.6894305698e-01, 4.3865103687e-02, 8.7193162635e-02],
#          [4.3874248980e-02, 9.5498047729e-01, 1.1465919271e-03],
#          [8.7184009335e-02, 1.1557408272e-03, 9.1166031832e-01]],
#
#         [[7.7514472538e-01, 3.0894243365e-03, 2.2203333322e-01],
#          [3.1026437866e-03, 9.9671228245e-01, 1.8805149536e-04],
#          [2.2202003954e-01, 2.0132209830e-04, 7.7804319274e-01]]], dtype=torch.float64)
# Column sums:
# tensor([[1.0000000904e+00, 1.0000000899e+00, 1.0000000049e+00],
#         [1.0000013153e+00, 1.0000013218e+00, 1.0000000729e+00],
#         [1.0002674087e+00, 1.0000030289e+00, 1.0002645775e+00]], dtype=torch.float64)
#
# ####################################################################################################
# STEP 3: probabilities.py: apply batched probabilities to batched fluxes
# ####################################################################################################
# flux_initial:
# tensor([[1.0000000000e+00, 2.0000000000e+00, 1.0000000000e-01],
#         [1.5000000000e+00, 1.0000000000e+00, 2.0000000000e-01],
#         [5.0000000000e-01, 3.0000000000e+00, 3.0000000000e-01]], dtype=torch.float64)
# flux_final:
# tensor([[1.0576589074e+00, 1.8931966640e+00, 1.4914469912e-01],
#         [1.3647183217e+00, 1.0210211691e+00, 3.1426381849e-01],
#         [4.6345063566e-01, 2.9917445847e+00, 3.4502694388e-01]], dtype=torch.float64)
#
# ==========================================================================================
# BATCHED core PIPELINE TEST PASSED
# ==========================================================================================
# ------------------------------------------------------------------------------------------
# PASSED: test_core_pipeline_batched
