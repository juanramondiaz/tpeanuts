# %% [markdown]
# <div style="background-color:#EAEAEA;padding:20px;border-left:5px solid #6C757D;border-radius:6px;">
# <table style="width:100%; border:none;"><tr style="border:none;">
# <td style="border:none; vertical-align:top;">
# <h1 style="font-size:32px; margin-top:0;">Master's Thesis</h1>
# <hr style="margin:16px 0 22px 0;">
# <p style="font-size:22px; line-height:1.5; margin:0;"><strong>Master's Degree in Advanced Physics</strong> - <strong>Universitat de Valencia</strong></p>
# <p style="font-size:17px; margin-top:28px; margin-bottom:6px;">This notebook is part of the <strong>Master's Thesis (MSc Dissertation)</strong>:</p>
# <div style="font-size:25px;font-weight:700;line-height:1.3;margin-top:14px;margin-bottom:26px;">Fast Simulation of Neutrino Oscillations in Matter</div>
# <p style="font-size:14px; line-height:1.55;"><strong>Author</strong><br>Juan Ramon Diaz Santos - <a href="mailto:diazjuan@alumni.uv.es">diazjuan@alumni.uv.es</a></p>
# <p style="font-size:14px; line-height:1.55;"><strong>Supervisors</strong><br>Roberto Ruiz de Austri Bazan - <a href="mailto:rruiz@ific.uv.es">rruiz@ific.uv.es</a><br>Michele Lucente - <a href="mailto:michele.lucente@unibo.it">michele.lucente@unibo.it</a></p>
# <p style="font-size:14px; line-height:1.55; margin-bottom:0;"><strong>Date</strong><br>September 2026</p></td>
# <td style="border:none;width:230px;padding-left:25px;text-align:right;vertical-align:top;"><img src="../logo_uv.png" alt="Universitat de Valencia" style="width:200px; margin-top:5px;"></td>
# </tr></table></div>

# %% [markdown]
# # Benchmark 1 - TPeanuts vs Peanuts Reference Performance
# ---
# This notebook measures wall-clock performance for the torch-native `tpeanuts` implementation against the bundled legacy `peanuts` implementation. The benchmark covers vacuum propagation, solar production, Earth matter propagation, exposure-style angular integration, the solar-to-detector chain, and a conditional GPU comparison when CUDA is available.
#
# The purpose is performance characterization, not precision validation. Precision and bit-level compatibility are studied in the validation notebooks; here the same physical inputs are used so timing differences can be interpreted as implementation and batching effects.
#
# ---
#
# ## Table of Contents
#
# | # | Section |
# |---|---|
# | [0](#0.-Theoretical-Framework) | **Theoretical Framework** |
# | [1](#1.-Libraries) | **Libraries** |
# | [2](#2.-Paths-and-Configuration) | **Paths and Configuration** |
# | [3](#3.-Vacuum-Propagation) | **Vacuum Propagation** |
# | [4](#4.-Solar-Production) | **Solar Production** |
# | [5](#5.-Earth-Propagation) | **Earth Propagation** |
# | [6](#6.-Integrated-Probabilities) | **Integrated Probabilities** |
# | [7](#7.-Solar-to-Detector-Chain) | **Solar-to-Detector Chain** |
# | [8](#8.-GPU-Benchmark-Conditional) | **GPU Benchmark (Conditional)** |
# | [9](#9.-Summary) | **Summary** |

# %% [markdown]
# ## 0. Theoretical Framework
#
# This stage defines and evaluates theoretical framework under the physical, numerical, and hardware conditions stated above, with explicit control of accuracy and reproducibility.

# %% [markdown]
# ### 0.1 Performance Benchmarking Strategy
#
# This notebook compares two implementations of the same neutrino-oscillation workflows: the torch-native `tpeanuts` API and the legacy NumPy/Numba `peanuts` routines. The measured quantity is wall-clock execution time for fixed input grids. Each benchmark is executed after warm-up calls and repeated several times; the reported speedup is
#
# $$S = \frac{t_\mathrm{legacy}}{t_\mathrm{tpeanuts}},$$
#
# so that $S>1$ means `tpeanuts` is faster than the legacy reference.
#
# ---

# %% [markdown]
# ### 0.2 Vectorization and Grid Scaling
#
# The torch implementation is designed to evaluate many energies and nadir angles in batched tensor operations. The benchmark therefore scans energy-grid size $N_E$ and, for Earth-dependent workflows, nadir-grid size $N_\eta$. Log-log timing slopes provide a compact diagnostic of algorithmic scaling,
#
# $$t(N) \propto N^p,$$
#
# where the fitted exponent $p$ distinguishes roughly linear scaling from larger overheads.
#
# ---

# %% [markdown]
# ### 0.3 Physics Workflows Benchmarked
#
# The benchmark covers the main observable layers used in the project:
#
# | Workflow | Observable |
# |----------|------------|
# | Vacuum propagation | flavour-transition matrix and incoherent flux contraction |
# | Solar production | adiabatic solar flavour probabilities and mass-basis source weights |
# | Earth propagation | mass-basis Earth regeneration over energy-nadir grids |
# | Integrated probabilities | nadir-averaged probabilities with a simple exposure weight |
# | Solar-to-detector chain | solar mass weights followed by Earth propagation |
#
# The Hamiltonians and probability definitions follow the standard three-flavour oscillation framework in vacuum and matter, with matter effects described by the Wolfenstein charged-current potential.
#
# ---

# %% [markdown]
# ### 0.4 Reference Implementation and Precision Mode
#
# The legacy `peanuts` implementation is scalar and loop-based for many workflows, while `tpeanuts` exposes batched tensor APIs. The optional `legacy_precision` flag in solar and matter calculations reproduces rounded constants used by the reference implementation when numerical agreement is the goal. In this performance notebook, the flag is configurable but the main observable is runtime.
#
# **References**
#
# - [1] Wolfenstein, L. (1978). Neutrino oscillations in matter. *Phys. Rev. D* **17**, 2369.
# - [2] Mikheyev, S. P., & Smirnov, A. Yu. (1985). Resonance amplification of oscillations in matter. *Sov. J. Nucl. Phys.* **42**, 913.
# - [3] Esteban, I. et al. (2022). NuFIT 5.2 global analysis of three-flavour neutrino oscillations. *JHEP* **09**, 178.
# - [4] Harris, C. R. et al. (2020). Array programming with NumPy. *Nature* **585**, 357.
# - [5] Paszke, A. et al. (2019). PyTorch: An Imperative Style, High-Performance Deep Learning Library. NeurIPS.

# %% [markdown]
# ## 1. Libraries
#
# This stage defines and evaluates libraries under the physical, numerical, and hardware conditions stated above, with explicit control of accuracy and reproducibility.

# %%
from __future__ import annotations

import gc
import math
import time
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
import torch
from IPython.display import display

from tpeanuts.notebooks.notebookConfig import load_notebook_config
from tpeanuts.notebooks.notebooks_helper import save_and_show, to_numpy
from tpeanuts.util.context import RuntimeContext

from tpeanuts.core.common.oscillation import OscillationParameters
from tpeanuts.config.propagation import PropagationConfig
from tpeanuts.core.common.probability import probability_incoherent
from tpeanuts.medium.earth.profile import EarthParameters, EarthProfile
from tpeanuts.medium.earth.probability import earth_probability_state
from tpeanuts.medium.solar.probability import solar_probability_state, solar_probability_mass
from tpeanuts.medium.solar.profile import SolarMediumParameters, SolarMediumProfile
from tpeanuts.source.solar import SolarSourceParameters, SolarNeutrinoSource
from tpeanuts.medium.solar.validation import legacy_modules
from tpeanuts.medium.vacuum.probability import vacuum_probability_transition

from peanuts.earth import Pearth as legacy_pearth
from peanuts.earth import earthdensity as LegacyEarthDensity
from peanuts.pmns import PMNS as LegacyPMNS
from peanuts.vacuum import Pvacuum as legacy_pvacuum


print(f"Torch version : {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
from tpeanuts.util.math import numpy_trapezoid
from tpeanuts.notebooks.benchmark.benchmark_helpers import *
# Out:
# Warning!: Python module pyslha not found, disabling slha reading routines
# Torch version : 2.5.1+cu121
# CUDA available: True

# %% [markdown]
# ## 2. Paths and Configuration
#
# This section resolves the project paths, creates the benchmark output directory, and fixes the physical and numerical configuration used in the timing study.

# %% [markdown]
# ### 2.1 Paths
#
# `load_notebook_config()` resolves the project root, applies the shared notebook style, and creates the output directory. Following the project notebook convention, outputs from this notebook are saved under `benchmark/`, which is the relative notebook path below `notebooks/` without the notebook filename.
#
# **Expected results:**<br>
# - The printed paths should point to the package root, the bundled legacy data directory, the explicit TPeanuts solar CSV files, and the benchmark output directory used by all CSV files and figures.

# %%
config = load_notebook_config(device=torch.device("cpu"))

PACKAGE_DIR = config.package_dir
OUTPUT_ROOT = config.output_root

OUTPUT_DATA_ROOT       = config.output_data_root
OUTPUT_ANALYSIS_ROOT   = config.output_analysis_root
OUTPUT_BENCHMARK_ROOT  = config.output_benchmark_root

OUTPUT_DIR = config.output_dir("benchmark")

DATA_DIR        = config.data_dir
LEGACY_DATA_DIR = config.legacy_data_dir

EARTH_DENSITY_TPEANUTS = str(DATA_DIR / "earth" / "prem" / "fit" / "even_power_electron.csv")
EARTH_DENSITY_LEGACY   = str(LEGACY_DATA_DIR / "earth_density.csv")
SOLAR_MODEL_FILE = str(LEGACY_DATA_DIR / "nudistr_b16_agss09.dat")
SOLAR_FLUX_FILE = str(LEGACY_DATA_DIR / "fluxes_b16.dat")
SOLAR_DENSITY_CSV_FILE = str(DATA_DIR / "solar" / "bahcall" / "density" / "bp2000_density_electron_neutron_monotonic.csv")
SOLAR_FLUX_CSV_FILE = str(DATA_DIR / "solar" / "bahcall" / "flux" / "fluxes_bahcall_bp2004.csv")
SPECTRUM_FILES = {
    "8B":         str(LEGACY_DATA_DIR / "8B_shape_Ortiz_et_al.csv"),
    "hep":        str(LEGACY_DATA_DIR / "hep_shape.csv"),
    "pp":         str(LEGACY_DATA_DIR / "pp_shape.csv"),
    "17F":        str(LEGACY_DATA_DIR / "f17_shape.csv"),
    "7Beground":  str(LEGACY_DATA_DIR / "be7ground_shape.csv"),
    "7Beexcited": str(LEGACY_DATA_DIR / "be7excited_shape.csv"),
    "13N":        str(LEGACY_DATA_DIR / "n13_shape.csv"),
    "15O":        str(LEGACY_DATA_DIR / "o15_shape.csv"),
}

print(f"PACKAGE_DIR = {PACKAGE_DIR}")
print("Legacy Data Dir :", LEGACY_DATA_DIR)
print("Torch solar model:", SOLAR_DENSITY_CSV_FILE)
print("Torch solar flux :", SOLAR_FLUX_CSV_FILE)
print("Output directory:", OUTPUT_DIR)
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Legacy Data Dir : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\peanuts
# Torch solar model: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\solar\bahcall\density\bp2000_density_electron_neutron_monotonic.csv
# Torch solar flux : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\solar\bahcall\flux\fluxes_bahcall_bp2004.csv
# Output directory: v:\output\benchmark

# %% [markdown]
# ### 2.2 Configuration
#
# This section defines the physical inputs and timing controls used by the benchmark. The oscillation parameters are loaded from the project preset, the Earth and solar density files are fixed explicitly, and the benchmark grids control the computational load.
#
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | Oscillation preset | default `oscillation_parameters_from_preset` | Three-flavour NuFIT-style benchmark point |
# | Vacuum baseline | 1300 km | Long-baseline reference distance |
# | Solar source | `8B` | Source used for solar production benchmarks |
# | Earth profile | bundled `even_power_electron.csv` | Five-layer perturbative Earth propagation profile |
# | Solar profile | bundled B16 AGSS09 CSV | TPeanuts solar density and production profile |
# | Legacy profile | bundled `data/peanuts` files | Legacy `peanuts` reference data |
# | Energy grid sizes | 4 to 1024 | Scaling axis for all workflows |
# | Nadir grid sizes | 4 to 256 | Scaling axis for Earth-dependent workflows |
# | Timing repeats/warmups | configurable below | Warm-up removes first-call/JIT effects from timing |
#
# **Expected results:**<br>
# - The configuration cell should print the active repeat/warm-up counts and build one consistent set of oscillation parameters for both implementations.

# %%
DEVICE = config.device
DTYPE  = config.dtype
SHOW_PLOTS = config.show_plots
GPU_DEVICE = torch.device("cuda", 0) if torch.cuda.is_available() else None

context     = RuntimeContext.resolve(DEVICE, DTYPE)
oscillation = PropagationConfig.oscillation_parameters_from_preset(context=context, antinu=False)
pmns        = oscillation.pmns
THETA12  = float(pmns.params.theta12.detach().cpu())
THETA13  = float(pmns.params.theta13.detach().cpu())
THETA23  = float(pmns.params.theta23.detach().cpu())
DELTA_CP = float(pmns.params.delta.detach().cpu())
DM21_EV2 = float(oscillation.mass_spectrum.DeltamSq21.detach().cpu())
DM3L_EV2 = float(oscillation.mass_spectrum.DeltamSq3l.detach().cpu())
legacy_pmns = LegacyPMNS(THETA12, THETA13, THETA23, DELTA_CP)

#ENERGY_GRID_SIZES = [4, 8, 16, 32, 64, 128, 256, 512]
#NADIR_GRID_SIZES  = [4, 8, 16, 32, 64, 128, 256, 512]
N_EGRIDS = 9
N_AGRIDS = 9
ENERGY_GRID_SIZES = [4*2**n for n in range(N_EGRIDS)]
NADIR_GRID_SIZES = [4*2**n for n in range(N_AGRIDS)]
EARTH_METHOD_COMPARISON_ENERGY_SIZES = [16, 64, 256]
EARTH_METHOD_COMPARISON_NADIR_SIZES = [16, 64, 256]

# More repeats/warmups for stable timing and proper Numba JIT warm-up
TIMING_REPEATS = 5   # was 2 — minimum for reliable min/mean
TIMING_WARMUPS = 3   # was 1 — ensures Numba JIT compiles before timing

EARTH_METHOD          = "analytical"   # "analytical" or "numerical"
LEGACY_EARTH_MODE     = EARTH_METHOD
EARTH_NUMERICAL_STEPS = 160
EARTH_ODE_METHOD      = "midpoint"

EARTH_DEPTH_M          = 0.0
SOLAR_DETECTOR_DEPTH_M = 1000.0
SOLAR_SOURCE           = "8B"
VACUUM_BASELINE_KM     = 1300.0

# Solar matter-mixing precision mode (see benchmark0_tpeanuts_vs_peanuts_precision.ipynb,
# Section 4.4, for the diagnosis): False (default) evaluates Vk/th12_M/th13_M
# from full-precision physical constants; True switches to the legacy peanuts
# combined Vk prefactor (3.868e-7 / 2.533, each hardcoded to 4 significant
# digits there). Only affects numerical agreement with legacy, not timing.
SOLAR_LEGACY_PRECISION = False

MASS_WEIGHTS    = torch.tensor([0.20, 0.30, 0.50], dtype=DTYPE, device=DEVICE)
MASS_WEIGHTS_NP = np.array([0.20, 0.30, 0.50], dtype=np.float64)

print("Performance benchmark parameters loaded.")
print(f"  TIMING_REPEATS = {TIMING_REPEATS},  TIMING_WARMUPS = {TIMING_WARMUPS}")
# Out:
# Performance benchmark parameters loaded.
#   TIMING_REPEATS = 5,  TIMING_WARMUPS = 3

# %% [markdown]
# The following cell builds the shared Earth and solar model objects used by the benchmark. TPeanuts uses the current `EarthProfile`, `EarthParameters`, `SolarMediumProfile`, `SolarMediumParameters`, `SolarNeutrinoSource`, and `SolarSourceParameters` APIs, while the legacy side uses the bundled `peanuts` objects.
#
# **Expected results:**<br>
# - both TPeanuts and legacy density/solar models should load successfully before any timing loop starts.

# %%
earth_profile_t = EarthProfile(
    params=EarthParameters(
        profile_perturbative_kwargs={"density_file": EARTH_DENSITY_TPEANUTS, "tabulated_density": False},
    ),
    context=context,
)
earth_density_l = LegacyEarthDensity(density_file=EARTH_DENSITY_LEGACY, tabulated_density=False)
# SOLAR_DENSITY_CSV_FILE (bp2000_density_electron_neutron_monotonic.csv) starts at
# r=0.001 R_sun rather than r=0.0, which conflicts with SolarNeutrinoSource's default
# production_radius grid (always [0.0, 1.0]) and raises ValueError in
# solar_probability_state/solar_probability_mass. This is a performance benchmark, not
# a precision comparison (see Section 0.4), so the plain bundled default solar medium
# (domain [0.0, 1.0], consistent with the default source) is used instead.
solar_medium = SolarMediumProfile.default(context=context)
solar_source = SolarNeutrinoSource.default(
    params=SolarSourceParameters(
        fluxes_path=SOLAR_FLUX_CSV_FILE,
    ),
    context=context,
)
legacy_pmns_module, legacy_solar_module = legacy_modules()
legacy_model = legacy_solar_module.SolarModel(
    solar_model_file=SOLAR_MODEL_FILE,
    flux_file=SOLAR_FLUX_FILE,
    spectrum_files=SPECTRUM_FILES,
)
legacy_pmns_solar = legacy_pmns_module.PMNS(THETA12, THETA13, THETA23, DELTA_CP)
print("Shared density and solar models loaded.")
# Out:
# Shared density and solar models loaded.

# %% [markdown]
# ### 2.3 Local Helpers
#
# The helper functions below keep repeated benchmark mechanics in one place: grid construction, timing loops, plotting, legacy wrappers, and small pipeline wrappers for solar, Earth, and solar-to-detector workflows. They are local to this notebook because they combine benchmark-specific timing logic with several physical modules.
#
# **Expected results:**<br>
# - This cell should only define functions and print a confirmation message.
# - No benchmark timing is performed yet.

# %%
configure_benchmark_helpers(globals(), backend="legacy")
print("Benchmark helpers imported from notebooks/benchmark/benchmark_helpers.py.")
# Out:
# Benchmark helpers imported from notebooks/benchmark/benchmark_helpers.py.

# %% [markdown]
# ## 3. Vacuum Propagation
#
# This section benchmarks vacuum flavour-transition probabilities and a synthetic incoherent flux contraction. The TPeanuts path uses the batched `vacuum_probability_transition` API, while the legacy path loops over `peanuts.vacuum.Pvacuum`.
#
# **Expected results:**<br>
# - The probability and flux timings should scale primarily with energy-grid size. TPeanuts is expected to benefit from batched tensor evaluation as the grid grows.

# %% [markdown]
# ### 3.1 Probability Timing
#
# The output table stores best, mean, and standard-deviation timings for each energy-grid size. The plot shows absolute timing and the fitted log-log scaling slope.
#
# **Expected results:**<br>
# - Both implementations should return finite timings; the speedup curve should reveal where tensor batching overtakes scalar legacy loops.

# %%
vacuum_probability_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=False)
    vacuum_probability_records.append(benchmark_pair(
        "vacuum probabilities", ne, None,
        lambda E=E: vacuum_probability_transition(oscillation, E, VACUUM_BASELINE_KM, context=context),
        lambda E=E: legacy_vacuum_matrix(E, VACUUM_BASELINE_KM),
    ))
vacuum_probability_df = pd.DataFrame(vacuum_probability_records)
display(vacuum_probability_df)
save_results(vacuum_probability_df, "vacuum_probability_timing")
plot_energy_scaling(vacuum_probability_df, "Vacuum probability timing", "vacuum_probability_timing.png")
# Out:
# vacuum probabilities               | NE=   4 | Neta=None | t=1.0434e-03s+/-7.1e-05 | leg=5.9530e-04s | x0.57
# vacuum probabilities               | NE=   8 | Neta=None | t=1.0310e-03s+/-1.4e-04 | leg=9.7740e-04s | x0.95
# vacuum probabilities               | NE=  16 | Neta=None | t=1.1514e-03s+/-1.1e-04 | leg=1.8338e-03s | x1.59
# vacuum probabilities               | NE=  32 | Neta=None | t=1.0715e-03s+/-1.5e-04 | leg=3.4786e-03s | x3.25
# vacuum probabilities               | NE=  64 | Neta=None | t=1.1763e-03s+/-1.2e-04 | leg=6.5294e-03s | x5.55
# vacuum probabilities               | NE= 128 | Neta=None | t=1.1950e-03s+/-2.5e-04 | leg=1.2690e-02s | x10.62
# vacuum probabilities               | NE= 256 | Neta=None | t=1.2404e-03s+/-1.2e-04 | leg=2.5282e-02s | x20.38
# vacuum probabilities               | NE= 512 | Neta=None | t=1.4083e-03s+/-2.4e-04 | leg=5.0676e-02s | x35.98
# vacuum probabilities               | NE=1024 | Neta=None | t=1.5741e-03s+/-1.4e-04 | leg=9.8763e-02s | x62.74
#                 section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  vacuum probabilities         4    None         0.001043       0.000595
# 1  vacuum probabilities         8    None         0.001031       0.000977
# 2  vacuum probabilities        16    None         0.001151       0.001834
# 3  vacuum probabilities        32    None         0.001072       0.003479
# 4  vacuum probabilities        64    None         0.001176       0.006529
# 5  vacuum probabilities       128    None         0.001195       0.012690
# 6  vacuum probabilities       256    None         0.001240       0.025282
# 7  vacuum probabilities       512    None         0.001408       0.050676
# 8  vacuum probabilities      1024    None         0.001574       0.098763
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.001112       0.000640        0.000071      0.000048
# 1         0.001139       0.001054        0.000143      0.000039
# 2         0.001215       0.002138        0.000112      0.000336
# 3         0.001228       0.003563        0.000149      0.000056
# 4         0.001301       0.006789        0.000116      0.000194
# 5         0.001423       0.013284        0.000248      0.001056
# 6         0.001323       0.025896        0.000116      0.000606
# 7         0.001610       0.051058        0.000239      0.000465
# 8         0.001762       0.103697        0.000145      0.003059
#
#    speedup_legacy_over_tpeanuts
# 0                      0.570539
# 1                      0.948012
# 2                      1.592670
# 3                      3.246477
# 4                      5.550795
# 5                     10.619247
# 6                     20.381732
# 7                     35.984023
# 8                     62.742265
# Saved: v:\output\benchmark\vacuum_probability_timing.csv
# v:\output\benchmark\vacuum_probability_timing.png

# %% [markdown]
# ### 3.2 Flux Timing
#
# This benchmark applies the vacuum probability matrix to a synthetic three-flavour flux vector.
#
# **Expected results:**<br>
# - The flux timing should follow the probability timing plus a small matrix-vector contraction overhead.

# %%
vacuum_flux_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=False)
    flux_t = synthetic_flux(E)
    flux_l = to_numpy(flux_t)
    vacuum_flux_records.append(benchmark_pair(
        "vacuum flux", ne, None,
        lambda E=E, ft=flux_t: probability_incoherent(
            vacuum_probability_transition(oscillation, E, VACUUM_BASELINE_KM, context=context), ft),
        lambda E=E, fl=flux_l: np.einsum("eba,ea->eb", legacy_vacuum_matrix(E, VACUUM_BASELINE_KM), fl),
    ))
vacuum_flux_df = pd.DataFrame(vacuum_flux_records)
display(vacuum_flux_df)
save_results(vacuum_flux_df, "vacuum_flux_timing")
plot_energy_scaling(vacuum_flux_df, "Vacuum flux timing", "vacuum_flux_timing.png")
# Out:
# vacuum flux                        | NE=   4 | Neta=None | t=1.1040e-03s+/-4.6e-05 | leg=6.1090e-04s | x0.55
# vacuum flux                        | NE=   8 | Neta=None | t=1.1181e-03s+/-1.6e-04 | leg=9.6750e-04s | x0.87
# vacuum flux                        | NE=  16 | Neta=None | t=1.1112e-03s+/-1.6e-04 | leg=1.8662e-03s | x1.68
# vacuum flux                        | NE=  32 | Neta=None | t=1.1149e-03s+/-1.5e-04 | leg=3.2098e-03s | x2.88
# vacuum flux                        | NE=  64 | Neta=None | t=1.2482e-03s+/-2.4e-04 | leg=6.3227e-03s | x5.07
# vacuum flux                        | NE= 128 | Neta=None | t=1.2786e-03s+/-1.1e-04 | leg=1.2574e-02s | x9.83
# vacuum flux                        | NE= 256 | Neta=None | t=1.3691e-03s+/-1.2e-04 | leg=2.5276e-02s | x18.46
# vacuum flux                        | NE= 512 | Neta=None | t=1.5085e-03s+/-1.3e-04 | leg=4.9855e-02s | x33.05
# vacuum flux                        | NE=1024 | Neta=None | t=1.6430e-03s+/-3.2e-04 | leg=1.0067e-01s | x61.27
#        section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  vacuum flux         4    None         0.001104       0.000611
# 1  vacuum flux         8    None         0.001118       0.000968
# 2  vacuum flux        16    None         0.001111       0.001866
# 3  vacuum flux        32    None         0.001115       0.003210
# 4  vacuum flux        64    None         0.001248       0.006323
# 5  vacuum flux       128    None         0.001279       0.012574
# 6  vacuum flux       256    None         0.001369       0.025276
# 7  vacuum flux       512    None         0.001509       0.049855
# 8  vacuum flux      1024    None         0.001643       0.100667
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.001192       0.000665        0.000046      0.000042
# 1         0.001284       0.001016        0.000156      0.000051
# 2         0.001296       0.001907        0.000165      0.000024
# 3         0.001316       0.003353        0.000147      0.000131
# 4         0.001437       0.006681        0.000245      0.000210
# 5         0.001367       0.013182        0.000109      0.000498
# 6         0.001516       0.025957        0.000123      0.000391
# 7         0.001763       0.051599        0.000131      0.001863
# 8         0.001842       0.102020        0.000324      0.001283
#
#    speedup_legacy_over_tpeanuts
# 0                      0.553351
# 1                      0.865307
# 2                      1.679446
# 3                      2.879003
# 4                      5.065454
# 5                      9.834428
# 6                     18.461909
# 7                     33.049122
# 8                     61.269933
# Saved: v:\output\benchmark\vacuum_flux_timing.csv
# v:\output\benchmark\vacuum_flux_timing.png

# %% [markdown]
# ## 4. Solar Production
#
# This section benchmarks solar production probabilities and mass-basis source weights for the selected solar source. `SOLAR_LEGACY_PRECISION` controls the matter-mixing prefactor used by `solar_probability_state` and `solar_probability_mass`; it affects numerical compatibility with legacy constants, not the benchmark structure.
#
# **Expected results:**<br>
# - TPeanuts should evaluate the full energy grid in one tensor call, while legacy solar probabilities are computed by scalar loops over energy.

# %% [markdown]
# ### 4.1 Probability Timing
#
# The benchmark compares `solar_probability_state` against legacy `Psolar` over increasing energy-grid sizes.
#
# **Expected results:**<br>
# - Timing should increase with grid size, and vectorized TPeanuts evaluation should reduce Python-loop overhead.

# %%
solar_probability_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=True)
    solar_probability_records.append(benchmark_pair(
        "solar probabilities", ne, None,
        lambda E=E: solar_probability_state(oscillation, E, solar_medium, solar_source, SOLAR_SOURCE,
                            legacy_precision=SOLAR_LEGACY_PRECISION),
        lambda E=E: np.stack([
            legacy_solar_module.Psolar(legacy_pmns_solar, DM21_EV2, DM3L_EV2, float(e),
                                       legacy_model.radius(), legacy_model.density(),
                                       legacy_model.fraction(SOLAR_SOURCE))
            for e in to_numpy(E)
        ]),
    ))
solar_probability_df = pd.DataFrame(solar_probability_records)
display(solar_probability_df)
save_results(solar_probability_df, "solar_probability_timing")
plot_energy_scaling(solar_probability_df, "Solar probability timing", "solar_probability_timing.png")
# Out:
# solar probabilities                | NE=   4 | Neta=None | t=3.1261e-03s+/-4.1e-04 | leg=6.3860e-04s | x0.20
# solar probabilities                | NE=   8 | Neta=None | t=3.6492e-03s+/-2.0e-04 | leg=1.0848e-03s | x0.30
# solar probabilities                | NE=  16 | Neta=None | t=3.8910e-03s+/-3.1e-04 | leg=1.9679e-03s | x0.51
# solar probabilities                | NE=  32 | Neta=None | t=5.4894e-03s+/-7.8e-04 | leg=4.0295e-03s | x0.73
# solar probabilities                | NE=  64 | Neta=None | t=7.4671e-03s+/-1.3e-03 | leg=7.5136e-03s | x1.01
# solar probabilities                | NE= 128 | Neta=None | t=1.0755e-02s+/-8.0e-04 | leg=1.5139e-02s | x1.41
# solar probabilities                | NE= 256 | Neta=None | t=2.3745e-02s+/-1.8e-03 | leg=2.9368e-02s | x1.24
# solar probabilities                | NE= 512 | Neta=None | t=5.9955e-02s+/-2.6e-03 | leg=5.9742e-02s | x1.00
# solar probabilities                | NE=1024 | Neta=None | t=1.3937e-01s+/-3.6e-03 | leg=1.1762e-01s | x0.84
#                section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  solar probabilities         4    None         0.003126       0.000639
# 1  solar probabilities         8    None         0.003649       0.001085
# 2  solar probabilities        16    None         0.003891       0.001968
# 3  solar probabilities        32    None         0.005489       0.004029
# 4  solar probabilities        64    None         0.007467       0.007514
# 5  solar probabilities       128    None         0.010755       0.015139
# 6  solar probabilities       256    None         0.023745       0.029368
# 7  solar probabilities       512    None         0.059955       0.059742
# 8  solar probabilities      1024    None         0.139375       0.117621
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.003509       0.000665        0.000406      0.000026
# 1         0.004042       0.001114        0.000198      0.000043
# 2         0.004374       0.002104        0.000305      0.000116
# 3         0.006183       0.004716        0.000776      0.001198
# 4         0.009004       0.007882        0.001342      0.000344
# 5         0.011411       0.015411        0.000798      0.000301
# 6         0.026376       0.030016        0.001772      0.000689
# 7         0.063640       0.061080        0.002559      0.001755
# 8         0.144641       0.119461        0.003578      0.001225
#
#    speedup_legacy_over_tpeanuts
# 0                      0.204280
# 1                      0.297271
# 2                      0.505757
# 3                      0.734051
# 4                      1.006227
# 5                      1.407660
# 6                      1.236786
# 7                      0.996437
# 8                      0.843919
# Saved: v:\output\benchmark\solar_probability_timing.csv
# v:\output\benchmark\solar_probability_timing.png

# %% [markdown]
# ### 4.2 Flux Timing
#
# This benchmark applies a simple source-spectrum weight to the solar mass-basis probabilities.
#
# **Expected results:**<br>
# - Timing should be close to the solar mass-probability timing because the spectrum multiplication is inexpensive.

# %%
solar_flux_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=True)
    spectrum_t = solar_source_spectrum(E)
    spectrum_l = to_numpy(spectrum_t)
    solar_flux_records.append(benchmark_pair(
        "solar flux", ne, None,
        lambda E=E, st=spectrum_t: tpeanuts_solar_mass(E) * st[:, None],
        lambda E=E, sl=spectrum_l: legacy_solar_mass(E) * sl[:, None],
    ))
solar_flux_df = pd.DataFrame(solar_flux_records)
display(solar_flux_df)
save_results(solar_flux_df, "solar_flux_timing")
plot_energy_scaling(solar_flux_df, "Solar flux timing", "solar_flux_timing.png")
# Out:
# solar flux                         | NE=   4 | Neta=None | t=2.4363e-03s+/-2.3e-04 | leg=5.9820e-04s | x0.25
# solar flux                         | NE=   8 | Neta=None | t=2.9295e-03s+/-2.7e-04 | leg=9.9690e-04s | x0.34
# solar flux                         | NE=  16 | Neta=None | t=3.4512e-03s+/-3.7e-04 | leg=1.8816e-03s | x0.55
# solar flux                         | NE=  32 | Neta=None | t=4.5940e-03s+/-1.7e-04 | leg=3.4215e-03s | x0.74
# solar flux                         | NE=  64 | Neta=None | t=7.0804e-03s+/-7.6e-03 | leg=6.9960e-03s | x0.99
# solar flux                         | NE= 128 | Neta=None | t=1.0422e-02s+/-3.5e-04 | leg=1.3602e-02s | x1.31
# solar flux                         | NE= 256 | Neta=None | t=2.2588e-02s+/-1.2e-03 | leg=2.7043e-02s | x1.20
# solar flux                         | NE= 512 | Neta=None | t=6.2467e-02s+/-3.9e-03 | leg=5.4532e-02s | x0.87
# solar flux                         | NE=1024 | Neta=None | t=1.3777e-01s+/-3.0e-03 | leg=1.1031e-01s | x0.80
#       section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  solar flux         4    None         0.002436       0.000598
# 1  solar flux         8    None         0.002929       0.000997
# 2  solar flux        16    None         0.003451       0.001882
# 3  solar flux        32    None         0.004594       0.003422
# 4  solar flux        64    None         0.007080       0.006996
# 5  solar flux       128    None         0.010422       0.013602
# 6  solar flux       256    None         0.022588       0.027043
# 7  solar flux       512    None         0.062467       0.054532
# 8  solar flux      1024    None         0.137766       0.110314
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.002727       0.000670        0.000232      0.000092
# 1         0.003250       0.001070        0.000271      0.000059
# 2         0.003830       0.002024        0.000370      0.000078
# 3         0.004805       0.003690        0.000172      0.000161
# 4         0.011283       0.007270        0.007582      0.000262
# 5         0.010918       0.014198        0.000346      0.000606
# 6         0.024354       0.027554        0.001230      0.000678
# 7         0.065868       0.055729        0.003852      0.000913
# 8         0.141148       0.112303        0.002974      0.001966
#
#    speedup_legacy_over_tpeanuts
# 0                      0.245536
# 1                      0.340297
# 2                      0.545202
# 3                      0.744776
# 4                      0.988080
# 5                      1.305138
# 6                      1.197230
# 7                      0.872973
# 8                      0.800730
# Saved: v:\output\benchmark\solar_flux_timing.csv
# v:\output\benchmark\solar_flux_timing.png

# %% [markdown]
# ## 5. Earth Propagation
#
# This section benchmarks Earth matter propagation over two-dimensional energy-nadir grids. Analytical TPeanuts propagation is batched over the grid, while the legacy reference loops over scalar `Pearth` calls.
#
# **Expected results:**<br>
# - Speedup should generally grow with the two-dimensional grid size, especially for analytical Earth propagation.

# %% [markdown]
# ### 5.1 Probability Timing
#
# The initial state is an incoherent mass-basis weight vector propagated through the Earth density profile.
#
# **Expected results:**<br>
# - The heatmap should show how speedup depends jointly on energy and nadir grid sizes.

# %%
earth_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        earth_probability_records.append(benchmark_pair(
            "earth probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: torch_pearth_probability(
                MASS_WEIGHTS, E[:, None], eta[None, :], EARTH_DEPTH_M, massbasis=True),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d): np.stack([
                legacy_pearth(MASS_WEIGHTS_NP, earth_density_l, legacy_pmns,
                              DM21_EV2, DM3L_EV2, float(e), float(a),
                              EARTH_DEPTH_M, mode=LEGACY_EARTH_MODE, massbasis=True)
                for e in E_np for a in eta_np
            ]).reshape(len(E_np), len(eta_np), 3),
        ))
earth_probability_df = pd.DataFrame(earth_probability_records)
display(earth_probability_df)
save_results(earth_probability_df, "earth_probability_timing")
plot_heatmap(earth_probability_df, "Earth probability speedup (LogNorm)",
              "earth_probability_speedup.png")
plot_speedup_cross_sections(earth_probability_df, "Earth probability speedup cross sections",
                              "earth_probability_speedup_cross_sections.png")
# Out:
# earth probabilities                | NE=   4 | Neta=   4 | t=1.3433e-02s+/-1.9e-03 | leg=8.5350e-04s | x0.06
# earth probabilities                | NE=   4 | Neta=   8 | t=1.3756e-02s+/-2.6e-03 | leg=1.4804e-03s | x0.11
# earth probabilities                | NE=   4 | Neta=  16 | t=1.4943e-02s+/-7.2e-04 | leg=2.5720e-03s | x0.17
# earth probabilities                | NE=   4 | Neta=  32 | t=1.8896e-02s+/-2.1e-03 | leg=4.9104e-03s | x0.26
# earth probabilities                | NE=   4 | Neta=  64 | t=2.1964e-02s+/-1.8e-03 | leg=9.1832e-03s | x0.42
# earth probabilities                | NE=   4 | Neta= 128 | t=3.0349e-02s+/-2.5e-03 | leg=1.8596e-02s | x0.61
# earth probabilities                | NE=   4 | Neta= 256 | t=4.6324e-02s+/-5.0e-03 | leg=3.7818e-02s | x0.82
# earth probabilities                | NE=   4 | Neta= 512 | t=6.4100e-02s+/-2.2e-03 | leg=7.4827e-02s | x1.17
# earth probabilities                | NE=   4 | Neta=1024 | t=1.0114e-01s+/-4.1e-03 | leg=1.4930e-01s | x1.48
# earth probabilities                | NE=   8 | Neta=   4 | t=1.3794e-02s+/-1.0e-03 | leg=1.5512e-03s | x0.11
# earth probabilities                | NE=   8 | Neta=   8 | t=1.4932e-02s+/-1.0e-03 | leg=2.5747e-03s | x0.17
# earth probabilities                | NE=   8 | Neta=  16 | t=1.7937e-02s+/-1.9e-03 | leg=4.9199e-03s | x0.27
# earth probabilities                | NE=   8 | Neta=  32 | t=2.1754e-02s+/-1.7e-03 | leg=9.6180e-03s | x0.44
# earth probabilities                | NE=   8 | Neta=  64 | t=3.0727e-02s+/-3.1e-03 | leg=1.8881e-02s | x0.61
# earth probabilities                | NE=   8 | Neta= 128 | t=4.9092e-02s+/-1.4e-03 | leg=3.7554e-02s | x0.76
# earth probabilities                | NE=   8 | Neta= 256 | t=6.6621e-02s+/-3.9e-03 | leg=7.5202e-02s | x1.13
# earth probabilities                | NE=   8 | Neta= 512 | t=1.0195e-01s+/-5.6e-03 | leg=1.5170e-01s | x1.49
# earth probabilities                | NE=   8 | Neta=1024 | t=1.7005e-01s+/-6.3e-03 | leg=2.9784e-01s | x1.75
# earth probabilities                | NE=  16 | Neta=   4 | t=1.4997e-02s+/-7.5e-04 | leg=2.9274e-03s | x0.20
# earth probabilities                | NE=  16 | Neta=   8 | t=1.7570e-02s+/-1.6e-03 | leg=5.4430e-03s | x0.31
# earth probabilities                | NE=  16 | Neta=  16 | t=2.1355e-02s+/-3.2e-03 | leg=9.6442e-03s | x0.45
# earth probabilities                | NE=  16 | Neta=  32 | t=2.8818e-02s+/-5.9e-04 | leg=1.8827e-02s | x0.65
# earth probabilities                | NE=  16 | Neta=  64 | t=4.5526e-02s+/-3.3e-03 | leg=3.8023e-02s | x0.84
# earth probabilities                | NE=  16 | Neta= 128 | t=6.5340e-02s+/-4.2e-03 | leg=7.6599e-02s | x1.17
# earth probabilities                | NE=  16 | Neta= 256 | t=1.0403e-01s+/-4.9e-03 | leg=1.5162e-01s | x1.46
# earth probabilities                | NE=  16 | Neta= 512 | t=1.7593e-01s+/-2.8e-03 | leg=3.0160e-01s | x1.71
# earth probabilities                | NE=  16 | Neta=1024 | t=3.4217e-01s+/-7.5e-03 | leg=6.1342e-01s | x1.79
# earth probabilities                | NE=  32 | Neta=   4 | t=1.7525e-02s+/-1.3e-03 | leg=5.9087e-03s | x0.34
# earth probabilities                | NE=  32 | Neta=   8 | t=2.2397e-02s+/-2.0e-03 | leg=1.0114e-02s | x0.45
# earth probabilities                | NE=  32 | Neta=  16 | t=2.9598e-02s+/-2.5e-03 | leg=1.9419e-02s | x0.66
# earth probabilities                | NE=  32 | Neta=  32 | t=4.5931e-02s+/-2.4e-03 | leg=3.8192e-02s | x0.83
# earth probabilities                | NE=  32 | Neta=  64 | t=6.4007e-02s+/-3.2e-03 | leg=7.6572e-02s | x1.20
# earth probabilities                | NE=  32 | Neta= 128 | t=1.0224e-01s+/-5.2e-03 | leg=1.5199e-01s | x1.49
# earth probabilities                | NE=  32 | Neta= 256 | t=1.7048e-01s+/-6.2e-03 | leg=3.0423e-01s | x1.78
# earth probabilities                | NE=  32 | Neta= 512 | t=3.6760e-01s+/-9.3e-03 | leg=6.1803e-01s | x1.68
# earth probabilities                | NE=  32 | Neta=1024 | t=7.1408e-01s+/-1.8e-02 | leg=1.2136e+00s | x1.70
# earth probabilities                | NE=  64 | Neta=   4 | t=2.2086e-02s+/-2.6e-03 | leg=1.1659e-02s | x0.53
# earth probabilities                | NE=  64 | Neta=   8 | t=3.1387e-02s+/-2.0e-03 | leg=2.0063e-02s | x0.64
# earth probabilities                | NE=  64 | Neta=  16 | t=4.4070e-02s+/-2.4e-03 | leg=3.8973e-02s | x0.88
# earth probabilities                | NE=  64 | Neta=  32 | t=6.4339e-02s+/-3.0e-03 | leg=7.5817e-02s | x1.18
# earth probabilities                | NE=  64 | Neta=  64 | t=1.0394e-01s+/-5.3e-03 | leg=1.5088e-01s | x1.45
# earth probabilities                | NE=  64 | Neta= 128 | t=1.7217e-01s+/-4.2e-03 | leg=3.0569e-01s | x1.78
# earth probabilities                | NE=  64 | Neta= 256 | t=3.4529e-01s+/-1.2e-02 | leg=6.0905e-01s | x1.76
# earth probabilities                | NE=  64 | Neta= 512 | t=6.9517e-01s+/-1.2e-02 | leg=1.2157e+00s | x1.75
# earth probabilities                | NE=  64 | Neta=1024 | t=1.3890e+00s+/-9.2e-03 | leg=2.4401e+00s | x1.76
# earth probabilities                | NE= 128 | Neta=   4 | t=2.8783e-02s+/-4.0e-03 | leg=2.3424e-02s | x0.81
# earth probabilities                | NE= 128 | Neta=   8 | t=4.5934e-02s+/-5.4e-03 | leg=4.0368e-02s | x0.88
# earth probabilities                | NE= 128 | Neta=  16 | t=6.4661e-02s+/-4.3e-03 | leg=7.7810e-02s | x1.20
# earth probabilities                | NE= 128 | Neta=  32 | t=1.1005e-01s+/-5.2e-03 | leg=1.5384e-01s | x1.40
# earth probabilities                | NE= 128 | Neta=  64 | t=1.6863e-01s+/-3.5e-03 | leg=3.1950e-01s | x1.89
# earth probabilities                | NE= 128 | Neta= 128 | t=3.6533e-01s+/-4.4e-03 | leg=6.0304e-01s | x1.65
# earth probabilities                | NE= 128 | Neta= 256 | t=6.9506e-01s+/-9.7e-03 | leg=1.2136e+00s | x1.75
# earth probabilities                | NE= 128 | Neta= 512 | t=1.3990e+00s+/-1.2e-02 | leg=2.4257e+00s | x1.73
# earth probabilities                | NE= 128 | Neta=1024 | t=2.7805e+00s+/-2.1e-02 | leg=4.8659e+00s | x1.75
# earth probabilities                | NE= 256 | Neta=   4 | t=4.5846e-02s+/-1.4e-03 | leg=4.6788e-02s | x1.02
# earth probabilities                | NE= 256 | Neta=   8 | t=6.5949e-02s+/-2.9e-03 | leg=8.1773e-02s | x1.24
# earth probabilities                | NE= 256 | Neta=  16 | t=1.0569e-01s+/-3.6e-03 | leg=1.5573e-01s | x1.47
# earth probabilities                | NE= 256 | Neta=  32 | t=1.6944e-01s+/-6.9e-03 | leg=3.0441e-01s | x1.80
# earth probabilities                | NE= 256 | Neta=  64 | t=3.4571e-01s+/-7.0e-03 | leg=6.0403e-01s | x1.75
# earth probabilities                | NE= 256 | Neta= 128 | t=7.1634e-01s+/-8.4e-03 | leg=1.2252e+00s | x1.71
# earth probabilities                | NE= 256 | Neta= 256 | t=1.3943e+00s+/-1.5e-02 | leg=2.4504e+00s | x1.76
# earth probabilities                | NE= 256 | Neta= 512 | t=2.7648e+00s+/-2.9e-02 | leg=4.8747e+00s | x1.76
# earth probabilities                | NE= 256 | Neta=1024 | t=5.5626e+00s+/-7.1e-02 | leg=9.7182e+00s | x1.75
# earth probabilities                | NE= 512 | Neta=   4 | t=6.6011e-02s+/-2.5e-03 | leg=9.3162e-02s | x1.41
# earth probabilities                | NE= 512 | Neta=   8 | t=1.0467e-01s+/-6.2e-03 | leg=1.6393e-01s | x1.57
# earth probabilities                | NE= 512 | Neta=  16 | t=1.6723e-01s+/-3.7e-03 | leg=3.0586e-01s | x1.83
# earth probabilities                | NE= 512 | Neta=  32 | t=3.4831e-01s+/-5.1e-03 | leg=6.1385e-01s | x1.76
# earth probabilities                | NE= 512 | Neta=  64 | t=6.9550e-01s+/-1.1e-02 | leg=1.2096e+00s | x1.74
# earth probabilities                | NE= 512 | Neta= 128 | t=1.3900e+00s+/-1.8e-02 | leg=2.4411e+00s | x1.76
# earth probabilities                | NE= 512 | Neta= 256 | t=2.8104e+00s+/-2.0e-02 | leg=4.8808e+00s | x1.74
# earth probabilities                | NE= 512 | Neta= 512 | t=5.6051e+00s+/-4.3e-02 | leg=9.7320e+00s | x1.74
# earth probabilities                | NE= 512 | Neta=1024 | t=1.1296e+01s+/-4.3e-02 | leg=1.9484e+01s | x1.72
# earth probabilities                | NE=1024 | Neta=   4 | t=1.0408e-01s+/-2.5e-03 | leg=1.8770e-01s | x1.80
# earth probabilities                | NE=1024 | Neta=   8 | t=1.6928e-01s+/-4.8e-03 | leg=3.2634e-01s | x1.93
# earth probabilities                | NE=1024 | Neta=  16 | t=3.3954e-01s+/-7.7e-03 | leg=6.1940e-01s | x1.82
# earth probabilities                | NE=1024 | Neta=  32 | t=6.8060e-01s+/-1.4e-02 | leg=1.2251e+00s | x1.80
# earth probabilities                | NE=1024 | Neta=  64 | t=1.3983e+00s+/-1.5e-02 | leg=2.4316e+00s | x1.74
# earth probabilities                | NE=1024 | Neta= 128 | t=2.8199e+00s+/-3.4e-02 | leg=4.8873e+00s | x1.73
# earth probabilities                | NE=1024 | Neta= 256 | t=5.6227e+00s+/-2.6e-02 | leg=9.7890e+00s | x1.74
# earth probabilities                | NE=1024 | Neta= 512 | t=1.1287e+01s+/-5.0e-02 | leg=1.9481e+01s | x1.73
# earth probabilities                | NE=1024 | Neta=1024 | t=2.2605e+01s+/-1.2e-02 | leg=3.9085e+01s | x1.73
#                 section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   earth probabilities         4        4         0.013433       0.000853
# 1   earth probabilities         4        8         0.013756       0.001480
# 2   earth probabilities         4       16         0.014943       0.002572
# 3   earth probabilities         4       32         0.018896       0.004910
# 4   earth probabilities         4       64         0.021964       0.009183
# ..                  ...       ...      ...              ...            ...
# 76  earth probabilities      1024       64         1.398257       2.431558
# 77  earth probabilities      1024      128         2.819851       4.887333
# 78  earth probabilities      1024      256         5.622746       9.788960
# 79  earth probabilities      1024      512        11.287444      19.481440
# 80  earth probabilities      1024     1024        22.604749      39.085130
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.016191       0.000926        0.001925      0.000054
# 1          0.015796       0.001646        0.002569      0.000264
# 2          0.015808       0.003111        0.000720      0.000800
# 3          0.021023       0.005074        0.002088      0.000136
# 4          0.025143       0.009857        0.001801      0.000477
# ..              ...            ...             ...           ...
# 76         1.419075       2.458544        0.014535      0.033696
# 77         2.868236       4.905166        0.033749      0.016910
# 78         5.665177       9.830085        0.026104      0.032119
# 79        11.362912      19.536403        0.049990      0.038028
# 80        22.620188      39.231747        0.011886      0.118178
#
#     speedup_legacy_over_tpeanuts
# 0                       0.063539
# 1                       0.107619
# 2                       0.172116
# 3                       0.259865
# 4                       0.418104
# ..                           ...
# 76                      1.738992
# 77                      1.733188
# 78                      1.740957
# 79                      1.725939
# 80                      1.729067
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\earth_probability_timing.csv
# v:\output\benchmark\earth_probability_speedup.png
# v:\output\benchmark\earth_probability_speedup_cross_sections.png

# %% [markdown]
# ### 5.2 Flux Timing
#
# This benchmark constructs a mass-to-flavour probability matrix and applies it to a synthetic flux vector.
#
# **Expected results:**<br>
# the cost should be higher than a single probability-vector call because three basis states are propagated.

# %%
earth_flux_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        flux   = synthetic_flux(E_1d)
        earth_flux_records.append(benchmark_pair(
            "earth flux", ne, neta,
            lambda E=E_1d, eta=eta_1d, fl=flux: _tpeanuts_earth_flux(E, eta, fl),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d), fl=to_numpy(flux):
                _legacy_earth_flux(E_np, eta_np, fl),
        ))
earth_flux_df = pd.DataFrame(earth_flux_records)
display(earth_flux_df)
save_results(earth_flux_df, "earth_flux_timing")
plot_heatmap(earth_flux_df, "Earth flux speedup (LogNorm)", "earth_flux_speedup.png")
plot_speedup_cross_sections(earth_flux_df, "Earth flux speedup cross sections",
                              "earth_flux_speedup_cross_sections.png")
# Out:
# earth flux                         | NE=   4 | Neta=   4 | t=1.3152e-02s+/-3.5e-03 | leg=2.5579e-03s | x0.19
# earth flux                         | NE=   4 | Neta=   8 | t=1.3535e-02s+/-1.5e-03 | leg=4.3435e-03s | x0.32
# earth flux                         | NE=   4 | Neta=  16 | t=1.4955e-02s+/-6.2e-04 | leg=8.0202e-03s | x0.54
# earth flux                         | NE=   4 | Neta=  32 | t=1.7300e-02s+/-2.3e-03 | leg=1.6148e-02s | x0.93
# earth flux                         | NE=   4 | Neta=  64 | t=2.1698e-02s+/-2.7e-03 | leg=3.2980e-02s | x1.52
# earth flux                         | NE=   4 | Neta= 128 | t=2.8639e-02s+/-4.3e-03 | leg=6.6057e-02s | x2.31
# earth flux                         | NE=   4 | Neta= 256 | t=4.8571e-02s+/-2.9e-03 | leg=1.3339e-01s | x2.75
# earth flux                         | NE=   4 | Neta= 512 | t=7.0989e-02s+/-1.6e-03 | leg=2.6320e-01s | x3.71
# earth flux                         | NE=   4 | Neta=1024 | t=1.0729e-01s+/-5.4e-03 | leg=5.3164e-01s | x4.95
# earth flux                         | NE=   8 | Neta=   4 | t=1.3800e-02s+/-1.3e-03 | leg=5.1087e-03s | x0.37
# earth flux                         | NE=   8 | Neta=   8 | t=1.4876e-02s+/-1.9e-03 | leg=8.6602e-03s | x0.58
# earth flux                         | NE=   8 | Neta=  16 | t=1.7435e-02s+/-1.2e-03 | leg=1.6525e-02s | x0.95
# earth flux                         | NE=   8 | Neta=  32 | t=2.1596e-02s+/-9.8e-04 | leg=3.2540e-02s | x1.51
# earth flux                         | NE=   8 | Neta=  64 | t=2.9363e-02s+/-2.4e-03 | leg=6.4537e-02s | x2.20
# earth flux                         | NE=   8 | Neta= 128 | t=4.4233e-02s+/-1.5e-03 | leg=1.2951e-01s | x2.93
# earth flux                         | NE=   8 | Neta= 256 | t=6.1822e-02s+/-3.8e-03 | leg=2.5929e-01s | x4.19
# earth flux                         | NE=   8 | Neta= 512 | t=1.0640e-01s+/-5.2e-03 | leg=5.1724e-01s | x4.86
# earth flux                         | NE=   8 | Neta=1024 | t=1.7251e-01s+/-4.8e-03 | leg=1.0434e+00s | x6.05
# earth flux                         | NE=  16 | Neta=   4 | t=1.4922e-02s+/-1.6e-03 | leg=9.7715e-03s | x0.65
# earth flux                         | NE=  16 | Neta=   8 | t=1.7620e-02s+/-1.0e-03 | leg=1.7377e-02s | x0.99
# earth flux                         | NE=  16 | Neta=  16 | t=2.1741e-02s+/-1.9e-03 | leg=3.2720e-02s | x1.50
# earth flux                         | NE=  16 | Neta=  32 | t=2.9518e-02s+/-2.0e-03 | leg=6.4180e-02s | x2.17
# earth flux                         | NE=  16 | Neta=  64 | t=4.4238e-02s+/-2.9e-03 | leg=1.2986e-01s | x2.94
# earth flux                         | NE=  16 | Neta= 128 | t=6.4800e-02s+/-1.7e-03 | leg=2.5889e-01s | x4.00
# earth flux                         | NE=  16 | Neta= 256 | t=1.0255e-01s+/-6.0e-03 | leg=5.1745e-01s | x5.05
# earth flux                         | NE=  16 | Neta= 512 | t=1.6850e-01s+/-3.7e-03 | leg=1.0365e+00s | x6.15
# earth flux                         | NE=  16 | Neta=1024 | t=3.4027e-01s+/-6.8e-03 | leg=2.0762e+00s | x6.10
# earth flux                         | NE=  32 | Neta=   4 | t=1.7570e-02s+/-2.7e-03 | leg=1.9650e-02s | x1.12
# earth flux                         | NE=  32 | Neta=   8 | t=2.2466e-02s+/-2.7e-03 | leg=3.4135e-02s | x1.52
# earth flux                         | NE=  32 | Neta=  16 | t=2.9298e-02s+/-2.7e-03 | leg=6.6529e-02s | x2.27
# earth flux                         | NE=  32 | Neta=  32 | t=4.3903e-02s+/-3.8e-03 | leg=1.3043e-01s | x2.97
# earth flux                         | NE=  32 | Neta=  64 | t=6.6615e-02s+/-4.6e-03 | leg=2.5803e-01s | x3.87
# earth flux                         | NE=  32 | Neta= 128 | t=1.0988e-01s+/-2.6e-03 | leg=5.2202e-01s | x4.75
# earth flux                         | NE=  32 | Neta= 256 | t=1.7612e-01s+/-3.9e-03 | leg=1.0315e+00s | x5.86
# earth flux                         | NE=  32 | Neta= 512 | t=3.4426e-01s+/-7.4e-03 | leg=2.0671e+00s | x6.00
# earth flux                         | NE=  32 | Neta=1024 | t=7.0676e-01s+/-6.7e-03 | leg=4.1375e+00s | x5.85
# earth flux                         | NE=  64 | Neta=   4 | t=2.2343e-02s+/-8.4e-04 | leg=3.9233e-02s | x1.76
# earth flux                         | NE=  64 | Neta=   8 | t=2.9372e-02s+/-2.6e-03 | leg=6.9546e-02s | x2.37
# earth flux                         | NE=  64 | Neta=  16 | t=4.4715e-02s+/-2.0e-03 | leg=1.3154e-01s | x2.94
# earth flux                         | NE=  64 | Neta=  32 | t=6.2898e-02s+/-4.0e-03 | leg=2.5895e-01s | x4.12
# earth flux                         | NE=  64 | Neta=  64 | t=1.0515e-01s+/-3.2e-03 | leg=5.1897e-01s | x4.94
# earth flux                         | NE=  64 | Neta= 128 | t=1.6229e-01s+/-8.6e-03 | leg=1.0398e+00s | x6.41
# earth flux                         | NE=  64 | Neta= 256 | t=3.4038e-01s+/-7.3e-03 | leg=2.0751e+00s | x6.10
# earth flux                         | NE=  64 | Neta= 512 | t=7.0012e-01s+/-1.6e-02 | leg=4.1175e+00s | x5.88
# earth flux                         | NE=  64 | Neta=1024 | t=1.4085e+00s+/-2.0e-02 | leg=8.2611e+00s | x5.86
# earth flux                         | NE= 128 | Neta=   4 | t=2.9953e-02s+/-3.1e-03 | leg=7.7652e-02s | x2.59
# earth flux                         | NE= 128 | Neta=   8 | t=4.4491e-02s+/-1.9e-03 | leg=1.3718e-01s | x3.08
# earth flux                         | NE= 128 | Neta=  16 | t=6.2042e-02s+/-4.8e-03 | leg=2.6161e-01s | x4.22
# earth flux                         | NE= 128 | Neta=  32 | t=1.0659e-01s+/-1.5e-03 | leg=5.1657e-01s | x4.85
# earth flux                         | NE= 128 | Neta=  64 | t=1.7028e-01s+/-5.0e-03 | leg=1.0347e+00s | x6.08
# earth flux                         | NE= 128 | Neta= 128 | t=3.4203e-01s+/-6.1e-03 | leg=2.0676e+00s | x6.05
# earth flux                         | NE= 128 | Neta= 256 | t=6.9256e-01s+/-8.6e-03 | leg=4.1324e+00s | x5.97
# earth flux                         | NE= 128 | Neta= 512 | t=1.4030e+00s+/-1.7e-02 | leg=8.2793e+00s | x5.90
# earth flux                         | NE= 128 | Neta=1024 | t=2.7914e+00s+/-2.9e-02 | leg=1.6610e+01s | x5.95
# earth flux                         | NE= 256 | Neta=   4 | t=4.5402e-02s+/-2.4e-03 | leg=1.5676e-01s | x3.45
# earth flux                         | NE= 256 | Neta=   8 | t=6.3211e-02s+/-1.8e-02 | leg=2.7427e-01s | x4.34
# earth flux                         | NE= 256 | Neta=  16 | t=1.0372e-01s+/-4.2e-03 | leg=5.3113e-01s | x5.12
# earth flux                         | NE= 256 | Neta=  32 | t=1.6949e-01s+/-4.8e-03 | leg=1.0377e+00s | x6.12
# earth flux                         | NE= 256 | Neta=  64 | t=3.4581e-01s+/-8.8e-03 | leg=2.0623e+00s | x5.96
# earth flux                         | NE= 256 | Neta= 128 | t=6.9846e-01s+/-6.6e-03 | leg=4.1521e+00s | x5.94
# earth flux                         | NE= 256 | Neta= 256 | t=1.4008e+00s+/-1.6e-02 | leg=8.2676e+00s | x5.90
# earth flux                         | NE= 256 | Neta= 512 | t=2.7819e+00s+/-3.6e-02 | leg=1.6580e+01s | x5.96
# earth flux                         | NE= 256 | Neta=1024 | t=5.6334e+00s+/-3.0e-02 | leg=3.3148e+01s | x5.88
# earth flux                         | NE= 512 | Neta=   4 | t=6.9279e-02s+/-4.2e-03 | leg=3.3011e-01s | x4.76
# earth flux                         | NE= 512 | Neta=   8 | t=1.1626e-01s+/-2.9e-03 | leg=5.5493e-01s | x4.77
# earth flux                         | NE= 512 | Neta=  16 | t=1.6860e-01s+/-5.3e-03 | leg=1.0531e+00s | x6.25
# earth flux                         | NE= 512 | Neta=  32 | t=3.4168e-01s+/-5.4e-03 | leg=2.0935e+00s | x6.13
# earth flux                         | NE= 512 | Neta=  64 | t=7.0514e-01s+/-6.2e-03 | leg=4.1311e+00s | x5.86
# earth flux                         | NE= 512 | Neta= 128 | t=1.4134e+00s+/-1.5e-02 | leg=8.3529e+00s | x5.91
# earth flux                         | NE= 512 | Neta= 256 | t=2.7754e+00s+/-2.4e-02 | leg=1.6617e+01s | x5.99
# earth flux                         | NE= 512 | Neta= 512 | t=5.6167e+00s+/-4.1e-02 | leg=3.3287e+01s | x5.93
# earth flux                         | NE= 512 | Neta=1024 | t=1.1332e+01s+/-2.7e+00 | leg=6.4404e+01s | x5.68
# earth flux                         | NE=1024 | Neta=   4 | t=1.0682e-01s+/-3.5e-03 | leg=6.1018e-01s | x5.71
# earth flux                         | NE=1024 | Neta=   8 | t=1.7194e-01s+/-4.7e-03 | leg=1.0732e+00s | x6.24
# earth flux                         | NE=1024 | Neta=  16 | t=3.4314e-01s+/-4.7e-03 | leg=2.0380e+00s | x5.94
# earth flux                         | NE=1024 | Neta=  32 | t=6.9360e-01s+/-6.3e-03 | leg=4.0309e+00s | x5.81
# earth flux                         | NE=1024 | Neta=  64 | t=1.4074e+00s+/-5.6e-03 | leg=8.0704e+00s | x5.73
# earth flux                         | NE=1024 | Neta= 128 | t=2.8031e+00s+/-2.6e-02 | leg=1.6166e+01s | x5.77
# earth flux                         | NE=1024 | Neta= 256 | t=5.6819e+00s+/-2.0e-02 | leg=3.2320e+01s | x5.69
# earth flux                         | NE=1024 | Neta= 512 | t=1.1324e+01s+/-2.2e-02 | leg=6.4688e+01s | x5.71
# earth flux                         | NE=1024 | Neta=1024 | t=2.2576e+01s+/-1.0e-01 | leg=1.2895e+02s | x5.71
#        section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   earth flux         4        4         0.013152       0.002558
# 1   earth flux         4        8         0.013535       0.004343
# 2   earth flux         4       16         0.014955       0.008020
# 3   earth flux         4       32         0.017300       0.016148
# 4   earth flux         4       64         0.021698       0.032980
# ..         ...       ...      ...              ...            ...
# 76  earth flux      1024       64         1.407436       8.070424
# 77  earth flux      1024      128         2.803077      16.166467
# 78  earth flux      1024      256         5.681929      32.319512
# 79  earth flux      1024      512        11.323545      64.688447
# 80  earth flux      1024     1024        22.576038     128.951133
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.015737       0.002622        0.003460      0.000103
# 1          0.014763       0.004546        0.001456      0.000153
# 2          0.015793       0.008620        0.000619      0.000430
# 3          0.019003       0.017402        0.002272      0.001633
# 4          0.024238       0.033130        0.002677      0.000134
# ..              ...            ...             ...           ...
# 76         1.417607       8.081558        0.005556      0.010531
# 77         2.838846      16.197732        0.025683      0.015794
# 78         5.705593      32.432832        0.019709      0.129932
# 79        11.350628      64.875205        0.021653      0.120816
# 80        22.730270     129.523513        0.100505      0.540862
#
#     speedup_legacy_over_tpeanuts
# 0                       0.194482
# 1                       0.320918
# 2                       0.536292
# 3                       0.933388
# 4                       1.519974
# ..                           ...
# 76                      5.734132
# 77                      5.767401
# 78                      5.688124
# 79                      5.712738
# 80                      5.711858
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\earth_flux_timing.csv
# v:\output\benchmark\earth_flux_speedup.png
# v:\output\benchmark\earth_flux_speedup_cross_sections.png

# %% [markdown]
# ### 5.3 Analytical vs Numerical Earth Method
#
# This diagnostic compares the perturbative analytical Earth method with the numerical thin-segment method inside TPeanuts.
#
# **Expected results:**<br>
# - Analytical propagation should usually be faster than numerical propagation for the configured grid sizes, with the speedup depending on `EARTH_NUMERICAL_STEPS`.

# %%
earth_method_records = []
for ne in EARTH_METHOD_COMPARISON_ENERGY_SIZES:
    for neta in EARTH_METHOD_COMPARISON_NADIR_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        t_ana, _, _ = timed_call(lambda E=E_1d, eta=eta_1d: _tpeanuts_pearth_analytical(E, eta))
        t_num, _, _ = timed_call(lambda E=E_1d, eta=eta_1d: _tpeanuts_pearth_numerical(E, eta))
        earth_method_records.append({
            "n_energy": ne, "n_nadir": neta,
            "analytical_s": t_ana, "numerical_s": t_num,
            "speedup_ana_over_num": t_num / max(t_ana, 1e-15),
        })
earth_method_df = pd.DataFrame(earth_method_records)
display(earth_method_df)
save_results(earth_method_df, "earth_method_comparison")

pivot = earth_method_df.pivot(index="n_nadir", columns="n_energy", values="speedup_ana_over_num")
fig, ax = plt.subplots(figsize=(6, 4))
im = ax.imshow(pivot.values, origin="lower", aspect="auto",
               norm=mcolors.LogNorm(vmin=0.1, vmax=max(pivot.values.max(), 1.1)), cmap="RdYlGn")
ax.set_xticks(np.arange(len(pivot.columns))); ax.set_xticklabels(pivot.columns)
ax.set_yticks(np.arange(len(pivot.index)));   ax.set_yticklabels(pivot.index)
for r in range(pivot.values.shape[0]):
    for c in range(pivot.values.shape[1]):
        ax.text(c, r, f"{pivot.values[r,c]:.1f}x", ha="center", va="center", fontsize=8)
ax.set_xlabel("Energy-grid size"); ax.set_ylabel("Nadir-grid size")
ax.set_title("Speedup: analytical / numerical Earth (>1 = analytical faster)")
fig.colorbar(im, ax=ax, label="Speedup (log)")
fig.tight_layout()
save_and_show("earth_method_comparison.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
#    n_energy  n_nadir  analytical_s  numerical_s  speedup_ana_over_num
# 0        16       16      0.022429     1.202920             53.632586
# 1        16       64      0.045348     4.746484            104.668680
# 2        16      256      0.104276    19.217528            184.295535
# 3        64       16      0.044216     4.787902            108.284631
# 4        64       64      0.103401    19.254883            186.216358
# 5        64      256      0.341125    77.203523            226.320397
# 6       256       16      0.108993    19.162014            175.809098
# 7       256       64      0.345023    76.978518            223.111524
# 8       256      256      1.391979   303.147238            217.781442
# Saved: v:\output\benchmark\earth_method_comparison.csv
# v:\output\benchmark\earth_method_comparison.png

# %% [markdown]
# ## 6. Integrated Probabilities
#
# This section benchmarks a simple nadir-averaged probability, using a uniform exposure weight over the configured nadir grid. It is a timing proxy for exposure-integrated observables.
#
# **Expected results:**<br>
#  - Timings should combine the Earth grid propagation cost with a small integration overhead.

# %%
integrated_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        integrated_probability_records.append(benchmark_pair(
            "integrated probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_integrated(E, eta, EARTH_DEPTH_M),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_integrated(E_np, eta_np, EARTH_DEPTH_M),
        ))
integrated_probability_df = pd.DataFrame(integrated_probability_records)
display(integrated_probability_df)
save_results(integrated_probability_df, "integrated_probability_timing")
plot_heatmap(integrated_probability_df, "Integrated probability speedup (LogNorm)",
              "integrated_probability_speedup.png")
plot_speedup_cross_sections(integrated_probability_df, "Integrated probability speedup cross sections",
                              "integrated_probability_speedup_cross_sections.png")
# Out:
# integrated probabilities           | NE=   4 | Neta=   4 | t=1.5472e-02s+/-6.8e-04 | leg=1.9448e-03s | x0.13
# integrated probabilities           | NE=   4 | Neta=   8 | t=1.6088e-02s+/-1.5e-03 | leg=2.6665e-03s | x0.17
# integrated probabilities           | NE=   4 | Neta=  16 | t=1.7295e-02s+/-2.0e-04 | leg=4.2260e-03s | x0.24
# integrated probabilities           | NE=   4 | Neta=  32 | t=1.9612e-02s+/-5.0e-04 | leg=7.7846e-03s | x0.40
# integrated probabilities           | NE=   4 | Neta=  64 | t=2.3636e-02s+/-2.7e-03 | leg=1.4023e-02s | x0.59
# integrated probabilities           | NE=   4 | Neta= 128 | t=3.2009e-02s+/-1.2e-03 | leg=2.7826e-02s | x0.87
# integrated probabilities           | NE=   4 | Neta= 256 | t=4.7337e-02s+/-2.5e-03 | leg=5.3861e-02s | x1.14
# integrated probabilities           | NE=   4 | Neta= 512 | t=6.6183e-02s+/-3.0e-03 | leg=1.0359e-01s | x1.57
# integrated probabilities           | NE=   4 | Neta=1024 | t=1.0975e-01s+/-4.4e-03 | leg=2.1166e-01s | x1.93
# integrated probabilities           | NE=   8 | Neta=   4 | t=1.6426e-02s+/-1.6e-03 | leg=3.8102e-03s | x0.23
# integrated probabilities           | NE=   8 | Neta=   8 | t=1.8318e-02s+/-2.4e-04 | leg=5.0350e-03s | x0.27
# integrated probabilities           | NE=   8 | Neta=  16 | t=1.9978e-02s+/-9.7e-04 | leg=8.6578e-03s | x0.43
# integrated probabilities           | NE=   8 | Neta=  32 | t=2.4082e-02s+/-2.5e-03 | leg=1.5125e-02s | x0.63
# integrated probabilities           | NE=   8 | Neta=  64 | t=3.1321e-02s+/-3.0e-03 | leg=2.8201e-02s | x0.90
# integrated probabilities           | NE=   8 | Neta= 128 | t=4.6179e-02s+/-1.2e-03 | leg=5.5007e-02s | x1.19
# integrated probabilities           | NE=   8 | Neta= 256 | t=6.5093e-02s+/-2.1e-03 | leg=1.0393e-01s | x1.60
# integrated probabilities           | NE=   8 | Neta= 512 | t=1.0931e-01s+/-2.8e-03 | leg=2.1287e-01s | x1.95
# integrated probabilities           | NE=   8 | Neta=1024 | t=1.6705e-01s+/-6.0e-03 | leg=4.2289e-01s | x2.53
# integrated probabilities           | NE=  16 | Neta=   4 | t=1.8473e-02s+/-1.1e-03 | leg=7.1316e-03s | x0.39
# integrated probabilities           | NE=  16 | Neta=   8 | t=2.1360e-02s+/-9.7e-04 | leg=9.9881e-03s | x0.47
# integrated probabilities           | NE=  16 | Neta=  16 | t=2.4595e-02s+/-1.5e-03 | leg=1.6681e-02s | x0.68
# integrated probabilities           | NE=  16 | Neta=  32 | t=3.2500e-02s+/-6.5e-04 | leg=2.8950e-02s | x0.89
# integrated probabilities           | NE=  16 | Neta=  64 | t=4.8188e-02s+/-2.6e-03 | leg=5.5197e-02s | x1.15
# integrated probabilities           | NE=  16 | Neta= 128 | t=6.7127e-02s+/-2.4e-03 | leg=1.0972e-01s | x1.63
# integrated probabilities           | NE=  16 | Neta= 256 | t=1.0551e-01s+/-4.6e-03 | leg=2.1585e-01s | x2.05
# integrated probabilities           | NE=  16 | Neta= 512 | t=1.7195e-01s+/-4.5e-03 | leg=4.2119e-01s | x2.45
# integrated probabilities           | NE=  16 | Neta=1024 | t=3.3272e-01s+/-1.1e-02 | leg=8.5041e-01s | x2.56
# integrated probabilities           | NE=  32 | Neta=   4 | t=2.2040e-02s+/-2.3e-04 | leg=1.3874e-02s | x0.63
# integrated probabilities           | NE=  32 | Neta=   8 | t=2.5899e-02s+/-2.2e-03 | leg=1.9798e-02s | x0.76
# integrated probabilities           | NE=  32 | Neta=  16 | t=3.3583e-02s+/-1.3e-03 | leg=3.3002e-02s | x0.98
# integrated probabilities           | NE=  32 | Neta=  32 | t=5.0675e-02s+/-1.7e-03 | leg=5.9306e-02s | x1.17
# integrated probabilities           | NE=  32 | Neta=  64 | t=6.8435e-02s+/-2.3e-03 | leg=1.1009e-01s | x1.61
# integrated probabilities           | NE=  32 | Neta= 128 | t=1.0985e-01s+/-3.5e-03 | leg=2.1963e-01s | x2.00
# integrated probabilities           | NE=  32 | Neta= 256 | t=1.7381e-01s+/-4.9e-03 | leg=4.3057e-01s | x2.48
# integrated probabilities           | NE=  32 | Neta= 512 | t=3.4795e-01s+/-4.0e-03 | leg=8.3146e-01s | x2.39
# integrated probabilities           | NE=  32 | Neta=1024 | t=7.0527e-01s+/-3.0e-02 | leg=1.6988e+00s | x2.41
# integrated probabilities           | NE=  64 | Neta=   4 | t=2.8496e-02s+/-1.5e-03 | leg=2.7250e-02s | x0.96
# integrated probabilities           | NE=  64 | Neta=   8 | t=3.7895e-02s+/-1.4e-03 | leg=3.9795e-02s | x1.05
# integrated probabilities           | NE=  64 | Neta=  16 | t=5.1904e-02s+/-3.9e-03 | leg=6.5955e-02s | x1.27
# integrated probabilities           | NE=  64 | Neta=  32 | t=7.0499e-02s+/-4.0e-03 | leg=1.1549e-01s | x1.64
# integrated probabilities           | NE=  64 | Neta=  64 | t=1.1315e-01s+/-3.3e-03 | leg=2.2443e-01s | x1.98
# integrated probabilities           | NE=  64 | Neta= 128 | t=1.7956e-01s+/-4.3e-03 | leg=4.3914e-01s | x2.45
# integrated probabilities           | NE=  64 | Neta= 256 | t=3.5869e-01s+/-6.1e-03 | leg=8.7292e-01s | x2.43
# integrated probabilities           | NE=  64 | Neta= 512 | t=6.9405e-01s+/-1.1e-02 | leg=1.6874e+00s | x2.43
# integrated probabilities           | NE=  64 | Neta=1024 | t=1.3618e+00s+/-1.2e-02 | leg=3.3583e+00s | x2.47
# integrated probabilities           | NE= 128 | Neta=   4 | t=3.8655e-02s+/-3.7e-03 | leg=5.3640e-02s | x1.39
# integrated probabilities           | NE= 128 | Neta=   8 | t=5.6540e-02s+/-2.6e-03 | leg=7.9437e-02s | x1.40
# integrated probabilities           | NE= 128 | Neta=  16 | t=7.2090e-02s+/-5.3e-03 | leg=1.3263e-01s | x1.84
# integrated probabilities           | NE= 128 | Neta=  32 | t=1.1758e-01s+/-5.2e-03 | leg=2.2904e-01s | x1.95
# integrated probabilities           | NE= 128 | Neta=  64 | t=1.8030e-01s+/-7.0e-03 | leg=4.4624e-01s | x2.47
# integrated probabilities           | NE= 128 | Neta= 128 | t=3.4498e-01s+/-7.1e-03 | leg=8.6688e-01s | x2.51
# integrated probabilities           | NE= 128 | Neta= 256 | t=7.0235e-01s+/-3.6e-03 | leg=1.7068e+00s | x2.43
# integrated probabilities           | NE= 128 | Neta= 512 | t=1.3755e+00s+/-2.1e-02 | leg=3.3855e+00s | x2.46
# integrated probabilities           | NE= 128 | Neta=1024 | t=2.7798e+00s+/-1.4e-02 | leg=6.7679e+00s | x2.43
# integrated probabilities           | NE= 256 | Neta=   4 | t=6.7057e-02s+/-3.8e-03 | leg=1.0910e-01s | x1.63
# integrated probabilities           | NE= 256 | Neta=   8 | t=8.9265e-02s+/-3.4e-03 | leg=1.5828e-01s | x1.77
# integrated probabilities           | NE= 256 | Neta=  16 | t=1.3040e-01s+/-2.5e-03 | leg=2.6184e-01s | x2.01
# integrated probabilities           | NE= 256 | Neta=  32 | t=1.9970e-01s+/-6.2e-03 | leg=4.7405e-01s | x2.37
# integrated probabilities           | NE= 256 | Neta=  64 | t=3.4987e-01s+/-8.5e-03 | leg=9.2460e-01s | x2.64
# integrated probabilities           | NE= 256 | Neta= 128 | t=7.0741e-01s+/-1.5e-02 | leg=1.7477e+00s | x2.47
# integrated probabilities           | NE= 256 | Neta= 256 | t=1.3891e+00s+/-2.3e-02 | leg=3.4399e+00s | x2.48
# integrated probabilities           | NE= 256 | Neta= 512 | t=2.7394e+00s+/-2.8e-02 | leg=6.8064e+00s | x2.48
# integrated probabilities           | NE= 256 | Neta=1024 | t=5.5592e+00s+/-2.7e-02 | leg=1.3530e+01s | x2.43
# integrated probabilities           | NE= 512 | Neta=   4 | t=1.2522e-01s+/-3.1e-03 | leg=2.2071e-01s | x1.76
# integrated probabilities           | NE= 512 | Neta=   8 | t=1.6937e-01s+/-1.5e-03 | leg=3.1680e-01s | x1.87
# integrated probabilities           | NE= 512 | Neta=  16 | t=2.2583e-01s+/-7.6e-03 | leg=5.2708e-01s | x2.33
# integrated probabilities           | NE= 512 | Neta=  32 | t=4.1178e-01s+/-5.8e-03 | leg=9.2342e-01s | x2.24
# integrated probabilities           | NE= 512 | Neta=  64 | t=7.4091e-01s+/-9.9e-03 | leg=1.7824e+00s | x2.41
# integrated probabilities           | NE= 512 | Neta= 128 | t=1.4439e+00s+/-1.5e-02 | leg=3.4764e+00s | x2.41
# integrated probabilities           | NE= 512 | Neta= 256 | t=2.8112e+00s+/-3.2e-02 | leg=6.8582e+00s | x2.44
# integrated probabilities           | NE= 512 | Neta= 512 | t=5.5783e+00s+/-3.4e-02 | leg=9.6966e+00s | x1.74
# integrated probabilities           | NE= 512 | Neta=1024 | t=1.1161e+01s+/-1.7e-01 | leg=1.9301e+01s | x1.73
# integrated probabilities           | NE=1024 | Neta=   4 | t=2.3733e-01s+/-9.9e-03 | leg=3.6682e-01s | x1.55
# integrated probabilities           | NE=1024 | Neta=   8 | t=3.0738e-01s+/-3.5e-03 | leg=5.0371e-01s | x1.64
# integrated probabilities           | NE=1024 | Neta=  16 | t=4.8228e-01s+/-8.3e-03 | leg=8.0510e-01s | x1.67
# integrated probabilities           | NE=1024 | Neta=  32 | t=8.2283e-01s+/-4.6e-03 | leg=1.3929e+00s | x1.69
# integrated probabilities           | NE=1024 | Neta=  64 | t=1.5714e+00s+/-1.7e-01 | leg=2.9650e+00s | x1.89
# integrated probabilities           | NE=1024 | Neta= 128 | t=3.3447e+00s+/-1.8e-02 | leg=5.3969e+00s | x1.61
# integrated probabilities           | NE=1024 | Neta= 256 | t=6.3306e+00s+/-3.7e-02 | leg=1.0346e+01s | x1.63
# integrated probabilities           | NE=1024 | Neta= 512 | t=1.1573e+01s+/-7.0e-02 | leg=2.0377e+01s | x1.76
# integrated probabilities           | NE=1024 | Neta=1024 | t=2.2932e+01s+/-1.9e-01 | leg=4.0462e+01s | x1.76
#                      section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   integrated probabilities         4        4         0.015472
# 1   integrated probabilities         4        8         0.016088
# 2   integrated probabilities         4       16         0.017295
# 3   integrated probabilities         4       32         0.019612
# 4   integrated probabilities         4       64         0.023636
# ..                       ...       ...      ...              ...
# 76  integrated probabilities      1024       64         1.571389
# 77  integrated probabilities      1024      128         3.344745
# 78  integrated probabilities      1024      256         6.330624
# 79  integrated probabilities      1024      512        11.573462
# 80  integrated probabilities      1024     1024        22.932011
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.001945         0.016048       0.002200        0.000678
# 1        0.002667         0.017229       0.002854        0.001487
# 2        0.004226         0.017533       0.004522        0.000199
# 3        0.007785         0.020089       0.007954        0.000499
# 4        0.014023         0.026016       0.015014        0.002687
# ..            ...              ...            ...             ...
# 76       2.965050         1.843553       2.979073        0.174027
# 77       5.396854         3.372805       5.431521        0.018198
# 78      10.346179         6.394791      10.432186        0.036671
# 79      20.376781        11.679058      20.389931        0.070232
# 80      40.461530        23.142859      40.701435        0.194921
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000210                      0.125696
# 1       0.000110                      0.165747
# 2       0.000153                      0.244347
# 3       0.000119                      0.396926
# 4       0.000911                      0.593295
# ..           ...                           ...
# 76      0.013104                      1.886898
# 77      0.035044                      1.613532
# 78      0.076217                      1.634306
# 79      0.012115                      1.760647
# 80      0.311503                      1.764413
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\integrated_probability_timing.csv
# v:\output\benchmark\integrated_probability_speedup.png
# v:\output\benchmark\integrated_probability_speedup_cross_sections.png

# %% [markdown]
# ## 7. Solar-to-Detector Chain
#
# This section benchmarks the full incoherent solar-to-detector structure: solar mass-basis production followed by Earth matter propagation at detector nadir angles.
#
# **Expected results:**<br>
# - This is one of the most complete benchmark paths and should show the cumulative benefit of batching the solar and Earth stages.

# %% [markdown]
# ### 7.1 Probability Timing
#
# The output probability is flavour-resolved at the detector for each energy and nadir angle.
#
# **Expected results:**<br>
# - Timing should scale with both the energy and nadir grids.

# %%
solar_detector_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        solar_detector_probability_records.append(benchmark_pair(
            "solar-detector probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_solar_detector_probabilities(E, eta),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_solar_detector_probabilities(E_np, eta_np),
        ))
solar_detector_probability_df = pd.DataFrame(solar_detector_probability_records)
display(solar_detector_probability_df)
save_results(solar_detector_probability_df, "solar_detector_probability_timing")
plot_heatmap(solar_detector_probability_df, "Solar-detector probability speedup (LogNorm)",
              "solar_detector_probability_speedup.png")
plot_speedup_cross_sections(solar_detector_probability_df,
                              "Solar-detector probability speedup cross sections",
                              "solar_detector_probability_speedup_cross_sections.png")
# Out:
# solar-detector probabilities       | NE=   4 | Neta=   4 | t=2.0742e-02s+/-9.8e-04 | leg=1.6559e-03s | x0.08
# solar-detector probabilities       | NE=   4 | Neta=   8 | t=1.9519e-02s+/-2.6e-03 | leg=2.3456e-03s | x0.12
# solar-detector probabilities       | NE=   4 | Neta=  16 | t=2.0864e-02s+/-4.5e-04 | leg=3.6955e-03s | x0.18
# solar-detector probabilities       | NE=   4 | Neta=  32 | t=2.4152e-02s+/-2.5e-03 | leg=6.5485e-03s | x0.27
# solar-detector probabilities       | NE=   4 | Neta=  64 | t=2.8520e-02s+/-2.6e-03 | leg=1.3852e-02s | x0.49
# solar-detector probabilities       | NE=   4 | Neta= 128 | t=3.5134e-02s+/-3.2e-03 | leg=2.6838e-02s | x0.76
# solar-detector probabilities       | NE=   4 | Neta= 256 | t=5.3750e-02s+/-3.1e-03 | leg=5.2886e-02s | x0.98
# solar-detector probabilities       | NE=   4 | Neta= 512 | t=7.6870e-02s+/-4.8e-03 | leg=1.0081e-01s | x1.31
# solar-detector probabilities       | NE=   4 | Neta=1024 | t=1.1751e-01s+/-5.1e-03 | leg=2.0694e-01s | x1.76
# solar-detector probabilities       | NE=   8 | Neta=   4 | t=1.9979e-02s+/-1.1e-03 | leg=2.7514e-03s | x0.14
# solar-detector probabilities       | NE=   8 | Neta=   8 | t=2.0885e-02s+/-9.3e-04 | leg=4.4332e-03s | x0.21
# solar-detector probabilities       | NE=   8 | Neta=  16 | t=2.3954e-02s+/-1.8e-03 | leg=7.2795e-03s | x0.30
# solar-detector probabilities       | NE=   8 | Neta=  32 | t=2.7973e-02s+/-2.1e-03 | leg=1.2117e-02s | x0.43
# solar-detector probabilities       | NE=   8 | Neta=  64 | t=3.6183e-02s+/-3.3e-03 | leg=2.7172e-02s | x0.75
# solar-detector probabilities       | NE=   8 | Neta= 128 | t=5.2455e-02s+/-3.1e-03 | leg=5.3039e-02s | x1.01
# solar-detector probabilities       | NE=   8 | Neta= 256 | t=7.7825e-02s+/-2.8e-03 | leg=9.9308e-02s | x1.28
# solar-detector probabilities       | NE=   8 | Neta= 512 | t=1.2001e-01s+/-5.5e-03 | leg=2.0723e-01s | x1.73
# solar-detector probabilities       | NE=   8 | Neta=1024 | t=1.9115e-01s+/-2.6e-03 | leg=4.1530e-01s | x2.17
# solar-detector probabilities       | NE=  16 | Neta=   4 | t=2.1975e-02s+/-1.7e-03 | leg=5.8876e-03s | x0.27
# solar-detector probabilities       | NE=  16 | Neta=   8 | t=2.3977e-02s+/-1.3e-03 | leg=8.6167e-03s | x0.36
# solar-detector probabilities       | NE=  16 | Neta=  16 | t=2.8518e-02s+/-1.0e-03 | leg=1.3517e-02s | x0.47
# solar-detector probabilities       | NE=  16 | Neta=  32 | t=3.6421e-02s+/-1.3e-03 | leg=2.5887e-02s | x0.71
# solar-detector probabilities       | NE=  16 | Neta=  64 | t=5.6486e-02s+/-3.6e-03 | leg=5.4014e-02s | x0.96
# solar-detector probabilities       | NE=  16 | Neta= 128 | t=7.7462e-02s+/-3.5e-03 | leg=1.0286e-01s | x1.33
# solar-detector probabilities       | NE=  16 | Neta= 256 | t=1.2621e-01s+/-2.3e-03 | leg=2.0935e-01s | x1.66
# solar-detector probabilities       | NE=  16 | Neta= 512 | t=1.9327e-01s+/-8.4e-03 | leg=4.1648e-01s | x2.15
# solar-detector probabilities       | NE=  16 | Neta=1024 | t=3.6849e-01s+/-1.3e-02 | leg=8.2582e-01s | x2.24
# solar-detector probabilities       | NE=  32 | Neta=   4 | t=2.5471e-02s+/-1.2e-03 | leg=1.1547e-02s | x0.45
# solar-detector probabilities       | NE=  32 | Neta=   8 | t=2.9595e-02s+/-1.5e-03 | leg=1.7151e-02s | x0.58
# solar-detector probabilities       | NE=  32 | Neta=  16 | t=3.7935e-02s+/-3.1e-03 | leg=3.9381e-02s | x1.04
# solar-detector probabilities       | NE=  32 | Neta=  32 | t=7.7600e-02s+/-1.5e-02 | leg=5.2277e-02s | x0.67
# solar-detector probabilities       | NE=  32 | Neta=  64 | t=8.5706e-02s+/-4.2e-03 | leg=1.0850e-01s | x1.27
# solar-detector probabilities       | NE=  32 | Neta= 128 | t=1.2255e-01s+/-2.9e-02 | leg=2.7447e-01s | x2.24
# solar-detector probabilities       | NE=  32 | Neta= 256 | t=2.4702e-01s+/-6.6e-02 | leg=4.3797e-01s | x1.77
# solar-detector probabilities       | NE=  32 | Neta= 512 | t=3.9615e-01s+/-7.1e-03 | leg=8.5633e-01s | x2.16
# solar-detector probabilities       | NE=  32 | Neta=1024 | t=8.1504e-01s+/-1.1e-02 | leg=1.6404e+00s | x2.01
# solar-detector probabilities       | NE=  64 | Neta=   4 | t=3.2756e-02s+/-1.7e-03 | leg=2.2894e-02s | x0.70
# solar-detector probabilities       | NE=  64 | Neta=   8 | t=4.2934e-02s+/-2.4e-03 | leg=3.4098e-02s | x0.79
# solar-detector probabilities       | NE=  64 | Neta=  16 | t=6.3449e-02s+/-1.1e-03 | leg=5.2619e-02s | x0.83
# solar-detector probabilities       | NE=  64 | Neta=  32 | t=8.3499e-02s+/-2.1e-03 | leg=1.0296e-01s | x1.23
# solar-detector probabilities       | NE=  64 | Neta=  64 | t=1.1812e-01s+/-5.5e-03 | leg=2.1430e-01s | x1.81
# solar-detector probabilities       | NE=  64 | Neta= 128 | t=1.9536e-01s+/-9.1e-03 | leg=4.1239e-01s | x2.11
# solar-detector probabilities       | NE=  64 | Neta= 256 | t=3.9109e-01s+/-3.1e-03 | leg=8.3459e-01s | x2.13
# solar-detector probabilities       | NE=  64 | Neta= 512 | t=7.6733e-01s+/-1.2e-02 | leg=1.6626e+00s | x2.17
# solar-detector probabilities       | NE=  64 | Neta=1024 | t=1.5442e+00s+/-1.4e-02 | leg=3.2835e+00s | x2.13
# solar-detector probabilities       | NE= 128 | Neta=   4 | t=4.5554e-02s+/-9.7e-04 | leg=4.3385e-02s | x0.95
# solar-detector probabilities       | NE= 128 | Neta=   8 | t=6.2126e-02s+/-2.3e-03 | leg=6.5121e-02s | x1.05
# solar-detector probabilities       | NE= 128 | Neta=  16 | t=8.0134e-02s+/-4.0e-03 | leg=1.0803e-01s | x1.35
# solar-detector probabilities       | NE= 128 | Neta=  32 | t=1.2445e-01s+/-6.6e-03 | leg=1.9695e-01s | x1.58
# solar-detector probabilities       | NE= 128 | Neta=  64 | t=1.8825e-01s+/-7.9e-03 | leg=4.1682e-01s | x2.21
# solar-detector probabilities       | NE= 128 | Neta= 128 | t=3.8022e-01s+/-8.1e-03 | leg=8.1841e-01s | x2.15
# solar-detector probabilities       | NE= 128 | Neta= 256 | t=7.4357e-01s+/-8.6e-03 | leg=1.6144e+00s | x2.17
# solar-detector probabilities       | NE= 128 | Neta= 512 | t=1.4754e+00s+/-1.2e-02 | leg=3.1924e+00s | x2.16
# solar-detector probabilities       | NE= 128 | Neta=1024 | t=2.9711e+00s+/-3.9e-02 | leg=6.3536e+00s | x2.14
# solar-detector probabilities       | NE= 256 | Neta=   4 | t=7.3161e-02s+/-2.2e-03 | leg=8.4906e-02s | x1.16
# solar-detector probabilities       | NE= 256 | Neta=   8 | t=9.3486e-02s+/-3.3e-03 | leg=1.3021e-01s | x1.39
# solar-detector probabilities       | NE= 256 | Neta=  16 | t=1.3849e-01s+/-2.9e-03 | leg=2.1483e-01s | x1.55
# solar-detector probabilities       | NE= 256 | Neta=  32 | t=1.9921e-01s+/-7.2e-03 | leg=3.9073e-01s | x1.96
# solar-detector probabilities       | NE= 256 | Neta=  64 | t=3.9145e-01s+/-1.3e-02 | leg=8.2959e-01s | x2.12
# solar-detector probabilities       | NE= 256 | Neta= 128 | t=7.6741e-01s+/-9.8e-03 | leg=1.6154e+00s | x2.11
# solar-detector probabilities       | NE= 256 | Neta= 256 | t=1.4975e+00s+/-9.4e-03 | leg=3.1956e+00s | x2.13
# solar-detector probabilities       | NE= 256 | Neta= 512 | t=3.0132e+00s+/-2.6e-02 | leg=6.3849e+00s | x2.12
# solar-detector probabilities       | NE= 256 | Neta=1024 | t=6.0186e+00s+/-3.4e-02 | leg=1.2717e+01s | x2.11
# solar-detector probabilities       | NE= 512 | Neta=   4 | t=1.3397e-01s+/-1.6e-03 | leg=1.7276e-01s | x1.29
# solar-detector probabilities       | NE= 512 | Neta=   8 | t=1.7990e-01s+/-9.1e-03 | leg=2.5733e-01s | x1.43
# solar-detector probabilities       | NE= 512 | Neta=  16 | t=2.4080e-01s+/-1.0e-02 | leg=4.2973e-01s | x1.78
# solar-detector probabilities       | NE= 512 | Neta=  32 | t=4.1803e-01s+/-8.4e-03 | leg=7.8756e-01s | x1.88
# solar-detector probabilities       | NE= 512 | Neta=  64 | t=7.9991e-01s+/-1.7e-02 | leg=1.6491e+00s | x2.06
# solar-detector probabilities       | NE= 512 | Neta= 128 | t=1.5560e+00s+/-5.3e-03 | leg=3.2627e+00s | x2.10
# solar-detector probabilities       | NE= 512 | Neta= 256 | t=3.0389e+00s+/-1.9e-02 | leg=6.4680e+00s | x2.13
# solar-detector probabilities       | NE= 512 | Neta= 512 | t=6.0403e+00s+/-5.5e-02 | leg=1.2802e+01s | x2.12
# solar-detector probabilities       | NE= 512 | Neta=1024 | t=1.2044e+01s+/-1.8e-02 | leg=2.2570e+01s | x1.87
# solar-detector probabilities       | NE=1024 | Neta=   4 | t=2.5645e-01s+/-3.9e-03 | leg=3.4782e-01s | x1.36
# solar-detector probabilities       | NE=1024 | Neta=   8 | t=3.2481e-01s+/-3.6e-03 | leg=5.2479e-01s | x1.62
# solar-detector probabilities       | NE=1024 | Neta=  16 | t=5.0953e-01s+/-1.1e-02 | leg=8.6597e-01s | x1.70
# solar-detector probabilities       | NE=1024 | Neta=  32 | t=8.9359e-01s+/-6.1e-03 | leg=1.5810e+00s | x1.77
# solar-detector probabilities       | NE=1024 | Neta=  64 | t=1.6200e+00s+/-1.4e-02 | leg=2.9671e+00s | x1.83
# solar-detector probabilities       | NE=1024 | Neta= 128 | t=3.1378e+00s+/-3.0e-02 | leg=5.8082e+00s | x1.85
# solar-detector probabilities       | NE=1024 | Neta= 256 | t=6.1222e+00s+/-6.4e-02 | leg=1.1469e+01s | x1.87
# solar-detector probabilities       | NE=1024 | Neta= 512 | t=1.2183e+01s+/-1.7e-02 | leg=2.2714e+01s | x1.86
# solar-detector probabilities       | NE=1024 | Neta=1024 | t=2.4114e+01s+/-9.3e-02 | leg=4.5319e+01s | x1.88
#                          section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   solar-detector probabilities         4        4         0.020742
# 1   solar-detector probabilities         4        8         0.019519
# 2   solar-detector probabilities         4       16         0.020864
# 3   solar-detector probabilities         4       32         0.024152
# 4   solar-detector probabilities         4       64         0.028520
# ..                           ...       ...      ...              ...
# 76  solar-detector probabilities      1024       64         1.619963
# 77  solar-detector probabilities      1024      128         3.137756
# 78  solar-detector probabilities      1024      256         6.122221
# 79  solar-detector probabilities      1024      512        12.183354
# 80  solar-detector probabilities      1024     1024        24.113531
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.001656         0.022568       0.001866        0.000976
# 1        0.002346         0.022958       0.002408        0.002617
# 2        0.003695         0.021522       0.003806        0.000452
# 3        0.006549         0.027241       0.007432        0.002549
# 4        0.013852         0.030611       0.013950        0.002586
# ..            ...              ...            ...             ...
# 76       2.967095         1.636275       2.992396        0.014005
# 77       5.808225         3.173592       5.857429        0.029662
# 78      11.468996         6.201315      11.535277        0.063610
# 79      22.713519        12.211671      22.770966        0.017364
# 80      45.318857        24.244585      45.439362        0.093287
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000377                      0.079832
# 1       0.000053                      0.120169
# 2       0.000109                      0.177123
# 3       0.001451                      0.271134
# 4       0.000157                      0.485698
# ..           ...                           ...
# 76      0.016036                      1.831582
# 77      0.033359                      1.851076
# 78      0.048601                      1.873339
# 79      0.063674                      1.864308
# 80      0.124490                      1.879395
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_probability_timing.csv
# v:\output\benchmark\solar_detector_probability_speedup.png
# v:\output\benchmark\solar_detector_probability_speedup_cross_sections.png

# %% [markdown]
# ### 7.2 Flux Timing
#
# This benchmark multiplies the detector probability by a synthetic solar-source spectral weight.
#
# **Expected results:**<br>
# - Timings should remain close to the probability benchmark because the flux multiplication is elementwise.

# %%
solar_detector_flux_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d      = energy_grid(ne, solar=True)
        eta_1d    = nadir_grid(neta)
        spectrum_t = solar_source_spectrum(E_1d)
        spectrum_l = to_numpy(spectrum_t)
        solar_detector_flux_records.append(benchmark_pair(
            "solar-detector flux", ne, neta,
            lambda E=E_1d, eta=eta_1d, st=spectrum_t:
                tpeanuts_solar_detector_probabilities(E, eta) * st[:, None, None],
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d), sl=spectrum_l:
                legacy_solar_detector_probabilities(E_np, eta_np) * sl[:, None, None],
        ))
solar_detector_flux_df = pd.DataFrame(solar_detector_flux_records)
display(solar_detector_flux_df)
save_results(solar_detector_flux_df, "solar_detector_flux_timing")
plot_heatmap(solar_detector_flux_df, "Solar-detector flux speedup (LogNorm)",
              "solar_detector_flux_speedup.png")
plot_speedup_cross_sections(solar_detector_flux_df,
                              "Solar-detector flux speedup cross sections",
                              "solar_detector_flux_speedup_cross_sections.png")
# Out:
# solar-detector flux                | NE=   4 | Neta=   4 | t=1.8290e-02s+/-1.5e-03 | leg=1.6125e-03s | x0.09
# solar-detector flux                | NE=   4 | Neta=   8 | t=2.2436e-02s+/-6.7e-04 | leg=2.3715e-03s | x0.11
# solar-detector flux                | NE=   4 | Neta=  16 | t=2.0378e-02s+/-2.0e-03 | leg=3.6401e-03s | x0.18
# solar-detector flux                | NE=   4 | Neta=  32 | t=2.3281e-02s+/-2.1e-03 | leg=6.4887e-03s | x0.28
# solar-detector flux                | NE=   4 | Neta=  64 | t=2.7965e-02s+/-2.5e-03 | leg=1.1706e-02s | x0.42
# solar-detector flux                | NE=   4 | Neta= 128 | t=3.5318e-02s+/-2.5e-03 | leg=2.3486e-02s | x0.66
# solar-detector flux                | NE=   4 | Neta= 256 | t=5.2195e-02s+/-2.7e-03 | leg=4.5762e-02s | x0.88
# solar-detector flux                | NE=   4 | Neta= 512 | t=8.0222e-02s+/-3.5e-03 | leg=8.7562e-02s | x1.09
# solar-detector flux                | NE=   4 | Neta=1024 | t=1.1724e-01s+/-1.9e-03 | leg=1.7253e-01s | x1.47
# solar-detector flux                | NE=   8 | Neta=   4 | t=1.9496e-02s+/-1.3e-03 | leg=3.0800e-03s | x0.16
# solar-detector flux                | NE=   8 | Neta=   8 | t=2.0806e-02s+/-5.9e-04 | leg=4.0727e-03s | x0.20
# solar-detector flux                | NE=   8 | Neta=  16 | t=2.3598e-02s+/-1.3e-03 | leg=6.8876e-03s | x0.29
# solar-detector flux                | NE=   8 | Neta=  32 | t=2.7591e-02s+/-1.3e-03 | leg=1.2420e-02s | x0.45
# solar-detector flux                | NE=   8 | Neta=  64 | t=3.5788e-02s+/-1.2e-03 | leg=2.2999e-02s | x0.64
# solar-detector flux                | NE=   8 | Neta= 128 | t=5.1958e-02s+/-2.1e-03 | leg=4.4057e-02s | x0.85
# solar-detector flux                | NE=   8 | Neta= 256 | t=7.3590e-02s+/-3.1e-03 | leg=8.8373e-02s | x1.20
# solar-detector flux                | NE=   8 | Neta= 512 | t=1.1042e-01s+/-7.8e-03 | leg=1.7726e-01s | x1.61
# solar-detector flux                | NE=   8 | Neta=1024 | t=1.8483e-01s+/-2.8e-03 | leg=3.4809e-01s | x1.88
# solar-detector flux                | NE=  16 | Neta=   4 | t=2.1291e-02s+/-1.9e-03 | leg=5.5349e-03s | x0.26
# solar-detector flux                | NE=  16 | Neta=   8 | t=2.3948e-02s+/-1.7e-03 | leg=8.2931e-03s | x0.35
# solar-detector flux                | NE=  16 | Neta=  16 | t=2.8220e-02s+/-2.1e-03 | leg=1.3440e-02s | x0.48
# solar-detector flux                | NE=  16 | Neta=  32 | t=3.6427e-02s+/-5.3e-04 | leg=2.3980e-02s | x0.66
# solar-detector flux                | NE=  16 | Neta=  64 | t=5.3916e-02s+/-2.9e-03 | leg=4.7149e-02s | x0.87
# solar-detector flux                | NE=  16 | Neta= 128 | t=7.8605e-02s+/-2.8e-03 | leg=9.0960e-02s | x1.16
# solar-detector flux                | NE=  16 | Neta= 256 | t=1.1587e-01s+/-6.6e-03 | leg=1.7292e-01s | x1.49
# solar-detector flux                | NE=  16 | Neta= 512 | t=1.8641e-01s+/-6.1e-03 | leg=3.4270e-01s | x1.84
# solar-detector flux                | NE=  16 | Neta=1024 | t=3.6935e-01s+/-7.0e-03 | leg=7.0569e-01s | x1.91
# solar-detector flux                | NE=  32 | Neta=   4 | t=2.4823e-02s+/-2.0e-03 | leg=1.1186e-02s | x0.45
# solar-detector flux                | NE=  32 | Neta=   8 | t=3.0519e-02s+/-2.1e-03 | leg=1.6264e-02s | x0.53
# solar-detector flux                | NE=  32 | Neta=  16 | t=3.7306e-02s+/-2.1e-03 | leg=2.7592e-02s | x0.74
# solar-detector flux                | NE=  32 | Neta=  32 | t=5.6792e-02s+/-3.5e-03 | leg=4.8586e-02s | x0.86
# solar-detector flux                | NE=  32 | Neta=  64 | t=8.0412e-02s+/-3.6e-03 | leg=9.3316e-02s | x1.16
# solar-detector flux                | NE=  32 | Neta= 128 | t=1.1939e-01s+/-3.4e-03 | leg=1.7583e-01s | x1.47
# solar-detector flux                | NE=  32 | Neta= 256 | t=1.8515e-01s+/-4.5e-03 | leg=3.4959e-01s | x1.89
# solar-detector flux                | NE=  32 | Neta= 512 | t=3.7027e-01s+/-1.5e-02 | leg=7.0128e-01s | x1.89
# solar-detector flux                | NE=  32 | Neta=1024 | t=7.3664e-01s+/-4.2e-02 | leg=1.4507e+00s | x1.97
# solar-detector flux                | NE=  64 | Neta=   4 | t=3.3770e-02s+/-2.9e-03 | leg=2.2213e-02s | x0.66
# solar-detector flux                | NE=  64 | Neta=   8 | t=4.0678e-02s+/-3.9e-03 | leg=3.2692e-02s | x0.80
# solar-detector flux                | NE=  64 | Neta=  16 | t=5.8030e-02s+/-3.4e-03 | leg=5.4794e-02s | x0.94
# solar-detector flux                | NE=  64 | Neta=  32 | t=8.2091e-02s+/-4.7e-03 | leg=9.5416e-02s | x1.16
# solar-detector flux                | NE=  64 | Neta=  64 | t=1.2265e-01s+/-3.5e-03 | leg=1.8617e-01s | x1.52
# solar-detector flux                | NE=  64 | Neta= 128 | t=1.8934e-01s+/-1.7e-03 | leg=3.6516e-01s | x1.93
# solar-detector flux                | NE=  64 | Neta= 256 | t=3.7214e-01s+/-1.2e-02 | leg=7.0154e-01s | x1.89
# solar-detector flux                | NE=  64 | Neta= 512 | t=7.3145e-01s+/-1.4e-02 | leg=1.4059e+00s | x1.92
# solar-detector flux                | NE=  64 | Neta=1024 | t=1.5164e+00s+/-1.6e-02 | leg=2.8053e+00s | x1.85
# solar-detector flux                | NE= 128 | Neta=   4 | t=4.5098e-02s+/-2.9e-03 | leg=4.2947e-02s | x0.95
# solar-detector flux                | NE= 128 | Neta=   8 | t=5.9222e-02s+/-3.0e-03 | leg=6.5068e-02s | x1.10
# solar-detector flux                | NE= 128 | Neta=  16 | t=8.3426e-02s+/-3.4e-03 | leg=1.0608e-01s | x1.27
# solar-detector flux                | NE= 128 | Neta=  32 | t=1.2643e-01s+/-2.2e-03 | leg=1.9763e-01s | x1.56
# solar-detector flux                | NE= 128 | Neta=  64 | t=1.9431e-01s+/-3.9e-03 | leg=3.7449e-01s | x1.93
# solar-detector flux                | NE= 128 | Neta= 128 | t=3.7678e-01s+/-1.3e-02 | leg=7.2337e-01s | x1.92
# solar-detector flux                | NE= 128 | Neta= 256 | t=7.5183e-01s+/-9.4e-03 | leg=1.4272e+00s | x1.90
# solar-detector flux                | NE= 128 | Neta= 512 | t=1.4945e+00s+/-1.1e-02 | leg=2.8382e+00s | x1.90
# solar-detector flux                | NE= 128 | Neta=1024 | t=3.0207e+00s+/-2.3e-02 | leg=5.5967e+00s | x1.85
# solar-detector flux                | NE= 256 | Neta=   4 | t=7.0393e-02s+/-2.7e-03 | leg=8.8637e-02s | x1.26
# solar-detector flux                | NE= 256 | Neta=   8 | t=9.1537e-02s+/-4.6e-03 | leg=1.3102e-01s | x1.43
# solar-detector flux                | NE= 256 | Neta=  16 | t=1.3771e-01s+/-6.3e-03 | leg=2.1010e-01s | x1.53
# solar-detector flux                | NE= 256 | Neta=  32 | t=2.0507e-01s+/-4.0e-03 | leg=3.9523e-01s | x1.93
# solar-detector flux                | NE= 256 | Neta=  64 | t=3.9177e-01s+/-4.4e-03 | leg=7.4452e-01s | x1.90
# solar-detector flux                | NE= 256 | Neta= 128 | t=7.6454e-01s+/-1.3e-02 | leg=1.4550e+00s | x1.90
# solar-detector flux                | NE= 256 | Neta= 256 | t=1.5059e+00s+/-4.6e-02 | leg=2.8668e+00s | x1.90
# solar-detector flux                | NE= 256 | Neta= 512 | t=3.0351e+00s+/-1.1e-02 | leg=5.6636e+00s | x1.87
# solar-detector flux                | NE= 256 | Neta=1024 | t=6.0128e+00s+/-4.9e-02 | leg=1.1294e+01s | x1.88
# solar-detector flux                | NE= 512 | Neta=   4 | t=1.2944e-01s+/-5.4e-03 | leg=1.7473e-01s | x1.35
# solar-detector flux                | NE= 512 | Neta=   8 | t=1.8050e-01s+/-1.5e-03 | leg=2.6088e-01s | x1.45
# solar-detector flux                | NE= 512 | Neta=  16 | t=2.4172e-01s+/-3.3e-03 | leg=4.3313e-01s | x1.79
# solar-detector flux                | NE= 512 | Neta=  32 | t=4.3042e-01s+/-5.8e-03 | leg=7.8180e-01s | x1.82
# solar-detector flux                | NE= 512 | Neta=  64 | t=8.0331e-01s+/-1.7e-02 | leg=1.4978e+00s | x1.86
# solar-detector flux                | NE= 512 | Neta= 128 | t=1.5427e+00s+/-2.2e-02 | leg=2.9011e+00s | x1.88
# solar-detector flux                | NE= 512 | Neta= 256 | t=3.0603e+00s+/-6.2e-02 | leg=5.7215e+00s | x1.87
# solar-detector flux                | NE= 512 | Neta= 512 | t=6.0592e+00s+/-4.3e-02 | leg=1.1315e+01s | x1.87
# solar-detector flux                | NE= 512 | Neta=1024 | t=1.2110e+01s+/-5.0e-02 | leg=2.2666e+01s | x1.87
# solar-detector flux                | NE=1024 | Neta=   4 | t=2.6154e-01s+/-4.8e-03 | leg=3.5516e-01s | x1.36
# solar-detector flux                | NE=1024 | Neta=   8 | t=3.2267e-01s+/-4.1e-03 | leg=5.1623e-01s | x1.60
# solar-detector flux                | NE=1024 | Neta=  16 | t=5.0704e-01s+/-7.4e-03 | leg=8.6901e-01s | x1.71
# solar-detector flux                | NE=1024 | Neta=  32 | t=8.9479e-01s+/-1.1e-02 | leg=1.5829e+00s | x1.77
# solar-detector flux                | NE=1024 | Neta=  64 | t=1.6364e+00s+/-1.4e-02 | leg=2.9802e+00s | x1.82
# solar-detector flux                | NE=1024 | Neta= 128 | t=3.1207e+00s+/-2.4e-02 | leg=5.8311e+00s | x1.87
# solar-detector flux                | NE=1024 | Neta= 256 | t=6.1739e+00s+/-2.8e-02 | leg=1.1470e+01s | x1.86
# solar-detector flux                | NE=1024 | Neta= 512 | t=1.2242e+01s+/-5.4e-02 | leg=2.2645e+01s | x1.85
# solar-detector flux                | NE=1024 | Neta=1024 | t=2.4373e+01s+/-2.2e-01 | leg=4.5209e+01s | x1.85
#                 section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   solar-detector flux         4        4         0.018290       0.001612
# 1   solar-detector flux         4        8         0.022436       0.002371
# 2   solar-detector flux         4       16         0.020378       0.003640
# 3   solar-detector flux         4       32         0.023281       0.006489
# 4   solar-detector flux         4       64         0.027965       0.011706
# ..                  ...       ...      ...              ...            ...
# 76  solar-detector flux      1024       64         1.636444       2.980241
# 77  solar-detector flux      1024      128         3.120703       5.831086
# 78  solar-detector flux      1024      256         6.173910      11.470424
# 79  solar-detector flux      1024      512        12.242385      22.645463
# 80  solar-detector flux      1024     1024        24.372646      45.208643
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.019226       0.001741        0.001508      0.000078
# 1          0.023669       0.002411        0.000668      0.000025
# 2          0.021743       0.003826        0.002009      0.000106
# 3          0.025160       0.006577        0.002066      0.000079
# 4          0.029822       0.012342        0.002476      0.000385
# ..              ...            ...             ...           ...
# 76         1.655152       3.000731        0.013552      0.018147
# 77         3.154617       5.850230        0.024475      0.010454
# 78         6.208218      11.499124        0.027600      0.042102
# 79        12.308545      22.771751        0.053750      0.108574
# 80        24.548929      45.328019        0.215622      0.080373
#
#     speedup_legacy_over_tpeanuts
# 0                       0.088163
# 1                       0.105699
# 2                       0.178628
# 3                       0.278712
# 4                       0.418601
# ..                           ...
# 76                      1.821169
# 77                      1.868517
# 78                      1.857887
# 79                      1.849759
# 80                      1.854893
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_flux_timing.csv
# v:\output\benchmark\solar_detector_flux_speedup.png
# v:\output\benchmark\solar_detector_flux_speedup_cross_sections.png

# %% [markdown]
# ### 7.3 Integrated Probability Timing
#
# This benchmark integrates the solar-to-detector probability over a uniform nadir-angle exposure. It exercises the same solar production and Earth propagation chain, plus the final angular contraction.
#
# **Expected results:**<br>
# - Timings should increase with both energy and nadir grid size. The speedup map should show whether tensor batching compensates for the extra integration step.

# %%
solar_detector_integrated_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        solar_detector_integrated_records.append(benchmark_pair(
            "solar-detector integrated", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_integrated(E, eta, SOLAR_DETECTOR_DEPTH_M),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_integrated(E_np, eta_np, SOLAR_DETECTOR_DEPTH_M),
        ))
solar_detector_integrated_df = pd.DataFrame(solar_detector_integrated_records)
display(solar_detector_integrated_df)
save_results(solar_detector_integrated_df, "solar_detector_integrated_timing")
plot_heatmap(solar_detector_integrated_df,
              "Solar-detector integrated speedup (LogNorm)",
              "solar_detector_integrated_speedup.png")
plot_speedup_cross_sections(solar_detector_integrated_df,
                              "Solar-detector integrated speedup cross sections",
                              "solar_detector_integrated_speedup_cross_sections.png")
# Out:
# solar-detector integrated          | NE=   4 | Neta=   4 | t=1.8609e-02s+/-1.8e-03 | leg=1.7853e-03s | x0.10
# solar-detector integrated          | NE=   4 | Neta=   8 | t=1.9100e-02s+/-1.5e-03 | leg=2.4771e-03s | x0.13
# solar-detector integrated          | NE=   4 | Neta=  16 | t=2.0542e-02s+/-1.2e-03 | leg=3.6669e-03s | x0.18
# solar-detector integrated          | NE=   4 | Neta=  32 | t=2.2425e-02s+/-4.2e-04 | leg=6.4373e-03s | x0.29
# solar-detector integrated          | NE=   4 | Neta=  64 | t=2.7519e-02s+/-2.2e-03 | leg=1.1935e-02s | x0.43
# solar-detector integrated          | NE=   4 | Neta= 128 | t=3.4543e-02s+/-2.4e-03 | leg=2.2626e-02s | x0.66
# solar-detector integrated          | NE=   4 | Neta= 256 | t=5.1924e-02s+/-4.5e-03 | leg=4.3321e-02s | x0.83
# solar-detector integrated          | NE=   4 | Neta= 512 | t=7.1465e-02s+/-5.3e-03 | leg=8.7974e-02s | x1.23
# solar-detector integrated          | NE=   4 | Neta=1024 | t=1.1608e-01s+/-5.5e-03 | leg=1.7197e-01s | x1.48
# solar-detector integrated          | NE=   8 | Neta=   4 | t=1.9575e-02s+/-1.2e-03 | leg=3.2854e-03s | x0.17
# solar-detector integrated          | NE=   8 | Neta=   8 | t=2.0962e-02s+/-1.9e-03 | leg=4.8849e-03s | x0.23
# solar-detector integrated          | NE=   8 | Neta=  16 | t=2.2983e-02s+/-1.2e-03 | leg=7.5741e-03s | x0.33
# solar-detector integrated          | NE=   8 | Neta=  32 | t=2.8301e-02s+/-2.0e-03 | leg=1.2442e-02s | x0.44
# solar-detector integrated          | NE=   8 | Neta=  64 | t=3.5192e-02s+/-1.7e-03 | leg=2.3370e-02s | x0.66
# solar-detector integrated          | NE=   8 | Neta= 128 | t=5.1811e-02s+/-3.4e-03 | leg=4.3812e-02s | x0.85
# solar-detector integrated          | NE=   8 | Neta= 256 | t=7.5957e-02s+/-2.6e-03 | leg=8.9571e-02s | x1.18
# solar-detector integrated          | NE=   8 | Neta= 512 | t=1.2185e-01s+/-6.4e-04 | leg=1.7712e-01s | x1.45
# solar-detector integrated          | NE=   8 | Neta=1024 | t=1.7947e-01s+/-6.6e-03 | leg=3.4951e-01s | x1.95
# solar-detector integrated          | NE=  16 | Neta=   4 | t=2.1496e-02s+/-1.6e-03 | leg=6.6408e-03s | x0.31
# solar-detector integrated          | NE=  16 | Neta=   8 | t=2.4044e-02s+/-2.5e-03 | leg=9.1039e-03s | x0.38
# solar-detector integrated          | NE=  16 | Neta=  16 | t=2.8415e-02s+/-2.1e-03 | leg=1.4563e-02s | x0.51
# solar-detector integrated          | NE=  16 | Neta=  32 | t=3.7535e-02s+/-2.0e-03 | leg=2.4903e-02s | x0.66
# solar-detector integrated          | NE=  16 | Neta=  64 | t=5.3502e-02s+/-3.2e-03 | leg=4.7803e-02s | x0.89
# solar-detector integrated          | NE=  16 | Neta= 128 | t=7.5115e-02s+/-3.2e-03 | leg=9.1427e-02s | x1.22
# solar-detector integrated          | NE=  16 | Neta= 256 | t=1.2256e-01s+/-2.8e-03 | leg=1.9107e-01s | x1.56
# solar-detector integrated          | NE=  16 | Neta= 512 | t=1.9175e-01s+/-3.5e-03 | leg=3.6989e-01s | x1.93
# solar-detector integrated          | NE=  16 | Neta=1024 | t=3.8294e-01s+/-8.0e-03 | leg=6.9412e-01s | x1.81
# solar-detector integrated          | NE=  32 | Neta=   4 | t=2.5223e-02s+/-1.4e-03 | leg=1.2283e-02s | x0.49
# solar-detector integrated          | NE=  32 | Neta=   8 | t=2.9516e-02s+/-1.2e-03 | leg=1.7594e-02s | x0.60
# solar-detector integrated          | NE=  32 | Neta=  16 | t=3.7208e-02s+/-2.3e-03 | leg=2.8854e-02s | x0.78
# solar-detector integrated          | NE=  32 | Neta=  32 | t=5.4633e-02s+/-2.8e-03 | leg=4.8784e-02s | x0.89
# solar-detector integrated          | NE=  32 | Neta=  64 | t=7.5955e-02s+/-2.7e-03 | leg=9.2996e-02s | x1.22
# solar-detector integrated          | NE=  32 | Neta= 128 | t=1.1962e-01s+/-2.4e-03 | leg=1.7740e-01s | x1.48
# solar-detector integrated          | NE=  32 | Neta= 256 | t=1.8303e-01s+/-6.8e-03 | leg=3.4932e-01s | x1.91
# solar-detector integrated          | NE=  32 | Neta= 512 | t=3.7005e-01s+/-6.2e-03 | leg=6.9106e-01s | x1.87
# solar-detector integrated          | NE=  32 | Neta=1024 | t=7.5298e-01s+/-1.7e-02 | leg=1.4068e+00s | x1.87
# solar-detector integrated          | NE=  64 | Neta=   4 | t=3.5866e-02s+/-1.4e-03 | leg=2.5155e-02s | x0.70
# solar-detector integrated          | NE=  64 | Neta=   8 | t=4.0716e-02s+/-3.4e-03 | leg=3.5486e-02s | x0.87
# solar-detector integrated          | NE=  64 | Neta=  16 | t=5.7692e-02s+/-6.3e-04 | leg=5.6833e-02s | x0.99
# solar-detector integrated          | NE=  64 | Neta=  32 | t=7.7854e-02s+/-2.9e-03 | leg=1.0050e-01s | x1.29
# solar-detector integrated          | NE=  64 | Neta=  64 | t=1.2298e-01s+/-3.5e-03 | leg=1.9007e-01s | x1.55
# solar-detector integrated          | NE=  64 | Neta= 128 | t=1.8973e-01s+/-3.0e-03 | leg=3.6550e-01s | x1.93
# solar-detector integrated          | NE=  64 | Neta= 256 | t=3.6714e-01s+/-1.1e-02 | leg=7.0861e-01s | x1.93
# solar-detector integrated          | NE=  64 | Neta= 512 | t=7.3372e-01s+/-1.2e-02 | leg=1.4110e+00s | x1.92
# solar-detector integrated          | NE=  64 | Neta=1024 | t=1.4815e+00s+/-1.3e-02 | leg=2.7988e+00s | x1.89
# solar-detector integrated          | NE= 128 | Neta=   4 | t=4.3473e-02s+/-3.3e-03 | leg=5.0177e-02s | x1.15
# solar-detector integrated          | NE= 128 | Neta=   8 | t=5.8604e-02s+/-2.0e-03 | leg=7.1151e-02s | x1.21
# solar-detector integrated          | NE= 128 | Neta=  16 | t=8.4210e-02s+/-3.6e-03 | leg=1.0994e-01s | x1.31
# solar-detector integrated          | NE= 128 | Neta=  32 | t=1.2048e-01s+/-4.0e-03 | leg=2.0281e-01s | x1.68
# solar-detector integrated          | NE= 128 | Neta=  64 | t=1.9274e-01s+/-2.7e-03 | leg=3.7690e-01s | x1.96
# solar-detector integrated          | NE= 128 | Neta= 128 | t=3.7168e-01s+/-5.6e-03 | leg=7.3278e-01s | x1.97
# solar-detector integrated          | NE= 128 | Neta= 256 | t=7.4761e-01s+/-1.2e-02 | leg=1.4370e+00s | x1.92
# solar-detector integrated          | NE= 128 | Neta= 512 | t=1.4676e+00s+/-1.6e-02 | leg=2.8412e+00s | x1.94
# solar-detector integrated          | NE= 128 | Neta=1024 | t=2.9545e+00s+/-2.2e-02 | leg=5.6077e+00s | x1.90
# solar-detector integrated          | NE= 256 | Neta=   4 | t=7.1941e-02s+/-5.1e-03 | leg=1.0110e-01s | x1.41
# solar-detector integrated          | NE= 256 | Neta=   8 | t=9.6814e-02s+/-4.8e-03 | leg=1.4149e-01s | x1.46
# solar-detector integrated          | NE= 256 | Neta=  16 | t=1.4041e-01s+/-4.2e-03 | leg=2.2157e-01s | x1.58
# solar-detector integrated          | NE= 256 | Neta=  32 | t=2.0069e-01s+/-7.6e-03 | leg=4.0323e-01s | x2.01
# solar-detector integrated          | NE= 256 | Neta=  64 | t=3.8787e-01s+/-7.4e-03 | leg=7.4244e-01s | x1.91
# solar-detector integrated          | NE= 256 | Neta= 128 | t=7.5364e-01s+/-9.0e-03 | leg=1.4697e+00s | x1.95
# solar-detector integrated          | NE= 256 | Neta= 256 | t=1.5117e+00s+/-2.4e-02 | leg=2.8803e+00s | x1.91
# solar-detector integrated          | NE= 256 | Neta= 512 | t=3.0119e+00s+/-3.3e-02 | leg=5.6474e+00s | x1.88
# solar-detector integrated          | NE= 256 | Neta=1024 | t=5.9844e+00s+/-3.2e-02 | leg=1.1271e+01s | x1.88
# solar-detector integrated          | NE= 512 | Neta=   4 | t=1.3088e-01s+/-3.7e-03 | leg=2.0134e-01s | x1.54
# solar-detector integrated          | NE= 512 | Neta=   8 | t=1.7941e-01s+/-2.6e-03 | leg=2.8111e-01s | x1.57
# solar-detector integrated          | NE= 512 | Neta=  16 | t=2.5175e-01s+/-1.4e-03 | leg=4.5615e-01s | x1.81
# solar-detector integrated          | NE= 512 | Neta=  32 | t=4.2316e-01s+/-8.2e-03 | leg=8.0370e-01s | x1.90
# solar-detector integrated          | NE= 512 | Neta=  64 | t=7.9818e-01s+/-1.5e-02 | leg=1.5076e+00s | x1.89
# solar-detector integrated          | NE= 512 | Neta= 128 | t=1.5210e+00s+/-1.6e-02 | leg=2.9239e+00s | x1.92
# solar-detector integrated          | NE= 512 | Neta= 256 | t=3.0381e+00s+/-1.9e-02 | leg=5.7293e+00s | x1.89
# solar-detector integrated          | NE= 512 | Neta= 512 | t=6.0031e+00s+/-3.1e-02 | leg=1.1285e+01s | x1.88
# solar-detector integrated          | NE= 512 | Neta=1024 | t=1.2003e+01s+/-4.5e-02 | leg=2.2640e+01s | x1.89
# solar-detector integrated          | NE=1024 | Neta=   4 | t=2.5264e-01s+/-4.1e-03 | leg=3.9617e-01s | x1.57
# solar-detector integrated          | NE=1024 | Neta=   8 | t=3.2957e-01s+/-5.9e-03 | leg=5.7177e-01s | x1.73
# solar-detector integrated          | NE=1024 | Neta=  16 | t=5.0697e-01s+/-9.3e-03 | leg=9.0678e-01s | x1.79
# solar-detector integrated          | NE=1024 | Neta=  32 | t=8.7558e-01s+/-7.9e-03 | leg=1.6147e+00s | x1.84
# solar-detector integrated          | NE=1024 | Neta=  64 | t=1.6242e+00s+/-2.1e-02 | leg=3.0119e+00s | x1.85
# solar-detector integrated          | NE=1024 | Neta= 128 | t=3.1148e+00s+/-1.7e-02 | leg=5.8394e+00s | x1.87
# solar-detector integrated          | NE=1024 | Neta= 256 | t=6.1169e+00s+/-3.9e-02 | leg=1.1495e+01s | x1.88
# solar-detector integrated          | NE=1024 | Neta= 512 | t=1.2076e+01s+/-3.4e-02 | leg=2.2659e+01s | x1.88
# solar-detector integrated          | NE=1024 | Neta=1024 | t=2.4195e+01s+/-1.0e-01 | leg=4.5118e+01s | x1.86
#                       section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   solar-detector integrated         4        4         0.018609
# 1   solar-detector integrated         4        8         0.019100
# 2   solar-detector integrated         4       16         0.020542
# 3   solar-detector integrated         4       32         0.022425
# 4   solar-detector integrated         4       64         0.027519
# ..                        ...       ...      ...              ...
# 76  solar-detector integrated      1024       64         1.624198
# 77  solar-detector integrated      1024      128         3.114758
# 78  solar-detector integrated      1024      256         6.116852
# 79  solar-detector integrated      1024      512        12.076199
# 80  solar-detector integrated      1024     1024        24.194684
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.001785         0.020239       0.001876        0.001829
# 1        0.002477         0.020445       0.002608        0.001514
# 2        0.003667         0.021429       0.003902        0.001173
# 3        0.006437         0.022921       0.006674        0.000422
# 4        0.011935         0.030247       0.012384        0.002228
# ..            ...              ...            ...             ...
# 76       3.011910         1.652721       3.033089        0.020823
# 77       5.839351         3.142379       5.871561        0.016687
# 78      11.494730         6.187333      11.539379        0.038745
# 79      22.659420        12.117101      22.751951        0.034054
# 80      45.118085        24.321276      45.271277        0.101857
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000080                      0.095940
# 1       0.000092                      0.129694
# 2       0.000274                      0.178504
# 3       0.000198                      0.287062
# 4       0.000353                      0.433694
# ..           ...                           ...
# 76      0.022852                      1.854398
# 77      0.020056                      1.874737
# 78      0.027987                      1.879191
# 79      0.057932                      1.876370
# 80      0.112881                      1.864793
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_integrated_timing.csv
# v:\output\benchmark\solar_detector_integrated_speedup.png
# v:\output\benchmark\solar_detector_integrated_speedup_cross_sections.png

# %% [markdown]
# ## 8. GPU Benchmark (Conditional)
#
# This optional benchmark runs only when a CUDA device is available. It compares CPU and GPU execution for the solar-to-detector probability stage using the same physical inputs and grid sizes.
#
# **Expected results:**<br>
# - On machines without CUDA the cell should skip cleanly.
# - When CUDA is available, the GPU speedup should become more meaningful for larger energy and nadir grids, where transfer overhead is less dominant.

# %%
if not torch.cuda.is_available():
    print("No CUDA device — skipping GPU benchmark.")
else:
    print(f"GPU: {torch.cuda.get_device_name(0)}")

    _ = torch.zeros(1, device=GPU_DEVICE)
    torch.cuda.synchronize()

    gpu_records = []
    for ne in ENERGY_GRID_SIZES:
        for neta in NADIR_GRID_SIZES:
            E_1d   = energy_grid(ne, solar=True)
            eta_1d = nadir_grid(neta)

            def tpeanuts_cpu():
                return tpeanuts_solar_detector_probabilities(E_1d, eta_1d, device=DEVICE)

            def tpeanuts_gpu():
                E_g   = E_1d.to(GPU_DEVICE)
                eta_g = eta_1d.to(GPU_DEVICE)
                result = tpeanuts_solar_detector_probabilities(E_g, eta_g, device=GPU_DEVICE)
                torch.cuda.synchronize()
                return result

            t_cpu, _, _ = timed_call(tpeanuts_cpu)
            t_gpu, _, _ = timed_call(tpeanuts_gpu)
            speedup_gpu = t_cpu / max(t_gpu, 1e-15)
            gpu_records.append({
                "n_energy": ne, "n_nadir": neta,
                "cpu_s": t_cpu, "gpu_s": t_gpu,
                "speedup_gpu_over_cpu": speedup_gpu,
            })
            print(f"NE={ne:4d} | Neta={neta:4d} | CPU={t_cpu:.4e}s | GPU={t_gpu:.4e}s | x{speedup_gpu:.2f}")

    gpu_df = pd.DataFrame(gpu_records)
    display(gpu_df)
    save_results(gpu_df, "gpu_timing")

    pivot_gpu = gpu_df.pivot(index="n_nadir", columns="n_energy", values="speedup_gpu_over_cpu")
    vmax_gpu  = max(pivot_gpu.values.max(), 1.1)
    fig, ax = plt.subplots(figsize=(7.5, 5.5))
    im = ax.imshow(pivot_gpu.values, origin="lower", aspect="auto",
                   norm=mcolors.LogNorm(vmin=0.1, vmax=vmax_gpu), cmap="RdYlGn")
    ax.set_xticks(np.arange(len(pivot_gpu.columns))); ax.set_xticklabels(pivot_gpu.columns)
    ax.set_yticks(np.arange(len(pivot_gpu.index)));   ax.set_yticklabels(pivot_gpu.index)
    for r in range(pivot_gpu.values.shape[0]):
        for c in range(pivot_gpu.values.shape[1]):
            ax.text(c, r, f"{pivot_gpu.values[r,c]:.1f}x", ha="center", va="center", fontsize=8)
    ax.set_xlabel("Energy-grid size"); ax.set_ylabel("Nadir-grid size")
    ax.set_title("GPU / CPU speedup — solar-detector probabilities")
    fig.colorbar(im, ax=ax, label="GPU speedup (log)")
    fig.tight_layout()
    save_and_show("gpu_speedup_heatmap.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# GPU: NVIDIA GeForce GTX 1080 Ti
# NE=   4 | Neta=   4 | CPU=1.8313e-02s | GPU=4.4279e-02s | x0.41
# NE=   4 | Neta=   8 | CPU=1.9153e-02s | GPU=4.4041e-02s | x0.43
# NE=   4 | Neta=  16 | CPU=2.0182e-02s | GPU=4.4769e-02s | x0.45
# NE=   4 | Neta=  32 | CPU=2.2898e-02s | GPU=4.5647e-02s | x0.50
# NE=   4 | Neta=  64 | CPU=2.7248e-02s | GPU=5.7358e-02s | x0.48
# NE=   4 | Neta= 128 | CPU=3.5870e-02s | GPU=6.9311e-02s | x0.52
# NE=   4 | Neta= 256 | CPU=5.1954e-02s | GPU=5.9854e-02s | x0.87
# NE=   4 | Neta= 512 | CPU=7.2194e-02s | GPU=7.3271e-02s | x0.99
# NE=   4 | Neta=1024 | CPU=1.1836e-01s | GPU=9.8506e-02s | x1.20
# NE=   8 | Neta=   4 | CPU=1.9480e-02s | GPU=4.4325e-02s | x0.44
# NE=   8 | Neta=   8 | CPU=2.1250e-02s | GPU=4.3701e-02s | x0.49
# NE=   8 | Neta=  16 | CPU=2.4024e-02s | GPU=4.5132e-02s | x0.53
# NE=   8 | Neta=  32 | CPU=2.7299e-02s | GPU=4.6481e-02s | x0.59
# NE=   8 | Neta=  64 | CPU=3.5900e-02s | GPU=4.9981e-02s | x0.72
# NE=   8 | Neta= 128 | CPU=5.3772e-02s | GPU=5.5666e-02s | x0.97
# NE=   8 | Neta= 256 | CPU=7.8482e-02s | GPU=6.9642e-02s | x1.13
# NE=   8 | Neta= 512 | CPU=1.1349e-01s | GPU=9.9720e-02s | x1.14
# NE=   8 | Neta=1024 | CPU=1.8962e-01s | GPU=1.6162e-01s | x1.17
# NE=  16 | Neta=   4 | CPU=2.1097e-02s | GPU=4.3856e-02s | x0.48
# NE=  16 | Neta=   8 | CPU=2.4116e-02s | GPU=4.5700e-02s | x0.53
# NE=  16 | Neta=  16 | CPU=2.8445e-02s | GPU=4.5976e-02s | x0.62
# NE=  16 | Neta=  32 | CPU=3.7372e-02s | GPU=4.9939e-02s | x0.75
# NE=  16 | Neta=  64 | CPU=5.7255e-02s | GPU=6.0997e-02s | x0.94
# NE=  16 | Neta= 128 | CPU=7.2663e-02s | GPU=7.4731e-02s | x0.97
# NE=  16 | Neta= 256 | CPU=1.1519e-01s | GPU=1.0109e-01s | x1.14
# NE=  16 | Neta= 512 | CPU=1.8429e-01s | GPU=1.6198e-01s | x1.14
# NE=  16 | Neta=1024 | CPU=3.8097e-01s | GPU=3.2191e-01s | x1.18
# NE=  32 | Neta=   4 | CPU=2.5057e-02s | GPU=4.4222e-02s | x0.57
# NE=  32 | Neta=   8 | CPU=2.9948e-02s | GPU=4.5880e-02s | x0.65
# NE=  32 | Neta=  16 | CPU=3.8508e-02s | GPU=4.8728e-02s | x0.79
# NE=  32 | Neta=  32 | CPU=5.4049e-02s | GPU=5.6657e-02s | x0.95
# NE=  32 | Neta=  64 | CPU=7.6505e-02s | GPU=7.1135e-02s | x1.08
# NE=  32 | Neta= 128 | CPU=1.1729e-01s | GPU=9.9559e-02s | x1.18
# NE=  32 | Neta= 256 | CPU=1.8317e-01s | GPU=1.6312e-01s | x1.12
# NE=  32 | Neta= 512 | CPU=3.7366e-01s | GPU=3.2154e-01s | x1.16
# NE=  32 | Neta=1024 | CPU=7.6993e-01s | GPU=6.6045e-01s | x1.17
# NE=  64 | Neta=   4 | CPU=3.2503e-02s | GPU=4.6695e-02s | x0.70
# NE=  64 | Neta=   8 | CPU=4.3165e-02s | GPU=4.9617e-02s | x0.87
# NE=  64 | Neta=  16 | CPU=5.8421e-02s | GPU=5.6512e-02s | x1.03
# NE=  64 | Neta=  32 | CPU=8.0822e-02s | GPU=7.0778e-02s | x1.14
# NE=  64 | Neta=  64 | CPU=1.1836e-01s | GPU=9.9700e-02s | x1.19
# NE=  64 | Neta= 128 | CPU=1.9042e-01s | GPU=1.6301e-01s | x1.17
# NE=  64 | Neta= 256 | CPU=3.8070e-01s | GPU=3.2157e-01s | x1.18
# NE=  64 | Neta= 512 | CPU=7.3397e-01s | GPU=6.3784e-01s | x1.15
# NE=  64 | Neta=1024 | CPU=1.4739e+00s | GPU=1.2749e+00s | x1.16
# NE= 128 | Neta=   4 | CPU=4.4686e-02s | GPU=5.0344e-02s | x0.89
# NE= 128 | Neta=   8 | CPU=6.1160e-02s | GPU=5.6283e-02s | x1.09
# NE= 128 | Neta=  16 | CPU=8.3843e-02s | GPU=7.1403e-02s | x1.17
# NE= 128 | Neta=  32 | CPU=1.1738e-01s | GPU=1.0084e-01s | x1.16
# NE= 128 | Neta=  64 | CPU=1.8931e-01s | GPU=1.6432e-01s | x1.15
# NE= 128 | Neta= 128 | CPU=3.7643e-01s | GPU=3.2464e-01s | x1.16
# NE= 128 | Neta= 256 | CPU=7.5026e-01s | GPU=6.4487e-01s | x1.16
# NE= 128 | Neta= 512 | CPU=1.4960e+00s | GPU=1.2851e+00s | x1.16
# NE= 128 | Neta=1024 | CPU=3.0064e+00s | GPU=2.5578e+00s | x1.18
# NE= 256 | Neta=   4 | CPU=6.8874e-02s | GPU=5.7292e-02s | x1.20
# NE= 256 | Neta=   8 | CPU=9.2066e-02s | GPU=7.1296e-02s | x1.29
# NE= 256 | Neta=  16 | CPU=1.3652e-01s | GPU=1.0154e-01s | x1.34
# NE= 256 | Neta=  32 | CPU=2.0122e-01s | GPU=1.6468e-01s | x1.22
# NE= 256 | Neta=  64 | CPU=3.8281e-01s | GPU=3.2544e-01s | x1.18
# NE= 256 | Neta= 128 | CPU=7.7066e-01s | GPU=6.4578e-01s | x1.19
# NE= 256 | Neta= 256 | CPU=1.5022e+00s | GPU=1.2853e+00s | x1.17
# NE= 256 | Neta= 512 | CPU=2.9889e+00s | GPU=2.5660e+00s | x1.16
# NE= 256 | Neta=1024 | CPU=5.9969e+00s | GPU=5.0894e+00s | x1.18
# NE= 512 | Neta=   4 | CPU=1.3562e-01s | GPU=7.4386e-02s | x1.82
# NE= 512 | Neta=   8 | CPU=1.8006e-01s | GPU=1.0334e-01s | x1.74
# NE= 512 | Neta=  16 | CPU=2.5836e-01s | GPU=1.6716e-01s | x1.55
# NE= 512 | Neta=  32 | CPU=4.3044e-01s | GPU=3.2603e-01s | x1.32
# NE= 512 | Neta=  64 | CPU=7.9348e-01s | GPU=6.4452e-01s | x1.23
# NE= 512 | Neta= 128 | CPU=1.5482e+00s | GPU=1.2877e+00s | x1.20
# NE= 512 | Neta= 256 | CPU=3.0545e+00s | GPU=2.5467e+00s | x1.20
# NE= 512 | Neta= 512 | CPU=6.0415e+00s | GPU=5.1294e+00s | x1.18
# NE= 512 | Neta=1024 | CPU=1.2090e+01s | GPU=1.0252e+01s | x1.18
# NE=1024 | Neta=   4 | CPU=2.5454e-01s | GPU=1.0665e-01s | x2.39
# NE=1024 | Neta=   8 | CPU=3.1947e-01s | GPU=1.7114e-01s | x1.87
# NE=1024 | Neta=  16 | CPU=5.0422e-01s | GPU=3.3034e-01s | x1.53
# NE=1024 | Neta=  32 | CPU=8.9170e-01s | GPU=6.5052e-01s | x1.37
# NE=1024 | Neta=  64 | CPU=1.6462e+00s | GPU=1.2894e+00s | x1.28
# NE=1024 | Neta= 128 | CPU=3.1379e+00s | GPU=2.5510e+00s | x1.23
# NE=1024 | Neta= 256 | CPU=6.0854e+00s | GPU=5.0937e+00s | x1.19
# NE=1024 | Neta= 512 | CPU=1.2117e+01s | GPU=1.0253e+01s | x1.18
# NE=1024 | Neta=1024 | CPU=2.4173e+01s | GPU=2.0500e+01s | x1.18
#     n_energy  n_nadir      cpu_s      gpu_s  speedup_gpu_over_cpu
# 0          4        4   0.018313   0.044279              0.413593
# 1          4        8   0.019153   0.044041              0.434884
# 2          4       16   0.020182   0.044769              0.450803
# 3          4       32   0.022898   0.045647              0.501646
# 4          4       64   0.027248   0.057358              0.475056
# ..       ...      ...        ...        ...                   ...
# 76      1024       64   1.646211   1.289402              1.276725
# 77      1024      128   3.137948   2.550954              1.230108
# 78      1024      256   6.085430   5.093728              1.194691
# 79      1024      512  12.117097  10.252921              1.181819
# 80      1024     1024  24.173225  20.499794              1.179194
#
# [81 rows x 5 columns]
# Saved: v:\output\benchmark\gpu_timing.csv
# v:\output\benchmark\gpu_speedup_heatmap.png

# %% [markdown]
# ## 9. Summary
# The summary combines all benchmark tables, stores a global CSV file, and produces aggregate speedup figures for the largest grid sizes. It is the final comparison layer for identifying where the torch-native implementation is faster or slower than the legacy reference.
#
# **Results Interpretation:**<br>
# - The median-speedup plot should make the dominant performance regimes visible, while the largest-grid comparison should summarize absolute timing and relative speedup for the most demanding benchmark points.

# %%
all_timing_df = pd.concat([
    vacuum_probability_df, vacuum_flux_df,
    solar_probability_df,  solar_flux_df,
    earth_probability_df,  earth_flux_df,
    integrated_probability_df,
    solar_detector_probability_df, solar_detector_flux_df,
    solar_detector_integrated_df,
], ignore_index=True)
display(all_timing_df)
save_results(all_timing_df, "all_performance_timing")

summary = (
    all_timing_df.groupby("section", as_index=False)
    .agg(
        median_speedup=("speedup_legacy_over_tpeanuts", "median"),
        min_speedup   =("speedup_legacy_over_tpeanuts", "min"),
        max_speedup   =("speedup_legacy_over_tpeanuts", "max"),
    )
    .sort_values("median_speedup", ascending=False)
)
display(summary)

fig, ax = plt.subplots(figsize=(11, 5.0))
xerr = np.array([
    summary["median_speedup"] - summary["min_speedup"],
    summary["max_speedup"]    - summary["median_speedup"],
])
colors = ["C2" if v > 1.0 else "C3" for v in summary["median_speedup"]]
ax.barh(summary["section"], summary["median_speedup"], xerr=xerr,
        color=colors, error_kw={"capsize": 4, "elinewidth": 1.2})
ax.axvline(1.0, color="black", lw=1.2, alpha=0.6)
ax.set_xlabel("Median speedup  (legacy / tpeanuts)")
ax.set_title("Performance summary — median speedup with min/max error bars")
fig.tight_layout()
save_and_show("summary_median_speedup.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)

largest_ne   = max(ENERGY_GRID_SIZES)
largest_neta = max(NADIR_GRID_SIZES)

large_rows = []
for df in [vacuum_probability_df, vacuum_flux_df, solar_probability_df, solar_flux_df,
           earth_probability_df, earth_flux_df, integrated_probability_df,
           solar_detector_probability_df, solar_detector_flux_df, solar_detector_integrated_df]:
    row = get_largest_timing_row(df, largest_ne, largest_neta)
    if row is not None:
        large_rows.append(row)
large_df = pd.DataFrame(large_rows).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(13, 5.5))
x    = np.arange(len(large_df))
w    = 0.35
ax1.bar(x - w/2, large_df["tpeanuts_best_s"], width=w, label="tpeanuts", color="C0", alpha=0.85)
ax1.bar(x + w/2, large_df["legacy_best_s"],   width=w, label="legacy",   color="C1", alpha=0.85)
ax1.set_yscale("log")
ax1.set_ylabel("Best time [s]  (log scale)")
ax1.set_xticks(x)
ax1.set_xticklabels(large_df["section"], rotation=30, ha="right", fontsize=8)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(x, large_df["speedup_legacy_over_tpeanuts"], "D-", color="C2", label="speedup", zorder=5)
ax2.axhline(1.0, color="gray", lw=0.8, ls="--")
ax2.set_ylabel("Speedup  (legacy / tpeanuts)", color="C2")
ax2.tick_params(axis="y", labelcolor="C2")
ax2.legend(loc="upper right")

fig.suptitle(f"Absolute time + speedup at NE={largest_ne}, Neta={largest_neta}")
fig.tight_layout()
save_and_show("summary_time_and_speedup.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
#                        section  n_energy n_nadir  tpeanuts_best_s  \
# 0         vacuum probabilities         4    None         0.001043
# 1         vacuum probabilities         8    None         0.001031
# 2         vacuum probabilities        16    None         0.001151
# 3         vacuum probabilities        32    None         0.001072
# 4         vacuum probabilities        64    None         0.001176
# ..                         ...       ...     ...              ...
# 517  solar-detector integrated      1024      64         1.624198
# 518  solar-detector integrated      1024     128         3.114758
# 519  solar-detector integrated      1024     256         6.116852
# 520  solar-detector integrated      1024     512        12.076199
# 521  solar-detector integrated      1024    1024        24.194684
#
#      legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0         0.000595         0.001112       0.000640        0.000071
# 1         0.000977         0.001139       0.001054        0.000143
# 2         0.001834         0.001215       0.002138        0.000112
# 3         0.003479         0.001228       0.003563        0.000149
# 4         0.006529         0.001301       0.006789        0.000116
# ..             ...              ...            ...             ...
# 517       3.011910         1.652721       3.033089        0.020823
# 518       5.839351         3.142379       5.871561        0.016687
# 519      11.494730         6.187333      11.539379        0.038745
# 520      22.659420        12.117101      22.751951        0.034054
# 521      45.118085        24.321276      45.271277        0.101857
#
#      legacy_std_s  speedup_legacy_over_tpeanuts
# 0        0.000048                      0.570539
# 1        0.000039                      0.948012
# 2        0.000336                      1.592670
# 3        0.000056                      3.246477
# 4        0.000194                      5.550795
# ..            ...                           ...
# 517      0.022852                      1.854398
# 518      0.020056                      1.874737
# 519      0.027987                      1.879191
# 520      0.057932                      1.876370
# 521      0.112881                      1.864793
#
# [522 rows x 10 columns]
# Saved: v:\output\benchmark\all_performance_timing.csv
#                         section  median_speedup  min_speedup  max_speedup
# 9          vacuum probabilities        5.550795     0.570539    62.742265
# 8                   vacuum flux        5.065454     0.553351    61.269933
# 0                    earth flux        4.935560     0.194482     6.407272
# 2      integrated probabilities        1.738258     0.125696     2.642686
# 7  solar-detector probabilities        1.615660     0.079832     2.241087
# 6     solar-detector integrated        1.558989     0.095940     2.009241
# 5           solar-detector flux        1.492442     0.088163     1.969353
# 1           earth probabilities        1.476256     0.063539     1.927764
# 4           solar probabilities        0.843919     0.204280     1.407660
# 3                    solar flux        0.800730     0.245536     1.305138
# v:\output\benchmark\summary_median_speedup.png
# v:\output\benchmark\summary_time_and_speedup.png
