# %% [markdown]
# <div style="background-color:#EAEAEA;padding:20px;border-left:5px solid #6C757D;border-radius:6px;">
# <table style="width:100%; border:none;"><tr style="border:none;">
# <td style="border:none; vertical-align:top;">
# <h1 style="font-size:32px; margin-top:0;">Master's Thesis</h1>
# <hr style="margin:16px 0 22px 0;">
# <p style="font-size:22px; line-height:1.5; margin:0;"><strong>Master's Degree in Advanced Physics</strong> - <strong>Universitat de Valencia</strong></p>
# <p style="font-size:17px; margin-top:28px; margin-bottom:6px;">This notebook is part of the <strong>Master's Thesis (MSc Dissertation)</strong>:</p>
# <div style="font-size:25px;font-weight:700;line-height:1.3;margin-top:14px;margin-bottom:26px;">Fast Simulation of Neutrino Oscillations in Matter</div>
# <p style="font-size:14px; line-height:1.55;"><strong>Author</strong><br>Juan Ramon Diaz Santos - <a href="mailto:diazjuan@alumni.uv.es">diazjuan@alumni.uv.es</a></p>
# <p style="font-size:14px; line-height:1.55;"><strong>Supervisors</strong><br>Roberto Ruiz de Austri Bazan - <a href="mailto:rruiz@ific.uv.es">rruiz@ific.uv.es</a><br>Michele Lucente - <a href="mailto:michele.lucente@unibo.it">michele.lucente@unibo.it</a></p>
# <p style="font-size:14px; line-height:1.55; margin-bottom:0;"><strong>Date</strong><br>September 2026</p></td>
# <td style="border:none;width:230px;padding-left:25px;text-align:right;vertical-align:top;"><img src="../logo_uv.png" alt="Universitat de Valencia" style="width:200px; margin-top:5px;"></td>
# </tr></table></div>

# %% [markdown]
# # Benchmark 1 - TPeanuts vs Peanuts Reference Performance
# ---
# This notebook measures wall-clock performance for the torch-native `tpeanuts` implementation against the bundled legacy `peanuts` implementation. The benchmark covers vacuum propagation, solar production, Earth matter propagation, exposure-style angular integration, the solar-to-detector chain, and a conditional GPU comparison when CUDA is available.
#
# The purpose is performance characterization, not precision validation. Precision and bit-level compatibility are studied in the validation notebooks; here the same physical inputs are used so timing differences can be interpreted as implementation and batching effects.
#
# ---
#
# ## Table of Contents
#
# | # | Section |
# |---|---|
# | [0](#0.-Theoretical-Framework) | **Theoretical Framework** |
# | [1](#1.-Libraries) | **Libraries** |
# | [2](#2.-Paths-and-Configuration) | **Paths and Configuration** |
# | [3](#3.-Vacuum-Propagation) | **Vacuum Propagation** |
# | [4](#4.-Solar-Production) | **Solar Production** |
# | [5](#5.-Earth-Propagation) | **Earth Propagation** |
# | [6](#6.-Integrated-Probabilities) | **Integrated Probabilities** |
# | [7](#7.-Solar-to-Detector-Chain) | **Solar-to-Detector Chain** |
# | [8](#8.-GPU-Benchmark-Conditional) | **GPU Benchmark (Conditional)** |
# | [9](#9.-Summary) | **Summary** |

# %% [markdown]
# ## 0. Theoretical Framework
#
# This stage defines and evaluates theoretical framework under the physical, numerical, and hardware conditions stated above, with explicit control of accuracy and reproducibility.

# %% [markdown]
# ### 0.1 Performance Benchmarking Strategy
#
# This notebook compares two implementations of the same neutrino-oscillation workflows: the torch-native `tpeanuts` API and the legacy NumPy/Numba `peanuts` routines. The measured quantity is wall-clock execution time for fixed input grids. Each benchmark is executed after warm-up calls and repeated several times; the reported speedup is
#
# $$S = \frac{t_\mathrm{legacy}}{t_\mathrm{tpeanuts}},$$
#
# so that $S>1$ means `tpeanuts` is faster than the legacy reference.
#
# ---

# %% [markdown]
# ### 0.2 Vectorization and Grid Scaling
#
# The torch implementation is designed to evaluate many energies and nadir angles in batched tensor operations. The benchmark therefore scans energy-grid size $N_E$ and, for Earth-dependent workflows, nadir-grid size $N_\eta$. Log-log timing slopes provide a compact diagnostic of algorithmic scaling,
#
# $$t(N) \propto N^p,$$
#
# where the fitted exponent $p$ distinguishes roughly linear scaling from larger overheads.
#
# ---

# %% [markdown]
# ### 0.3 Physics Workflows Benchmarked
#
# The benchmark covers the main observable layers used in the project:
#
# | Workflow | Observable |
# |----------|------------|
# | Vacuum propagation | flavour-transition matrix and incoherent flux contraction |
# | Solar production | adiabatic solar flavour probabilities and mass-basis source weights |
# | Earth propagation | mass-basis Earth regeneration over energy-nadir grids |
# | Integrated probabilities | nadir-averaged probabilities with a simple exposure weight |
# | Solar-to-detector chain | solar mass weights followed by Earth propagation |
#
# The Hamiltonians and probability definitions follow the standard three-flavour oscillation framework in vacuum and matter, with matter effects described by the Wolfenstein charged-current potential.
#
# ---

# %% [markdown]
# ### 0.4 Reference Implementation and Precision Mode
#
# The legacy `peanuts` implementation is scalar and loop-based for many workflows, while `tpeanuts` exposes batched tensor APIs. The optional `legacy_precision` flag in solar and matter calculations reproduces rounded constants used by the reference implementation when numerical agreement is the goal. In this performance notebook, the flag is configurable but the main observable is runtime.
#
# **References**
#
# - [1] L. Wolfenstein, *Neutrino oscillations in matter*, Phys. Rev. D **17**, 2369 (1978).
# - [2] S. P. Mikheyev and A. Yu. Smirnov, *Resonance amplification of oscillations in matter*, Sov. J. Nucl. Phys. **42**, 913 (1985).
# - [3] I. Esteban et al., *NuFIT 5.2 global analysis of three-flavour neutrino oscillations*, JHEP **09**, 178 (2022).
# - [4] C. R. Harris et al., *Array programming with NumPy*, Nature **585**, 357 (2020).
# - [5] A. Paszke et al., *PyTorch: An Imperative Style, High-Performance Deep Learning Library*, NeurIPS (2019).

# %% [markdown]
# ## 1. Libraries
#
# This stage defines and evaluates libraries under the physical, numerical, and hardware conditions stated above, with explicit control of accuracy and reproducibility.

# %%
from __future__ import annotations

import gc
import math
import time
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
import torch
from IPython.display import display

from tpeanuts.notebooks.notebookConfig import load_notebook_config
from tpeanuts.notebooks.notebooks_helper import save_and_show, to_numpy
from tpeanuts.util.context import RuntimeContext

from tpeanuts.core.common.oscillation import OscillationParameters
from tpeanuts.config.propagation import PropagationConfig
from tpeanuts.core.common.probability import probability_incoherent
from tpeanuts.medium.earth.profile import EarthParameters, EarthProfile
from tpeanuts.medium.earth.probability import earth_probability_state
from tpeanuts.medium.solar.probability import solar_probability_state, solar_probability_mass
from tpeanuts.medium.solar.profile import SolarMediumParameters, SolarMediumProfile
from tpeanuts.source.solar import SolarSourceParameters, SolarNeutrinoSource
from tpeanuts.medium.solar.validation import legacy_modules
from tpeanuts.medium.vacuum.probability import vacuum_probability_transition

from peanuts.earth import Pearth as legacy_pearth
from peanuts.earth import earthdensity as LegacyEarthDensity
from peanuts.pmns import PMNS as LegacyPMNS
from peanuts.vacuum import Pvacuum as legacy_pvacuum


print(f"Torch version : {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
from tpeanuts.util.math import numpy_trapezoid
from tpeanuts.notebooks.benchmark.benchmark_helpers import *
# Out:
# Warning!: Python module pyslha not found, disabling slha reading routines
# Torch version : 2.5.1+cu121
# CUDA available: True

# %% [markdown]
# ## 2. Paths and Configuration
#
# This section resolves the project paths, creates the benchmark output directory, and fixes the physical and numerical configuration used in the timing study.

# %% [markdown]
# ### 2.1 Paths
#
# `load_notebook_config()` resolves the project root, applies the shared notebook style, and creates the output directory. Following the project notebook convention, outputs from this notebook are saved under `benchmark/`, which is the relative notebook path below `notebooks/` without the notebook filename.
#
# **Expected results:**<br>
# - The printed paths should point to the package root, the bundled legacy data directory, the explicit TPeanuts solar CSV files, and the benchmark output directory used by all CSV files and figures.

# %%
config = load_notebook_config()

PACKAGE_DIR = config.package_dir
OUTPUT_ROOT = config.output_root

OUTPUT_DATA_ROOT       = config.output_data_root
OUTPUT_ANALYSIS_ROOT   = config.output_analysis_root
OUTPUT_BENCHMARK_ROOT  = config.output_benchmark_root

OUTPUT_DIR = config.output_dir("benchmark")

DATA_DIR        = config.data_dir
LEGACY_DATA_DIR = config.legacy_data_dir

EARTH_DENSITY_TPEANUTS = str(DATA_DIR / "earth" / "prem" / "fit" / "even_power_electron.csv")
EARTH_DENSITY_LEGACY   = str(LEGACY_DATA_DIR / "earth_density.csv")
SOLAR_MODEL_FILE = str(LEGACY_DATA_DIR / "nudistr_b16_agss09.dat")
SOLAR_FLUX_FILE = str(LEGACY_DATA_DIR / "fluxes_b16.dat")
SOLAR_DENSITY_CSV_FILE = str(DATA_DIR / "solar" / "bahcall" / "density" / "bp2000_density_electron_neutron_monotonic.csv")
SOLAR_FLUX_CSV_FILE = str(DATA_DIR / "solar" / "bahcall" / "flux" / "fluxes_bahcall_bp2004.csv")
SPECTRUM_FILES = {
    "8B":         str(LEGACY_DATA_DIR / "8B_shape_Ortiz_et_al.csv"),
    "hep":        str(LEGACY_DATA_DIR / "hep_shape.csv"),
    "pp":         str(LEGACY_DATA_DIR / "pp_shape.csv"),
    "17F":        str(LEGACY_DATA_DIR / "f17_shape.csv"),
    "7Beground":  str(LEGACY_DATA_DIR / "be7ground_shape.csv"),
    "7Beexcited": str(LEGACY_DATA_DIR / "be7excited_shape.csv"),
    "13N":        str(LEGACY_DATA_DIR / "n13_shape.csv"),
    "15O":        str(LEGACY_DATA_DIR / "o15_shape.csv"),
}

print(f"PACKAGE_DIR = {PACKAGE_DIR}")
print("Legacy Data Dir :", LEGACY_DATA_DIR)
print("Torch solar model:", SOLAR_DENSITY_CSV_FILE)
print("Torch solar flux :", SOLAR_FLUX_CSV_FILE)
print("Output directory:", OUTPUT_DIR)
# Out:
# PACKAGE_DIR = G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts
# Legacy Data Dir : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\peanuts
# Torch solar model: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\solar\bahcall\density\bp2000_density_electron_neutron_monotonic.csv
# Torch solar flux : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\solar\bahcall\flux\fluxes_bahcall_bp2004.csv
# Output directory: v:\output\benchmark

# %% [markdown]
# ### 2.2 Configuration
#
# This section defines the physical inputs and timing controls used by the benchmark. The oscillation parameters are loaded from the project preset, the Earth and solar density files are fixed explicitly, and the benchmark grids control the computational load.
#
# | Parameter | Value | Description |
# |-----------|-------|-------------|
# | Oscillation preset | default `oscillation_parameters_from_preset` | Three-flavour NuFIT-style benchmark point |
# | Vacuum baseline | 1300 km | Long-baseline reference distance |
# | Solar source | `8B` | Source used for solar production benchmarks |
# | Earth profile | bundled `even_power_electron.csv` | Five-layer perturbative Earth propagation profile |
# | Solar profile | bundled B16 AGSS09 CSV | TPeanuts solar density and production profile |
# | Legacy profile | bundled `data/peanuts` files | Legacy `peanuts` reference data |
# | Energy grid sizes | 4 to 1024 | Scaling axis for all workflows |
# | Nadir grid sizes | 4 to 256 | Scaling axis for Earth-dependent workflows |
# | Timing repeats/warmups | configurable below | Warm-up removes first-call/JIT effects from timing |
#
# **Expected results:**<br>
# - The configuration cell should print the active repeat/warm-up counts and build one consistent set of oscillation parameters for both implementations.

# %%
DEVICE = config.device
DTYPE  = config.dtype
SHOW_PLOTS = config.show_plots
GPU_DEVICE = torch.device("cuda", 0) if torch.cuda.is_available() else None

context     = RuntimeContext.resolve(DEVICE, DTYPE)
oscillation = PropagationConfig.oscillation_parameters_from_preset(context=context, antinu=False)
pmns        = oscillation.pmns
THETA12  = float(pmns.params.theta12.detach().cpu())
THETA13  = float(pmns.params.theta13.detach().cpu())
THETA23  = float(pmns.params.theta23.detach().cpu())
DELTA_CP = float(pmns.params.delta.detach().cpu())
DM21_EV2 = float(oscillation.mass_spectrum.DeltamSq21.detach().cpu())
DM3L_EV2 = float(oscillation.mass_spectrum.DeltamSq3l.detach().cpu())
legacy_pmns = LegacyPMNS(THETA12, THETA13, THETA23, DELTA_CP)

#ENERGY_GRID_SIZES = [4, 8, 16, 32, 64, 128, 256, 512]
#NADIR_GRID_SIZES  = [4, 8, 16, 32, 64, 128, 256, 512]
N_EGRIDS = 9
N_AGRIDS = 9
ENERGY_GRID_SIZES = [4*2**n for n in range(N_EGRIDS)]
NADIR_GRID_SIZES = [4*2**n for n in range(N_AGRIDS)]
EARTH_METHOD_COMPARISON_ENERGY_SIZES = [16, 64, 256]
EARTH_METHOD_COMPARISON_NADIR_SIZES = [16, 64, 256]

# More repeats/warmups for stable timing and proper Numba JIT warm-up
TIMING_REPEATS = 5   # was 2 — minimum for reliable min/mean
TIMING_WARMUPS = 3   # was 1 — ensures Numba JIT compiles before timing

EARTH_METHOD          = "analytical"   # "analytical" or "numerical"
LEGACY_EARTH_MODE     = EARTH_METHOD
EARTH_NUMERICAL_STEPS = 160
EARTH_ODE_METHOD      = "midpoint"

EARTH_DEPTH_M          = 0.0
SOLAR_DETECTOR_DEPTH_M = 1000.0
SOLAR_SOURCE           = "8B"
VACUUM_BASELINE_KM     = 1300.0

# Solar matter-mixing precision mode (see benchmark0_tpeanuts_vs_peanuts_precision.ipynb,
# Section 4.4, for the diagnosis): False (default) evaluates Vk/th12_M/th13_M
# from full-precision physical constants; True switches to the legacy peanuts
# combined Vk prefactor (3.868e-7 / 2.533, each hardcoded to 4 significant
# digits there). Only affects numerical agreement with legacy, not timing.
SOLAR_LEGACY_PRECISION = False

MASS_WEIGHTS    = torch.tensor([0.20, 0.30, 0.50], dtype=DTYPE, device=DEVICE)
MASS_WEIGHTS_NP = np.array([0.20, 0.30, 0.50], dtype=np.float64)

print("Performance benchmark parameters loaded.")
print(f"  TIMING_REPEATS = {TIMING_REPEATS},  TIMING_WARMUPS = {TIMING_WARMUPS}")
# Out:
# Performance benchmark parameters loaded.
#   TIMING_REPEATS = 5,  TIMING_WARMUPS = 3

# %% [markdown]
# The following cell builds the shared Earth and solar model objects used by the benchmark. TPeanuts uses the current `EarthProfile`, `EarthParameters`, `SolarMediumProfile`, `SolarMediumParameters`, `SolarNeutrinoSource`, and `SolarSourceParameters` APIs, while the legacy side uses the bundled `peanuts` objects.
#
# **Expected results:**<br>
# - both TPeanuts and legacy density/solar models should load successfully before any timing loop starts.

# %%
earth_profile_t = EarthProfile(
    params=EarthParameters(
        profile_perturbative_kwargs={"density_file": EARTH_DENSITY_TPEANUTS, "tabulated_density": False},
    ),
    context=context,
)
earth_density_l = LegacyEarthDensity(density_file=EARTH_DENSITY_LEGACY, tabulated_density=False)
# SOLAR_DENSITY_CSV_FILE (bp2000_density_electron_neutron_monotonic.csv) starts at
# r=0.001 R_sun rather than r=0.0, which conflicts with SolarNeutrinoSource's default
# production_radius grid (always [0.0, 1.0]) and raises ValueError in
# solar_probability_state/solar_probability_mass. This is a performance benchmark, not
# a precision comparison (see Section 0.4), so the plain bundled default solar medium
# (domain [0.0, 1.0], consistent with the default source) is used instead.
solar_medium = SolarMediumProfile.default(context=context)
solar_source = SolarNeutrinoSource.default(
    params=SolarSourceParameters(
        fluxes_path=SOLAR_FLUX_CSV_FILE,
    ),
    context=context,
)
legacy_pmns_module, legacy_solar_module = legacy_modules()
legacy_model = legacy_solar_module.SolarModel(
    solar_model_file=SOLAR_MODEL_FILE,
    flux_file=SOLAR_FLUX_FILE,
    spectrum_files=SPECTRUM_FILES,
)
legacy_pmns_solar = legacy_pmns_module.PMNS(THETA12, THETA13, THETA23, DELTA_CP)
print("Shared density and solar models loaded.")
# Out:
# Shared density and solar models loaded.

# %% [markdown]
# ### 2.3 Local Helpers
#
# The helper functions below keep repeated benchmark mechanics in one place: grid construction, timing loops, plotting, legacy wrappers, and small pipeline wrappers for solar, Earth, and solar-to-detector workflows. They are local to this notebook because they combine benchmark-specific timing logic with several physical modules.
#
# **Expected results:**<br>
# - This cell should only define functions and print a confirmation message.
# - No benchmark timing is performed yet.

# %%
configure_benchmark_helpers(globals(), backend="legacy")
print("Benchmark helpers imported from notebooks/benchmark/benchmark_helpers.py.")
# Out:
# Benchmark helpers imported from notebooks/benchmark/benchmark_helpers.py.

# %% [markdown]
# ## 3. Vacuum Propagation
#
# This section benchmarks vacuum flavour-transition probabilities and a synthetic incoherent flux contraction. The TPeanuts path uses the batched `vacuum_probability_transition` API, while the legacy path loops over `peanuts.vacuum.Pvacuum`.
#
# **Expected results:**<br>
# - The probability and flux timings should scale primarily with energy-grid size. TPeanuts is expected to benefit from batched tensor evaluation as the grid grows.

# %% [markdown]
# ### 3.1 Probability Timing
#
# The output table stores best, mean, and standard-deviation timings for each energy-grid size. The plot shows absolute timing and the fitted log-log scaling slope.
#
# **Expected results:**<br>
# - Both implementations should return finite timings; the speedup curve should reveal where tensor batching overtakes scalar legacy loops.

# %%
vacuum_probability_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=False)
    vacuum_probability_records.append(benchmark_pair(
        "vacuum probabilities", ne, None,
        lambda E=E: vacuum_probability_transition(oscillation, E, VACUUM_BASELINE_KM, context=context),
        lambda E=E: legacy_vacuum_matrix(E, VACUUM_BASELINE_KM),
    ))
vacuum_probability_df = pd.DataFrame(vacuum_probability_records)
display(vacuum_probability_df)
save_results(vacuum_probability_df, "vacuum_probability_timing")
plot_energy_scaling(vacuum_probability_df, "Vacuum probability timing", "vacuum_probability_timing.png")
# Out:
# vacuum probabilities               | NE=   4 | Neta=None | t=2.8766e-03s+/-2.9e-04 | leg=7.9410e-04s | x0.28
# vacuum probabilities               | NE=   8 | Neta=None | t=2.8823e-03s+/-1.4e-04 | leg=1.2075e-03s | x0.42
# vacuum probabilities               | NE=  16 | Neta=None | t=2.8356e-03s+/-1.8e-04 | leg=2.0512e-03s | x0.72
# vacuum probabilities               | NE=  32 | Neta=None | t=2.8426e-03s+/-5.8e-05 | leg=3.6895e-03s | x1.30
# vacuum probabilities               | NE=  64 | Neta=None | t=2.8565e-03s+/-3.9e-05 | leg=7.0355e-03s | x2.46
# vacuum probabilities               | NE= 128 | Neta=None | t=2.8165e-03s+/-5.3e-05 | leg=1.3682e-02s | x4.86
# vacuum probabilities               | NE= 256 | Neta=None | t=2.8776e-03s+/-2.9e-05 | leg=2.6908e-02s | x9.35
# vacuum probabilities               | NE= 512 | Neta=None | t=2.8657e-03s+/-1.8e-04 | leg=5.3288e-02s | x18.60
# vacuum probabilities               | NE=1024 | Neta=None | t=2.8778e-03s+/-1.1e-04 | leg=1.0630e-01s | x36.94
#                 section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  vacuum probabilities         4    None         0.002877       0.000794
# 1  vacuum probabilities         8    None         0.002882       0.001207
# 2  vacuum probabilities        16    None         0.002836       0.002051
# 3  vacuum probabilities        32    None         0.002843       0.003689
# 4  vacuum probabilities        64    None         0.002856       0.007035
# 5  vacuum probabilities       128    None         0.002816       0.013682
# 6  vacuum probabilities       256    None         0.002878       0.026908
# 7  vacuum probabilities       512    None         0.002866       0.053288
# 8  vacuum probabilities      1024    None         0.002878       0.106299
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.003122       0.000808        0.000285      0.000013
# 1         0.003164       0.001227        0.000143      0.000011
# 2         0.003008       0.002125        0.000182      0.000093
# 3         0.002893       0.003750        0.000058      0.000041
# 4         0.002908       0.007106        0.000039      0.000058
# 5         0.002878       0.014081        0.000053      0.000494
# 6         0.002933       0.027370        0.000029      0.000371
# 7         0.003020       0.055000        0.000183      0.002914
# 8         0.003028       0.107729        0.000105      0.001775
#
#    speedup_legacy_over_tpeanuts
# 0                      0.276055
# 1                      0.418936
# 2                      0.723374
# 3                      1.297931
# 4                      2.462979
# 5                      4.857944
# 6                      9.350952
# 7                     18.595177
# 8                     36.937452
# Saved: v:\output\benchmark\vacuum_probability_timing.csv
# v:\output\benchmark\vacuum_probability_timing.png

# %% [markdown]
# ### 3.2 Flux Timing
#
# This benchmark applies the vacuum probability matrix to a synthetic three-flavour flux vector.
#
# **Expected results:**<br>
# - The flux timing should follow the probability timing plus a small matrix-vector contraction overhead.

# %%
vacuum_flux_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=False)
    flux_t = synthetic_flux(E)
    flux_l = to_numpy(flux_t)
    vacuum_flux_records.append(benchmark_pair(
        "vacuum flux", ne, None,
        lambda E=E, ft=flux_t: probability_incoherent(
            vacuum_probability_transition(oscillation, E, VACUUM_BASELINE_KM, context=context), ft),
        lambda E=E, fl=flux_l: np.einsum("eba,ea->eb", legacy_vacuum_matrix(E, VACUUM_BASELINE_KM), fl),
    ))
vacuum_flux_df = pd.DataFrame(vacuum_flux_records)
display(vacuum_flux_df)
save_results(vacuum_flux_df, "vacuum_flux_timing")
plot_energy_scaling(vacuum_flux_df, "Vacuum flux timing", "vacuum_flux_timing.png")
# Out:
# vacuum flux                        | NE=   4 | Neta=None | t=3.4050e-03s+/-1.7e-04 | leg=8.2860e-04s | x0.24
# vacuum flux                        | NE=   8 | Neta=None | t=3.8077e-03s+/-3.5e-04 | leg=1.2379e-03s | x0.33
# vacuum flux                        | NE=  16 | Neta=None | t=3.7755e-03s+/-2.4e-04 | leg=2.0901e-03s | x0.55
# vacuum flux                        | NE=  32 | Neta=None | t=3.8536e-03s+/-8.9e-04 | leg=3.7653e-03s | x0.98
# vacuum flux                        | NE=  64 | Neta=None | t=3.8228e-03s+/-1.9e-03 | leg=7.1177e-03s | x1.86
# vacuum flux                        | NE= 128 | Neta=None | t=3.8093e-03s+/-2.9e-04 | leg=1.3846e-02s | x3.63
# vacuum flux                        | NE= 256 | Neta=None | t=3.9871e-03s+/-8.7e-04 | leg=2.7150e-02s | x6.81
# vacuum flux                        | NE= 512 | Neta=None | t=3.7560e-03s+/-2.0e-04 | leg=5.3710e-02s | x14.30
# vacuum flux                        | NE=1024 | Neta=None | t=3.9723e-03s+/-5.8e-05 | leg=1.0753e-01s | x27.07
#        section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  vacuum flux         4    None         0.003405       0.000829
# 1  vacuum flux         8    None         0.003808       0.001238
# 2  vacuum flux        16    None         0.003775       0.002090
# 3  vacuum flux        32    None         0.003854       0.003765
# 4  vacuum flux        64    None         0.003823       0.007118
# 5  vacuum flux       128    None         0.003809       0.013846
# 6  vacuum flux       256    None         0.003987       0.027150
# 7  vacuum flux       512    None         0.003756       0.053710
# 8  vacuum flux      1024    None         0.003972       0.107525
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.003570       0.000869        0.000167      0.000059
# 1         0.004119       0.001283        0.000346      0.000054
# 2         0.004006       0.002146        0.000240      0.000048
# 3         0.004470       0.003806        0.000885      0.000028
# 4         0.004937       0.007456        0.001911      0.000598
# 5         0.004171       0.013954        0.000292      0.000088
# 6         0.004714       0.027324        0.000874      0.000199
# 7         0.003960       0.053872        0.000201      0.000238
# 8         0.004052       0.107965        0.000058      0.000222
#
#    speedup_legacy_over_tpeanuts
# 0                      0.243348
# 1                      0.325104
# 2                      0.553596
# 3                      0.977086
# 4                      1.861908
# 5                      3.634789
# 6                      6.809461
# 7                     14.299707
# 8                     27.068726
# Saved: v:\output\benchmark\vacuum_flux_timing.csv
# v:\output\benchmark\vacuum_flux_timing.png

# %% [markdown]
# ## 4. Solar Production
#
# This section benchmarks solar production probabilities and mass-basis source weights for the selected solar source. `SOLAR_LEGACY_PRECISION` controls the matter-mixing prefactor used by `solar_probability_state` and `solar_probability_mass`; it affects numerical compatibility with legacy constants, not the benchmark structure.
#
# **Expected results:**<br>
# - TPeanuts should evaluate the full energy grid in one tensor call, while legacy solar probabilities are computed by scalar loops over energy.

# %% [markdown]
# ### 4.1 Probability Timing
#
# The benchmark compares `solar_probability_state` against legacy `Psolar` over increasing energy-grid sizes.
#
# **Expected results:**<br>
# - Timing should increase with grid size, and vectorized TPeanuts evaluation should reduce Python-loop overhead.

# %%
solar_probability_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=True)
    solar_probability_records.append(benchmark_pair(
        "solar probabilities", ne, None,
        lambda E=E: solar_probability_state(oscillation, E, solar_medium, solar_source, SOLAR_SOURCE,
                            legacy_precision=SOLAR_LEGACY_PRECISION),
        lambda E=E: np.stack([
            legacy_solar_module.Psolar(legacy_pmns_solar, DM21_EV2, DM3L_EV2, float(e),
                                       legacy_model.radius(), legacy_model.density(),
                                       legacy_model.fraction(SOLAR_SOURCE))
            for e in to_numpy(E)
        ]),
    ))
solar_probability_df = pd.DataFrame(solar_probability_records)
display(solar_probability_df)
save_results(solar_probability_df, "solar_probability_timing")
plot_energy_scaling(solar_probability_df, "Solar probability timing", "solar_probability_timing.png")
# Out:
# solar probabilities                | NE=   4 | Neta=None | t=6.1412e-03s+/-4.3e-04 | leg=8.9400e-04s | x0.15
# solar probabilities                | NE=   8 | Neta=None | t=6.1636e-03s+/-3.0e-03 | leg=1.4046e-03s | x0.23
# solar probabilities                | NE=  16 | Neta=None | t=6.3399e-03s+/-3.5e-04 | leg=2.3569e-03s | x0.37
# solar probabilities                | NE=  32 | Neta=None | t=6.5764e-03s+/-2.4e-04 | leg=4.3261e-03s | x0.66
# solar probabilities                | NE=  64 | Neta=None | t=7.0053e-03s+/-1.5e-04 | leg=8.2364e-03s | x1.18
# solar probabilities                | NE= 128 | Neta=None | t=8.2557e-03s+/-3.8e-04 | leg=1.6049e-02s | x1.94
# solar probabilities                | NE= 256 | Neta=None | t=5.5459e-03s+/-2.7e-04 | leg=3.1645e-02s | x5.71
# solar probabilities                | NE= 512 | Neta=None | t=5.8440e-03s+/-1.3e-04 | leg=6.2968e-02s | x10.77
# solar probabilities                | NE=1024 | Neta=None | t=6.5882e-03s+/-4.9e-04 | leg=1.2541e-01s | x19.04
#                section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  solar probabilities         4    None         0.006141       0.000894
# 1  solar probabilities         8    None         0.006164       0.001405
# 2  solar probabilities        16    None         0.006340       0.002357
# 3  solar probabilities        32    None         0.006576       0.004326
# 4  solar probabilities        64    None         0.007005       0.008236
# 5  solar probabilities       128    None         0.008256       0.016049
# 6  solar probabilities       256    None         0.005546       0.031645
# 7  solar probabilities       512    None         0.005844       0.062968
# 8  solar probabilities      1024    None         0.006588       0.125409
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.006481       0.000967        0.000430      0.000080
# 1         0.007892       0.001421        0.003038      0.000018
# 2         0.006629       0.002438        0.000347      0.000096
# 3         0.006858       0.004350        0.000240      0.000020
# 4         0.007156       0.008274        0.000146      0.000053
# 5         0.008710       0.016780        0.000381      0.001343
# 6         0.005726       0.031760        0.000272      0.000151
# 7         0.005956       0.063555        0.000131      0.000384
# 8         0.006946       0.128601        0.000487      0.003109
#
#    speedup_legacy_over_tpeanuts
# 0                      0.145574
# 1                      0.227886
# 2                      0.371757
# 3                      0.657822
# 4                      1.175738
# 5                      1.943942
# 6                      5.706089
# 7                     10.774795
# 8                     19.035336
# Saved: v:\output\benchmark\solar_probability_timing.csv
# v:\output\benchmark\solar_probability_timing.png

# %% [markdown]
# ### 4.2 Flux Timing
#
# This benchmark applies a simple source-spectrum weight to the solar mass-basis probabilities.
#
# **Expected results:**<br>
# - Timing should be close to the solar mass-probability timing because the spectrum multiplication is inexpensive.

# %%
solar_flux_records = []
for ne in ENERGY_GRID_SIZES:
    E = energy_grid(ne, solar=True)
    spectrum_t = solar_source_spectrum(E)
    spectrum_l = to_numpy(spectrum_t)
    solar_flux_records.append(benchmark_pair(
        "solar flux", ne, None,
        lambda E=E, st=spectrum_t: tpeanuts_solar_mass(E) * st[:, None],
        lambda E=E, sl=spectrum_l: legacy_solar_mass(E) * sl[:, None],
    ))
solar_flux_df = pd.DataFrame(solar_flux_records)
display(solar_flux_df)
save_results(solar_flux_df, "solar_flux_timing")
plot_energy_scaling(solar_flux_df, "Solar flux timing", "solar_flux_timing.png")
# Out:
# solar flux                         | NE=   4 | Neta=None | t=3.7573e-03s+/-4.6e-04 | leg=8.0160e-04s | x0.21
# solar flux                         | NE=   8 | Neta=None | t=3.7746e-03s+/-6.7e-05 | leg=1.2788e-03s | x0.34
# solar flux                         | NE=  16 | Neta=None | t=3.8400e-03s+/-1.6e-04 | leg=2.1726e-03s | x0.57
# solar flux                         | NE=  32 | Neta=None | t=3.8095e-03s+/-1.9e-04 | leg=3.9527e-03s | x1.04
# solar flux                         | NE=  64 | Neta=None | t=3.8423e-03s+/-7.4e-05 | leg=7.5640e-03s | x1.97
# solar flux                         | NE= 128 | Neta=None | t=3.8674e-03s+/-1.1e-04 | leg=1.4766e-02s | x3.82
# solar flux                         | NE= 256 | Neta=None | t=3.9286e-03s+/-1.4e-04 | leg=2.8945e-02s | x7.37
# solar flux                         | NE= 512 | Neta=None | t=4.2233e-03s+/-1.1e-04 | leg=5.7300e-02s | x13.57
# solar flux                         | NE=1024 | Neta=None | t=5.0993e-03s+/-3.3e-03 | leg=1.1512e-01s | x22.58
#       section  n_energy n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0  solar flux         4    None         0.003757       0.000802
# 1  solar flux         8    None         0.003775       0.001279
# 2  solar flux        16    None         0.003840       0.002173
# 3  solar flux        32    None         0.003810       0.003953
# 4  solar flux        64    None         0.003842       0.007564
# 5  solar flux       128    None         0.003867       0.014766
# 6  solar flux       256    None         0.003929       0.028945
# 7  solar flux       512    None         0.004223       0.057300
# 8  solar flux      1024    None         0.005099       0.115118
#
#    tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0         0.004263       0.000817        0.000462      0.000008
# 1         0.003855       0.001307        0.000067      0.000046
# 2         0.003977       0.002211        0.000161      0.000034
# 3         0.003974       0.003968        0.000185      0.000016
# 4         0.003935       0.007883        0.000074      0.000593
# 5         0.004021       0.014864        0.000113      0.000071
# 6         0.004039       0.029280        0.000142      0.000241
# 7         0.004348       0.057801        0.000107      0.000371
# 8         0.009261       0.116056        0.003337      0.000877
#
#    speedup_legacy_over_tpeanuts
# 0                      0.213345
# 1                      0.338791
# 2                      0.565781
# 3                      1.037590
# 4                      1.968613
# 5                      3.817991
# 6                      7.367816
# 7                     13.567613
# 8                     22.575256
# Saved: v:\output\benchmark\solar_flux_timing.csv
# v:\output\benchmark\solar_flux_timing.png

# %% [markdown]
# ## 5. Earth Propagation
#
# This section benchmarks Earth matter propagation over two-dimensional energy-nadir grids. Analytical TPeanuts propagation is batched over the grid, while the legacy reference loops over scalar `Pearth` calls.
#
# **Expected results:**<br>
# - Speedup should generally grow with the two-dimensional grid size, especially for analytical Earth propagation.

# %% [markdown]
# ### 5.1 Probability Timing
#
# The initial state is an incoherent mass-basis weight vector propagated through the Earth density profile.
#
# **Expected results:**<br>
# - The heatmap should show how speedup depends jointly on energy and nadir grid sizes.

# %%
earth_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        earth_probability_records.append(benchmark_pair(
            "earth probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: torch_pearth_probability(
                MASS_WEIGHTS, E[:, None], eta[None, :], EARTH_DEPTH_M, massbasis=True),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d): np.stack([
                legacy_pearth(MASS_WEIGHTS_NP, earth_density_l, legacy_pmns,
                              DM21_EV2, DM3L_EV2, float(e), float(a),
                              EARTH_DEPTH_M, mode=LEGACY_EARTH_MODE, massbasis=True)
                for e in E_np for a in eta_np
            ]).reshape(len(E_np), len(eta_np), 3),
        ))
earth_probability_df = pd.DataFrame(earth_probability_records)
display(earth_probability_df)
save_results(earth_probability_df, "earth_probability_timing")
plot_heatmap(earth_probability_df, "Earth probability speedup (LogNorm)",
              "earth_probability_speedup.png")
plot_speedup_cross_sections(earth_probability_df, "Earth probability speedup cross sections",
                              "earth_probability_speedup_cross_sections.png")
# Out:
# earth probabilities                | NE=   4 | Neta=   4 | t=3.6084e-02s+/-1.8e-03 | leg=9.3220e-04s | x0.03
# earth probabilities                | NE=   4 | Neta=   8 | t=3.3374e-02s+/-2.7e-04 | leg=1.5178e-03s | x0.05
# earth probabilities                | NE=   4 | Neta=  16 | t=3.3676e-02s+/-2.0e-04 | leg=2.7696e-03s | x0.08
# earth probabilities                | NE=   4 | Neta=  32 | t=3.5975e-02s+/-1.4e-03 | leg=5.2597e-03s | x0.15
# earth probabilities                | NE=   4 | Neta=  64 | t=3.8971e-02s+/-8.3e-04 | leg=1.0253e-02s | x0.26
# earth probabilities                | NE=   4 | Neta= 128 | t=4.2382e-02s+/-3.2e-03 | leg=2.0444e-02s | x0.48
# earth probabilities                | NE=   4 | Neta= 256 | t=5.1279e-02s+/-1.1e-03 | leg=4.0692e-02s | x0.79
# earth probabilities                | NE=   4 | Neta= 512 | t=6.6476e-02s+/-6.9e-04 | leg=8.0021e-02s | x1.20
# earth probabilities                | NE=   4 | Neta=1024 | t=9.1621e-02s+/-1.7e-03 | leg=1.6072e-01s | x1.75
# earth probabilities                | NE=   8 | Neta=   4 | t=3.3983e-02s+/-8.6e-04 | leg=1.7086e-03s | x0.05
# earth probabilities                | NE=   8 | Neta=   8 | t=3.3210e-02s+/-8.9e-04 | leg=2.8564e-03s | x0.09
# earth probabilities                | NE=   8 | Neta=  16 | t=3.3844e-02s+/-2.8e-04 | leg=5.2848e-03s | x0.16
# earth probabilities                | NE=   8 | Neta=  32 | t=3.5717e-02s+/-2.6e-03 | leg=1.0254e-02s | x0.29
# earth probabilities                | NE=   8 | Neta=  64 | t=5.1551e-02s+/-5.9e-03 | leg=2.0215e-02s | x0.39
# earth probabilities                | NE=   8 | Neta= 128 | t=4.7452e-02s+/-7.2e-04 | leg=4.0421e-02s | x0.85
# earth probabilities                | NE=   8 | Neta= 256 | t=6.0352e-02s+/-8.2e-04 | leg=7.9633e-02s | x1.32
# earth probabilities                | NE=   8 | Neta= 512 | t=8.4834e-02s+/-2.1e-03 | leg=1.6071e-01s | x1.89
# earth probabilities                | NE=   8 | Neta=1024 | t=1.4426e-01s+/-1.3e-03 | leg=3.1876e-01s | x2.21
# earth probabilities                | NE=  16 | Neta=   4 | t=3.3405e-02s+/-9.4e-04 | leg=3.2635e-03s | x0.10
# earth probabilities                | NE=  16 | Neta=   8 | t=3.3973e-02s+/-1.1e-03 | leg=5.4707e-03s | x0.16
# earth probabilities                | NE=  16 | Neta=  16 | t=3.5134e-02s+/-4.2e-04 | leg=1.0424e-02s | x0.30
# earth probabilities                | NE=  16 | Neta=  32 | t=3.8136e-02s+/-2.0e-04 | leg=2.0190e-02s | x0.53
# earth probabilities                | NE=  16 | Neta=  64 | t=4.4558e-02s+/-3.7e-04 | leg=4.0126e-02s | x0.90
# earth probabilities                | NE=  16 | Neta= 128 | t=5.8268e-02s+/-5.6e-04 | leg=8.0425e-02s | x1.38
# earth probabilities                | NE=  16 | Neta= 256 | t=8.4519e-02s+/-7.4e-04 | leg=1.6051e-01s | x1.90
# earth probabilities                | NE=  16 | Neta= 512 | t=1.4436e-01s+/-1.4e-03 | leg=3.2046e-01s | x2.22
# earth probabilities                | NE=  16 | Neta=1024 | t=2.8782e-01s+/-2.3e-03 | leg=6.3816e-01s | x2.22
# earth probabilities                | NE=  32 | Neta=   4 | t=3.4577e-02s+/-8.7e-04 | leg=6.3228e-03s | x0.18
# earth probabilities                | NE=  32 | Neta=   8 | t=3.6612e-02s+/-9.1e-04 | leg=1.0991e-02s | x0.30
# earth probabilities                | NE=  32 | Neta=  16 | t=4.1494e-02s+/-1.2e-03 | leg=2.0672e-02s | x0.50
# earth probabilities                | NE=  32 | Neta=  32 | t=4.7514e-02s+/-2.5e-03 | leg=4.0635e-02s | x0.86
# earth probabilities                | NE=  32 | Neta=  64 | t=6.3425e-02s+/-4.2e-04 | leg=8.0354e-02s | x1.27
# earth probabilities                | NE=  32 | Neta= 128 | t=8.9701e-02s+/-7.8e-04 | leg=1.6164e-01s | x1.80
# earth probabilities                | NE=  32 | Neta= 256 | t=1.4432e-01s+/-1.1e-03 | leg=3.2261e-01s | x2.24
# earth probabilities                | NE=  32 | Neta= 512 | t=2.9061e-01s+/-4.4e-03 | leg=6.3723e-01s | x2.19
# earth probabilities                | NE=  32 | Neta=1024 | t=5.7725e-01s+/-2.7e-03 | leg=1.2801e+00s | x2.22
# earth probabilities                | NE=  64 | Neta=   4 | t=4.2391e-02s+/-2.6e-03 | leg=1.2683e-02s | x0.30
# earth probabilities                | NE=  64 | Neta=   8 | t=3.9685e-02s+/-9.3e-04 | leg=2.1756e-02s | x0.55
# earth probabilities                | NE=  64 | Neta=  16 | t=4.7567e-02s+/-1.3e-03 | leg=4.1315e-02s | x0.87
# earth probabilities                | NE=  64 | Neta=  32 | t=6.0722e-02s+/-2.5e-04 | leg=8.1484e-02s | x1.34
# earth probabilities                | NE=  64 | Neta=  64 | t=8.4806e-02s+/-1.1e-03 | leg=1.6132e-01s | x1.90
# earth probabilities                | NE=  64 | Neta= 128 | t=1.4424e-01s+/-2.4e-03 | leg=3.2494e-01s | x2.25
# earth probabilities                | NE=  64 | Neta= 256 | t=2.8871e-01s+/-2.7e-03 | leg=6.4427e-01s | x2.23
# earth probabilities                | NE=  64 | Neta= 512 | t=5.7753e-01s+/-5.3e-03 | leg=1.2987e+00s | x2.25
# earth probabilities                | NE=  64 | Neta=1024 | t=1.1666e+00s+/-3.4e-02 | leg=2.5750e+00s | x2.21
# earth probabilities                | NE= 128 | Neta=   4 | t=4.0123e-02s+/-5.6e-04 | leg=2.5106e-02s | x0.63
# earth probabilities                | NE= 128 | Neta=   8 | t=4.7726e-02s+/-1.6e-03 | leg=4.3310e-02s | x0.91
# earth probabilities                | NE= 128 | Neta=  16 | t=5.7561e-02s+/-1.5e-03 | leg=8.2320e-02s | x1.43
# earth probabilities                | NE= 128 | Neta=  32 | t=8.4800e-02s+/-1.5e-03 | leg=1.6189e-01s | x1.91
# earth probabilities                | NE= 128 | Neta=  64 | t=1.4383e-01s+/-1.9e-03 | leg=3.2081e-01s | x2.23
# earth probabilities                | NE= 128 | Neta= 128 | t=2.8748e-01s+/-2.1e-03 | leg=6.4928e-01s | x2.26
# earth probabilities                | NE= 128 | Neta= 256 | t=5.7498e-01s+/-3.4e-03 | leg=1.2852e+00s | x2.24
# earth probabilities                | NE= 128 | Neta= 512 | t=1.1558e+00s+/-2.9e-03 | leg=2.5791e+00s | x2.23
# earth probabilities                | NE= 128 | Neta=1024 | t=2.3080e+00s+/-5.4e-03 | leg=5.1352e+00s | x2.22
# earth probabilities                | NE= 256 | Neta=   4 | t=4.9219e-02s+/-7.2e-04 | leg=4.9691e-02s | x1.01
# earth probabilities                | NE= 256 | Neta=   8 | t=6.3984e-02s+/-5.2e-04 | leg=8.6680e-02s | x1.35
# earth probabilities                | NE= 256 | Neta=  16 | t=8.3535e-02s+/-6.6e-04 | leg=1.6391e-01s | x1.96
# earth probabilities                | NE= 256 | Neta=  32 | t=1.4456e-01s+/-5.7e-04 | leg=3.2378e-01s | x2.24
# earth probabilities                | NE= 256 | Neta=  64 | t=2.8779e-01s+/-2.4e-03 | leg=6.4382e-01s | x2.24
# earth probabilities                | NE= 256 | Neta= 128 | t=5.7404e-01s+/-4.2e-03 | leg=1.2949e+00s | x2.26
# earth probabilities                | NE= 256 | Neta= 256 | t=1.1538e+00s+/-4.4e-03 | leg=2.5768e+00s | x2.23
# earth probabilities                | NE= 256 | Neta= 512 | t=2.3121e+00s+/-7.4e-03 | leg=5.1774e+00s | x2.24
# earth probabilities                | NE= 256 | Neta=1024 | t=4.6313e+00s+/-6.7e-03 | leg=1.0340e+01s | x2.23
# earth probabilities                | NE= 512 | Neta=   4 | t=6.2968e-02s+/-1.7e-03 | leg=9.9535e-02s | x1.58
# earth probabilities                | NE= 512 | Neta=   8 | t=8.9160e-02s+/-1.7e-03 | leg=1.7426e-01s | x1.95
# earth probabilities                | NE= 512 | Neta=  16 | t=1.4333e-01s+/-1.9e-03 | leg=3.2952e-01s | x2.30
# earth probabilities                | NE= 512 | Neta=  32 | t=2.8555e-01s+/-3.6e-03 | leg=6.4906e-01s | x2.27
# earth probabilities                | NE= 512 | Neta=  64 | t=5.7265e-01s+/-3.5e-03 | leg=1.2945e+00s | x2.26
# earth probabilities                | NE= 512 | Neta= 128 | t=1.1546e+00s+/-8.3e-03 | leg=2.5970e+00s | x2.25
# earth probabilities                | NE= 512 | Neta= 256 | t=2.3113e+00s+/-7.4e-03 | leg=5.1655e+00s | x2.23
# earth probabilities                | NE= 512 | Neta= 512 | t=4.6375e+00s+/-6.8e-03 | leg=1.0373e+01s | x2.24
# earth probabilities                | NE= 512 | Neta=1024 | t=9.2734e+00s+/-2.5e-02 | leg=2.0766e+01s | x2.24
# earth probabilities                | NE=1024 | Neta=   4 | t=8.4062e-02s+/-3.4e-03 | leg=1.9841e-01s | x2.36
# earth probabilities                | NE=1024 | Neta=   8 | t=1.4284e-01s+/-5.3e-04 | leg=3.4637e-01s | x2.42
# earth probabilities                | NE=1024 | Neta=  16 | t=2.8482e-01s+/-2.8e-03 | leg=6.5876e-01s | x2.31
# earth probabilities                | NE=1024 | Neta=  32 | t=5.7487e-01s+/-2.9e-03 | leg=1.3055e+00s | x2.27
# earth probabilities                | NE=1024 | Neta=  64 | t=1.1536e+00s+/-8.2e-03 | leg=2.5895e+00s | x2.24
# earth probabilities                | NE=1024 | Neta= 128 | t=2.3164e+00s+/-2.7e-03 | leg=5.2052e+00s | x2.25
# earth probabilities                | NE=1024 | Neta= 256 | t=4.6271e+00s+/-6.4e-03 | leg=1.0382e+01s | x2.24
# earth probabilities                | NE=1024 | Neta= 512 | t=9.2577e+00s+/-2.6e-02 | leg=2.0777e+01s | x2.24
# earth probabilities                | NE=1024 | Neta=1024 | t=1.8524e+01s+/-3.2e-02 | leg=4.1660e+01s | x2.25
#                 section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   earth probabilities         4        4         0.036084       0.000932
# 1   earth probabilities         4        8         0.033374       0.001518
# 2   earth probabilities         4       16         0.033676       0.002770
# 3   earth probabilities         4       32         0.035975       0.005260
# 4   earth probabilities         4       64         0.038971       0.010253
# ..                  ...       ...      ...              ...            ...
# 76  earth probabilities      1024       64         1.153568       2.589520
# 77  earth probabilities      1024      128         2.316440       5.205182
# 78  earth probabilities      1024      256         4.627119      10.381764
# 79  earth probabilities      1024      512         9.257664      20.777019
# 80  earth probabilities      1024     1024        18.524363      41.660241
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.037393       0.000957        0.001811      0.000022
# 1          0.033684       0.001552        0.000268      0.000020
# 2          0.034011       0.002944        0.000200      0.000208
# 3          0.037484       0.005373        0.001387      0.000139
# 4          0.040098       0.011044        0.000833      0.001403
# ..              ...            ...             ...           ...
# 76         1.161383       2.596412        0.008221      0.008984
# 77         2.319333       5.221896        0.002704      0.012917
# 78         4.636126      10.443063        0.006446      0.042085
# 79         9.289760      20.827248        0.026341      0.032620
# 80        18.569551      41.789833        0.031685      0.116820
#
#     speedup_legacy_over_tpeanuts
# 0                       0.025834
# 1                       0.045479
# 2                       0.082243
# 3                       0.146203
# 4                       0.263093
# ..                           ...
# 76                      2.244791
# 77                      2.247061
# 78                      2.243678
# 79                      2.244305
# 80                      2.248943
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\earth_probability_timing.csv
# v:\output\benchmark\earth_probability_speedup.png
# v:\output\benchmark\earth_probability_speedup_cross_sections.png

# %% [markdown]
# ### 5.2 Flux Timing
#
# This benchmark constructs a mass-to-flavour probability matrix and applies it to a synthetic flux vector.
#
# **Expected results:**<br>
# the cost should be higher than a single probability-vector call because three basis states are propagated.

# %%
earth_flux_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        flux   = synthetic_flux(E_1d)
        earth_flux_records.append(benchmark_pair(
            "earth flux", ne, neta,
            lambda E=E_1d, eta=eta_1d, fl=flux: _tpeanuts_earth_flux(E, eta, fl),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d), fl=to_numpy(flux):
                _legacy_earth_flux(E_np, eta_np, fl),
        ))
earth_flux_df = pd.DataFrame(earth_flux_records)
display(earth_flux_df)
save_results(earth_flux_df, "earth_flux_timing")
plot_heatmap(earth_flux_df, "Earth flux speedup (LogNorm)", "earth_flux_speedup.png")
plot_speedup_cross_sections(earth_flux_df, "Earth flux speedup cross sections",
                              "earth_flux_speedup_cross_sections.png")
# Out:
# earth flux                         | NE=   4 | Neta=   4 | t=5.4156e-02s+/-9.2e-04 | leg=2.7659e-03s | x0.05
# earth flux                         | NE=   4 | Neta=   8 | t=5.8021e-02s+/-5.4e-04 | leg=4.7873e-03s | x0.08
# earth flux                         | NE=   4 | Neta=  16 | t=3.3387e-02s+/-7.3e-04 | leg=8.3278e-03s | x0.25
# earth flux                         | NE=   4 | Neta=  32 | t=3.4941e-02s+/-2.8e-03 | leg=1.6999e-02s | x0.49
# earth flux                         | NE=   4 | Neta=  64 | t=4.2491e-02s+/-2.1e-03 | leg=3.3748e-02s | x0.79
# earth flux                         | NE=   4 | Neta= 128 | t=3.9341e-02s+/-2.7e-04 | leg=6.7330e-02s | x1.71
# earth flux                         | NE=   4 | Neta= 256 | t=4.7437e-02s+/-8.1e-04 | leg=1.3473e-01s | x2.84
# earth flux                         | NE=   4 | Neta= 512 | t=5.7327e-02s+/-1.1e-03 | leg=2.6773e-01s | x4.67
# earth flux                         | NE=   4 | Neta=1024 | t=8.4301e-02s+/-1.3e-03 | leg=5.3798e-01s | x6.38
# earth flux                         | NE=   8 | Neta=   4 | t=3.2926e-02s+/-8.4e-04 | leg=5.3739e-03s | x0.16
# earth flux                         | NE=   8 | Neta=   8 | t=3.3209e-02s+/-2.1e-03 | leg=9.1989e-03s | x0.28
# earth flux                         | NE=   8 | Neta=  16 | t=3.3852e-02s+/-6.3e-04 | leg=1.7279e-02s | x0.51
# earth flux                         | NE=   8 | Neta=  32 | t=3.4799e-02s+/-4.4e-04 | leg=3.3830e-02s | x0.97
# earth flux                         | NE=   8 | Neta=  64 | t=3.7463e-02s+/-5.0e-03 | leg=6.6782e-02s | x1.78
# earth flux                         | NE=   8 | Neta= 128 | t=4.3750e-02s+/-8.6e-04 | leg=1.3454e-01s | x3.08
# earth flux                         | NE=   8 | Neta= 256 | t=5.7383e-02s+/-7.4e-04 | leg=2.6771e-01s | x4.67
# earth flux                         | NE=   8 | Neta= 512 | t=8.3470e-02s+/-5.2e-04 | leg=5.3487e-01s | x6.41
# earth flux                         | NE=   8 | Neta=1024 | t=1.4331e-01s+/-2.4e-03 | leg=1.0691e+00s | x7.46
# earth flux                         | NE=  16 | Neta=   4 | t=3.3560e-02s+/-1.7e-03 | leg=1.0416e-02s | x0.31
# earth flux                         | NE=  16 | Neta=   8 | t=3.4547e-02s+/-1.0e-03 | leg=1.8101e-02s | x0.52
# earth flux                         | NE=  16 | Neta=  16 | t=3.6563e-02s+/-6.8e-04 | leg=3.4211e-02s | x0.94
# earth flux                         | NE=  16 | Neta=  32 | t=4.0344e-02s+/-9.8e-04 | leg=6.7614e-02s | x1.68
# earth flux                         | NE=  16 | Neta=  64 | t=4.8344e-02s+/-4.0e-04 | leg=1.3493e-01s | x2.79
# earth flux                         | NE=  16 | Neta= 128 | t=6.6165e-02s+/-1.3e-03 | leg=2.6865e-01s | x4.06
# earth flux                         | NE=  16 | Neta= 256 | t=9.0433e-02s+/-1.7e-03 | leg=5.3543e-01s | x5.92
# earth flux                         | NE=  16 | Neta= 512 | t=1.4578e-01s+/-2.8e-03 | leg=1.0794e+00s | x7.40
# earth flux                         | NE=  16 | Neta=1024 | t=2.9740e-01s+/-2.4e-03 | leg=2.1518e+00s | x7.24
# earth flux                         | NE=  32 | Neta=   4 | t=3.4311e-02s+/-1.4e-03 | leg=2.0574e-02s | x0.60
# earth flux                         | NE=  32 | Neta=   8 | t=3.5889e-02s+/-1.2e-04 | leg=3.5888e-02s | x1.00
# earth flux                         | NE=  32 | Neta=  16 | t=4.0665e-02s+/-4.9e-04 | leg=6.8492e-02s | x1.68
# earth flux                         | NE=  32 | Neta=  32 | t=4.8451e-02s+/-3.4e-04 | leg=1.3545e-01s | x2.80
# earth flux                         | NE=  32 | Neta=  64 | t=6.3590e-02s+/-3.6e-04 | leg=2.6700e-01s | x4.20
# earth flux                         | NE=  32 | Neta= 128 | t=8.4360e-02s+/-3.6e-03 | leg=5.4163e-01s | x6.42
# earth flux                         | NE=  32 | Neta= 256 | t=1.4404e-01s+/-2.0e-03 | leg=1.0793e+00s | x7.49
# earth flux                         | NE=  32 | Neta= 512 | t=2.8823e-01s+/-1.9e-03 | leg=2.1484e+00s | x7.45
# earth flux                         | NE=  32 | Neta=1024 | t=5.7560e-01s+/-3.0e-03 | leg=4.2988e+00s | x7.47
# earth flux                         | NE=  64 | Neta=   4 | t=3.7495e-02s+/-6.3e-04 | leg=4.0723e-02s | x1.09
# earth flux                         | NE=  64 | Neta=   8 | t=3.9879e-02s+/-6.9e-04 | leg=7.2137e-02s | x1.81
# earth flux                         | NE=  64 | Neta=  16 | t=4.8671e-02s+/-9.4e-04 | leg=1.3610e-01s | x2.80
# earth flux                         | NE=  64 | Neta=  32 | t=6.3629e-02s+/-3.2e-04 | leg=2.7064e-01s | x4.25
# earth flux                         | NE=  64 | Neta=  64 | t=8.3434e-02s+/-7.4e-04 | leg=5.4101e-01s | x6.48
# earth flux                         | NE=  64 | Neta= 128 | t=1.4349e-01s+/-4.7e-04 | leg=1.0770e+00s | x7.51
# earth flux                         | NE=  64 | Neta= 256 | t=2.8718e-01s+/-2.6e-03 | leg=2.1451e+00s | x7.47
# earth flux                         | NE=  64 | Neta= 512 | t=5.7747e-01s+/-1.3e-03 | leg=4.2838e+00s | x7.42
# earth flux                         | NE=  64 | Neta=1024 | t=1.1652e+00s+/-4.7e-03 | leg=8.5774e+00s | x7.36
# earth flux                         | NE= 128 | Neta=   4 | t=4.0049e-02s+/-8.9e-04 | leg=8.1072e-02s | x2.02
# earth flux                         | NE= 128 | Neta=   8 | t=4.7059e-02s+/-2.3e-04 | leg=1.4315e-01s | x3.04
# earth flux                         | NE= 128 | Neta=  16 | t=5.9519e-02s+/-7.5e-04 | leg=2.7233e-01s | x4.58
# earth flux                         | NE= 128 | Neta=  32 | t=8.4197e-02s+/-3.3e-04 | leg=5.3804e-01s | x6.39
# earth flux                         | NE= 128 | Neta=  64 | t=1.4356e-01s+/-2.3e-03 | leg=1.0672e+00s | x7.43
# earth flux                         | NE= 128 | Neta= 128 | t=2.8747e-01s+/-1.6e-03 | leg=2.1487e+00s | x7.47
# earth flux                         | NE= 128 | Neta= 256 | t=5.7953e-01s+/-4.7e-04 | leg=4.2986e+00s | x7.42
# earth flux                         | NE= 128 | Neta= 512 | t=1.1546e+00s+/-5.0e-03 | leg=8.5596e+00s | x7.41
# earth flux                         | NE= 128 | Neta=1024 | t=2.2946e+00s+/-9.7e-03 | leg=1.7129e+01s | x7.47
# earth flux                         | NE= 256 | Neta=   4 | t=4.8485e-02s+/-2.2e-03 | leg=1.6191e-01s | x3.34
# earth flux                         | NE= 256 | Neta=   8 | t=5.8365e-02s+/-1.3e-03 | leg=2.8677e-01s | x4.91
# earth flux                         | NE= 256 | Neta=  16 | t=8.4803e-02s+/-5.3e-04 | leg=5.4858e-01s | x6.47
# earth flux                         | NE= 256 | Neta=  32 | t=1.4428e-01s+/-6.3e-04 | leg=1.0810e+00s | x7.49
# earth flux                         | NE= 256 | Neta=  64 | t=2.8721e-01s+/-2.7e-03 | leg=2.1447e+00s | x7.47
# earth flux                         | NE= 256 | Neta= 128 | t=5.8063e-01s+/-7.3e-03 | leg=4.3079e+00s | x7.42
# earth flux                         | NE= 256 | Neta= 256 | t=1.1566e+00s+/-1.4e-03 | leg=8.5645e+00s | x7.41
# earth flux                         | NE= 256 | Neta= 512 | t=2.2947e+00s+/-1.1e-02 | leg=1.7167e+01s | x7.48
# earth flux                         | NE= 256 | Neta=1024 | t=4.6287e+00s+/-1.4e-02 | leg=3.4438e+01s | x7.44
# earth flux                         | NE= 512 | Neta=   4 | t=6.3243e-02s+/-1.8e-03 | leg=3.2575e-01s | x5.15
# earth flux                         | NE= 512 | Neta=   8 | t=8.9998e-02s+/-9.8e-04 | leg=5.7255e-01s | x6.36
# earth flux                         | NE= 512 | Neta=  16 | t=1.4304e-01s+/-1.3e-03 | leg=1.0914e+00s | x7.63
# earth flux                         | NE= 512 | Neta=  32 | t=2.8690e-01s+/-1.7e-03 | leg=2.1508e+00s | x7.50
# earth flux                         | NE= 512 | Neta=  64 | t=5.7576e-01s+/-3.5e-03 | leg=4.2878e+00s | x7.45
# earth flux                         | NE= 512 | Neta= 128 | t=1.1548e+00s+/-2.9e-03 | leg=8.6283e+00s | x7.47
# earth flux                         | NE= 512 | Neta= 256 | t=2.3173e+00s+/-4.1e-03 | leg=1.7209e+01s | x7.43
# earth flux                         | NE= 512 | Neta= 512 | t=4.6008e+00s+/-2.7e-02 | leg=3.4411e+01s | x7.48
# earth flux                         | NE= 512 | Neta=1024 | t=9.2769e+00s+/-1.7e-02 | leg=6.9008e+01s | x7.44
# earth flux                         | NE=1024 | Neta=   4 | t=8.9932e-02s+/-7.2e-04 | leg=6.5474e-01s | x7.28
# earth flux                         | NE=1024 | Neta=   8 | t=1.4275e-01s+/-1.1e-03 | leg=1.1433e+00s | x8.01
# earth flux                         | NE=1024 | Neta=  16 | t=2.8565e-01s+/-3.3e-03 | leg=2.1859e+00s | x7.65
# earth flux                         | NE=1024 | Neta=  32 | t=5.7253e-01s+/-1.9e-03 | leg=4.3212e+00s | x7.55
# earth flux                         | NE=1024 | Neta=  64 | t=1.1541e+00s+/-5.0e-03 | leg=8.5992e+00s | x7.45
# earth flux                         | NE=1024 | Neta= 128 | t=2.3163e+00s+/-5.9e-03 | leg=1.7242e+01s | x7.44
# earth flux                         | NE=1024 | Neta= 256 | t=4.6135e+00s+/-1.3e-02 | leg=3.4442e+01s | x7.47
# earth flux                         | NE=1024 | Neta= 512 | t=9.2756e+00s+/-1.1e-02 | leg=6.8835e+01s | x7.42
# earth flux                         | NE=1024 | Neta=1024 | t=1.8529e+01s+/-2.0e-02 | leg=1.3773e+02s | x7.43
#        section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   earth flux         4        4         0.054156       0.002766
# 1   earth flux         4        8         0.058021       0.004787
# 2   earth flux         4       16         0.033387       0.008328
# 3   earth flux         4       32         0.034941       0.016999
# 4   earth flux         4       64         0.042491       0.033748
# ..         ...       ...      ...              ...            ...
# 76  earth flux      1024       64         1.154118       8.599246
# 77  earth flux      1024      128         2.316349      17.242234
# 78  earth flux      1024      256         4.613480      34.442177
# 79  earth flux      1024      512         9.275620      68.834795
# 80  earth flux      1024     1024        18.528858     137.731201
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.054956       0.002832        0.000916      0.000034
# 1          0.058793       0.005539        0.000537      0.001287
# 2          0.034106       0.008760        0.000728      0.000276
# 3          0.037123       0.017153        0.002782      0.000115
# 4          0.045220       0.034041        0.002128      0.000276
# ..              ...            ...             ...           ...
# 76         1.160534       8.644992        0.004997      0.030292
# 77         2.325170      17.290382        0.005890      0.033037
# 78         4.634006      34.520315        0.012513      0.078062
# 79         9.287095      68.899410        0.010838      0.051298
# 80        18.556435     137.888705        0.019606      0.121594
#
#     speedup_legacy_over_tpeanuts
# 0                       0.051073
# 1                       0.082510
# 2                       0.249432
# 3                       0.486493
# 4                       0.794239
# ..                           ...
# 76                      7.450922
# 77                      7.443712
# 78                      7.465553
# 79                      7.421045
# 80                      7.433335
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\earth_flux_timing.csv
# v:\output\benchmark\earth_flux_speedup.png
# v:\output\benchmark\earth_flux_speedup_cross_sections.png

# %% [markdown]
# ### 5.3 Analytical vs Numerical Earth Method
#
# This diagnostic compares the perturbative analytical Earth method with the numerical thin-segment method inside TPeanuts.
#
# **Expected results:**<br>
# - Analytical propagation should usually be faster than numerical propagation for the configured grid sizes, with the speedup depending on `EARTH_NUMERICAL_STEPS`.

# %%
earth_method_records = []
for ne in EARTH_METHOD_COMPARISON_ENERGY_SIZES:
    for neta in EARTH_METHOD_COMPARISON_NADIR_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        t_ana, _, _ = timed_call(lambda E=E_1d, eta=eta_1d: _tpeanuts_pearth_analytical(E, eta))
        t_num, _, _ = timed_call(lambda E=E_1d, eta=eta_1d: _tpeanuts_pearth_numerical(E, eta))
        earth_method_records.append({
            "n_energy": ne, "n_nadir": neta,
            "analytical_s": t_ana, "numerical_s": t_num,
            "speedup_ana_over_num": t_num / max(t_ana, 1e-15),
        })
earth_method_df = pd.DataFrame(earth_method_records)
display(earth_method_df)
save_results(earth_method_df, "earth_method_comparison")

pivot = earth_method_df.pivot(index="n_nadir", columns="n_energy", values="speedup_ana_over_num")
fig, ax = plt.subplots(figsize=(6, 4))
im = ax.imshow(pivot.values, origin="lower", aspect="auto",
               norm=mcolors.LogNorm(vmin=0.1, vmax=max(pivot.values.max(), 1.1)), cmap="RdYlGn")
ax.set_xticks(np.arange(len(pivot.columns))); ax.set_xticklabels(pivot.columns)
ax.set_yticks(np.arange(len(pivot.index)));   ax.set_yticklabels(pivot.index)
for r in range(pivot.values.shape[0]):
    for c in range(pivot.values.shape[1]):
        ax.text(c, r, f"{pivot.values[r,c]:.1f}x", ha="center", va="center", fontsize=8)
ax.set_xlabel("Energy-grid size"); ax.set_ylabel("Nadir-grid size")
ax.set_title("Speedup: analytical / numerical Earth (>1 = analytical faster)")
fig.colorbar(im, ax=ax, label="Speedup (log)")
fig.tight_layout()
save_and_show("earth_method_comparison.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
#    n_energy  n_nadir  analytical_s  numerical_s  speedup_ana_over_num
# 0        16       16      0.036350     3.343203             91.971555
# 1        16       64      0.047450    13.183309            277.834637
# 2        16      256      0.085921    49.547614            576.666120
# 3        64       16      0.046917    12.913067            275.233916
# 4        64       64      0.088923    53.365519            600.133142
# 5        64      256      0.291224   213.589179            733.418373
# 6       256       16      0.089141    53.776954            603.281034
# 7       256       64      0.287406   214.223637            745.370693
# 8       256      256      1.159312   855.582146            738.008531
# Saved: v:\output\benchmark\earth_method_comparison.csv
# v:\output\benchmark\earth_method_comparison.png

# %% [markdown]
# ## 6. Integrated Probabilities
#
# This section benchmarks a simple nadir-averaged probability, using a uniform exposure weight over the configured nadir grid. It is a timing proxy for exposure-integrated observables.
#
# **Expected results:**<br>
#  - Timings should combine the Earth grid propagation cost with a small integration overhead.

# %%
integrated_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        integrated_probability_records.append(benchmark_pair(
            "integrated probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_integrated(E, eta, EARTH_DEPTH_M),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_integrated(E_np, eta_np, EARTH_DEPTH_M),
        ))
integrated_probability_df = pd.DataFrame(integrated_probability_records)
display(integrated_probability_df)
save_results(integrated_probability_df, "integrated_probability_timing")
plot_heatmap(integrated_probability_df, "Integrated probability speedup (LogNorm)",
              "integrated_probability_speedup.png")
plot_speedup_cross_sections(integrated_probability_df, "Integrated probability speedup cross sections",
                              "integrated_probability_speedup_cross_sections.png")
# Out:
# integrated probabilities           | NE=   4 | Neta=   4 | t=4.0467e-02s+/-1.6e-03 | leg=2.0617e-03s | x0.05
# integrated probabilities           | NE=   4 | Neta=   8 | t=4.0338e-02s+/-4.4e-03 | leg=2.8784e-03s | x0.07
# integrated probabilities           | NE=   4 | Neta=  16 | t=5.1238e-02s+/-9.1e-03 | leg=4.4957e-03s | x0.09
# integrated probabilities           | NE=   4 | Neta=  32 | t=3.8040e-02s+/-9.5e-04 | leg=7.7258e-03s | x0.20
# integrated probabilities           | NE=   4 | Neta=  64 | t=3.9900e-02s+/-1.2e-03 | leg=1.4418e-02s | x0.36
# integrated probabilities           | NE=   4 | Neta= 128 | t=4.3618e-02s+/-1.0e-03 | leg=2.7668e-02s | x0.63
# integrated probabilities           | NE=   4 | Neta= 256 | t=5.1204e-02s+/-1.3e-03 | leg=5.3940e-02s | x1.05
# integrated probabilities           | NE=   4 | Neta= 512 | t=6.4037e-02s+/-8.8e-04 | leg=1.0679e-01s | x1.67
# integrated probabilities           | NE=   4 | Neta=1024 | t=8.8478e-02s+/-1.1e-03 | leg=2.1437e-01s | x2.42
# integrated probabilities           | NE=   8 | Neta=   4 | t=3.6313e-02s+/-9.3e-04 | leg=3.8112e-03s | x0.10
# integrated probabilities           | NE=   8 | Neta=   8 | t=3.6884e-02s+/-6.1e-04 | leg=5.3357e-03s | x0.14
# integrated probabilities           | NE=   8 | Neta=  16 | t=3.7652e-02s+/-6.6e-04 | leg=8.5679e-03s | x0.23
# integrated probabilities           | NE=   8 | Neta=  32 | t=3.8944e-02s+/-7.9e-04 | leg=1.5209e-02s | x0.39
# integrated probabilities           | NE=   8 | Neta=  64 | t=4.1676e-02s+/-1.2e-03 | leg=2.8382e-02s | x0.68
# integrated probabilities           | NE=   8 | Neta= 128 | t=4.8107e-02s+/-6.7e-04 | leg=5.5277e-02s | x1.15
# integrated probabilities           | NE=   8 | Neta= 256 | t=6.0227e-02s+/-2.1e-03 | leg=1.0756e-01s | x1.79
# integrated probabilities           | NE=   8 | Neta= 512 | t=8.9345e-02s+/-5.5e-04 | leg=2.1379e-01s | x2.39
# integrated probabilities           | NE=   8 | Neta=1024 | t=1.4880e-01s+/-3.3e-04 | leg=4.2497e-01s | x2.86
# integrated probabilities           | NE=  16 | Neta=   4 | t=3.6945e-02s+/-1.3e-03 | leg=7.0330e-03s | x0.19
# integrated probabilities           | NE=  16 | Neta=   8 | t=4.2250e-02s+/-2.2e-03 | leg=1.0441e-02s | x0.25
# integrated probabilities           | NE=  16 | Neta=  16 | t=4.0582e-02s+/-1.8e-03 | leg=1.6891e-02s | x0.42
# integrated probabilities           | NE=  16 | Neta=  32 | t=4.3309e-02s+/-1.9e-03 | leg=2.9594e-02s | x0.68
# integrated probabilities           | NE=  16 | Neta=  64 | t=5.0823e-02s+/-1.4e-03 | leg=5.6245e-02s | x1.11
# integrated probabilities           | NE=  16 | Neta= 128 | t=6.2328e-02s+/-2.1e-03 | leg=1.0944e-01s | x1.76
# integrated probabilities           | NE=  16 | Neta= 256 | t=8.8453e-02s+/-1.5e-03 | leg=2.1575e-01s | x2.44
# integrated probabilities           | NE=  16 | Neta= 512 | t=1.4831e-01s+/-1.4e-03 | leg=4.2474e-01s | x2.86
# integrated probabilities           | NE=  16 | Neta=1024 | t=2.9501e-01s+/-1.6e-03 | leg=8.5248e-01s | x2.89
# integrated probabilities           | NE=  32 | Neta=   4 | t=4.0757e-02s+/-1.2e-03 | leg=1.4413e-02s | x0.35
# integrated probabilities           | NE=  32 | Neta=   8 | t=3.9717e-02s+/-2.4e-03 | leg=2.0602e-02s | x0.52
# integrated probabilities           | NE=  32 | Neta=  16 | t=4.3158e-02s+/-1.0e-03 | leg=3.3814e-02s | x0.78
# integrated probabilities           | NE=  32 | Neta=  32 | t=4.9402e-02s+/-9.6e-04 | leg=5.9670e-02s | x1.21
# integrated probabilities           | NE=  32 | Neta=  64 | t=6.2527e-02s+/-2.1e-03 | leg=1.1302e-01s | x1.81
# integrated probabilities           | NE=  32 | Neta= 128 | t=8.8509e-02s+/-3.4e-03 | leg=2.2329e-01s | x2.52
# integrated probabilities           | NE=  32 | Neta= 256 | t=1.4916e-01s+/-4.8e-03 | leg=4.2977e-01s | x2.88
# integrated probabilities           | NE=  32 | Neta= 512 | t=2.9283e-01s+/-2.3e-03 | leg=8.5338e-01s | x2.91
# integrated probabilities           | NE=  32 | Neta=1024 | t=5.8105e-01s+/-2.4e-03 | leg=1.7103e+00s | x2.94
# integrated probabilities           | NE=  64 | Neta=   4 | t=3.8578e-02s+/-1.3e-03 | leg=2.7908e-02s | x0.72
# integrated probabilities           | NE=  64 | Neta=   8 | t=4.1914e-02s+/-8.8e-04 | leg=4.0570e-02s | x0.97
# integrated probabilities           | NE=  64 | Neta=  16 | t=5.9399e-02s+/-4.9e-03 | leg=6.6487e-02s | x1.12
# integrated probabilities           | NE=  64 | Neta=  32 | t=6.5317e-02s+/-4.5e-04 | leg=1.1947e-01s | x1.83
# integrated probabilities           | NE=  64 | Neta=  64 | t=8.7333e-02s+/-1.4e-03 | leg=2.2584e-01s | x2.59
# integrated probabilities           | NE=  64 | Neta= 128 | t=1.4791e-01s+/-1.8e-03 | leg=4.3892e-01s | x2.97
# integrated probabilities           | NE=  64 | Neta= 256 | t=2.9487e-01s+/-1.4e-03 | leg=8.5873e-01s | x2.91
# integrated probabilities           | NE=  64 | Neta= 512 | t=5.8153e-01s+/-3.0e-03 | leg=1.7069e+00s | x2.94
# integrated probabilities           | NE=  64 | Neta=1024 | t=1.1623e+00s+/-2.8e-03 | leg=3.4223e+00s | x2.94
# integrated probabilities           | NE= 128 | Neta=   4 | t=4.5282e-02s+/-5.8e-04 | leg=5.5799e-02s | x1.23
# integrated probabilities           | NE= 128 | Neta=   8 | t=5.1542e-02s+/-1.3e-03 | leg=8.0306e-02s | x1.56
# integrated probabilities           | NE= 128 | Neta=  16 | t=6.8476e-02s+/-1.6e-03 | leg=1.3393e-01s | x1.96
# integrated probabilities           | NE= 128 | Neta=  32 | t=8.8731e-02s+/-1.9e-03 | leg=2.4172e-01s | x2.72
# integrated probabilities           | NE= 128 | Neta=  64 | t=1.4761e-01s+/-6.1e-03 | leg=4.5221e-01s | x3.06
# integrated probabilities           | NE= 128 | Neta= 128 | t=2.9166e-01s+/-1.3e-03 | leg=8.7912e-01s | x3.01
# integrated probabilities           | NE= 128 | Neta= 256 | t=5.8122e-01s+/-5.5e-03 | leg=1.7258e+00s | x2.97
# integrated probabilities           | NE= 128 | Neta= 512 | t=1.1902e+00s+/-1.9e-02 | leg=3.4283e+00s | x2.88
# integrated probabilities           | NE= 128 | Neta=1024 | t=2.3307e+00s+/-3.7e-02 | leg=6.8493e+00s | x2.94
# integrated probabilities           | NE= 256 | Neta=   4 | t=5.2357e-02s+/-8.0e-04 | leg=1.1100e-01s | x2.12
# integrated probabilities           | NE= 256 | Neta=   8 | t=6.4702e-02s+/-1.4e-03 | leg=1.6234e-01s | x2.51
# integrated probabilities           | NE= 256 | Neta=  16 | t=9.0510e-02s+/-9.6e-04 | leg=2.6590e-01s | x2.94
# integrated probabilities           | NE= 256 | Neta=  32 | t=1.4946e-01s+/-1.6e-03 | leg=4.7775e-01s | x3.20
# integrated probabilities           | NE= 256 | Neta=  64 | t=2.9040e-01s+/-1.4e-03 | leg=9.0835e-01s | x3.13
# integrated probabilities           | NE= 256 | Neta= 128 | t=5.7734e-01s+/-3.5e-03 | leg=1.7559e+00s | x3.04
# integrated probabilities           | NE= 256 | Neta= 256 | t=1.1616e+00s+/-2.9e-03 | leg=3.4739e+00s | x2.99
# integrated probabilities           | NE= 256 | Neta= 512 | t=2.3339e+00s+/-1.5e-02 | leg=6.9195e+00s | x2.96
# integrated probabilities           | NE= 256 | Neta=1024 | t=4.8992e+00s+/-4.0e-02 | leg=1.3721e+01s | x2.80
# integrated probabilities           | NE= 512 | Neta=   4 | t=6.9988e-02s+/-6.8e-04 | leg=2.2289e-01s | x3.18
# integrated probabilities           | NE= 512 | Neta=   8 | t=9.4541e-02s+/-2.4e-03 | leg=3.2225e-01s | x3.41
# integrated probabilities           | NE= 512 | Neta=  16 | t=1.4975e-01s+/-5.7e-04 | leg=5.3623e-01s | x3.58
# integrated probabilities           | NE= 512 | Neta=  32 | t=2.9447e-01s+/-2.5e-03 | leg=9.5749e-01s | x3.25
# integrated probabilities           | NE= 512 | Neta=  64 | t=5.8394e-01s+/-7.6e-03 | leg=1.8080e+00s | x3.10
# integrated probabilities           | NE= 512 | Neta= 128 | t=1.2271e+00s+/-1.7e-02 | leg=3.5617e+00s | x2.90
# integrated probabilities           | NE= 512 | Neta= 256 | t=2.4383e+00s+/-5.4e-03 | leg=7.0106e+00s | x2.88
# integrated probabilities           | NE= 512 | Neta= 512 | t=4.8993e+00s+/-4.5e-03 | leg=1.3760e+01s | x2.81
# integrated probabilities           | NE= 512 | Neta=1024 | t=9.3044e+00s+/-1.5e-01 | leg=2.7337e+01s | x2.94
# integrated probabilities           | NE=1024 | Neta=   4 | t=9.6311e-02s+/-2.5e-03 | leg=4.4470e-01s | x4.62
# integrated probabilities           | NE=1024 | Neta=   8 | t=1.5511e-01s+/-5.1e-03 | leg=6.4824e-01s | x4.18
# integrated probabilities           | NE=1024 | Neta=  16 | t=2.9629e-01s+/-1.8e-03 | leg=1.0660e+00s | x3.60
# integrated probabilities           | NE=1024 | Neta=  32 | t=5.8328e-01s+/-3.6e-03 | leg=1.9256e+00s | x3.30
# integrated probabilities           | NE=1024 | Neta=  64 | t=1.2301e+00s+/-2.6e-02 | leg=3.6428e+00s | x2.96
# integrated probabilities           | NE=1024 | Neta= 128 | t=2.4579e+00s+/-5.1e-03 | leg=7.1574e+00s | x2.91
# integrated probabilities           | NE=1024 | Neta= 256 | t=4.8844e+00s+/-1.4e-02 | leg=1.3913e+01s | x2.85
# integrated probabilities           | NE=1024 | Neta= 512 | t=9.2892e+00s+/-4.3e-02 | leg=2.7646e+01s | x2.98
# integrated probabilities           | NE=1024 | Neta=1024 | t=1.8704e+01s+/-5.9e-01 | leg=5.4783e+01s | x2.93
#                      section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   integrated probabilities         4        4         0.040467
# 1   integrated probabilities         4        8         0.040338
# 2   integrated probabilities         4       16         0.051238
# 3   integrated probabilities         4       32         0.038040
# 4   integrated probabilities         4       64         0.039900
# ..                       ...       ...      ...              ...
# 76  integrated probabilities      1024       64         1.230056
# 77  integrated probabilities      1024      128         2.457887
# 78  integrated probabilities      1024      256         4.884449
# 79  integrated probabilities      1024      512         9.289158
# 80  integrated probabilities      1024     1024        18.704256
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.002062         0.042393       0.002113        0.001574
# 1        0.002878         0.043028       0.002908        0.004360
# 2        0.004496         0.056175       0.004946        0.009119
# 3        0.007726         0.039275       0.007870        0.000954
# 4        0.014418         0.040837       0.014602        0.001173
# ..            ...              ...            ...             ...
# 76       3.642761         1.251483       3.657872        0.025800
# 77       7.157391         2.466708       7.196584        0.005143
# 78      13.913017         4.906574      13.937045        0.013704
# 79      27.645549         9.343298      27.702831        0.042748
# 80      54.783140        19.214570      54.842994        0.592358
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000033                      0.050948
# 1       0.000023                      0.071357
# 2       0.000830                      0.087742
# 3       0.000151                      0.203096
# 4       0.000133                      0.361341
# ..           ...                           ...
# 76      0.016641                      2.961459
# 77      0.026909                      2.912010
# 78      0.017121                      2.848431
# 79      0.058529                      2.976109
# 80      0.037045                      2.928913
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\integrated_probability_timing.csv
# v:\output\benchmark\integrated_probability_speedup.png
# v:\output\benchmark\integrated_probability_speedup_cross_sections.png

# %% [markdown]
# ## 7. Solar-to-Detector Chain
#
# This section benchmarks the full incoherent solar-to-detector structure: solar mass-basis production followed by Earth matter propagation at detector nadir angles.
#
# **Expected results:**<br>
# - This is one of the most complete benchmark paths and should show the cumulative benefit of batching the solar and Earth stages.

# %% [markdown]
# ### 7.1 Probability Timing
#
# The output probability is flavour-resolved at the detector for each energy and nadir angle.
#
# **Expected results:**<br>
# - Timing should scale with both the energy and nadir grids.

# %%
solar_detector_probability_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        solar_detector_probability_records.append(benchmark_pair(
            "solar-detector probabilities", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_solar_detector_probabilities(E, eta),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_solar_detector_probabilities(E_np, eta_np),
        ))
solar_detector_probability_df = pd.DataFrame(solar_detector_probability_records)
display(solar_detector_probability_df)
save_results(solar_detector_probability_df, "solar_detector_probability_timing")
plot_heatmap(solar_detector_probability_df, "Solar-detector probability speedup (LogNorm)",
              "solar_detector_probability_speedup.png")
plot_speedup_cross_sections(solar_detector_probability_df,
                              "Solar-detector probability speedup cross sections",
                              "solar_detector_probability_speedup_cross_sections.png")
# Out:
# solar-detector probabilities       | NE=   4 | Neta=   4 | t=4.9010e-02s+/-1.2e-03 | leg=1.9080e-03s | x0.04
# solar-detector probabilities       | NE=   4 | Neta=   8 | t=5.6102e-02s+/-1.4e-02 | leg=2.8268e-03s | x0.05
# solar-detector probabilities       | NE=   4 | Neta=  16 | t=7.1958e-02s+/-1.2e-02 | leg=4.7622e-03s | x0.07
# solar-detector probabilities       | NE=   4 | Neta=  32 | t=4.7227e-02s+/-2.9e-03 | leg=8.4539e-03s | x0.18
# solar-detector probabilities       | NE=   4 | Neta=  64 | t=4.9455e-02s+/-5.4e-04 | leg=1.5946e-02s | x0.32
# solar-detector probabilities       | NE=   4 | Neta= 128 | t=5.4009e-02s+/-1.8e-03 | leg=3.1884e-02s | x0.59
# solar-detector probabilities       | NE=   4 | Neta= 256 | t=6.1825e-02s+/-2.4e-03 | leg=6.1335e-02s | x0.99
# solar-detector probabilities       | NE=   4 | Neta= 512 | t=7.4577e-02s+/-9.7e-04 | leg=1.2076e-01s | x1.62
# solar-detector probabilities       | NE=   4 | Neta=1024 | t=1.0016e-01s+/-2.9e-03 | leg=2.4217e-01s | x2.42
# solar-detector probabilities       | NE=   8 | Neta=   4 | t=4.4210e-02s+/-8.0e-04 | leg=3.4809e-03s | x0.08
# solar-detector probabilities       | NE=   8 | Neta=   8 | t=4.4683e-02s+/-4.0e-04 | leg=5.3255e-03s | x0.12
# solar-detector probabilities       | NE=   8 | Neta=  16 | t=4.5808e-02s+/-1.1e-03 | leg=9.2614e-03s | x0.20
# solar-detector probabilities       | NE=   8 | Neta=  32 | t=4.7297e-02s+/-1.3e-03 | leg=1.6609e-02s | x0.35
# solar-detector probabilities       | NE=   8 | Neta=  64 | t=5.0742e-02s+/-1.7e-03 | leg=3.1644e-02s | x0.62
# solar-detector probabilities       | NE=   8 | Neta= 128 | t=5.6331e-02s+/-1.8e-03 | leg=6.1676e-02s | x1.09
# solar-detector probabilities       | NE=   8 | Neta= 256 | t=7.1539e-02s+/-8.8e-04 | leg=1.2259e-01s | x1.71
# solar-detector probabilities       | NE=   8 | Neta= 512 | t=9.9818e-02s+/-1.0e-03 | leg=2.4385e-01s | x2.44
# solar-detector probabilities       | NE=   8 | Neta=1024 | t=1.6313e-01s+/-1.6e-03 | leg=4.8557e-01s | x2.98
# solar-detector probabilities       | NE=  16 | Neta=   4 | t=4.5500e-02s+/-8.6e-04 | leg=6.9313e-03s | x0.15
# solar-detector probabilities       | NE=  16 | Neta=   8 | t=4.6298e-02s+/-4.5e-04 | leg=1.0506e-02s | x0.23
# solar-detector probabilities       | NE=  16 | Neta=  16 | t=4.7539e-02s+/-5.3e-04 | leg=1.7768e-02s | x0.37
# solar-detector probabilities       | NE=  16 | Neta=  32 | t=5.0752e-02s+/-8.1e-04 | leg=3.3275e-02s | x0.66
# solar-detector probabilities       | NE=  16 | Neta=  64 | t=5.7454e-02s+/-9.5e-04 | leg=6.3327e-02s | x1.10
# solar-detector probabilities       | NE=  16 | Neta= 128 | t=7.2373e-02s+/-7.5e-04 | leg=1.2370e-01s | x1.71
# solar-detector probabilities       | NE=  16 | Neta= 256 | t=1.0083e-01s+/-2.0e-03 | leg=2.4504e-01s | x2.43
# solar-detector probabilities       | NE=  16 | Neta= 512 | t=1.6502e-01s+/-4.7e-04 | leg=4.8530e-01s | x2.94
# solar-detector probabilities       | NE=  16 | Neta=1024 | t=3.2550e-01s+/-1.9e-03 | leg=9.6907e-01s | x2.98
# solar-detector probabilities       | NE=  32 | Neta=   4 | t=5.2291e-02s+/-3.3e-04 | leg=1.3574e-02s | x0.26
# solar-detector probabilities       | NE=  32 | Neta=   8 | t=4.8515e-02s+/-1.2e-03 | leg=2.1125e-02s | x0.44
# solar-detector probabilities       | NE=  32 | Neta=  16 | t=5.2652e-02s+/-4.8e-04 | leg=3.5784e-02s | x0.68
# solar-detector probabilities       | NE=  32 | Neta=  32 | t=6.1412e-02s+/-1.0e-03 | leg=6.4803e-02s | x1.06
# solar-detector probabilities       | NE=  32 | Neta=  64 | t=7.4934e-02s+/-1.6e-03 | leg=1.2631e-01s | x1.69
# solar-detector probabilities       | NE=  32 | Neta= 128 | t=1.0002e-01s+/-1.4e-03 | leg=2.4602e-01s | x2.46
# solar-detector probabilities       | NE=  32 | Neta= 256 | t=1.6421e-01s+/-1.5e-03 | leg=4.8697e-01s | x2.97
# solar-detector probabilities       | NE=  32 | Neta= 512 | t=3.2588e-01s+/-2.5e-03 | leg=9.7791e-01s | x3.00
# solar-detector probabilities       | NE=  32 | Neta=1024 | t=6.7436e-01s+/-2.6e-03 | leg=1.9399e+00s | x2.88
# solar-detector probabilities       | NE=  64 | Neta=   4 | t=4.9019e-02s+/-8.4e-04 | leg=2.6864e-02s | x0.55
# solar-detector probabilities       | NE=  64 | Neta=   8 | t=5.4142e-02s+/-3.7e-04 | leg=4.1474e-02s | x0.77
# solar-detector probabilities       | NE=  64 | Neta=  16 | t=6.2980e-02s+/-2.6e-04 | leg=7.1509e-02s | x1.14
# solar-detector probabilities       | NE=  64 | Neta=  32 | t=7.6138e-02s+/-1.1e-03 | leg=1.3160e-01s | x1.73
# solar-detector probabilities       | NE=  64 | Neta=  64 | t=1.0052e-01s+/-1.9e-03 | leg=2.5367e-01s | x2.52
# solar-detector probabilities       | NE=  64 | Neta= 128 | t=1.6408e-01s+/-2.3e-03 | leg=4.9567e-01s | x3.02
# solar-detector probabilities       | NE=  64 | Neta= 256 | t=3.2522e-01s+/-9.0e-04 | leg=9.7351e-01s | x2.99
# solar-detector probabilities       | NE=  64 | Neta= 512 | t=6.4594e-01s+/-7.1e-03 | leg=1.9415e+00s | x3.01
# solar-detector probabilities       | NE=  64 | Neta=1024 | t=1.2935e+00s+/-4.3e-03 | leg=3.8902e+00s | x3.01
# solar-detector probabilities       | NE= 128 | Neta=   4 | t=5.4713e-02s+/-5.6e-04 | leg=5.4415e-02s | x0.99
# solar-detector probabilities       | NE= 128 | Neta=   8 | t=6.2915e-02s+/-4.1e-04 | leg=8.2617e-02s | x1.31
# solar-detector probabilities       | NE= 128 | Neta=  16 | t=7.6502e-02s+/-1.6e-03 | leg=1.4254e-01s | x1.86
# solar-detector probabilities       | NE= 128 | Neta=  32 | t=1.0027e-01s+/-1.2e-03 | leg=2.6335e-01s | x2.63
# solar-detector probabilities       | NE= 128 | Neta=  64 | t=1.6462e-01s+/-2.1e-03 | leg=5.0402e-01s | x3.06
# solar-detector probabilities       | NE= 128 | Neta= 128 | t=3.2656e-01s+/-1.7e-03 | leg=9.9115e-01s | x3.04
# solar-detector probabilities       | NE= 128 | Neta= 256 | t=6.4833e-01s+/-2.9e-03 | leg=1.9532e+00s | x3.01
# solar-detector probabilities       | NE= 128 | Neta= 512 | t=1.2953e+00s+/-4.4e-03 | leg=3.8798e+00s | x3.00
# solar-detector probabilities       | NE= 128 | Neta=1024 | t=2.5870e+00s+/-7.3e-03 | leg=7.7899e+00s | x3.01
# solar-detector probabilities       | NE= 256 | Neta=   4 | t=6.2694e-02s+/-1.4e-03 | leg=1.0767e-01s | x1.72
# solar-detector probabilities       | NE= 256 | Neta=   8 | t=7.9983e-02s+/-1.2e-03 | leg=1.6508e-01s | x2.06
# solar-detector probabilities       | NE= 256 | Neta=  16 | t=1.0181e-01s+/-1.6e-03 | leg=2.8418e-01s | x2.79
# solar-detector probabilities       | NE= 256 | Neta=  32 | t=1.6335e-01s+/-9.6e-04 | leg=5.2656e-01s | x3.22
# solar-detector probabilities       | NE= 256 | Neta=  64 | t=3.2271e-01s+/-3.4e-03 | leg=1.0134e+00s | x3.14
# solar-detector probabilities       | NE= 256 | Neta= 128 | t=6.4300e-01s+/-6.6e-03 | leg=1.9855e+00s | x3.09
# solar-detector probabilities       | NE= 256 | Neta= 256 | t=1.2993e+00s+/-3.4e-03 | leg=3.9265e+00s | x3.02
# solar-detector probabilities       | NE= 256 | Neta= 512 | t=2.5943e+00s+/-4.0e-03 | leg=7.8060e+00s | x3.01
# solar-detector probabilities       | NE= 256 | Neta=1024 | t=5.1764e+00s+/-4.8e-02 | leg=1.5574e+01s | x3.01
# solar-detector probabilities       | NE= 512 | Neta=   4 | t=1.1639e-01s+/-1.1e-02 | leg=2.1619e-01s | x1.86
# solar-detector probabilities       | NE= 512 | Neta=   8 | t=1.0506e-01s+/-1.2e-03 | leg=3.2884e-01s | x3.13
# solar-detector probabilities       | NE= 512 | Neta=  16 | t=1.6574e-01s+/-1.1e-03 | leg=5.7125e-01s | x3.45
# solar-detector probabilities       | NE= 512 | Neta=  32 | t=3.2537e-01s+/-2.4e-03 | leg=1.0587e+00s | x3.25
# solar-detector probabilities       | NE= 512 | Neta=  64 | t=6.4516e-01s+/-4.5e-03 | leg=2.0102e+00s | x3.12
# solar-detector probabilities       | NE= 512 | Neta= 128 | t=1.2972e+00s+/-1.4e-02 | leg=3.9791e+00s | x3.07
# solar-detector probabilities       | NE= 512 | Neta= 256 | t=2.5888e+00s+/-6.5e-03 | leg=7.8582e+00s | x3.04
# solar-detector probabilities       | NE= 512 | Neta= 512 | t=5.1832e+00s+/-2.7e-03 | leg=1.5657e+01s | x3.02
# solar-detector probabilities       | NE= 512 | Neta=1024 | t=1.0349e+01s+/-7.9e-03 | leg=3.1144e+01s | x3.01
# solar-detector probabilities       | NE=1024 | Neta=   4 | t=1.0868e-01s+/-1.0e-03 | leg=4.3140e-01s | x3.97
# solar-detector probabilities       | NE=1024 | Neta=   8 | t=1.7055e-01s+/-5.1e-03 | leg=6.6109e-01s | x3.88
# solar-detector probabilities       | NE=1024 | Neta=  16 | t=3.2989e-01s+/-1.4e-03 | leg=1.1382e+00s | x3.45
# solar-detector probabilities       | NE=1024 | Neta=  32 | t=6.5111e-01s+/-2.3e-03 | leg=2.1022e+00s | x3.23
# solar-detector probabilities       | NE=1024 | Neta=  64 | t=1.3062e+00s+/-4.1e-02 | leg=4.0699e+00s | x3.12
# solar-detector probabilities       | NE=1024 | Neta= 128 | t=2.5992e+00s+/-5.9e-03 | leg=7.9563e+00s | x3.06
# solar-detector probabilities       | NE=1024 | Neta= 256 | t=5.1800e+00s+/-8.7e-03 | leg=1.5740e+01s | x3.04
# solar-detector probabilities       | NE=1024 | Neta= 512 | t=1.0367e+01s+/-1.1e-02 | leg=3.1212e+01s | x3.01
# solar-detector probabilities       | NE=1024 | Neta=1024 | t=2.0730e+01s+/-9.8e-03 | leg=6.2380e+01s | x3.01
#                          section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   solar-detector probabilities         4        4         0.049010
# 1   solar-detector probabilities         4        8         0.056102
# 2   solar-detector probabilities         4       16         0.071958
# 3   solar-detector probabilities         4       32         0.047227
# 4   solar-detector probabilities         4       64         0.049455
# ..                           ...       ...      ...              ...
# 76  solar-detector probabilities      1024       64         1.306198
# 77  solar-detector probabilities      1024      128         2.599150
# 78  solar-detector probabilities      1024      256         5.179959
# 79  solar-detector probabilities      1024      512        10.367496
# 80  solar-detector probabilities      1024     1024        20.729776
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.001908         0.050557       0.002052        0.001214
# 1        0.002827         0.069717       0.002872        0.013822
# 2        0.004762         0.081015       0.004853        0.011868
# 3        0.008454         0.049811       0.008701        0.002947
# 4        0.015946         0.050255       0.016495        0.000542
# ..            ...              ...            ...             ...
# 76       4.069938         1.330788       4.078123        0.040689
# 77       7.956331         2.605274       7.967438        0.005875
# 78      15.739634         5.195498      15.770238        0.008659
# 79      31.212050        10.380974      31.283835        0.011247
# 80      62.379740        20.744346      62.438205        0.009764
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000228                      0.038931
# 1       0.000029                      0.050386
# 2       0.000148                      0.066181
# 3       0.000237                      0.179005
# 4       0.000379                      0.322439
# ..           ...                           ...
# 76      0.010508                      3.115867
# 77      0.010584                      3.061128
# 78      0.027384                      3.038564
# 79      0.040655                      3.010568
# 80      0.048053                      3.009186
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_probability_timing.csv
# v:\output\benchmark\solar_detector_probability_speedup.png
# v:\output\benchmark\solar_detector_probability_speedup_cross_sections.png

# %% [markdown]
# ### 7.2 Flux Timing
#
# This benchmark multiplies the detector probability by a synthetic solar-source spectral weight.
#
# **Expected results:**<br>
# - Timings should remain close to the probability benchmark because the flux multiplication is elementwise.

# %%
solar_detector_flux_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d      = energy_grid(ne, solar=True)
        eta_1d    = nadir_grid(neta)
        spectrum_t = solar_source_spectrum(E_1d)
        spectrum_l = to_numpy(spectrum_t)
        solar_detector_flux_records.append(benchmark_pair(
            "solar-detector flux", ne, neta,
            lambda E=E_1d, eta=eta_1d, st=spectrum_t:
                tpeanuts_solar_detector_probabilities(E, eta) * st[:, None, None],
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d), sl=spectrum_l:
                legacy_solar_detector_probabilities(E_np, eta_np) * sl[:, None, None],
        ))
solar_detector_flux_df = pd.DataFrame(solar_detector_flux_records)
display(solar_detector_flux_df)
save_results(solar_detector_flux_df, "solar_detector_flux_timing")
plot_heatmap(solar_detector_flux_df, "Solar-detector flux speedup (LogNorm)",
              "solar_detector_flux_speedup.png")
plot_speedup_cross_sections(solar_detector_flux_df,
                              "Solar-detector flux speedup cross sections",
                              "solar_detector_flux_speedup_cross_sections.png")
# Out:
# solar-detector flux                | NE=   4 | Neta=   4 | t=6.3797e-02s+/-1.2e-02 | leg=1.9527e-03s | x0.03
# solar-detector flux                | NE=   4 | Neta=   8 | t=6.7443e-02s+/-1.3e-02 | leg=2.8755e-03s | x0.04
# solar-detector flux                | NE=   4 | Neta=  16 | t=6.8938e-02s+/-1.5e-02 | leg=4.7505e-03s | x0.07
# solar-detector flux                | NE=   4 | Neta=  32 | t=4.7863e-02s+/-7.7e-04 | leg=8.4193e-03s | x0.18
# solar-detector flux                | NE=   4 | Neta=  64 | t=5.0107e-02s+/-3.7e-03 | leg=1.6073e-02s | x0.32
# solar-detector flux                | NE=   4 | Neta= 128 | t=5.4063e-02s+/-1.3e-03 | leg=3.1359e-02s | x0.58
# solar-detector flux                | NE=   4 | Neta= 256 | t=6.2471e-02s+/-2.8e-03 | leg=6.1382e-02s | x0.98
# solar-detector flux                | NE=   4 | Neta= 512 | t=7.3799e-02s+/-1.1e-03 | leg=1.2479e-01s | x1.69
# solar-detector flux                | NE=   4 | Neta=1024 | t=1.0124e-01s+/-2.3e-03 | leg=2.4113e-01s | x2.38
# solar-detector flux                | NE=   8 | Neta=   4 | t=4.5132e-02s+/-2.1e-03 | leg=3.5937e-03s | x0.08
# solar-detector flux                | NE=   8 | Neta=   8 | t=4.4786e-02s+/-2.8e-04 | leg=5.4080e-03s | x0.12
# solar-detector flux                | NE=   8 | Neta=  16 | t=4.6003e-02s+/-6.0e-04 | leg=9.1110e-03s | x0.20
# solar-detector flux                | NE=   8 | Neta=  32 | t=4.8553e-02s+/-5.0e-04 | leg=1.6650e-02s | x0.34
# solar-detector flux                | NE=   8 | Neta=  64 | t=5.1002e-02s+/-3.4e-04 | leg=3.1430e-02s | x0.62
# solar-detector flux                | NE=   8 | Neta= 128 | t=5.7380e-02s+/-2.8e-04 | leg=6.2238e-02s | x1.08
# solar-detector flux                | NE=   8 | Neta= 256 | t=7.1846e-02s+/-8.9e-04 | leg=1.2182e-01s | x1.70
# solar-detector flux                | NE=   8 | Neta= 512 | t=1.0017e-01s+/-4.8e-04 | leg=2.4150e-01s | x2.41
# solar-detector flux                | NE=   8 | Neta=1024 | t=1.6274e-01s+/-2.6e-03 | leg=4.8130e-01s | x2.96
# solar-detector flux                | NE=  16 | Neta=   4 | t=4.5137e-02s+/-6.5e-04 | leg=6.9706e-03s | x0.15
# solar-detector flux                | NE=  16 | Neta=   8 | t=4.6340e-02s+/-5.9e-04 | leg=1.0326e-02s | x0.22
# solar-detector flux                | NE=  16 | Neta=  16 | t=4.7629e-02s+/-1.3e-03 | leg=1.8033e-02s | x0.38
# solar-detector flux                | NE=  16 | Neta=  32 | t=5.1342e-02s+/-5.2e-04 | leg=3.2981e-02s | x0.64
# solar-detector flux                | NE=  16 | Neta=  64 | t=5.7138e-02s+/-6.4e-04 | leg=6.3561e-02s | x1.11
# solar-detector flux                | NE=  16 | Neta= 128 | t=7.1588e-02s+/-1.3e-03 | leg=1.2369e-01s | x1.73
# solar-detector flux                | NE=  16 | Neta= 256 | t=1.0048e-01s+/-5.0e-04 | leg=2.4473e-01s | x2.44
# solar-detector flux                | NE=  16 | Neta= 512 | t=1.6412e-01s+/-2.1e-03 | leg=4.8702e-01s | x2.97
# solar-detector flux                | NE=  16 | Neta=1024 | t=3.2544e-01s+/-2.2e-03 | leg=9.6667e-01s | x2.97
# solar-detector flux                | NE=  32 | Neta=   4 | t=5.2242e-02s+/-7.1e-04 | leg=1.3696e-02s | x0.26
# solar-detector flux                | NE=  32 | Neta=   8 | t=5.7337e-02s+/-1.1e-02 | leg=2.0977e-02s | x0.37
# solar-detector flux                | NE=  32 | Neta=  16 | t=6.5521e-02s+/-4.6e-04 | leg=3.5741e-02s | x0.55
# solar-detector flux                | NE=  32 | Neta=  32 | t=6.0743e-02s+/-6.6e-04 | leg=6.5748e-02s | x1.08
# solar-detector flux                | NE=  32 | Neta=  64 | t=7.4666e-02s+/-5.8e-04 | leg=1.2541e-01s | x1.68
# solar-detector flux                | NE=  32 | Neta= 128 | t=1.0083e-01s+/-1.3e-03 | leg=2.4611e-01s | x2.44
# solar-detector flux                | NE=  32 | Neta= 256 | t=1.6528e-01s+/-1.7e-03 | leg=4.9026e-01s | x2.97
# solar-detector flux                | NE=  32 | Neta= 512 | t=3.2838e-01s+/-8.5e-03 | leg=9.8545e-01s | x3.00
# solar-detector flux                | NE=  32 | Neta=1024 | t=6.5567e-01s+/-9.4e-03 | leg=1.9442e+00s | x2.97
# solar-detector flux                | NE=  64 | Neta=   4 | t=4.8989e-02s+/-7.7e-04 | leg=2.7306e-02s | x0.56
# solar-detector flux                | NE=  64 | Neta=   8 | t=5.3291e-02s+/-2.4e-04 | leg=4.1566e-02s | x0.78
# solar-detector flux                | NE=  64 | Neta=  16 | t=6.0675e-02s+/-1.8e-03 | leg=7.1342e-02s | x1.18
# solar-detector flux                | NE=  64 | Neta=  32 | t=7.3243e-02s+/-8.5e-04 | leg=1.3124e-01s | x1.79
# solar-detector flux                | NE=  64 | Neta=  64 | t=1.0160e-01s+/-1.4e-03 | leg=2.5347e-01s | x2.49
# solar-detector flux                | NE=  64 | Neta= 128 | t=1.6445e-01s+/-1.3e-03 | leg=4.9518e-01s | x3.01
# solar-detector flux                | NE=  64 | Neta= 256 | t=3.2529e-01s+/-7.7e-04 | leg=9.8036e-01s | x3.01
# solar-detector flux                | NE=  64 | Neta= 512 | t=6.5028e-01s+/-2.4e-03 | leg=1.9525e+00s | x3.00
# solar-detector flux                | NE=  64 | Neta=1024 | t=1.2992e+00s+/-7.1e-03 | leg=3.8825e+00s | x2.99
# solar-detector flux                | NE= 128 | Neta=   4 | t=5.2646e-02s+/-5.5e-04 | leg=5.3882e-02s | x1.02
# solar-detector flux                | NE= 128 | Neta=   8 | t=6.0932e-02s+/-4.3e-04 | leg=8.2819e-02s | x1.36
# solar-detector flux                | NE= 128 | Neta=  16 | t=7.4754e-02s+/-1.6e-03 | leg=1.4224e-01s | x1.90
# solar-detector flux                | NE= 128 | Neta=  32 | t=1.0040e-01s+/-2.2e-03 | leg=2.6276e-01s | x2.62
# solar-detector flux                | NE= 128 | Neta=  64 | t=1.6498e-01s+/-1.8e-03 | leg=5.0676e-01s | x3.07
# solar-detector flux                | NE= 128 | Neta= 128 | t=3.2566e-01s+/-1.6e-03 | leg=9.9018e-01s | x3.04
# solar-detector flux                | NE= 128 | Neta= 256 | t=6.5016e-01s+/-4.6e-03 | leg=1.9582e+00s | x3.01
# solar-detector flux                | NE= 128 | Neta= 512 | t=1.2942e+00s+/-8.6e-03 | leg=3.8854e+00s | x3.00
# solar-detector flux                | NE= 128 | Neta=1024 | t=2.5875e+00s+/-6.2e-03 | leg=7.7674e+00s | x3.00
# solar-detector flux                | NE= 256 | Neta=   4 | t=6.0672e-02s+/-7.3e-04 | leg=1.0767e-01s | x1.77
# solar-detector flux                | NE= 256 | Neta=   8 | t=7.5470e-02s+/-1.1e-03 | leg=1.6538e-01s | x2.19
# solar-detector flux                | NE= 256 | Neta=  16 | t=1.0182e-01s+/-1.0e-03 | leg=2.8567e-01s | x2.81
# solar-detector flux                | NE= 256 | Neta=  32 | t=1.6481e-01s+/-1.4e-03 | leg=5.2683e-01s | x3.20
# solar-detector flux                | NE= 256 | Neta=  64 | t=3.2499e-01s+/-2.0e-03 | leg=1.0095e+00s | x3.11
# solar-detector flux                | NE= 256 | Neta= 128 | t=6.4711e-01s+/-4.3e-03 | leg=1.9874e+00s | x3.07
# solar-detector flux                | NE= 256 | Neta= 256 | t=1.2962e+00s+/-2.6e-02 | leg=3.9396e+00s | x3.04
# solar-detector flux                | NE= 256 | Neta= 512 | t=2.5886e+00s+/-5.7e-03 | leg=7.8880e+00s | x3.05
# solar-detector flux                | NE= 256 | Neta=1024 | t=5.1863e+00s+/-4.8e-02 | leg=1.5645e+01s | x3.02
# solar-detector flux                | NE= 512 | Neta=   4 | t=7.8516e-02s+/-2.8e-03 | leg=2.1646e-01s | x2.76
# solar-detector flux                | NE= 512 | Neta=   8 | t=1.0281e-01s+/-1.9e-03 | leg=3.3250e-01s | x3.23
# solar-detector flux                | NE= 512 | Neta=  16 | t=1.6598e-01s+/-1.5e-03 | leg=5.6904e-01s | x3.43
# solar-detector flux                | NE= 512 | Neta=  32 | t=3.2766e-01s+/-3.8e-03 | leg=1.0635e+00s | x3.25
# solar-detector flux                | NE= 512 | Neta=  64 | t=6.5424e-01s+/-8.5e-03 | leg=2.0300e+00s | x3.10
# solar-detector flux                | NE= 512 | Neta= 128 | t=1.2975e+00s+/-4.1e-03 | leg=4.0078e+00s | x3.09
# solar-detector flux                | NE= 512 | Neta= 256 | t=2.5948e+00s+/-8.2e-03 | leg=7.8947e+00s | x3.04
# solar-detector flux                | NE= 512 | Neta= 512 | t=5.1445e+00s+/-3.4e-02 | leg=1.5629e+01s | x3.04
# solar-detector flux                | NE= 512 | Neta=1024 | t=1.0377e+01s+/-2.4e-02 | leg=3.1191e+01s | x3.01
# solar-detector flux                | NE=1024 | Neta=   4 | t=1.1080e-01s+/-8.5e-04 | leg=4.3186e-01s | x3.90
# solar-detector flux                | NE=1024 | Neta=   8 | t=1.7569e-01s+/-8.4e-04 | leg=6.6560e-01s | x3.79
# solar-detector flux                | NE=1024 | Neta=  16 | t=3.4412e-01s+/-1.6e-03 | leg=1.1478e+00s | x3.34
# solar-detector flux                | NE=1024 | Neta=  32 | t=6.8295e-01s+/-7.3e-04 | leg=2.1256e+00s | x3.11
# solar-detector flux                | NE=1024 | Neta=  64 | t=1.3528e+00s+/-2.7e-03 | leg=4.0535e+00s | x3.00
# solar-detector flux                | NE=1024 | Neta= 128 | t=2.5949e+00s+/-5.9e-03 | leg=7.9620e+00s | x3.07
# solar-detector flux                | NE=1024 | Neta= 256 | t=5.1781e+00s+/-1.2e-02 | leg=1.5849e+01s | x3.06
# solar-detector flux                | NE=1024 | Neta= 512 | t=1.0450e+01s+/-2.1e-02 | leg=3.1219e+01s | x2.99
# solar-detector flux                | NE=1024 | Neta=1024 | t=2.1052e+01s+/-4.7e-01 | leg=6.2530e+01s | x2.97
#                 section  n_energy  n_nadir  tpeanuts_best_s  legacy_best_s  \
# 0   solar-detector flux         4        4         0.063797       0.001953
# 1   solar-detector flux         4        8         0.067443       0.002876
# 2   solar-detector flux         4       16         0.068938       0.004751
# 3   solar-detector flux         4       32         0.047863       0.008419
# 4   solar-detector flux         4       64         0.050107       0.016073
# ..                  ...       ...      ...              ...            ...
# 76  solar-detector flux      1024       64         1.352835       4.053456
# 77  solar-detector flux      1024      128         2.594947       7.962038
# 78  solar-detector flux      1024      256         5.178127      15.848625
# 79  solar-detector flux      1024      512        10.449745      31.219187
# 80  solar-detector flux      1024     1024        21.051951      62.530042
#
#     tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  legacy_std_s  \
# 0          0.073386       0.002063        0.011759      0.000160
# 1          0.075613       0.003179        0.012901      0.000538
# 2          0.082261       0.004900        0.014636      0.000170
# 3          0.049072       0.008676        0.000771      0.000135
# 4          0.052380       0.016226        0.003685      0.000099
# ..              ...            ...             ...           ...
# 76         1.356773       4.092144        0.002723      0.033780
# 77         2.603988       7.992693        0.005911      0.044938
# 78         5.201630      15.940553        0.012492      0.049045
# 79        10.489247      31.329062        0.021364      0.080074
# 80        21.568757      62.742853        0.468879      0.196678
#
#     speedup_legacy_over_tpeanuts
# 0                       0.030608
# 1                       0.042636
# 2                       0.068910
# 3                       0.175903
# 4                       0.320771
# ..                           ...
# 76                      2.996267
# 77                      3.068285
# 78                      3.060687
# 79                      2.987555
# 80                      2.970273
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_flux_timing.csv
# v:\output\benchmark\solar_detector_flux_speedup.png
# v:\output\benchmark\solar_detector_flux_speedup_cross_sections.png

# %% [markdown]
# ### 7.3 Integrated Probability Timing
#
# This benchmark integrates the solar-to-detector probability over a uniform nadir-angle exposure. It exercises the same solar production and Earth propagation chain, plus the final angular contraction.
#
# **Expected results:**<br>
# - Timings should increase with both energy and nadir grid size. The speedup map should show whether tensor batching compensates for the extra integration step.

# %%
solar_detector_integrated_records = []
for ne in ENERGY_GRID_SIZES:
    for neta in NADIR_GRID_SIZES:
        E_1d   = energy_grid(ne, solar=True)
        eta_1d = nadir_grid(neta)
        solar_detector_integrated_records.append(benchmark_pair(
            "solar-detector integrated", ne, neta,
            lambda E=E_1d, eta=eta_1d: tpeanuts_integrated(E, eta, SOLAR_DETECTOR_DEPTH_M),
            lambda E_np=to_numpy(E_1d), eta_np=to_numpy(eta_1d):
                legacy_integrated(E_np, eta_np, SOLAR_DETECTOR_DEPTH_M),
        ))
solar_detector_integrated_df = pd.DataFrame(solar_detector_integrated_records)
display(solar_detector_integrated_df)
save_results(solar_detector_integrated_df, "solar_detector_integrated_timing")
plot_heatmap(solar_detector_integrated_df,
              "Solar-detector integrated speedup (LogNorm)",
              "solar_detector_integrated_speedup.png")
plot_speedup_cross_sections(solar_detector_integrated_df,
                              "Solar-detector integrated speedup cross sections",
                              "solar_detector_integrated_speedup_cross_sections.png")
# Out:
# solar-detector integrated          | NE=   4 | Neta=   4 | t=5.7255e-02s+/-2.4e-03 | leg=2.2333e-03s | x0.04
# solar-detector integrated          | NE=   4 | Neta=   8 | t=5.5790e-02s+/-3.1e-03 | leg=3.1082e-03s | x0.06
# solar-detector integrated          | NE=   4 | Neta=  16 | t=5.8196e-02s+/-1.7e-03 | leg=4.9475e-03s | x0.09
# solar-detector integrated          | NE=   4 | Neta=  32 | t=6.3268e-02s+/-2.7e-03 | leg=8.7532e-03s | x0.14
# solar-detector integrated          | NE=   4 | Neta=  64 | t=6.9626e-02s+/-9.6e-03 | leg=1.5890e-02s | x0.23
# solar-detector integrated          | NE=   4 | Neta= 128 | t=9.0585e-02s+/-4.1e-03 | leg=3.1319e-02s | x0.35
# solar-detector integrated          | NE=   4 | Neta= 256 | t=8.7049e-02s+/-4.4e-03 | leg=6.2005e-02s | x0.71
# solar-detector integrated          | NE=   4 | Neta= 512 | t=1.0180e-01s+/-6.6e-03 | leg=1.2234e-01s | x1.20
# solar-detector integrated          | NE=   4 | Neta=1024 | t=1.0796e-01s+/-1.2e-03 | leg=2.4416e-01s | x2.26
# solar-detector integrated          | NE=   8 | Neta=   4 | t=4.5461e-02s+/-7.2e-04 | leg=4.0620e-03s | x0.09
# solar-detector integrated          | NE=   8 | Neta=   8 | t=4.6585e-02s+/-3.8e-04 | leg=5.9020e-03s | x0.13
# solar-detector integrated          | NE=   8 | Neta=  16 | t=4.7079e-02s+/-2.4e-03 | leg=9.5538e-03s | x0.20
# solar-detector integrated          | NE=   8 | Neta=  32 | t=4.9450e-02s+/-7.9e-04 | leg=1.7122e-02s | x0.35
# solar-detector integrated          | NE=   8 | Neta=  64 | t=5.2814e-02s+/-2.6e-03 | leg=3.2012e-02s | x0.61
# solar-detector integrated          | NE=   8 | Neta= 128 | t=5.9200e-02s+/-1.2e-03 | leg=6.2818e-02s | x1.06
# solar-detector integrated          | NE=   8 | Neta= 256 | t=7.5666e-02s+/-6.8e-04 | leg=1.2337e-01s | x1.63
# solar-detector integrated          | NE=   8 | Neta= 512 | t=1.0513e-01s+/-3.6e-03 | leg=2.4671e-01s | x2.35
# solar-detector integrated          | NE=   8 | Neta=1024 | t=1.6602e-01s+/-6.5e-03 | leg=4.8491e-01s | x2.92
# solar-detector integrated          | NE=  16 | Neta=   4 | t=4.5853e-02s+/-8.9e-04 | leg=7.8207e-03s | x0.17
# solar-detector integrated          | NE=  16 | Neta=   8 | t=4.5991e-02s+/-3.6e-03 | leg=1.1180e-02s | x0.24
# solar-detector integrated          | NE=  16 | Neta=  16 | t=4.7329e-02s+/-1.7e-03 | leg=1.8408e-02s | x0.39
# solar-detector integrated          | NE=  16 | Neta=  32 | t=6.5032e-02s+/-5.0e-03 | leg=3.3834e-02s | x0.52
# solar-detector integrated          | NE=  16 | Neta=  64 | t=8.4175e-02s+/-4.6e-03 | leg=6.3890e-02s | x0.76
# solar-detector integrated          | NE=  16 | Neta= 128 | t=1.0891e-01s+/-4.5e-03 | leg=1.2418e-01s | x1.14
# solar-detector integrated          | NE=  16 | Neta= 256 | t=1.0185e-01s+/-2.5e-03 | leg=2.4547e-01s | x2.41
# solar-detector integrated          | NE=  16 | Neta= 512 | t=1.6410e-01s+/-7.6e-04 | leg=4.8626e-01s | x2.96
# solar-detector integrated          | NE=  16 | Neta=1024 | t=3.2550e-01s+/-2.0e-03 | leg=9.7165e-01s | x2.99
# solar-detector integrated          | NE=  32 | Neta=   4 | t=4.6384e-02s+/-1.6e-03 | leg=1.5167e-02s | x0.33
# solar-detector integrated          | NE=  32 | Neta=   8 | t=4.8041e-02s+/-8.1e-04 | leg=2.2460e-02s | x0.47
# solar-detector integrated          | NE=  32 | Neta=  16 | t=5.1074e-02s+/-1.7e-03 | leg=3.6942e-02s | x0.72
# solar-detector integrated          | NE=  32 | Neta=  32 | t=5.7450e-02s+/-1.3e-03 | leg=6.7398e-02s | x1.17
# solar-detector integrated          | NE=  32 | Neta=  64 | t=7.1842e-02s+/-1.2e-03 | leg=1.3018e-01s | x1.81
# solar-detector integrated          | NE=  32 | Neta= 128 | t=1.0316e-01s+/-2.9e-03 | leg=2.5995e-01s | x2.52
# solar-detector integrated          | NE=  32 | Neta= 256 | t=1.7033e-01s+/-5.8e-04 | leg=4.9820e-01s | x2.92
# solar-detector integrated          | NE=  32 | Neta= 512 | t=3.3888e-01s+/-1.6e-03 | leg=9.7385e-01s | x2.87
# solar-detector integrated          | NE=  32 | Neta=1024 | t=6.4770e-01s+/-3.4e-03 | leg=1.9361e+00s | x2.99
# solar-detector integrated          | NE=  64 | Neta=   4 | t=4.7724e-02s+/-2.0e-03 | leg=2.9951e-02s | x0.63
# solar-detector integrated          | NE=  64 | Neta=   8 | t=5.1149e-02s+/-1.0e-03 | leg=4.4520e-02s | x0.87
# solar-detector integrated          | NE=  64 | Neta=  16 | t=5.7318e-02s+/-2.0e-03 | leg=7.4593e-02s | x1.30
# solar-detector integrated          | NE=  64 | Neta=  32 | t=9.2479e-02s+/-1.3e-03 | leg=1.3405e-01s | x1.45
# solar-detector integrated          | NE=  64 | Neta=  64 | t=1.0169e-01s+/-2.6e-03 | leg=2.5640e-01s | x2.52
# solar-detector integrated          | NE=  64 | Neta= 128 | t=1.6534e-01s+/-9.8e-04 | leg=4.9681e-01s | x3.00
# solar-detector integrated          | NE=  64 | Neta= 256 | t=3.2500e-01s+/-3.2e-03 | leg=9.8444e-01s | x3.03
# solar-detector integrated          | NE=  64 | Neta= 512 | t=6.4990e-01s+/-1.8e-03 | leg=1.9472e+00s | x3.00
# solar-detector integrated          | NE=  64 | Neta=1024 | t=1.2951e+00s+/-9.0e-03 | leg=3.8841e+00s | x3.00
# solar-detector integrated          | NE= 128 | Neta=   4 | t=6.9882e-02s+/-3.2e-03 | leg=5.9794e-02s | x0.86
# solar-detector integrated          | NE= 128 | Neta=   8 | t=8.7035e-02s+/-4.5e-03 | leg=8.8666e-02s | x1.02
# solar-detector integrated          | NE= 128 | Neta=  16 | t=8.6994e-02s+/-1.7e-03 | leg=1.4872e-01s | x1.71
# solar-detector integrated          | NE= 128 | Neta=  32 | t=1.0879e-01s+/-2.2e-03 | leg=2.6972e-01s | x2.48
# solar-detector integrated          | NE= 128 | Neta=  64 | t=1.6363e-01s+/-1.5e-03 | leg=5.1231e-01s | x3.13
# solar-detector integrated          | NE= 128 | Neta= 128 | t=3.2688e-01s+/-1.7e-03 | leg=1.0013e+00s | x3.06
# solar-detector integrated          | NE= 128 | Neta= 256 | t=6.5164e-01s+/-2.6e-03 | leg=1.9606e+00s | x3.01
# solar-detector integrated          | NE= 128 | Neta= 512 | t=1.2961e+00s+/-5.1e-03 | leg=3.9138e+00s | x3.02
# solar-detector integrated          | NE= 128 | Neta=1024 | t=2.5865e+00s+/-6.4e-03 | leg=7.8075e+00s | x3.02
# solar-detector integrated          | NE= 256 | Neta=   4 | t=8.9439e-02s+/-3.6e-03 | leg=1.1974e-01s | x1.34
# solar-detector integrated          | NE= 256 | Neta=   8 | t=1.0986e-01s+/-9.8e-04 | leg=1.7597e-01s | x1.60
# solar-detector integrated          | NE= 256 | Neta=  16 | t=1.1049e-01s+/-7.9e-04 | leg=2.9892e-01s | x2.71
# solar-detector integrated          | NE= 256 | Neta=  32 | t=1.6436e-01s+/-1.0e-03 | leg=5.3527e-01s | x3.26
# solar-detector integrated          | NE= 256 | Neta=  64 | t=3.2591e-01s+/-1.9e-03 | leg=1.0253e+00s | x3.15
# solar-detector integrated          | NE= 256 | Neta= 128 | t=6.4563e-01s+/-2.9e-03 | leg=2.0025e+00s | x3.10
# solar-detector integrated          | NE= 256 | Neta= 256 | t=1.2984e+00s+/-4.2e-03 | leg=3.9511e+00s | x3.04
# solar-detector integrated          | NE= 256 | Neta= 512 | t=2.5893e+00s+/-1.1e-02 | leg=7.8415e+00s | x3.03
# solar-detector integrated          | NE= 256 | Neta=1024 | t=5.1828e+00s+/-1.5e-02 | leg=1.5636e+01s | x3.02
# solar-detector integrated          | NE= 512 | Neta=   4 | t=8.1224e-02s+/-1.6e-03 | leg=2.4184e-01s | x2.98
# solar-detector integrated          | NE= 512 | Neta=   8 | t=1.0315e-01s+/-6.1e-04 | leg=3.5587e-01s | x3.45
# solar-detector integrated          | NE= 512 | Neta=  16 | t=1.6664e-01s+/-1.6e-03 | leg=5.9646e-01s | x3.58
# solar-detector integrated          | NE= 512 | Neta=  32 | t=3.2599e-01s+/-3.0e-03 | leg=1.0796e+00s | x3.31
# solar-detector integrated          | NE= 512 | Neta=  64 | t=6.4588e-01s+/-3.5e-03 | leg=2.0536e+00s | x3.18
# solar-detector integrated          | NE= 512 | Neta= 128 | t=1.3070e+00s+/-2.0e-03 | leg=4.0082e+00s | x3.07
# solar-detector integrated          | NE= 512 | Neta= 256 | t=2.5902e+00s+/-7.2e-03 | leg=7.8964e+00s | x3.05
# solar-detector integrated          | NE= 512 | Neta= 512 | t=5.1470e+00s+/-1.7e-02 | leg=1.5658e+01s | x3.04
# solar-detector integrated          | NE= 512 | Neta=1024 | t=1.0353e+01s+/-1.7e-02 | leg=3.1231e+01s | x3.02
# solar-detector integrated          | NE=1024 | Neta=   4 | t=1.0756e-01s+/-3.3e-04 | leg=4.8038e-01s | x4.47
# solar-detector integrated          | NE=1024 | Neta=   8 | t=1.7139e-01s+/-1.7e-03 | leg=7.1107e-01s | x4.15
# solar-detector integrated          | NE=1024 | Neta=  16 | t=3.3085e-01s+/-2.7e-03 | leg=1.1924e+00s | x3.60
# solar-detector integrated          | NE=1024 | Neta=  32 | t=6.5040e-01s+/-3.6e-03 | leg=2.1552e+00s | x3.31
# solar-detector integrated          | NE=1024 | Neta=  64 | t=1.2990e+00s+/-4.5e-03 | leg=4.0952e+00s | x3.15
# solar-detector integrated          | NE=1024 | Neta= 128 | t=2.5976e+00s+/-5.3e-03 | leg=8.0176e+00s | x3.09
# solar-detector integrated          | NE=1024 | Neta= 256 | t=5.1530e+00s+/-2.1e-02 | leg=1.5797e+01s | x3.07
# solar-detector integrated          | NE=1024 | Neta= 512 | t=1.0366e+01s+/-1.4e-02 | leg=3.1344e+01s | x3.02
# solar-detector integrated          | NE=1024 | Neta=1024 | t=2.0734e+01s+/-1.7e-02 | leg=6.2448e+01s | x3.01
#                       section  n_energy  n_nadir  tpeanuts_best_s  \
# 0   solar-detector integrated         4        4         0.057255
# 1   solar-detector integrated         4        8         0.055790
# 2   solar-detector integrated         4       16         0.058196
# 3   solar-detector integrated         4       32         0.063268
# 4   solar-detector integrated         4       64         0.069626
# ..                        ...       ...      ...              ...
# 76  solar-detector integrated      1024       64         1.299022
# 77  solar-detector integrated      1024      128         2.597566
# 78  solar-detector integrated      1024      256         5.152954
# 79  solar-detector integrated      1024      512        10.365606
# 80  solar-detector integrated      1024     1024        20.734083
#
#     legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0        0.002233         0.060778       0.002379        0.002448
# 1        0.003108         0.060435       0.003251        0.003143
# 2        0.004947         0.060594       0.005303        0.001725
# 3        0.008753         0.066479       0.008958        0.002679
# 4        0.015890         0.079911       0.016421        0.009585
# ..            ...              ...            ...             ...
# 76       4.095176         1.305496       4.105846        0.004509
# 77       8.017596         2.605895       8.029171        0.005270
# 78      15.797326         5.188338      15.843933        0.020510
# 79      31.344478        10.382632      31.389263        0.013619
# 80      62.448231        20.757916      62.516973        0.016699
#
#     legacy_std_s  speedup_legacy_over_tpeanuts
# 0       0.000168                      0.039006
# 1       0.000161                      0.055713
# 2       0.000669                      0.085015
# 3       0.000148                      0.138352
# 4       0.000342                      0.228219
# ..           ...                           ...
# 76      0.010462                      3.152508
# 77      0.012571                      3.086580
# 78      0.032750                      3.065683
# 79      0.023975                      3.023892
# 80      0.058273                      3.011864
#
# [81 rows x 10 columns]
# Saved: v:\output\benchmark\solar_detector_integrated_timing.csv
# v:\output\benchmark\solar_detector_integrated_speedup.png
# v:\output\benchmark\solar_detector_integrated_speedup_cross_sections.png

# %% [markdown]
# ## 8. GPU Benchmark (Conditional)
#
# This optional benchmark runs only when a CUDA device is available. It compares CPU and GPU execution for the solar-to-detector probability stage using the same physical inputs and grid sizes.
#
# **Expected results:**<br>
# - On machines without CUDA the cell should skip cleanly.
# - When CUDA is available, the GPU speedup should become more meaningful for larger energy and nadir grids, where transfer overhead is less dominant.

# %%
if not torch.cuda.is_available():
    print("No CUDA device — skipping GPU benchmark.")
else:
    print(f"GPU: {torch.cuda.get_device_name(0)}")

    _ = torch.zeros(1, device=GPU_DEVICE)
    torch.cuda.synchronize()

    gpu_records = []
    for ne in ENERGY_GRID_SIZES:
        for neta in NADIR_GRID_SIZES:
            E_1d   = energy_grid(ne, solar=True)
            eta_1d = nadir_grid(neta)

            def tpeanuts_cpu():
                return tpeanuts_solar_detector_probabilities(E_1d, eta_1d, device=DEVICE)

            def tpeanuts_gpu():
                E_g   = E_1d.to(GPU_DEVICE)
                eta_g = eta_1d.to(GPU_DEVICE)
                result = tpeanuts_solar_detector_probabilities(E_g, eta_g, device=GPU_DEVICE)
                torch.cuda.synchronize()
                return result

            t_cpu, _, _ = timed_call(tpeanuts_cpu)
            t_gpu, _, _ = timed_call(tpeanuts_gpu)
            speedup_gpu = t_cpu / max(t_gpu, 1e-15)
            gpu_records.append({
                "n_energy": ne, "n_nadir": neta,
                "cpu_s": t_cpu, "gpu_s": t_gpu,
                "speedup_gpu_over_cpu": speedup_gpu,
            })
            print(f"NE={ne:4d} | Neta={neta:4d} | CPU={t_cpu:.4e}s | GPU={t_gpu:.4e}s | x{speedup_gpu:.2f}")

    gpu_df = pd.DataFrame(gpu_records)
    display(gpu_df)
    save_results(gpu_df, "gpu_timing")

    pivot_gpu = gpu_df.pivot(index="n_nadir", columns="n_energy", values="speedup_gpu_over_cpu")
    vmax_gpu  = max(pivot_gpu.values.max(), 1.1)
    fig, ax = plt.subplots(figsize=(7.5, 5.5))
    im = ax.imshow(pivot_gpu.values, origin="lower", aspect="auto",
                   norm=mcolors.LogNorm(vmin=0.1, vmax=vmax_gpu), cmap="RdYlGn")
    ax.set_xticks(np.arange(len(pivot_gpu.columns))); ax.set_xticklabels(pivot_gpu.columns)
    ax.set_yticks(np.arange(len(pivot_gpu.index)));   ax.set_yticklabels(pivot_gpu.index)
    for r in range(pivot_gpu.values.shape[0]):
        for c in range(pivot_gpu.values.shape[1]):
            ax.text(c, r, f"{pivot_gpu.values[r,c]:.1f}x", ha="center", va="center", fontsize=8)
    ax.set_xlabel("Energy-grid size"); ax.set_ylabel("Nadir-grid size")
    ax.set_title("GPU / CPU speedup — solar-detector probabilities")
    fig.colorbar(im, ax=ax, label="GPU speedup (log)")
    fig.tight_layout()
    save_and_show("gpu_speedup_heatmap.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# GPU: NVIDIA GeForce GTX 1080 Ti
# NE=   4 | Neta=   4 | CPU=4.9918e-02s | GPU=4.9813e-02s | x1.00
# NE=   4 | Neta=   8 | CPU=5.0271e-02s | GPU=5.0002e-02s | x1.01
# NE=   4 | Neta=  16 | CPU=5.1468e-02s | GPU=5.1454e-02s | x1.00
# NE=   4 | Neta=  32 | CPU=5.4512e-02s | GPU=5.4541e-02s | x1.00
# NE=   4 | Neta=  64 | CPU=6.0332e-02s | GPU=5.9896e-02s | x1.01
# NE=   4 | Neta= 128 | CPU=7.2066e-02s | GPU=8.0588e-02s | x0.89
# NE=   4 | Neta= 256 | CPU=8.3595e-02s | GPU=8.2177e-02s | x1.02
# NE=   4 | Neta= 512 | CPU=8.7966e-02s | GPU=8.8604e-02s | x0.99
# NE=   4 | Neta=1024 | CPU=1.0295e-01s | GPU=1.0447e-01s | x0.99
# NE=   8 | Neta=   4 | CPU=4.6405e-02s | GPU=4.4439e-02s | x1.04
# NE=   8 | Neta=   8 | CPU=4.6600e-02s | GPU=4.7315e-02s | x0.98
# NE=   8 | Neta=  16 | CPU=5.0597e-02s | GPU=4.8516e-02s | x1.04
# NE=   8 | Neta=  32 | CPU=4.7219e-02s | GPU=4.7813e-02s | x0.99
# NE=   8 | Neta=  64 | CPU=5.1447e-02s | GPU=5.1123e-02s | x1.01
# NE=   8 | Neta= 128 | CPU=5.7424e-02s | GPU=5.7803e-02s | x0.99
# NE=   8 | Neta= 256 | CPU=7.1585e-02s | GPU=7.1330e-02s | x1.00
# NE=   8 | Neta= 512 | CPU=1.0012e-01s | GPU=1.0124e-01s | x0.99
# NE=   8 | Neta=1024 | CPU=1.6292e-01s | GPU=1.6427e-01s | x0.99
# NE=  16 | Neta=   4 | CPU=4.5552e-02s | GPU=4.5387e-02s | x1.00
# NE=  16 | Neta=   8 | CPU=4.6858e-02s | GPU=4.6245e-02s | x1.01
# NE=  16 | Neta=  16 | CPU=4.7876e-02s | GPU=4.8827e-02s | x0.98
# NE=  16 | Neta=  32 | CPU=5.0816e-02s | GPU=5.0521e-02s | x1.01
# NE=  16 | Neta=  64 | CPU=5.7153e-02s | GPU=5.6973e-02s | x1.00
# NE=  16 | Neta= 128 | CPU=7.1999e-02s | GPU=7.6315e-02s | x0.94
# NE=  16 | Neta= 256 | CPU=1.0059e-01s | GPU=1.0077e-01s | x1.00
# NE=  16 | Neta= 512 | CPU=1.6459e-01s | GPU=1.6492e-01s | x1.00
# NE=  16 | Neta=1024 | CPU=3.2587e-01s | GPU=3.2700e-01s | x1.00
# NE=  32 | Neta=   4 | CPU=4.6169e-02s | GPU=4.6381e-02s | x1.00
# NE=  32 | Neta=   8 | CPU=4.6973e-02s | GPU=4.8050e-02s | x0.98
# NE=  32 | Neta=  16 | CPU=5.0786e-02s | GPU=5.0544e-02s | x1.00
# NE=  32 | Neta=  32 | CPU=5.8243e-02s | GPU=5.7722e-02s | x1.01
# NE=  32 | Neta=  64 | CPU=7.1637e-02s | GPU=7.1980e-02s | x1.00
# NE=  32 | Neta= 128 | CPU=1.0053e-01s | GPU=1.0084e-01s | x1.00
# NE=  32 | Neta= 256 | CPU=1.6420e-01s | GPU=1.6490e-01s | x1.00
# NE=  32 | Neta= 512 | CPU=3.2695e-01s | GPU=3.2621e-01s | x1.00
# NE=  32 | Neta=1024 | CPU=6.4955e-01s | GPU=6.4804e-01s | x1.00
# NE=  64 | Neta=   4 | CPU=4.8216e-02s | GPU=4.7484e-02s | x1.02
# NE=  64 | Neta=   8 | CPU=6.1130e-02s | GPU=6.1408e-02s | x1.00
# NE=  64 | Neta=  16 | CPU=8.1692e-02s | GPU=8.2008e-02s | x1.00
# NE=  64 | Neta=  32 | CPU=9.9101e-02s | GPU=8.3107e-02s | x1.19
# NE=  64 | Neta=  64 | CPU=1.0571e-01s | GPU=1.0046e-01s | x1.05
# NE=  64 | Neta= 128 | CPU=1.6322e-01s | GPU=1.6627e-01s | x0.98
# NE=  64 | Neta= 256 | CPU=3.2675e-01s | GPU=3.2608e-01s | x1.00
# NE=  64 | Neta= 512 | CPU=6.4984e-01s | GPU=6.4627e-01s | x1.01
# NE=  64 | Neta=1024 | CPU=1.2944e+00s | GPU=1.2955e+00s | x1.00
# NE= 128 | Neta=   4 | CPU=5.1247e-02s | GPU=4.9690e-02s | x1.03
# NE= 128 | Neta=   8 | CPU=6.0532e-02s | GPU=6.1707e-02s | x0.98
# NE= 128 | Neta=  16 | CPU=8.3095e-02s | GPU=8.3328e-02s | x1.00
# NE= 128 | Neta=  32 | CPU=1.0745e-01s | GPU=1.0101e-01s | x1.06
# NE= 128 | Neta=  64 | CPU=1.6520e-01s | GPU=1.6530e-01s | x1.00
# NE= 128 | Neta= 128 | CPU=3.2564e-01s | GPU=3.2632e-01s | x1.00
# NE= 128 | Neta= 256 | CPU=6.4999e-01s | GPU=6.4997e-01s | x1.00
# NE= 128 | Neta= 512 | CPU=1.2983e+00s | GPU=1.3012e+00s | x1.00
# NE= 128 | Neta=1024 | CPU=2.5919e+00s | GPU=2.5936e+00s | x1.00
# NE= 256 | Neta=   4 | CPU=5.9303e-02s | GPU=5.7158e-02s | x1.04
# NE= 256 | Neta=   8 | CPU=8.2916e-02s | GPU=8.3651e-02s | x0.99
# NE= 256 | Neta=  16 | CPU=1.0175e-01s | GPU=1.0092e-01s | x1.01
# NE= 256 | Neta=  32 | CPU=1.6571e-01s | GPU=1.6603e-01s | x1.00
# NE= 256 | Neta=  64 | CPU=3.2507e-01s | GPU=3.2608e-01s | x1.00
# NE= 256 | Neta= 128 | CPU=6.4987e-01s | GPU=6.4903e-01s | x1.00
# NE= 256 | Neta= 256 | CPU=1.2952e+00s | GPU=1.2990e+00s | x1.00
# NE= 256 | Neta= 512 | CPU=2.5931e+00s | GPU=2.5921e+00s | x1.00
# NE= 256 | Neta=1024 | CPU=5.1826e+00s | GPU=5.1860e+00s | x1.00
# NE= 512 | Neta=   4 | CPU=7.4390e-02s | GPU=7.5789e-02s | x0.98
# NE= 512 | Neta=   8 | CPU=1.0356e-01s | GPU=1.0314e-01s | x1.00
# NE= 512 | Neta=  16 | CPU=1.6686e-01s | GPU=1.6853e-01s | x0.99
# NE= 512 | Neta=  32 | CPU=3.2690e-01s | GPU=3.3068e-01s | x0.99
# NE= 512 | Neta=  64 | CPU=6.5235e-01s | GPU=6.5273e-01s | x1.00
# NE= 512 | Neta= 128 | CPU=1.2991e+00s | GPU=1.2980e+00s | x1.00
# NE= 512 | Neta= 256 | CPU=2.5915e+00s | GPU=2.5954e+00s | x1.00
# NE= 512 | Neta= 512 | CPU=5.1861e+00s | GPU=5.1805e+00s | x1.00
# NE= 512 | Neta=1024 | CPU=1.0380e+01s | GPU=1.0397e+01s | x1.00
# NE=1024 | Neta=   4 | CPU=1.0729e-01s | GPU=1.0793e-01s | x0.99
# NE=1024 | Neta=   8 | CPU=1.7206e-01s | GPU=1.7234e-01s | x1.00
# NE=1024 | Neta=  16 | CPU=3.3163e-01s | GPU=3.3187e-01s | x1.00
# NE=1024 | Neta=  32 | CPU=6.5644e-01s | GPU=6.5918e-01s | x1.00
# NE=1024 | Neta=  64 | CPU=1.3064e+00s | GPU=1.3008e+00s | x1.00
# NE=1024 | Neta= 128 | CPU=2.6047e+00s | GPU=2.6020e+00s | x1.00
# NE=1024 | Neta= 256 | CPU=5.1813e+00s | GPU=5.1892e+00s | x1.00
# NE=1024 | Neta= 512 | CPU=1.0382e+01s | GPU=1.0383e+01s | x1.00
# NE=1024 | Neta=1024 | CPU=2.0748e+01s | GPU=2.0769e+01s | x1.00
#     n_energy  n_nadir      cpu_s      gpu_s  speedup_gpu_over_cpu
# 0          4        4   0.049918   0.049813              1.002106
# 1          4        8   0.050271   0.050002              1.005378
# 2          4       16   0.051468   0.051454              1.000264
# 3          4       32   0.054512   0.054541              0.999470
# 4          4       64   0.060332   0.059896              1.007274
# ..       ...      ...        ...        ...                   ...
# 76      1024       64   1.306402   1.300843              1.004273
# 77      1024      128   2.604720   2.602014              1.001040
# 78      1024      256   5.181330   5.189186              0.998486
# 79      1024      512  10.382020  10.382785              0.999926
# 80      1024     1024  20.747802  20.768690              0.998994
#
# [81 rows x 5 columns]
# Saved: v:\output\benchmark\gpu_timing.csv
# v:\output\benchmark\gpu_speedup_heatmap.png

# %% [markdown]
# ## 9. Summary
# The summary combines all benchmark tables, stores a global CSV file, and produces aggregate speedup figures for the largest grid sizes. It is the final comparison layer for identifying where the torch-native implementation is faster or slower than the legacy reference.
#
# **Results Interpretation:**<br>
# - The median-speedup plot should make the dominant performance regimes visible, while the largest-grid comparison should summarize absolute timing and relative speedup for the most demanding benchmark points.

# %%
all_timing_df = pd.concat([
    vacuum_probability_df, vacuum_flux_df,
    solar_probability_df,  solar_flux_df,
    earth_probability_df,  earth_flux_df,
    integrated_probability_df,
    solar_detector_probability_df, solar_detector_flux_df,
    solar_detector_integrated_df,
], ignore_index=True)
display(all_timing_df)
save_results(all_timing_df, "all_performance_timing")

summary = (
    all_timing_df.groupby("section", as_index=False)
    .agg(
        median_speedup=("speedup_legacy_over_tpeanuts", "median"),
        min_speedup   =("speedup_legacy_over_tpeanuts", "min"),
        max_speedup   =("speedup_legacy_over_tpeanuts", "max"),
    )
    .sort_values("median_speedup", ascending=False)
)
display(summary)

fig, ax = plt.subplots(figsize=(11, 5.0))
xerr = np.array([
    summary["median_speedup"] - summary["min_speedup"],
    summary["max_speedup"]    - summary["median_speedup"],
])
colors = ["C2" if v > 1.0 else "C3" for v in summary["median_speedup"]]
ax.barh(summary["section"], summary["median_speedup"], xerr=xerr,
        color=colors, error_kw={"capsize": 4, "elinewidth": 1.2})
ax.axvline(1.0, color="black", lw=1.2, alpha=0.6)
ax.set_xlabel("Median speedup  (legacy / tpeanuts)")
ax.set_title("Performance summary — median speedup with min/max error bars")
fig.tight_layout()
save_and_show("summary_median_speedup.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)

largest_ne   = max(ENERGY_GRID_SIZES)
largest_neta = max(NADIR_GRID_SIZES)

large_rows = []
for df in [vacuum_probability_df, vacuum_flux_df, solar_probability_df, solar_flux_df,
           earth_probability_df, earth_flux_df, integrated_probability_df,
           solar_detector_probability_df, solar_detector_flux_df, solar_detector_integrated_df]:
    row = get_largest_timing_row(df, largest_ne, largest_neta)
    if row is not None:
        large_rows.append(row)
large_df = pd.DataFrame(large_rows).reset_index(drop=True)

fig, ax1 = plt.subplots(figsize=(13, 5.5))
x    = np.arange(len(large_df))
w    = 0.35
ax1.bar(x - w/2, large_df["tpeanuts_best_s"], width=w, label="tpeanuts", color="C0", alpha=0.85)
ax1.bar(x + w/2, large_df["legacy_best_s"],   width=w, label="legacy",   color="C1", alpha=0.85)
ax1.set_yscale("log")
ax1.set_ylabel("Best time [s]  (log scale)")
ax1.set_xticks(x)
ax1.set_xticklabels(large_df["section"], rotation=30, ha="right", fontsize=8)
ax1.legend(loc="upper left")

ax2 = ax1.twinx()
ax2.plot(x, large_df["speedup_legacy_over_tpeanuts"], "D-", color="C2", label="speedup", zorder=5)
ax2.axhline(1.0, color="gray", lw=0.8, ls="--")
ax2.set_ylabel("Speedup  (legacy / tpeanuts)", color="C2")
ax2.tick_params(axis="y", labelcolor="C2")
ax2.legend(loc="upper right")

fig.suptitle(f"Absolute time + speedup at NE={largest_ne}, Neta={largest_neta}")
fig.tight_layout()
save_and_show("summary_time_and_speedup.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
#                        section  n_energy n_nadir  tpeanuts_best_s  \
# 0         vacuum probabilities         4    None         0.002877
# 1         vacuum probabilities         8    None         0.002882
# 2         vacuum probabilities        16    None         0.002836
# 3         vacuum probabilities        32    None         0.002843
# 4         vacuum probabilities        64    None         0.002856
# ..                         ...       ...     ...              ...
# 517  solar-detector integrated      1024      64         1.299022
# 518  solar-detector integrated      1024     128         2.597566
# 519  solar-detector integrated      1024     256         5.152954
# 520  solar-detector integrated      1024     512        10.365606
# 521  solar-detector integrated      1024    1024        20.734083
#
#      legacy_best_s  tpeanuts_mean_s  legacy_mean_s  tpeanuts_std_s  \
# 0         0.000794         0.003122       0.000808        0.000285
# 1         0.001207         0.003164       0.001227        0.000143
# 2         0.002051         0.003008       0.002125        0.000182
# 3         0.003689         0.002893       0.003750        0.000058
# 4         0.007035         0.002908       0.007106        0.000039
# ..             ...              ...            ...             ...
# 517       4.095176         1.305496       4.105846        0.004509
# 518       8.017596         2.605895       8.029171        0.005270
# 519      15.797326         5.188338      15.843933        0.020510
# 520      31.344478        10.382632      31.389263        0.013619
# 521      62.448231        20.757916      62.516973        0.016699
#
#      legacy_std_s  speedup_legacy_over_tpeanuts
# 0        0.000013                      0.276055
# 1        0.000011                      0.418936
# 2        0.000093                      0.723374
# 3        0.000041                      1.297931
# 4        0.000058                      2.462979
# ..            ...                           ...
# 517      0.010462                      3.152508
# 518      0.012571                      3.086580
# 519      0.032750                      3.065683
# 520      0.023975                      3.023892
# 521      0.058273                      3.011864
#
# [522 rows x 10 columns]
# Saved: v:\output\benchmark\all_performance_timing.csv
#                         section  median_speedup  min_speedup  max_speedup
# 0                    earth flux        6.407936     0.051073     8.009045
# 2      integrated probabilities        2.724208     0.050948     4.617349
# 5           solar-detector flux        2.617053     0.030608     3.897860
# 7  solar-detector probabilities        2.523693     0.038931     3.969349
# 6     solar-detector integrated        2.521527     0.039006     4.466265
# 9          vacuum probabilities        2.462979     0.276055    36.937452
# 3                    solar flux        1.968613     0.213345    22.575256
# 1           earth probabilities        1.902192     0.025834     2.424825
# 8                   vacuum flux        1.861908     0.243348    27.068726
# 4           solar probabilities        1.175738     0.145574    19.035336
# v:\output\benchmark\summary_median_speedup.png
# v:\output\benchmark\summary_time_and_speedup.png
