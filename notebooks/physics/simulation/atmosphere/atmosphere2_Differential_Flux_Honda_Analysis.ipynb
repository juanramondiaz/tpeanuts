# %% [markdown]
# <div style="background-color:#EAEAEA;padding:20px;border-left:5px solid #6C757D;border-radius:6px;">
# <table style="width:100%; border:none;"><tr style="border:none;">
# <td style="border:none; vertical-align:top;">
# <h1 style="font-size:32px; margin-top:0;">Master's Thesis</h1>
# <hr style="margin:16px 0 22px 0;">
# <p style="font-size:22px; line-height:1.5; margin:0;"><strong>Master's Degree in Advanced Physics</strong> - <strong>Universitat de Valencia</strong></p>
# <p style="font-size:17px; margin-top:28px; margin-bottom:6px;">This notebook is part of the <strong>Master's Thesis (MSc Dissertation)</strong>:</p>
# <div style="font-size:25px;font-weight:700;line-height:1.3;margin-top:14px;margin-bottom:26px;">Fast Simulation of Neutrino Oscillations in Matter</div>
# <p style="font-size:14px; line-height:1.55;"><strong>Author</strong><br>Juan Ramon Diaz Santos - <a href="mailto:diazjuan@alumni.uv.es">diazjuan@alumni.uv.es</a></p>
# <p style="font-size:14px; line-height:1.55;"><strong>Supervisors</strong><br>Roberto Ruiz de Austri Bazan - <a href="mailto:rruiz@ific.uv.es">rruiz@ific.uv.es</a><br>Michele Lucente - <a href="mailto:michele.lucente@unibo.it">michele.lucente@unibo.it</a></p>
# <p style="font-size:14px; line-height:1.55; margin-bottom:0;"><strong>Date</strong><br>September 2026</p></td>
# <td style="border:none;width:230px;padding-left:25px;text-align:right;vertical-align:top;"><img src="../../logo_uv.png" alt="Universitat de Valencia" style="width:200px; margin-top:5px;"></td>
# </tr></table></div>

# %% [markdown]
# # Atmosphere Analysis 2 — Differential Flux with Honda Tables
# ---
# **Description:** Uses the Honda/HKKM tables through the tpeanuts `external.honda` API to produce the height-differential atmospheric neutrino source flux $\Phi(E,h;\alpha) = \Phi(E;\alpha) \times f(h|E,\alpha)$ used as the upper boundary condition for atmosphere-neutrino propagation.
#
# **Physics:** Honda/HKKM integrated flux tables · production-height quantiles · height-differential source flux $\Phi(E,h)$
#
# ## Table of Contents
#
# | # | Section |
# |---|---|
# | [0](#0.-Theoretical-Framework) | **Theoretical Framework** |
# | [1](#1.-Libraries) | **Libraries** |
# | [2](#2.-Paths-and-Configuration) | **Paths and Configuration** |
# | [3](#3.-Single-Direction-Differential-Flux) | **Single-Direction Differential Flux** |
# | [4](#4.-Angular-Dependence) | **Angular Dependence** |
# | [5](#5.-Production-Height-Statistics) | **Production Height Statistics** |
# | [6](#6.-Particle-and-Flavour-Comparison) | **Particle and Flavour Comparison** |
# | [7](#7.-Solar-and-Mountain-Corrections) | **Solar and Mountain Corrections** |
# | [8](#8.-Flux-Normalization-Check) | **Flux Normalization Check** |
# | [9](#9.-Summary) | **Summary** |

# %% [markdown]
# | # | Section |
# |---|---------|
# | [0](#0.-Theory-Background) | **Theory Background**: 0.1 Honda/HKKM tables, 0.2 integrated flux $\Phi(E,\cos\alpha)$, 0.3 production-height quantiles, 0.4 differential flux $\Phi(E,h;\alpha)$, 0.5 PDF reconstruction |
# | [1](#1.-Libraries) | **Libraries**: imports and configuration |
# | [2](#2.-Honda-Table-Structure) | **Honda Table Structure**: 2.1 file catalogue, 2.2 table selection |
# | [3](#3.-Single-Direction-Differential-Flux) | **Single-Direction Differential Flux**: 3.1 integrated $\Phi(E;\alpha)$, 3.2 height PDF $f(h|E)$, 3.3 $\Phi(E,h)$ heatmap |
# | [4](#4.-Angular-Dependence) | **Angular Dependence**: 4.1 multi-angle grid, 4.2 angular profiles |
# | [5](#5.-Production-Height-Statistics) | **Production Height Statistics**: 5.1 median height, 5.2 height PDF heatmap |
# | [6](#6.-Particle-and-Flavour-Comparison) | **Particle Comparison**: 6.1 $\nu_e$ vs $\nu_\mu$ spectra, 6.2 $\nu/\bar\nu$ ratios |
# | [7](#7.-Solar-and-Mountain-Corrections) | **Solar and Mountain Corrections**: 7.1 solar min vs max, 7.2 mountain effect |
# | [8](#8.-Flux-Normalization-Check) | **Flux Normalization**: 8.1 integrate $f(h|E)\,\mathrm{d}h$ |
# | [9](#9.-Summary) | **Summary** |

# %% [markdown]
# ## 0. Theoretical Framework
#
# ---

# %% [markdown]
# ### 0.1 The Honda/HKKM Atmospheric Neutrino Flux Tables
#
# The **Honda/HKKM tables** (Honda, Kajita, Kasahara, Midorikawa) are the standard
# reference dataset for the atmospheric neutrino flux at underground detectors. They
# are computed with a full 3-D Monte Carlo simulation of cosmic-ray air showers,
# tracking the production and decay of pions, kaons, and muons through the atmosphere
# to predict the neutrino flux at the detector. Tables are published for a set of
# experimental sites (Frejus, Gran Sasso, Super-Kamiokande, INO, ORCA/ARCA, ...),
# with variants for season averaging (all-year, summer, winter), solar activity level
# (solar minimum / solar maximum), and the possible presence of a nearby mountain.
#
# The data files are plain-text tables compressed as ``.d.gz`` gzip archives. Two
# families of files are distributed per site:
#
# | File family | Filename pattern | Content |
# |-------------|-----------------|---------|
# | Flux tables | `frj-ally-20-01-solmin.d.gz` | $\Phi(E,\cos\alpha)$ per flavour |
# | Height tables | `frj-ally-aa-numu.d.gz` | Production-height quantiles per flavour |
#
#   ---
#
#   ### 0.2 Height-Integrated Flux $\Phi(E,\cos\alpha)$
#
#   Each **flux table** contains the differential neutrino flux at the detector,
#   integrated over all production heights and averaged over azimuth (in the
#   azimuth-averaged variant). The file is organised in blocks, one per
#   $\cos Z = \cos\alpha$ bin:
#
#   ```
#   average flux in [cosZ = 0.90 -- 1.00, phi_Az = 0.00 -- 360.00]
#   Enu(GeV)     NuMu      NuMubar    NuE       NuEbar
#   1.000E-01   1.054E+00  9.682E-01  5.424E-01  4.949E-01
#   1.259E-01   7.700E-01  7.087E-01  3.958E-01  3.622E-01
#   ...
#   ```
#
# - [3] **20 zenith bins** with centres $\cos\alpha = 0.95, 0.85, \ldots, -0.95$
#   ($\alpha = 0^\circ$ is straight down at the surface, $\alpha = 180^\circ$ straight up).
# - [4] **~50 energy rows** log-spaced from 0.1 GeV to $10^4$ GeV.
# - [5] **Four flavour columns:** $\nu_\mu$, $\bar\nu_\mu$, $\nu_e$, $\bar\nu_e$.
# - [6] **Units:** $(\mathrm{m}^2\,\mathrm{s}\,\mathrm{sr}\,\mathrm{GeV})^{-1}$
#   (tpeanuts converts to $\mathrm{cm}^{-2}$ by dividing by $10^4$).
#
#   The height-integrated flux is related to the height-differential flux by:
#
#   $$\Phi(E;\,\cos\alpha) \;=\; \int_0^{h_{\rm top}} \Phi(E,\,h;\,\alpha)\,\mathrm{d}h$$
#
#   where $h_{\rm top} \sim 120$ km is the top of the relevant atmosphere column.
#
#   ---
#
#   ### 0.3 Production-Height Quantile Tables
#
#   The **production-height tables** encode the statistical distribution of the
#   altitude $h$ at which the parent meson or muon decayed to produce the detected
#   neutrino. They are stored as **quantiles** of this distribution, not as
#   a continuous PDF.
#
#   For each $(E, \cos\alpha)$ bin, the file gives the altitudes
#   $h_{10\%},\, h_{20\%},\,\ldots,\, h_{90\%}$ (in metres) such that a fraction
#   $p$ of the neutrinos arriving with energy $E$ from direction $\cos\alpha$ were
#   produced below altitude $h_p$:
#
#   $$F(h_p\,|\,E,\cos\alpha) \;\equiv\; \Pr[h_{\rm prod} \le h_p] \;=\; p$$
#
#   Separate files are provided per neutrino flavour
#   ($\nu_\mu$, $\bar\nu_\mu$, $\nu_e$, $\bar\nu_e$).
#   A typical block header looks like:
#
#   ```
#   1  1  5  1   0.10  0.20  0.30  0.40  0.50  0.60  0.70  0.80  0.90
#   1.000E-01   8400.  10600.  12300.  13800.  15200.  16700.  18400.  20600.  24300.
#   ...
#   ```
#
#   where the header tokens are (site, flavour, zenith-bin, azimuth-bin, probabilities)
#   and each data row is $E_{\nu}$ [GeV] followed by the nine altitude quantiles [m].
#
#   ---
#
#   ### 0.4 Height-Differential Flux $\Phi(E, h;\, \alpha)$
#
#   The **height-differential flux** is the quantity that tpeanuts uses as the upper
#   boundary condition for atmospheric neutrino propagation. It represents the
#   neutrino source rate per unit altitude interval:
#
#   $$\boxed{\Phi(E,\,h;\,\alpha) \;=\; \Phi(E;\,\alpha) \;\times\; f(h\,|\,E,\,\alpha)}$$
#
#   where $f(h\,|\,E,\,\alpha)$ is the **production-height probability density**,
#   normalised so that
#
#   $$\int_0^{h_{\rm top}} f(h\,|\,E,\,\alpha)\,\mathrm{d}h \;=\; 1.$$
#
#   By construction, integrating $\Phi(E,h;\alpha)$ over $h$ recovers the original
#   Honda integrated flux $\Phi(E;\alpha)$.
#   The units of $\Phi(E,h;\alpha)$ are
#   $(\mathrm{cm}^2\,\mathrm{s}\,\mathrm{sr}\,\mathrm{GeV}\,\mathrm{km})^{-1}$.
#
#   ---
#
#   ### 0.5 Reconstruction of $f(h\,|\,E,\,\alpha)$ from Quantiles
#
#   Since the Honda tables provide $f$ only through its quantiles, tpeanuts
#   reconstructs the PDF from the quantile data via numerical differentiation of the
#   empirical CDF:
#
# - [7] **Build anchor points:** prepend $(h=0,\;F=0)$ and append $(h=h_{\rm top},\;F=1)$
#   to the Honda quantile pairs $\{(h_{10\%}, 0.10),\,(h_{20\%}, 0.20),\,\ldots\}$.
# - [8] **Interpolate the CDF** piecewise-linearly between nodes onto the output height
#   grid $\{h_k\}$ (default: 501 points from 0 to 120 km).
# - [9] **Differentiate numerically:** $f(h_k) = \mathrm{d}F/\mathrm{d}h\,|_{h_k}$
#   using central differences; clip negative values to zero.
# - [10] **Renormalise:** $f \leftarrow f\,/\,\int f\,\mathrm{d}h$
#   to enforce exact unit normalisation on the discrete grid.
#
#   This reconstruction recovers the integrated flux to better than $10^{-3}$
#   relative error for all $(E,\alpha)$ bins (see Section 8 for the numerical check).
#
#   ---
#
# **References**
#
# - [1] Honda, M., Kajita, T., Kasahara, K., Midorikawa, S., Sanuki, T. (2007). Calculation of atmospheric neutrino flux using the interaction model calibrated with atmospheric muon data. *Phys. Rev. D* **75**, 043006.
# - [2] Honda, M., Athar, M. A., Kajita, T., Kasahara, K., Midorikawa, S. (2015). Atmospheric neutrino flux calculation using the NRLMSISE-00 atmospheric model. *Phys. Rev. D* **92**, 023004. **Web:** [http://www.icrr.u-tokyo.ac.jp/~mhonda/](http://www.icrr.u-tokyo.ac.jp/~mhonda/).
# - [3] Honda, M., Kajita, T., Kasahara, K., Midorikawa, S. (2004). New calculation of the atmospheric neutrino flux in a three-dimensional scheme. *Phys. Rev. D* **70**, 043008.
# - [4] Honda, M., Athar, M. A., Kajita, T., Kasahara, K., Midorikawa, S. (2015). Atmospheric neutrino flux calculation using the NRLMSISE-00 atmospheric model. *Phys. Rev. D* **92**, 023004.

# %% [markdown]
# ## 1. Libraries
#
# Imports and notebook configuration.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path

from tpeanuts.notebooks.notebookConfig import load_notebook_config
from tpeanuts.notebooks.notebooks_helper import save_and_show
import tpeanuts.config.default as default
from tpeanuts.external.honda import (
    generate_flux_for_particle_angle,
    generate_flux_for_particles_angle_grid,
    HondaTableSelection,
    find_honda_data_dir,
    honda_cosz_centers,
)
from tpeanuts.external.honda.tables import (

    choose_flux_file,
    choose_height_file,
    classify_table_name,
)
from tpeanuts.util.math import numpy_trapezoid

# %%
config     = load_notebook_config()
OUTPUT_DIR = config.output_dir("analysis", "atmosphere",'honda_analysis')
HONDA_DIR = config.package_dir / default.honda_dataset
SHOW_PLOTS = config.show_plots
print(f"Honda directory  : {HONDA_DIR}")
print(f"Output directory : {OUTPUT_DIR}")
print(f"Device           : {config.device}")
# Out:
# Honda directory  : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\atmosphere\honda\raw
# Output directory : v:\output\analysis\atmosphere\honda_analysis
# Device           : cuda:0

# %% [markdown]
# ## 2. Paths and Configuration
#
# Honda/HKKM tables are plain-text (gzip-compressed) ``.d.gz`` files distributed per experimental site. Each filename encodes the site code, season, solar activity, angular binning mode, and (for height files) neutrino flavour. The tpeanuts function `find_honda_data_dir(path=HONDA_DIR)` locates the local copy of these files and `classify_table_name()` decodes each filename into its metadata.

# %% [markdown]
# ### 2.1 Paths
#
# Notebook-relative input and output locations are resolved here so that the analysis is reproducible from the repository root with no hidden execution-state dependencies.

# %% [markdown]
# ### 2.2 Configuration
#
# The first step is to locate the Honda data directory and inspect which table variants are available.

# %%
honda_dir = find_honda_data_dir(path=HONDA_DIR)
files = sorted(honda_dir.glob("*.d.gz"))
print(f"Honda data directory: {honda_dir}")
print(f"Found {len(files)} table files:")
print()
fmt = "  {:<48s}  {:<20s}  {}"
print(fmt.format("Filename", "Table type", "Angular mode / flavour"))
print("  " + "-" * 90)
MAX_FILES = 20
for ix, f in enumerate(files):
    if MAX_FILES is not None:
        if ix > MAX_FILES:
            print(f'\n\t... only the {MAX_FILES} first files are listed')
            break
    meta = classify_table_name(f.name)
    ttype = meta.get("table_type", "?")
    detail = meta.get("angular_mode", meta.get("flavour", ""))
    solar  = meta.get("solar", "")
    mtn    = " [mtn]" if meta.get("mountain") else ""
    suffix = f"{solar}{mtn}" if solar else ""
    print(fmt.format(f.name, ttype, f"{detail}  {suffix}".strip()))
# Out:
# Honda data directory: G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\atmosphere\honda\raw
# Found 588 table files:
#
#   Filename                                          Table type            Angular mode / flavour
#   ------------------------------------------------------------------------------------------
#   frj-0305-01-01-solmax.d.gz                        flux                  all-direction-averaged  solmax
#   frj-0305-01-01-solmin.d.gz                        flux                  all-direction-averaged  solmin
#   frj-0305-20-01-mtn-solmax.d.gz                    flux                  azimuth-averaged  solmax [mtn]
#   frj-0305-20-01-mtn-solmin.d.gz                    flux                  azimuth-averaged  solmin [mtn]
#   frj-0305-20-01-solmax.d.gz                        flux                  azimuth-averaged  solmax
#   frj-0305-20-01-solmin.d.gz                        flux                  azimuth-averaged  solmin
#   frj-0305-20-12-mtn-solmax.d.gz                    flux                  zenith+azimuth  solmax [mtn]
#   frj-0305-20-12-mtn-solmin.d.gz                    flux                  zenith+azimuth  solmin [mtn]
#   frj-0305-20-12-solmax.d.gz                        flux                  zenith+azimuth  solmax
#   frj-0305-20-12-solmin.d.gz                        flux                  zenith+azimuth  solmin
#   frj-0608-01-01-solmax.d.gz                        flux                  all-direction-averaged  solmax
#   frj-0608-01-01-solmin.d.gz                        flux                  all-direction-averaged  solmin
#   frj-0608-20-01-mtn-solmax.d.gz                    flux                  azimuth-averaged  solmax [mtn]
#   frj-0608-20-01-mtn-solmin.d.gz                    flux                  azimuth-averaged  solmin [mtn]
#   frj-0608-20-01-solmax.d.gz                        flux                  azimuth-averaged  solmax
#   frj-0608-20-01-solmin.d.gz                        flux                  azimuth-averaged  solmin
#   frj-0608-20-12-mtn-solmax.d.gz                    flux                  zenith+azimuth  solmax [mtn]
#   frj-0608-20-12-mtn-solmin.d.gz                    flux                  zenith+azimuth  solmin [mtn]
#   frj-0608-20-12-solmax.d.gz                        flux                  zenith+azimuth  solmax
#   frj-0608-20-12-solmin.d.gz                        flux                  zenith+azimuth  solmin
#   frj-0608-aa-nue.d.gz                              production_height     nue
#
# 	... only the 20 first files are listed

# %% [markdown]
# **Configuration**
#
# `HondaTableSelection` is a frozen dataclass that selects one table variant by site, season, solar activity, mountain flag, and angular mode. The defaults match the Frejus (FNAL/Daya Bay equivalent) all-year azimuth-averaged solar-minimum flux.
#
# | Parameter | Meaning | Example values |
# |-----------|---------|---------------|
# | `site_code` | Honda site identifier, matching the first token in the table filename | `"frj"` (Frejus), `"grn"` (Gran Sasso), `"kam"` (Kamioka/Super-K) |
# | `season_code` | Season-averaging token | `"ally"` (all-year), `"summ"`, `"wint"` |
# | `solar` | Solar modulation level | `"solmin"`, `"solmax"` |
# | `mountain` | Include nearby mountain shadow | `True` / `False` |
# | `angular_mode` | Zenith/azimuth binning | `"azimuth-averaged"`, `"zenith+azimuth"` |
#
# Available `site_code` values depend on the local Honda `.d.gz` catalogue. In the dataset used here, the recognised first filename tokens are:
#
# | `site_code` | Site |
# |-------------|------|
# | `"frj"` | Frejus / FNAL-Daya Bay equivalent site |
# | `"grn"` | Gran Sasso |
# | `"hms"` | Homestake |
# | `"ino"` | INO |
# | `"juno"` | JUNO |
# | `"kam"` | Kamioka / Super-Kamiokande |
# | `"pyh"` | Pyhasalmi |
# | `"sno"` | Sudbury / SNO |
# | `"spl"` | South Pole |
#
# `tpeanuts` does not hard-code this list in `HondaTableSelection`; it selects files by matching `site_code` against the first token of the available Honda table filenames.
#
# The `solar` parameter selects the solar-modulation assumption used in the Honda primary cosmic-ray calculation. The available values are:
#
# | `solar` | Meaning | Filename token |
# |---------|---------|----------------|
# | `"solmin"` | Solar minimum: weaker heliospheric modulation and therefore a larger low-energy primary cosmic-ray flux | `solmin` |
# | `"solmax"` | Solar maximum: stronger modulation and therefore a suppressed low-energy primary cosmic-ray flux | `solmax` |
#
# The solar choice mostly affects the sub-GeV to few-GeV atmospheric neutrino flux. At higher energies the difference becomes progressively smaller.
#
# **Expected results:**
# - The selected flux file and per-flavour height files are listed.

# %%
sel = HondaTableSelection(
    site_code    = "frj",
    season_code  = "ally",
    solar        = "solmin",
    mountain     = False,
    angular_mode = "azimuth-averaged",
)

flux_file = choose_flux_file(honda_dir, sel)
print(f"Selected flux file : {flux_file.name}")
print(f"Selection          : {sel}")
print()
print("Height files by particle:")
for particle in ["nue", "antinue", "numu", "antinumu"]:
    hf = choose_height_file(honda_dir, sel, particle)
    print(f"  {particle:10s}: {hf.name if hf else 'not found'}")
# Out:
# Selected flux file : frj-ally-20-01-solmin.d.gz
# Selection          : HondaTableSelection(site_code='frj', season_code='ally', solar='solmin', mountain=False, angular_mode='azimuth-averaged', azimuth_averaged_height=True)
#
# Height files by particle:
#   nue       : frj-ally-aa-nue.d.gz
#   antinue   : frj-ally-aa-nuebar.d.gz
#   numu      : frj-ally-aa-numu.d.gz
#   antinumu  : frj-ally-aa-numubar.d.gz

# %% [markdown]
# ### 2.3 Local Helpers
#
# Notebook-local functions encapsulate repeated transformations used by the analysis. They are defined here, after paths and configuration, so the computational sections contain only the physical evaluation workflow.

# %%
def nearest_result(results_dict, alpha):
    """Look up a generate_flux_for_particles_angle_grid result by nearest angle key.

    The 'results' dict is keyed by the *resolved detector theta_deg*, not the
    input surface alpha_deg: at detector_depth_m=0 the two agree numerically but
    not bit-exactly (floating-point round-off through the surface<->detector
    trig conversion), so an exact-float lookup can raise a spurious KeyError.
    """
    keys = list(results_dict.keys())
    nearest_key = min(keys, key=lambda k: abs(k - alpha))
    return results_dict[nearest_key]


def median_height(f_Eh_arr, h_km_arr):
    cdf    = np.cumsum(f_Eh_arr * np.gradient(h_km_arr), axis=1)
    cdf   /= cdf[:, -1:].clip(1e-30)
    h_med  = np.array([np.interp(0.5, cdf[ie], h_km_arr) for ie in range(cdf.shape[0])])
    return h_med

# %% [markdown]
# ## 3. Single-Direction Differential Flux
#
# `generate_flux_for_particle_angle()` produces the full height-differential source flux for one particle at one zenith angle. It:
# 1. Interpolates the Honda integrated flux $\Phi(E; X_{\rm obs})$ onto the requested energy grid (log-linear in $E$, linear in Honda $\cos Z = \cos\alpha$).
# 2. Reconstructs the production-height PDF $f(h|E,\alpha)$ from the Honda quantile tables as $d{\rm CDF}/dh$, normalized so $\int f(h|E,\alpha)\,dh = 1$.
# 3. Returns the product $\Phi(E,h) = \Phi(E; X_{\rm obs}) \times f(h|E,\alpha)$.

# %%
ALPHA_DEG = 30.0     # surface/Honda zenith angle in degrees (0 = straight down, 90 = horizontal)
PARTICLE  = "numu"   # Honda-supported particles: nue, antinue, numu, antinumu

result = generate_flux_for_particle_angle(
    PARTICLE,
    alpha_deg = ALPHA_DEG,
    selection = sel,
    honda_data_dir = HONDA_DIR,
    save      = False,
)

E_GeV  = result["E_grid_GeV"].cpu().numpy()   # (nE,)  energy grid in GeV
h_km   = result["h_grid_km"].cpu().numpy()    # (nh,)  height grid in km
phi_E  = result["phi_E_obs"].cpu().numpy()    # (nE,)  height-integrated flux  [cm^-2 s^-1 sr^-1 GeV^-1]
f_Eh   = result["f_Eh"].cpu().numpy()         # (nE, nh)  height density  [km^-1]
phi_Eh = result["phi_Eh"].cpu().numpy()       # (nE, nh)  Phi(E,h)  [cm^-2 s^-1 sr^-1 GeV^-1 km^-1]

print(f"Energy grid : {E_GeV.size} points, {E_GeV[0]:.3f} -- {E_GeV[-1]:.0f} GeV")
print(f"Height grid : {h_km.size} points, {h_km[0]:.0f} -- {h_km[-1]:.0f} km")
print(f"phi_E shape : {phi_E.shape}")
print(f"f_Eh  shape : {f_Eh.shape}")
print(f"phi_Eh shape: {phi_Eh.shape}")
# Out:
# Energy grid : 101 points, 0.100 -- 10000 GeV
# Height grid : 501 points, 0 -- 120 km
# phi_E shape : (101,)
# f_Eh  shape : (101, 501)
# phi_Eh shape: (101, 501)

# %% [markdown]
# ### 3.1 Height-Integrated Energy Spectrum $\Phi(E; \alpha)$
#
# $\Phi(E; \alpha)$ is the total (height-integrated) flux at the detector for a fixed zenith direction $\theta$. It is the quantity published directly in Honda tables.
#
# **Expected results:**
# - A steeply falling spectrum from $\sim 10$ GeV (cm² s sr GeV)⁻¹ at 0.1 GeV to $\sim 10^{-9}$ at 100 GeV. The $E^2$-weighted version reveals the spectral shape more clearly.

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

# Left: absolute flux
ax = axes[0]
ax.loglog(E_GeV, phi_E, color="#4c72b0", lw=2,
          label=rf"$\nu_\mu$, $\alpha={ALPHA_DEG:.0f}°$")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$\Phi(E; \alpha)$ [(cm² s sr GeV)⁻¹]")
ax.set_title("Height-integrated flux", fontsize=10)
ax.legend()
ax.grid(True, which="both", alpha=0.3)

# Right: E^2-weighted flux
ax = axes[1]
ax.loglog(E_GeV, phi_E * E_GeV**2, color="#4c72b0", lw=2,
          label=rf"$\nu_\mu$, $\alpha={ALPHA_DEG:.0f}°$")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$E_\nu^2\,\Phi(E; \alpha)$ [(cm² s sr GeV)⁻¹ GeV²]")
ax.set_title(r"$E^2$-weighted flux", fontsize=10)
ax.legend()
ax.grid(True, which="both", alpha=0.3)

fig.suptitle(
    rf"Honda/HKKM $\nu_\mu$ flux — Frejus, all-year, sol.min, $\alpha={ALPHA_DEG:.0f}°$",
    fontsize=10,
)
fig.tight_layout()
save_and_show("atm2_fig21_phi_E.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig21_phi_E.png

# %% [markdown]
# ### 3.2 Production Height PDF $f(h|E, \theta)$
#
# The production-height PDF $f(h|E,\alpha)$ encodes where in the atmosphere the parent mesons and muons decayed to produce the observed neutrinos. It is reconstructed from the Honda quantile data (10%, 20%, ..., 90% height quantiles) as the numerical derivative of the piecewise-linear CDF.
#
# - At **low energy** ($E_\nu \lesssim 0.3$ GeV) pion decays dominate: production is spread over a wide height range, typically peaking around 15–25 km.
# - At **high energy** ($E_\nu \gtrsim 3$ GeV) muon decays become important and the distribution shifts to lower altitudes (10–20 km) and narrows.
#
# **Expected results:**
# - Broad peaks at 10–25 km shifting downward with increasing energy.

# %%
E_show  = [0.1, 0.3, 1.0, 3.0, 10.0, 30.0]   # GeV
colors  = plt.cm.plasma(np.linspace(0.15, 0.85, len(E_show)))

fig, ax = plt.subplots(figsize=(8.5, 4.5))
for e_tgt, col in zip(E_show, colors):
    ie = np.argmin(np.abs(E_GeV - e_tgt))
    ax.plot(h_km, f_Eh[ie], color=col, lw=1.8, label=f"{E_GeV[ie]:.2g} GeV")

ax.set_xlabel("Production height $h$ [km]")
ax.set_ylabel(r"$f(h|E,\alpha)$ [km$^{-1}$]")
ax.set_title(
    rf"Production height PDF $f(h|E)$ for $\nu_\mu$ at $\alpha={ALPHA_DEG:.0f}°$",
    fontsize=10,
)
ax.set_xlim(0, 60)
ax.legend(title=r"$E_\nu$", ncol=2, fontsize=8)
ax.grid(True, alpha=0.3)
fig.tight_layout()
save_and_show("atm2_fig22_fEh.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig22_fEh.png

# %% [markdown]
# ### 3.3 Height-Differential Flux $\Phi(E, h)$
#
# The height-differential source flux $\Phi(E,h) = \Phi(E; X_{\rm obs}) \times f(h|E,\alpha)$ is the quantity that tpeanuts uses as the upper boundary condition for the neutrino transport equation. Its shape $(n_E, n_h)$ gives the neutrino source as a function of both energy and production altitude.
#
# **Expected results:**
# - A 2D field concentrated between 10–30 km at low energies and shifting toward lower altitudes with energy, with overall magnitude following the steeply falling Honda energy spectrum.

# %%
# log10 of phi_Eh for visualization; mask zeros
with np.errstate(divide="ignore"):
    log_phi = np.where(phi_Eh > 0, np.log10(phi_Eh), np.nan)

fig, ax = plt.subplots(figsize=(9.5, 5.0))
E_mesh  = np.concatenate([[E_GeV[0] * 0.9], 0.5 * (E_GeV[:-1] + E_GeV[1:]),
                           [E_GeV[-1] * 1.1]])
h_mesh  = np.concatenate([[0.0], 0.5 * (h_km[:-1] + h_km[1:]),
                           [h_km[-1] + (h_km[-1] - h_km[-2])]])
im = ax.pcolormesh(E_mesh, h_mesh, log_phi.T, cmap="plasma",
                   shading="flat", vmin=-22, vmax=-8)
ax.set_xscale("log")
ax.set_xlim(E_GeV[0], E_GeV[-1])
ax.set_ylim(0, 80)
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel("Production height $h$ [km]")
ax.set_title(
    rf"$\log_{{10}}\,\Phi(E,h)$ — $\nu_\mu$, $\alpha={ALPHA_DEG:.0f}°$"
    r"  [(cm² s sr GeV)⁻¹ km⁻¹]",
    fontsize=9,
)
plt.colorbar(im, ax=ax, label=r"$\log_{{10}}\,\Phi(E,h)$", pad=0.01)
fig.tight_layout()
save_and_show("atm2_fig23_phi_Eh.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig23_phi_Eh.png

# %% [markdown]
# ## 4. Angular Dependence
#
# The Honda tables cover 20 surface-zenith bins in $\cos Z = \cos\alpha \in [-0.95, 0.95]$ with step 0.10. The height-differential flux varies substantially with zenith angle because:
# - **Downward-going** ($\cos\alpha \approx 1$, $\alpha \approx 0°$): short path length through the atmosphere, higher production heights, lower flux at multi-GeV energies.
# - **Horizontal** ($\alpha \approx 90°$, $\cos\alpha \approx 0$): long atmospheric path, broad height distribution, enhanced multi-GeV flux from pion decay.
#
# The standard Honda 20-bin cosθ grid is returned by `honda_cosz_centers()`.

# %% [markdown]
# ### 4.1 Generate Multi-Angle Grid
#
# `generate_flux_for_particles_angle_grid()` builds the flux over a grid of angles and particle types in one call, sharing the loaded Honda tables internally for efficiency.

# %%
cosz_centers = honda_cosz_centers()  # 20 standard Honda bins: 0.95 down to -0.95
print(f"Honda 20-bin cosZ centers: {cosz_centers}")

# ALPHA_GRID = np.array([0., 15., 30., 45., 60., 75., 85.])   # surface/Honda zenith angles
ALPHA_GRID = np.linspace(0., 85., 18)   # surface/Honda zenith angles in degrees
PARTICLES  = ["numu", "nue", "antinumu", "antinue"]

grid = generate_flux_for_particles_angle_grid(
    honda_data_dir = HONDA_DIR,
    particles      = PARTICLES,
    alpha_grid_deg = ALPHA_GRID,
    selection      = sel,
    save           = False,
)

print(f"Generated flux for {len(PARTICLES)} particles x {len(ALPHA_GRID)} angles.")
for flav, gdata in grid.items():
    alpha_keys = sorted(gdata["results"].keys())
    print(f"  {flav:10s}: alpha = {[f'{a:.0f}' for a in alpha_keys]}")
# Out:
# Honda 20-bin cosZ centers: [ 0.95  0.85  0.75  0.65  0.55  0.45  0.35  0.25  0.15  0.05 -0.05 -0.15 -0.25 -0.35 -0.45 -0.55 -0.65 -0.75 -0.85 -0.95]
# Generated flux for 4 particles x 18 angles.
#   numu      : alpha = ['0', '5', '10', '15', '20', '25', '30', '35', '40', '45', '50', '55', '60', '65', '70', '75', '80', '85']
#   nue       : alpha = ['0', '5', '10', '15', '20', '25', '30', '35', '40', '45', '50', '55', '60', '65', '70', '75', '80', '85']
#   antinumu  : alpha = ['0', '5', '10', '15', '20', '25', '30', '35', '40', '45', '50', '55', '60', '65', '70', '75', '80', '85']
#   antinue   : alpha = ['0', '5', '10', '15', '20', '25', '30', '35', '40', '45', '50', '55', '60', '65', '70', '75', '80', '85']

# %% [markdown]
# ### 4.2 Angular Profile of $\Phi(E; \alpha)$
#
# The height-integrated $\nu_\mu$ flux as a function of energy for several zenith angles, and the angular profile at a fixed reference energy.
#
# **Expected results:**
# - The horizontal direction ($\alpha = 85°$) is enhanced by a factor $\sim 2\text{–}3$ relative to the vertical ($\alpha = 0°$) at energies above $\sim 1$ GeV.

# %%
E_ref  = 1.0   # GeV reference energy for the angular plot
colors_alpha = plt.cm.coolwarm(np.linspace(0.1, 0.9, len(ALPHA_GRID)))

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

# Left: energy spectra at different alpha
ax = axes[0]
for alpha, col in zip(ALPHA_GRID, colors_alpha):
    r   = nearest_result(grid["numu"]["results"], float(alpha))
    E   = r["E_grid_GeV"].cpu().numpy()
    phi = r["phi_E_obs"].cpu().numpy()
    ax.loglog(E, phi * E**2, color=col, lw=1.6, label=rf"$\alpha={alpha:.0f}°$")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$E^2 \Phi$ [(cm² s sr GeV)⁻¹ GeV²]")
ax.set_title(r"$E^2\Phi$ vs $E$ — $\nu_\mu$ at several $\alpha$", fontsize=10)
ax.legend(fontsize=7, ncol=2)
ax.grid(True, which="both", alpha=0.3)

# Right: angular profile at E_ref
ax = axes[1]
phi_at_E = []
for alpha in ALPHA_GRID:
    r    = nearest_result(grid["numu"]["results"], float(alpha))
    E    = r["E_grid_GeV"].cpu().numpy()
    phi  = r["phi_E_obs"].cpu().numpy()
    ie   = np.argmin(np.abs(E - E_ref))
    phi_at_E.append(phi[ie])

cos_alpha_grid = np.cos(np.deg2rad(ALPHA_GRID))
ax.plot(cos_alpha_grid, phi_at_E, "o-", color="#4c72b0", lw=1.8, ms=6)
ax.set_xlabel(r"$\cos\alpha$")
ax.set_ylabel(r"$\Phi(E_{\rm ref}; \alpha)$ [(cm² s sr GeV)⁻¹]")
ax.set_title(rf"Angular profile at $E_\nu = {E_ref}$ GeV — $\nu_\mu$", fontsize=10)
ax.grid(True, alpha=0.3)

fig.tight_layout()
save_and_show("atm2_fig32_angular.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig32_angular.png

# %% [markdown]
# ## 5. Production Height Statistics
#
# Summarising $f(h|E,\alpha)$ through its median and interquartile range gives compact information about how the production-height distribution shifts with energy and angle.

# %% [markdown]
# ### 5.1 Median Production Height vs Energy
#
# The median height $\tilde h(E, \alpha)$ is where the CDF of $f(h|E,\alpha)$ equals 0.5. A higher median means neutrinos are produced higher in the atmosphere (lower atmospheric density, fewer hadronic interactions).

# %%
colors_alpha = plt.cm.coolwarm(np.linspace(0.1, 0.9, len(ALPHA_GRID)))

fig, ax = plt.subplots(figsize=(8.5, 4.5))
for alpha, col in zip(ALPHA_GRID, colors_alpha):
    r      = nearest_result(grid["numu"]["results"], float(alpha))
    E      = r["E_grid_GeV"].cpu().numpy()
    f      = r["f_Eh"].cpu().numpy()
    h      = r["h_grid_km"].cpu().numpy()
    h_med  = median_height(f, h)
    ax.semilogx(E, h_med, color=col, lw=1.6, label=rf"$\alpha={alpha:.0f}°$")

ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel("Median production height [km]")
ax.set_title(r"Median $\tilde h(E,\alpha)$ — $\nu_\mu$, Frejus, sol.min", fontsize=10)
ax.legend(fontsize=7, ncol=2)
ax.grid(True, which="both", alpha=0.3)
fig.tight_layout()
save_and_show("atm2_fig41_median_h.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig41_median_h.png

# %% [markdown]
# ### 5.2 Height PDF Heatmap vs Zenith Angle
#
# A 2D heatmap of $f(h|E_0, \alpha)$ as a function of surface angle $\alpha$ and $h$ at a fixed reference energy $E_0$ reveals how the production-height distribution broadens toward horizontal directions.
#
# **Expected results**:
#  - The height of the maximum does not have to be independent of the zenith angle.
#  -  What may be more directly comparable between different angles is the shower development in terms of atmospheric depth or slant depth.
#  -  When the zenith angle changes, the path length through the atmosphere changes, as do the decay/interact probability and the effective relation between distance along the trajectory and vertical altitude.

# %%
E0 = 1.0   # GeV

f_alpha_h = []
for alpha in ALPHA_GRID:
    r  = nearest_result(grid["numu"]["results"], float(alpha))
    E  = r["E_grid_GeV"].cpu().numpy()
    f  = r["f_Eh"].cpu().numpy()
    h  = r["h_grid_km"].cpu().numpy()
    ie = np.argmin(np.abs(E - E0))
    f_alpha_h.append(f[ie])

F = np.array(f_alpha_h)   # (n_alpha, n_h)

fig, ax = plt.subplots(figsize=(9, 4))
im = ax.pcolormesh(h, ALPHA_GRID, F, cmap="YlOrRd", shading="auto")
ax.set_xlabel("Production height $h$ [km]")
ax.set_ylabel(r"Surface zenith angle $\alpha$ [deg]")
ax.set_title(
    rf"$f(h|E={E0}\,{{\rm GeV}},\,\alpha)$ — $\nu_\mu$, Frejus, sol.min"
    r" [km$^{-1}$]",
    fontsize=9,
)
ax.set_xlim(0, 80)
plt.colorbar(im, ax=ax, label=r"$f$ [km$^{-1}$]", pad=0.01)
fig.tight_layout()
save_and_show("atm2_fig42_fEh_theta.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig42_fEh_theta.png

# %% [markdown]
# ## 6. Particle and Flavour Comparison
#
# At energies below a few GeV, the atmospheric neutrino flux has a well-known composition dominated by $\nu_\mu$ and $\bar\nu_\mu$ from charged pion and muon decays. The sub-GeV electron neutrinos receive an extra contribution from 3-body kaon decays. Above a few GeV the ratio $\nu_\mu / \nu_e \to 2$ as the muons from pion decays decay before reaching the ground.

# %% [markdown]
# ### 6.1 $\nu_e$ vs $\nu_\mu$ Spectra
#
# **Expected results:**
# - $\Phi(\nu_\mu)$ exceeds $\Phi(\nu_e)$ by a factor $\sim 2$ above 1 GeV.
# - Below $\sim 0.3$ GeV the ratio $\Phi(\nu_\mu)/\Phi(\nu_e)$ drops toward 1 because the muons stop before decaying.

# %%
ALPHA0 = 30.0   # surface zenith angle in degrees
styles = {
    "numu":    dict(color="#4c72b0", lw=2.0, label=r"$\nu_\mu$"),
    "nue":     dict(color="#dd8452", lw=2.0, label=r"$\nu_e$"),
    "antinumu":dict(color="#4c72b0", lw=1.5, ls="--", label=r"$\bar\nu_\mu$"),
    "antinue": dict(color="#dd8452", lw=1.5, ls="--", label=r"$\bar\nu_e$"),
}

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

# Left: all four flavours
ax = axes[0]
for flav, style in styles.items():
    r   = nearest_result(grid[flav]["results"], ALPHA0)
    E   = r["E_grid_GeV"].cpu().numpy()
    phi = r["phi_E_obs"].cpu().numpy()
    ax.loglog(E, phi * E**2, **style)
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$E^2\,\Phi$ [(cm² s sr GeV)⁻¹ GeV²]")
ax.set_title(rf"Atmospheric flux by flavour, $\alpha={ALPHA0:.0f}°$", fontsize=10)
ax.legend(fontsize=9)
ax.grid(True, which="both", alpha=0.3)

# Right: nu_mu / nu_e ratio
ax = axes[1]
r_mu = nearest_result(grid["numu"]["results"], ALPHA0)
r_e  = nearest_result(grid["nue"]["results"], ALPHA0)
E_mu = r_mu["E_grid_GeV"].cpu().numpy()
phi_mu = r_mu["phi_E_obs"].cpu().numpy()
phi_e  = np.interp(E_mu, r_e["E_grid_GeV"].cpu().numpy(), r_e["phi_E_obs"].cpu().numpy())
ratio  = np.where(phi_e > 0, phi_mu / phi_e, np.nan)
ax.loglog(E_mu, ratio, color="#4c72b0", lw=2, label=r"$\nu_\mu / \nu_e$")
ax.axhline(2.0, color="k", lw=0.9, ls="--", label="ratio = 2")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$\Phi(\nu_\mu) / \Phi(\nu_e)$")
ax.set_title(rf"Flavour ratio, $\alpha={ALPHA0:.0f}°$", fontsize=10)
ax.legend()
ax.grid(True, which="both", alpha=0.3)
ax.set_ylim(1e0, 1e2)

fig.tight_layout()
save_and_show("atm2_fig51_flavour.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig51_flavour.png

# %% [markdown]
# ### 6.2 $\nu / \bar\nu$ Ratios
#
# The ratio $\Phi(\nu_\mu) / \Phi(\bar\nu_\mu)$ is driven by the excess of positive pions over negative pions in cosmic-ray proton-dominated showers (the proton excess model). Above a few GeV it stabilises around $\sim 1.1\text{–}1.3$.
#
# **Expected results:**
# - $\nu / \bar\nu > 1$ for both $\mu$ and $e$ flavours; weakly energy-dependent above 1 GeV.

# %%
fig, ax = plt.subplots(figsize=(7.5, 4.5))

for (flav, aflav, label, col) in [
    ("numu",  "antinumu", r"$\nu_\mu / \bar\nu_\mu$", "#4c72b0"),
    ("nue",   "antinue",  r"$\nu_e / \bar\nu_e$",        "#dd8452"),
]:
    r_nu   = nearest_result(grid[flav]["results"], ALPHA0)
    r_anu  = nearest_result(grid[aflav]["results"], ALPHA0)
    E      = r_nu["E_grid_GeV"].cpu().numpy()
    phi_nu = r_nu["phi_E_obs"].cpu().numpy()
    phi_an = np.interp(E, r_anu["E_grid_GeV"].cpu().numpy(), r_anu["phi_E_obs"].cpu().numpy())
    ratio  = np.where(phi_an > 0, phi_nu / phi_an, np.nan)
    ax.semilogx(E, ratio, color=col, lw=2, label=label)

ax.axhline(1.0, color="k", lw=0.8, ls=":")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$\nu / \bar\nu$ flux ratio")
ax.set_title(rf"Neutrino/antineutrino ratio, $\alpha={ALPHA0:.0f}°$, Frejus sol.min", fontsize=10)
ax.legend()
ax.grid(True, which="both", alpha=0.3)
ax.set_ylim(0.8, 2.5)
fig.tight_layout()
save_and_show("atm2_fig52_nu_ratio.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig52_nu_ratio.png

# %% [markdown]
# ## 7. Solar and Mountain Corrections
#
# Honda provides two solar-activity variants (solar minimum and solar maximum) and a mountain-corrected table for sites with a significant nearby mountain that shadows part of the solid angle.
#
# - **Solar modulation**: the lower-energy primary cosmic-ray flux ($E_p \lesssim 10$ GeV) is suppressed during solar maximum by the heliospheric magnetic field. This reduces the sub-GeV atmospheric neutrino flux by up to $\sim 10\%$.
# - **Mountain effect**: a nearby mountain blocks downward-going cosmic rays in certain azimuth/zenith ranges, reducing the neutrino flux in the corresponding solid-angle region. Relevant for Frejus (Grandes Jorasses ridge) and Gran Sasso.

# %% [markdown]
# ### 7.1 Solar Min vs Solar Max
#
# **Expected results:**
# - Solar-maximum flux is lower than solar-minimum by up to $\sim 10\%$ at 0.1–0.3 GeV, with negligible difference above $\sim 5$ GeV.

# %%
ALPHA0 = 30.0   # reference surface zenith angle in degrees

sel_max = HondaTableSelection(
    site_code    = "frj",
    season_code  = "ally",
    solar        = "solmax",
    mountain     = False,
    angular_mode = "azimuth-averaged",
)

r_min = generate_flux_for_particle_angle("numu", alpha_deg=ALPHA0, selection=sel,     save=False, honda_data_dir = HONDA_DIR,)
r_max = generate_flux_for_particle_angle("numu", alpha_deg=ALPHA0, selection=sel_max, save=False, honda_data_dir = HONDA_DIR,)

E_min   = r_min["E_grid_GeV"].cpu().numpy()
phi_min = r_min["phi_E_obs"].cpu().numpy()
phi_max = np.interp(E_min, r_max["E_grid_GeV"].cpu().numpy(), r_max["phi_E_obs"].cpu().numpy())
ratio   = np.where(phi_min > 0, phi_max / phi_min, np.nan)

fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

ax = axes[0]
ax.loglog(E_min, phi_min * E_min**2, color="#4c72b0", lw=2, label="solar min")
ax.loglog(E_min, phi_max * E_min**2, color="#dd8452", lw=2, ls="--", label="solar max")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$E^2\,\Phi$ [(cm² s sr GeV)⁻¹ GeV²]")
ax.set_title(r"$E^2\Phi$ solar min vs max — $\nu_\mu$", fontsize=10)
ax.legend()
ax.grid(True, which="both", alpha=0.3)

ax = axes[1]
ax.semilogx(E_min, ratio, color="#4c72b0", lw=2)
ax.axhline(1.0, color="k", lw=0.8, ls=":")
ax.set_xlabel(r"$E_\nu$ [GeV]")
ax.set_ylabel(r"$\Phi_{\rm solmax} / \Phi_{\rm solmin}$")
ax.set_title(r"Solar modulation ratio — $\nu_\mu$", fontsize=10)
ax.grid(True, which="both", alpha=0.3)

fig.suptitle(rf"Frejus, all-year, $\alpha={ALPHA0:.0f}°$", fontsize=10)
fig.tight_layout()
save_and_show("atm2_fig61_solar.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig61_solar.png

# %% [markdown]
# ### 7.2 Mountain Correction
#
# For sites with a nearby mountain (e.g. Frejus, with the Grandes Jorasses ridge), a fraction of the downward-going sky is shielded. This reduces the neutrino flux in the affected solid-angle sector. The azimuth-averaged tables fold this correction over all azimuth bins.
#
# **Expected results:**
# - The mountain correction is $\lesssim 5\%$ for the azimuth-averaged flux at Frejus.
# - It is most visible at large surface zenith angles ($\alpha \sim 60\text{–}80°$) where the mountain covers a larger fraction of the solid angle.

# %%
try:
    sel_mtn = HondaTableSelection(
        site_code    = "frj",
        season_code  = "ally",
        solar        = "solmin",
        mountain     = True,
        angular_mode = "azimuth-averaged",
    )
    _ = choose_flux_file(honda_dir, sel_mtn)   # will raise if not found
    has_mountain = True
except FileNotFoundError:
    has_mountain = False
    print("Mountain-corrected table not found for this site; skipping comparison.")

if has_mountain:
    alpha_vals_mtn = np.array([0., 30., 60., 80.])
    phi_nomt  = {}
    phi_mt    = {}
    for alpha in alpha_vals_mtn:
        r0 = generate_flux_for_particle_angle("numu", alpha_deg=alpha, selection=sel,     save=False, honda_data_dir = HONDA_DIR,)
        rm = generate_flux_for_particle_angle("numu", alpha_deg=alpha, selection=sel_mtn, save=False, honda_data_dir = HONDA_DIR,)
        E  = r0["E_grid_GeV"].cpu().numpy()
        phi_nomt[alpha] = r0["phi_E_obs"].cpu().numpy()
        phi_mt[alpha]   = np.interp(E, rm["E_grid_GeV"].cpu().numpy(), rm["phi_E_obs"].cpu().numpy())

    fig, ax = plt.subplots(figsize=(8.5, 4.5))
    colors_mtn = plt.cm.coolwarm(np.linspace(0.1, 0.9, len(alpha_vals_mtn)))
    for alpha, col in zip(alpha_vals_mtn, colors_mtn):
        ratio = np.where(phi_nomt[alpha] > 0, phi_mt[alpha] / phi_nomt[alpha], np.nan)
        ax.semilogx(E, ratio, color=col, lw=1.8, label=rf"$\alpha={alpha:.0f}°$")
    ax.axhline(1.0, color="k", lw=0.8, ls=":")
    ax.set_xlabel(r"$E_\nu$ [GeV]")
    ax.set_ylabel(r"$\Phi_{\rm mtn} / \Phi_{\rm no-mtn}$")
    ax.set_title(r"Mountain correction ratio — $\nu_\mu$, Frejus", fontsize=10)
    ax.legend(fontsize=8)
    ax.grid(True, which="both", alpha=0.3)
    fig.tight_layout()
    save_and_show("atm2_fig62_mountain.png", fig, output_dir=OUTPUT_DIR, show_plots=SHOW_PLOTS)
# Out:
# v:\output\analysis\atmosphere\honda_analysis\atm2_fig62_mountain.png

# %% [markdown]
# ## 8. Flux Normalization Check
#
# The height density $f(h|E,\alpha)$ is normalized so that $\int_0^\infty f(h|E,\alpha)\,dh = 1$ for each $(E, \alpha)$ bin. Integrating the height-differential flux $\Phi(E,h)$ over $h$ must recover the original Honda integrated flux $\Phi(E; X_{\rm obs})$:
#
# $$\Phi(E; X_{\rm obs}) = \int_0^{h_{\rm max}} \Phi(E,h)\,dh$$
#
# This serves as a basic consistency check of the height-distribution reconstruction.

# %% [markdown]
# ### 8.1 Integrate $\Phi(E,h)$ over Height
#
# **Expected results:**
# - The reconstructed $\int \Phi(E,h)\,dh$ agrees with $\Phi(E; X_{\rm obs})$ to better than 0.1% for all energies and angles (machine-precision limit of the numerical differentiation of the CDF).

# %%
print(f"{'Particle':10s}  {'alpha':>7s}  {'max|1 - integral|':>18s}  {'mean|1 - integral|':>20s}")
print("-" * 62)

for flav in ["numu", "nue"]:
    for alpha in [0., 30., 60., 85.]:
        r    = nearest_result(grid[flav]["results"], alpha)
        E    = r["E_grid_GeV"].cpu().numpy()
        h    = r["h_grid_km"].cpu().numpy()
        phi  = r["phi_E_obs"].cpu().numpy()
        f    = r["f_Eh"].cpu().numpy()
        phi_h = r["phi_Eh"].cpu().numpy()   # (nE, nh)

        # Check 1: normalization of f(h|E)
        norm_f = numpy_trapezoid(f, h, axis=1)   # should be 1 for all E

        # Check 2: integral of phi_Eh over h should recover phi_E
        phi_recov = numpy_trapezoid(phi_h, h, axis=1)
        with np.errstate(invalid="ignore", divide="ignore"):
            rel_err = np.where(phi > 0, np.abs(phi_recov / phi - 1.0), np.nan)

        # phi <= 0 everywhere for some (flavour, angle) combinations (e.g. the
        # grazing alpha=85 deg case can have zero flux over part or all of the
        # energy grid), leaving rel_err entirely NaN for that row -- np.nanmax/
        # np.nanmean on an all-NaN array is well-defined (NaN) but numpy warns
        # ("All-NaN slice encountered" / "Mean of empty slice"). Guard exactly
        # like the equivalent pattern already used elsewhere in this project
        # (see notebooks/external/IA/difussion/run1_difussion_build_dataset.ipynb's
        # describe_sample()) instead of letting the warning fire on expected data.
        has_valid = np.isfinite(rel_err).any()
        max_err = np.nanmax(rel_err) if has_valid else np.nan
        mean_err = np.nanmean(rel_err) if has_valid else np.nan

        print(f"{flav:10s}  {alpha:6.0f}°  "
              f"{max_err:>18.2e}  {mean_err:>20.2e}")

print()
print("Normalization of f(h|E) (should be 1):")
r0     = nearest_result(grid["numu"]["results"], 30.0)
f0     = r0["f_Eh"].cpu().numpy()
h0     = r0["h_grid_km"].cpu().numpy()
norms  = numpy_trapezoid(f0, h0, axis=1)
print(f"  min = {norms.min():.6f}   max = {norms.max():.6f}"
      f"   mean = {norms.mean():.6f}")
# Out:
# Particle      alpha   max|1 - integral|    mean|1 - integral|
# --------------------------------------------------------------
# numu             0°            4.44e-16              1.22e-16
# numu            30°            3.33e-16              7.58e-17
# numu            60°            2.22e-16              9.67e-17
# numu            85°            4.44e-16              1.28e-16
# nue              0°            4.44e-16              1.09e-16
# nue             30°            4.44e-16              1.11e-16
# nue             60°            3.33e-16              1.13e-16
# nue             85°            6.66e-16              1.08e-16
#
# Normalization of f(h|E) (should be 1):
#   min = 1.000000   max = 1.000000   mean = 1.000000

# %% [markdown]
# ## 9. Summary
# | Step | Function / class | Output |
# |------|-----------------|--------|
# | Locate data | `find_honda_data_dir(path=HONDA_DIR)` | Path to `.d.gz` directory |
# | Select variant | `HondaTableSelection(site_code, season_code, solar, mountain, angular_mode)` | Frozen config dataclass |
# | Single angle | `generate_flux_for_particle_angle(particle, alpha_deg=..., selection=sel, save=False)` | `E_grid_GeV`, `h_grid_km`, `phi_E_obs`, `f_Eh`, `phi_Eh` |
# | Full grid | `generate_flux_for_particles_angle_grid(particles, alpha_grid_deg=..., selection=sel, save=False)` | Dict keyed by flavour → Dict keyed by θ |
# | Native cosθ bins | `honda_cosz_centers()` | 20-element array from 0.95 to −0.95 |
#
# **Key physics findings:**
# - Production height PDF $f(h|E,\alpha)$ peaks between 10–25 km; higher energy and more horizontal directions are produced lower in the atmosphere when described in geometric height.
# - The $\nu_\mu / \nu_e$ ratio approaches 2 above $\sim 1$ GeV.
# - Solar modulation reduces the flux by up to $\sim 10\%$ below $\sim 0.5$ GeV.
# - The normalization check confirms $\int f(h|E)\,dh = 1$ to better than $10^{-4}$ relative error.
#
# **Next step:** Use `generate_flux_for_particles_angle_grid(..., save=True, output_config=...)` to write the height-differential flux files needed by the tpeanuts atmosphere propagation pipeline.

# %%
print("=" * 60)
print("Atmosphere Analysis 2 — Summary")
print("=" * 60)
print(f"  Honda data dir  : {honda_dir}")
print(f"  Site / season   : {sel.site_code} / {sel.season_code}")
print(f"  Solar           : {sel.solar}")
print(f"  Angular mode    : {sel.angular_mode}")
print(f"  Energy range    : {E_GeV[0]:.3g} -- {E_GeV[-1]:.3g} GeV ({E_GeV.size} pts)")
print(f"  Height range    : {h_km[0]:.0f} -- {h_km[-1]:.0f} km ({h_km.size} pts)")
print(f"  Particles shown : {PARTICLES}")
print(f"  Alpha grid      : {list(ALPHA_GRID)}")
print(f"  Output dir      : {OUTPUT_DIR}")
# Out:
# ============================================================
# Atmosphere Analysis 2 — Summary
# ============================================================
#   Honda data dir  : G:\Mi unidad\03.Codigo\034.TFM.UV\Tpeanuts\data\atmosphere\honda\raw
#   Site / season   : frj / ally
#   Solar           : solmin
#   Angular mode    : azimuth-averaged
#   Energy range    : 0.1 -- 1e+04 GeV (101 pts)
#   Height range    : 0 -- 120 km (501 pts)
#   Particles shown : ['numu', 'nue', 'antinumu', 'antinue']
#   Alpha grid      : [0.0, 5.0, 10.0, 15.0, 20.0, 25.0, 30.0, 35.0, 40.0, 45.0, 50.0, 55.0, 60.0, 65.0, 70.0, 75.0, 80.0, 85.0]
#   Output dir      : v:\output\analysis\atmosphere\honda_analysis
